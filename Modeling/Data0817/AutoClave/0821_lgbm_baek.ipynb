# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ### 데이터 읽어오기

# %%
import pandas as pd

THRESHOLD = 0.3
RANDOM_STATE = 110

train_data = pd.read_csv("../../../data/train_data_0817.csv")
test_data = pd.read_csv("../../../data/test_data_0817.csv")

# %%
train_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40506 entries, 0 to 40505
# Data columns (total 38 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   CURE SPEED Collect Result_Dam                   40506 non-null  int64
#  1   DISCHARGED SPEED OF RESIN Collect Result_Dam    40506 non-null  int64
#  2   Head Clean Position Z Collect Result_Dam        40506 non-null  float64
#  3   Head Purge Position Z Collect Result_Dam        40506 non-null  float64
#  4   Head Zero Position Y Collect Result_Dam         40506 non-null  float64
#  5   Stage2_Circle_Distance_Speed_Dam                40506 non-null  int64
#  6   WorkMode Collect Result                         40506 non-null  float64
#  7   Chamber Temp. Collect Result_AutoClave          40506 non-null  int64
#  8   DISCHARGED SPEED OF RESIN Collect Result_Fill1  40506 non-null  float64
#  9   Head Purge Position Z Collect Result_Fill1      40506 non-null  int64
#  10  CURE SPEED Collect Result_Fill2                 40506 non-null  int64
#  11  Head Purge Position Z Collect Result_Fill2      40506 non-null  float64
#  12  target                                          40506 non-null  object
#  13  Equipment_same_num                              40506 non-null  int64
#  14  Production_Qty_Collect_Result                   40506 non-null  int64
#  15  CURE_DISTANCE_Dam                               40506 non-null  float64
#  16  HEAD NORMAL DISTANCE_STAGE1_STAGE3_Dam          40506 non-null  float64
#  17  HEAD NORMAL DISTANCE_TRIANGLE_height_Dam        40506 non-null  float64
#  18  HEAD NORMAL DISTANCE_STAGE1_STAGE3_Fill1        40506 non-null  float64
#  19  HEAD NORMAL DISTANCE_TRIANGLE_height_Fill1      40506 non-null  float64
#  20  HEAD NORMAL DISTANCE_STAGE1_STAGE2_Fill2        40506 non-null  float64
#  21  volume_time_multip_avg_Dam                      40506 non-null  float64
#  22  volume_time_multip_avg_Fill1                    40506 non-null  float64
#  23  average_thickness_Dam                           40506 non-null  float64
#  24  1st_pressure_time_AutoClave                     40506 non-null  float64
#  25  2nd_pressure_time_AutoClave                     40506 non-null  float64
#  26  3rd_pressure_time_AutoClave                     40506 non-null  float64
#  27  time_ratio_Dam                                  40506 non-null  float64
#  28  time_ratio_Fill1                                40506 non-null  float64
#  29  time_ratio_Fill2                                40506 non-null  float64
#  30  time_ratio_AutoClave                            40506 non-null  float64
#  31  model_receip_encoded                            40506 non-null  float64
#  32  workorder_receip_encoded                        40506 non-null  float64
#  33  PalletID_Collect_Result_encoded                 40506 non-null  float64
#  34  cure_end_position_XZ_Fill2_encoded              40506 non-null  float64
#  35  cure_start_position_XZ_Fill2_encoded            40506 non-null  float64
#  36  stage1_line13_distance_speed_Dam_encoded        40506 non-null  float64
#  37  stage2_line24_distance_speed_Dam_encoded        40506 non-null  float64
# dtypes: float64(29), int64(8), object(1)
# memory usage: 11.7+ MB

# %%
# dam, fill1, fill2 공통 변수
var_dam_fill = [
    'Equipment_same_num',
    'PalletID_Collect_Result_encoded',
    'Production_Qty_Collect_Result',
    'WorkMode Collect Result'
]

# %%
# 전체 공통 변수
### correlation 확인을 위한 변수 리스트
var_all_corr = [
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### train
var_all_train = [
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### test
var_all_test = [
    'Set ID',
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

# %%
# '_Dam'을 포함하는 변수 선택
dam_variables = [var for var in train_data.columns if '_Dam' in var]

# train
final_columns_train = var_dam_fill + var_all_train + dam_variables
train_data_dam = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + dam_variables
test_data_dam = test_data[final_columns_test]

# %%
# '_Fill1'을 포함하는 변수 선택
fill1_variables = [var for var in train_data.columns if '_Fill1' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill1_variables
train_data_fill1 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill1_variables
test_data_fill1 = test_data[final_columns_test]

# %%
# '_Fill2'을 포함하는 변수 선택
fill2_variables = [var for var in train_data.columns if '_Fill2' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill2_variables
train_data_fill2 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill2_variables
test_data_fill2 = test_data[final_columns_test]

# %%
# '_AutoClave'을 포함하는 변수 선택
autoclave_variables = [var for var in train_data.columns if '_AutoClave' in var]

# train
final_columns_train = var_all_train + autoclave_variables
train_data_autoclave = train_data[final_columns_train]

# test 
final_columns_test = var_all_test + autoclave_variables
test_data_autoclave = test_data[final_columns_test]

# %%
# 각 DataFrame의 칼럼 수 계산
num_columns_train_data = train_data.shape[1]
num_columns_train_data_dam = train_data_dam.shape[1]
num_columns_train_data_autoclave = train_data_autoclave.shape[1]
num_columns_train_data_fill1 = train_data_fill1.shape[1]
num_columns_train_data_fill2 = train_data_fill2.shape[1]

num_columns_test_data = test_data.shape[1]
num_columns_test_data_dam = test_data_dam.shape[1]
num_columns_test_data_autoclave = test_data_autoclave.shape[1]
num_columns_test_data_fill1 = test_data_fill1.shape[1]
num_columns_test_data_fill2 = test_data_fill2.shape[1]

# 각 DataFrame의 칼럼 수 출력
print("----train data-----")
print(f"train_data DataFrame의 칼럼 수: {num_columns_train_data}")
print(f"train_data_dam DataFrame의 칼럼 수: {num_columns_train_data_dam}")
print(f"train_data_autoclave DataFrame의 칼럼 수: {num_columns_train_data_autoclave}")
print(f"train_data_fill1 DataFrame의 칼럼 수: {num_columns_train_data_fill1}")
print(f"train_data_fill2 DataFrame의 칼럼 수: {num_columns_train_data_fill2}")
print("----test data-----")
print(f"test_data DataFrame의 칼럼 수: {num_columns_test_data}")
print(f"test_data_dam DataFrame의 칼럼 수: {num_columns_test_data_dam}")
print(f"test_data_autoclave DataFrame의 칼럼 수: {num_columns_test_data_autoclave}")
print(f"test_data_fill1 DataFrame의 칼럼 수: {num_columns_test_data_fill1}")
print(f"test_data_fill2 DataFrame의 칼럼 수: {num_columns_test_data_fill2}")
# Out:
# ----train data-----
# train_data DataFrame의 칼럼 수: 38
# train_data_dam DataFrame의 칼럼 수: 21
# train_data_autoclave DataFrame의 칼럼 수: 8
# train_data_fill1 DataFrame의 칼럼 수: 13
# train_data_fill2 DataFrame의 칼럼 수: 13
# ----test data-----
# test_data DataFrame의 칼럼 수: 39
# test_data_dam DataFrame의 칼럼 수: 22
# test_data_autoclave DataFrame의 칼럼 수: 9
# test_data_fill1 DataFrame의 칼럼 수: 14
# test_data_fill2 DataFrame의 칼럼 수: 14

# %% [markdown]
# ---

# %% [markdown]
# ## Optuna

# %% [markdown]
# 스레스홀드 0.3으로 맞춘상태에서 튜닝 진행한 것

# %%
# import optuna
# from lightgbm import LGBMClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import f1_score

# # 'Normal'과 'AbNormal'을 숫자로 변환
# train_data_autoclave['target'] = train_data_autoclave['target'].map({'Normal': 0, 'AbNormal': 1})

# # 스레드홀드 설정
# THRESHOLD = 0.3

# def objectiveLGBM_dart(trial, x_tr, y_tr, x_val, y_val):
#     param = {
#         'n_estimators': trial.suggest_int('n_estimators', 500, 3000),
#         'num_leaves': trial.suggest_int('num_leaves', 500, 3000),
#         'max_depth': trial.suggest_int('max_depth', 10, 300),
#         'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1),
#         'min_child_samples': trial.suggest_int('min_child_samples', 3, 300),
        
#         'boosting_type': 'dart',  # 'boosting'를 'boosting_type'으로 수정
#         'random_state': RANDOM_STATE,
#         'verbose': -1
#     }
       
#     model = LGBMClassifier(**param)
#     model.fit(x_tr, y_tr)
#     pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
#     pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
    
#     score = f1_score(y_val, pred, average="binary")
    
#     return score

# # 데이터셋 분할
# x_train, x_val, y_train, y_val = train_test_split(
#     train_data_autoclave.drop("target", axis=1),
#     train_data_autoclave["target"],
#     test_size=0.2,
#     shuffle=True,
#     random_state=RANDOM_STATE,
# )

# # 하이퍼 파라미터 튜닝
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=200)

# print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))

# %% [markdown]
# Trial 91 finished with value: 0.2374821173104435
# parameters: {'n_estimators': 2733, 'num_leaves': 2080, 'max_depth': 17, 'learning_rate': 0.048548896042732353,
# 'min_child_samples': 206}

# %%
# import optuna
# from lightgbm import LGBMClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import f1_score

# # 'Normal'과 'AbNormal'을 숫자로 변환
# train_data_autoclave['target'] = train_data_autoclave['target'].map({'Normal': 0, 'AbNormal': 1})

# # 스레드홀드 설정
# THRESHOLD = 0.3

# def objectiveLGBM_dart(trial, x_tr, y_tr, x_val, y_val):
#     param = {
#         'n_estimators': trial.suggest_int('n_estimators', 1200, 3500),
#         'num_leaves': trial.suggest_int('num_leaves', 1000, 3500),
#         'max_depth': trial.suggest_int('max_depth', 10, 140),
#         'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1),
#         'min_child_samples': trial.suggest_int('min_child_samples', 100, 350),
        
#         'boosting_type': 'dart',  # 'boosting'를 'boosting_type'으로 수정
#         'random_state': RANDOM_STATE,
#         'verbose': -1
#     }
       
#     model = LGBMClassifier(**param)
#     model.fit(x_tr, y_tr)
#     pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
#     pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
    
#     score = f1_score(y_val, pred, average="binary")
    
#     return score

# # 데이터셋 분할
# x_train, x_val, y_train, y_val = train_test_split(
#     train_data_autoclave.drop("target", axis=1),
#     train_data_autoclave["target"],
#     test_size=0.2,
#     shuffle=True,
#     random_state=RANDOM_STATE,
# )

# # 하이퍼 파라미터 튜닝
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=300)

# print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))

# %% [markdown]
# Trial 199 finished with value: 0.2511078286558346
# parameters: {'n_estimators': 1563, 'num_leaves': 1885, 'max_depth': 15, 'learning_rate': 0.07033655355880039, 'min_child_samples': 158}

# %% [markdown]
# 한번더 돌렸을때 더 낮은 성능 나옴

# %%
import optuna
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# 'Normal'과 'AbNormal'을 숫자로 변환
train_data_autoclave['target'] = train_data_autoclave['target'].map({'Normal': 0, 'AbNormal': 1})

# 스레드홀드 설정
THRESHOLD = 0.3

def objectiveLGBM_dart(trial, x_tr, y_tr, x_val, y_val):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 1000, 3500),
        'num_leaves': trial.suggest_int('num_leaves', 1000, 3500),
        'max_depth': trial.suggest_int('max_depth', 5, 100),
        'learning_rate': trial.suggest_float('learning_rate', 0.0003, 0.3),
        'min_child_samples': trial.suggest_int('min_child_samples', 50, 350),
        
        'boosting_type': 'dart',  # 'boosting'를 'boosting_type'으로 수정
        'random_state': RANDOM_STATE,
        'verbose': -1
    }
       
    model = LGBMClassifier(**param)
    model.fit(x_tr, y_tr)
    pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
    pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
    
    score = f1_score(y_val, pred, average="binary")
    
    return score

# 데이터셋 분할
x_train, x_val, y_train, y_val = train_test_split(
    train_data_autoclave.drop("target", axis=1),
    train_data_autoclave["target"],
    test_size=0.2,
    shuffle=True,
    random_state=RANDOM_STATE,
)

# 하이퍼 파라미터 튜닝
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=300)

print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# C:\Users\juneh\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# [I 2024-08-22 00:14:57,408] A new study created in memory with name: no-name-3e3cb540-91db-482f-8569-280763adc857
# [I 2024-08-22 00:15:38,155] Trial 0 finished with value: 0.1948955916473318 and parameters: {'n_estimators': 1290, 'num_leaves': 2646, 'max_depth': 41, 'learning_rate': 0.18395093969213586, 'min_child_samples': 254}. Best is trial 0 with value: 0.1948955916473318.
# [I 2024-08-22 00:19:14,487] Trial 1 finished with value: 0.18253968253968253 and parameters: {'n_estimators': 2706, 'num_leaves': 3388, 'max_depth': 66, 'learning_rate': 0.15402919924162803, 'min_child_samples': 75}. Best is trial 0 with value: 0.1948955916473318.
# [I 2024-08-22 00:20:42,280] Trial 2 finished with value: 0.1338155515370705 and parameters: {'n_estimators': 1969, 'num_leaves': 1726, 'max_depth': 17, 'learning_rate': 0.0033286437432812747, 'min_child_samples': 174}. Best is trial 0 with value: 0.1948955916473318.
# [I 2024-08-22 00:22:29,087] Trial 3 finished with value: 0.21396731054977713 and parameters: {'n_estimators': 2231, 'num_leaves': 1053, 'max_depth': 58, 'learning_rate': 0.023561721119973494, 'min_child_samples': 172}. Best is trial 3 with value: 0.21396731054977713.
# [I 2024-08-22 00:24:23,769] Trial 4 finished with value: 0.19658119658119658 and parameters: {'n_estimators': 1785, 'num_leaves': 2927, 'max_depth': 62, 'learning_rate': 0.12538224344127344, 'min_child_samples': 150}. Best is trial 3 with value: 0.21396731054977713.
# [I 2024-08-22 00:25:42,010] Trial 5 finished with value: 0.196078431372549 and parameters: {'n_estimators': 1062, 'num_leaves': 1223, 'max_depth': 86, 'learning_rate': 0.1474860351915402, 'min_child_samples': 125}. Best is trial 3 with value: 0.21396731054977713.
# [I 2024-08-22 00:30:35,432] Trial 6 finished with value: 0.18145956607495067 and parameters: {'n_estimators': 2903, 'num_leaves': 2351, 'max_depth': 42, 'learning_rate': 0.19332900436168748, 'min_child_samples': 101}. Best is trial 3 with value: 0.21396731054977713.
# [I 2024-08-22 00:34:38,103] Trial 7 finished with value: 0.19027484143763215 and parameters: {'n_estimators': 2773, 'num_leaves': 1100, 'max_depth': 62, 'learning_rate': 0.06124285172137882, 'min_child_samples': 124}. Best is trial 3 with value: 0.21396731054977713.
# [I 2024-08-22 00:37:55,906] Trial 8 finished with value: 0.1841332027424094 and parameters: {'n_estimators': 1998, 'num_leaves': 2785, 'max_depth': 81, 'learning_rate': 0.26849303362178684, 'min_child_samples': 116}. Best is trial 3 with value: 0.21396731054977713.
# [I 2024-08-22 00:38:40,692] Trial 9 finished with value: 0.21895861148197598 and parameters: {'n_estimators': 1032, 'num_leaves': 2902, 'max_depth': 22, 'learning_rate': 0.2381283650041344, 'min_child_samples': 336}. Best is trial 9 with value: 0.21895861148197598.
# [I 2024-08-22 00:39:03,695] Trial 10 finished with value: 0.1952054794520548 and parameters: {'n_estimators': 1512, 'num_leaves': 3486, 'max_depth': 5, 'learning_rate': 0.29555834990878715, 'min_child_samples': 345}. Best is trial 9 with value: 0.21895861148197598.
# [I 2024-08-22 00:41:04,227] Trial 11 finished with value: 0.1958333333333333 and parameters: {'n_estimators': 2356, 'num_leaves': 1754, 'max_depth': 25, 'learning_rate': 0.231443397943606, 'min_child_samples': 240}. Best is trial 9 with value: 0.21895861148197598.
# [I 2024-08-22 00:43:23,764] Trial 12 finished with value: 0.20293398533007337 and parameters: {'n_estimators': 3316, 'num_leaves': 1855, 'max_depth': 40, 'learning_rate': 0.08118532022943992, 'min_child_samples': 350}. Best is trial 9 with value: 0.21895861148197598.
# [I 2024-08-22 00:45:40,506] Trial 13 finished with value: 0.13539651837524178 and parameters: {'n_estimators': 3422, 'num_leaves': 2331, 'max_depth': 28, 'learning_rate': 0.005640494120839085, 'min_child_samples': 279}. Best is trial 9 with value: 0.21895861148197598.
# [I 2024-08-22 00:48:03,211] Trial 14 finished with value: 0.19203268641470886 and parameters: {'n_estimators': 2342, 'num_leaves': 3136, 'max_depth': 51, 'learning_rate': 0.230456852442053, 'min_child_samples': 207}. Best is trial 9 with value: 0.21895861148197598.
# [I 2024-08-22 00:48:41,496] Trial 15 finished with value: 0.20632279534109815 and parameters: {'n_estimators': 1000, 'num_leaves': 1452, 'max_depth': 96, 'learning_rate': 0.07677259967587338, 'min_child_samples': 298}. Best is trial 9 with value: 0.21895861148197598.
# [I 2024-08-22 00:49:25,375] Trial 16 finished with value: 0.17883211678832117 and parameters: {'n_estimators': 1585, 'num_leaves': 2099, 'max_depth': 8, 'learning_rate': 0.04025317170191632, 'min_child_samples': 202}. Best is trial 9 with value: 0.21895861148197598.
# [I 2024-08-22 00:56:54,293] Trial 17 finished with value: 0.182 and parameters: {'n_estimators': 3072, 'num_leaves': 2505, 'max_depth': 75, 'learning_rate': 0.1157592854097311, 'min_child_samples': 57}. Best is trial 9 with value: 0.21895861148197598.
# [I 2024-08-22 00:59:13,998] Trial 18 finished with value: 0.19595959595959594 and parameters: {'n_estimators': 2074, 'num_leaves': 3102, 'max_depth': 32, 'learning_rate': 0.233849899683726, 'min_child_samples': 168}. Best is trial 9 with value: 0.21895861148197598.
# [I 2024-08-22 01:01:16,004] Trial 19 finished with value: 0.19267015706806281 and parameters: {'n_estimators': 2552, 'num_leaves': 2130, 'max_depth': 50, 'learning_rate': 0.2675408621401027, 'min_child_samples': 314}. Best is trial 9 with value: 0.21895861148197598.
# [I 2024-08-22 01:02:21,447] Trial 20 finished with value: 0.2094763092269327 and parameters: {'n_estimators': 1356, 'num_leaves': 1413, 'max_depth': 19, 'learning_rate': 0.18603788329689552, 'min_child_samples': 222}. Best is trial 9 with value: 0.21895861148197598.
# [I 2024-08-22 01:03:17,175] Trial 21 finished with value: 0.2126081582200247 and parameters: {'n_estimators': 1354, 'num_leaves': 1002, 'max_depth': 20, 'learning_rate': 0.17584006318632314, 'min_child_samples': 229}. Best is trial 9 with value: 0.21895861148197598.
# [I 2024-08-22 01:04:05,649] Trial 22 finished with value: 0.23118279569892472 and parameters: {'n_estimators': 1240, 'num_leaves': 1047, 'max_depth': 14, 'learning_rate': 0.2081417226320949, 'min_child_samples': 260}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:05:06,256] Trial 23 finished with value: 0.21621621621621623 and parameters: {'n_estimators': 1700, 'num_leaves': 1398, 'max_depth': 11, 'learning_rate': 0.22377735992631892, 'min_child_samples': 263}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:06:18,607] Trial 24 finished with value: 0.22509702457956013 and parameters: {'n_estimators': 1721, 'num_leaves': 1359, 'max_depth': 13, 'learning_rate': 0.21141408022047087, 'min_child_samples': 265}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:07:05,689] Trial 25 finished with value: 0.22695035460992907 and parameters: {'n_estimators': 1196, 'num_leaves': 1951, 'max_depth': 14, 'learning_rate': 0.20632913811358236, 'min_child_samples': 319}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:07:54,083] Trial 26 finished with value: 0.22251655629139072 and parameters: {'n_estimators': 1229, 'num_leaves': 1648, 'max_depth': 13, 'learning_rate': 0.26183046039464875, 'min_child_samples': 303}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:09:17,728] Trial 27 finished with value: 0.20366132723112126 and parameters: {'n_estimators': 1510, 'num_leaves': 1928, 'max_depth': 33, 'learning_rate': 0.20670162342955964, 'min_child_samples': 279}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:09:51,604] Trial 28 finished with value: 0.18246869409660108 and parameters: {'n_estimators': 1748, 'num_leaves': 1580, 'max_depth': 5, 'learning_rate': 0.1536528516873204, 'min_child_samples': 323}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:11:02,616] Trial 29 finished with value: 0.20606060606060606 and parameters: {'n_estimators': 1170, 'num_leaves': 1310, 'max_depth': 38, 'learning_rate': 0.1722698026567965, 'min_child_samples': 257}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:11:59,046] Trial 30 finished with value: 0.21204188481675393 and parameters: {'n_estimators': 1386, 'num_leaves': 1236, 'max_depth': 15, 'learning_rate': 0.20778096168807333, 'min_child_samples': 283}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:12:39,747] Trial 31 finished with value: 0.2222222222222222 and parameters: {'n_estimators': 1211, 'num_leaves': 1678, 'max_depth': 13, 'learning_rate': 0.2774951394165356, 'min_child_samples': 309}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:13:30,000] Trial 32 finished with value: 0.20601851851851855 and parameters: {'n_estimators': 1167, 'num_leaves': 1562, 'max_depth': 28, 'learning_rate': 0.25187924869417144, 'min_child_samples': 295}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:14:36,308] Trial 33 finished with value: 0.20873786407766992 and parameters: {'n_estimators': 1866, 'num_leaves': 1909, 'max_depth': 12, 'learning_rate': 0.2542730283725792, 'min_child_samples': 248}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:15:36,727] Trial 34 finished with value: 0.2141057934508816 and parameters: {'n_estimators': 1600, 'num_leaves': 2105, 'max_depth': 16, 'learning_rate': 0.21563065475622295, 'min_child_samples': 326}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:16:37,821] Trial 35 finished with value: 0.20046082949308752 and parameters: {'n_estimators': 1278, 'num_leaves': 1143, 'max_depth': 20, 'learning_rate': 0.2870775526805359, 'min_child_samples': 266}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:17:19,333] Trial 36 finished with value: 0.22804314329738062 and parameters: {'n_estimators': 1445, 'num_leaves': 1588, 'max_depth': 9, 'learning_rate': 0.1993778737066866, 'min_child_samples': 300}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:18:28,460] Trial 37 finished with value: 0.20640569395017794 and parameters: {'n_estimators': 1485, 'num_leaves': 1535, 'max_depth': 25, 'learning_rate': 0.1963527116260257, 'min_child_samples': 285}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:20:15,468] Trial 38 finished with value: 0.2 and parameters: {'n_estimators': 1835, 'num_leaves': 1275, 'max_depth': 45, 'learning_rate': 0.1657292720849281, 'min_child_samples': 231}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:21:42,410] Trial 39 finished with value: 0.20368098159509201 and parameters: {'n_estimators': 1683, 'num_leaves': 1366, 'max_depth': 34, 'learning_rate': 0.12389587362765946, 'min_child_samples': 268}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:22:39,905] Trial 40 finished with value: 0.225609756097561 and parameters: {'n_estimators': 2094, 'num_leaves': 1107, 'max_depth': 8, 'learning_rate': 0.14149063171277643, 'min_child_samples': 186}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:23:49,346] Trial 41 finished with value: 0.22955523672883787 and parameters: {'n_estimators': 2075, 'num_leaves': 1071, 'max_depth': 9, 'learning_rate': 0.13957821854226435, 'min_child_samples': 165}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:24:45,091] Trial 42 finished with value: 0.22769230769230772 and parameters: {'n_estimators': 2171, 'num_leaves': 1088, 'max_depth': 7, 'learning_rate': 0.14015323277384945, 'min_child_samples': 149}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:25:49,822] Trial 43 finished with value: 0.22699386503067487 and parameters: {'n_estimators': 2546, 'num_leaves': 1191, 'max_depth': 8, 'learning_rate': 0.10046938453375236, 'min_child_samples': 147}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:26:39,854] Trial 44 finished with value: 0.22706065318818044 and parameters: {'n_estimators': 2524, 'num_leaves': 1161, 'max_depth': 7, 'learning_rate': 0.10111620819864764, 'min_child_samples': 147}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:27:12,287] Trial 45 finished with value: 0.1811722912966252 and parameters: {'n_estimators': 2190, 'num_leaves': 1031, 'max_depth': 5, 'learning_rate': 0.13370558796635035, 'min_child_samples': 147}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:28:20,730] Trial 46 finished with value: 0.22686567164179103 and parameters: {'n_estimators': 2448, 'num_leaves': 1130, 'max_depth': 9, 'learning_rate': 0.09853251372706112, 'min_child_samples': 164}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:31:48,529] Trial 47 finished with value: 0.18932527693857 and parameters: {'n_estimators': 2809, 'num_leaves': 1208, 'max_depth': 23, 'learning_rate': 0.16119095664352412, 'min_child_samples': 105}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:34:04,108] Trial 48 finished with value: 0.19823788546255508 and parameters: {'n_estimators': 2644, 'num_leaves': 1012, 'max_depth': 18, 'learning_rate': 0.11335916400441556, 'min_child_samples': 130}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:34:44,807] Trial 49 finished with value: 0.16356877323420074 and parameters: {'n_estimators': 2198, 'num_leaves': 1273, 'max_depth': 5, 'learning_rate': 0.0611852145867714, 'min_child_samples': 183}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:38:49,394] Trial 50 finished with value: 0.188 and parameters: {'n_estimators': 1957, 'num_leaves': 1496, 'max_depth': 71, 'learning_rate': 0.14207500751665952, 'min_child_samples': 87}. Best is trial 22 with value: 0.23118279569892472.
# [I 2024-08-22 01:39:58,001] Trial 51 finished with value: 0.23680456490727533 and parameters: {'n_estimators': 2453, 'num_leaves': 1179, 'max_depth': 9, 'learning_rate': 0.10136252625616365, 'min_child_samples': 146}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 01:41:11,195] Trial 52 finished with value: 0.22318840579710145 and parameters: {'n_estimators': 2356, 'num_leaves': 1153, 'max_depth': 10, 'learning_rate': 0.08421464700353583, 'min_child_samples': 133}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 01:43:37,817] Trial 53 finished with value: 0.2046511627906977 and parameters: {'n_estimators': 3090, 'num_leaves': 1094, 'max_depth': 16, 'learning_rate': 0.09705659665275143, 'min_child_samples': 153}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 01:46:08,138] Trial 54 finished with value: 0.19558359621451105 and parameters: {'n_estimators': 2291, 'num_leaves': 1794, 'max_depth': 56, 'learning_rate': 0.12948199169303118, 'min_child_samples': 191}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 01:48:20,070] Trial 55 finished with value: 0.18843683083511778 and parameters: {'n_estimators': 2447, 'num_leaves': 1302, 'max_depth': 22, 'learning_rate': 0.18471410369573046, 'min_child_samples': 213}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 01:52:01,064] Trial 56 finished with value: 0.19376391982182628 and parameters: {'n_estimators': 2651, 'num_leaves': 1431, 'max_depth': 29, 'learning_rate': 0.05990315589686074, 'min_child_samples': 116}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 01:53:27,447] Trial 57 finished with value: 0.2303370786516854 and parameters: {'n_estimators': 2901, 'num_leaves': 1009, 'max_depth': 9, 'learning_rate': 0.11231002498508069, 'min_child_samples': 158}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 01:56:11,522] Trial 58 finished with value: 0.19165727170236752 and parameters: {'n_estimators': 2971, 'num_leaves': 1000, 'max_depth': 18, 'learning_rate': 0.11820827314028069, 'min_child_samples': 172}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 01:58:26,686] Trial 59 finished with value: 0.21162790697674422 and parameters: {'n_estimators': 3168, 'num_leaves': 1093, 'max_depth': 11, 'learning_rate': 0.15207230422622106, 'min_child_samples': 161}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:01:38,726] Trial 60 finished with value: 0.1867785939139559 and parameters: {'n_estimators': 2878, 'num_leaves': 1231, 'max_depth': 89, 'learning_rate': 0.1126584084345102, 'min_child_samples': 198}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:02:43,323] Trial 61 finished with value: 0.2115702479338843 and parameters: {'n_estimators': 2479, 'num_leaves': 1196, 'max_depth': 7, 'learning_rate': 0.0738286627574174, 'min_child_samples': 136}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:03:59,052] Trial 62 finished with value: 0.23076923076923078 and parameters: {'n_estimators': 2090, 'num_leaves': 1068, 'max_depth': 10, 'learning_rate': 0.10217269046005126, 'min_child_samples': 156}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:05:13,705] Trial 63 finished with value: 0.23529411764705885 and parameters: {'n_estimators': 2116, 'num_leaves': 1070, 'max_depth': 11, 'learning_rate': 0.08929593199286792, 'min_child_samples': 179}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:07:01,853] Trial 64 finished with value: 0.20500595947556616 and parameters: {'n_estimators': 1947, 'num_leaves': 1317, 'max_depth': 24, 'learning_rate': 0.08675656280337948, 'min_child_samples': 160}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:08:18,957] Trial 65 finished with value: 0.21185372005044137 and parameters: {'n_estimators': 2058, 'num_leaves': 1008, 'max_depth': 15, 'learning_rate': 0.10916541544671508, 'min_child_samples': 172}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:09:45,588] Trial 66 finished with value: 0.22349570200573066 and parameters: {'n_estimators': 2275, 'num_leaves': 2460, 'max_depth': 12, 'learning_rate': 0.09029831171832778, 'min_child_samples': 176}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:10:59,843] Trial 67 finished with value: 0.22945736434108527 and parameters: {'n_estimators': 1089, 'num_leaves': 1454, 'max_depth': 20, 'learning_rate': 0.0470572648401834, 'min_child_samples': 118}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:12:04,845] Trial 68 finished with value: 0.21105527638190955 and parameters: {'n_estimators': 1062, 'num_leaves': 1377, 'max_depth': 20, 'learning_rate': 0.028990562426256694, 'min_child_samples': 121}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:15:37,680] Trial 69 finished with value: 0.2139175257731959 and parameters: {'n_estimators': 3403, 'num_leaves': 1060, 'max_depth': 17, 'learning_rate': 0.038505124090932506, 'min_child_samples': 108}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:17:54,055] Trial 70 finished with value: 0.22784810126582278 and parameters: {'n_estimators': 2710, 'num_leaves': 1435, 'max_depth': 14, 'learning_rate': 0.05121067211787989, 'min_child_samples': 137}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:18:52,736] Trial 71 finished with value: 0.2027491408934708 and parameters: {'n_estimators': 1894, 'num_leaves': 1262, 'max_depth': 10, 'learning_rate': 0.07209708479766445, 'min_child_samples': 338}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:19:47,529] Trial 72 finished with value: 0.22402159244264505 and parameters: {'n_estimators': 1411, 'num_leaves': 1635, 'max_depth': 11, 'learning_rate': 0.1945471529884371, 'min_child_samples': 155}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:20:42,458] Trial 73 finished with value: 0.13001912045889102 and parameters: {'n_estimators': 1132, 'num_leaves': 1490, 'max_depth': 27, 'learning_rate': 0.01598862209197402, 'min_child_samples': 198}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:22:03,829] Trial 74 finished with value: 0.1990740740740741 and parameters: {'n_estimators': 1096, 'num_leaves': 1165, 'max_depth': 21, 'learning_rate': 0.1261531540454688, 'min_child_samples': 90}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:23:04,124] Trial 75 finished with value: 0.2258592471358429 and parameters: {'n_estimators': 1300, 'num_leaves': 1343, 'max_depth': 15, 'learning_rate': 0.06939929425050727, 'min_child_samples': 213}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:23:40,701] Trial 76 finished with value: 0.22150882825040127 and parameters: {'n_estimators': 2117, 'num_leaves': 1079, 'max_depth': 5, 'learning_rate': 0.2437373799875594, 'min_child_samples': 181}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:24:36,217] Trial 77 finished with value: 0.22252010723860585 and parameters: {'n_estimators': 1623, 'num_leaves': 1229, 'max_depth': 9, 'learning_rate': 0.22237248021026534, 'min_child_samples': 140}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:26:36,856] Trial 78 finished with value: 0.19469026548672566 and parameters: {'n_estimators': 1469, 'num_leaves': 2724, 'max_depth': 18, 'learning_rate': 0.1072058521333692, 'min_child_samples': 58}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:27:16,289] Trial 79 finished with value: 0.22191400832177532 and parameters: {'n_estimators': 1017, 'num_leaves': 3258, 'max_depth': 12, 'learning_rate': 0.17323972754637015, 'min_child_samples': 124}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:28:54,756] Trial 80 finished with value: 0.20355029585798817 and parameters: {'n_estimators': 2038, 'num_leaves': 1129, 'max_depth': 46, 'learning_rate': 0.09300834481854726, 'min_child_samples': 243}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:30:56,146] Trial 81 finished with value: 0.23222060957910012 and parameters: {'n_estimators': 2800, 'num_leaves': 1458, 'max_depth': 14, 'learning_rate': 0.04553697266614913, 'min_child_samples': 141}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:33:06,189] Trial 82 finished with value: 0.23303834808259588 and parameters: {'n_estimators': 2945, 'num_leaves': 1694, 'max_depth': 14, 'learning_rate': 0.04270737061553712, 'min_child_samples': 166}. Best is trial 51 with value: 0.23680456490727533.
# [I 2024-08-22 02:35:13,296] Trial 83 finished with value: 0.24242424242424243 and parameters: {'n_estimators': 2990, 'num_leaves': 1708, 'max_depth': 14, 'learning_rate': 0.047528270872797346, 'min_child_samples': 166}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 02:37:37,408] Trial 84 finished with value: 0.20583190394511147 and parameters: {'n_estimators': 2969, 'num_leaves': 1865, 'max_depth': 14, 'learning_rate': 0.015263716063282272, 'min_child_samples': 163}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 02:39:56,303] Trial 85 finished with value: 0.2267716535433071 and parameters: {'n_estimators': 2785, 'num_leaves': 1063, 'max_depth': 16, 'learning_rate': 0.025923262507799822, 'min_child_samples': 189}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 02:41:38,455] Trial 86 finished with value: 0.13090909090909092 and parameters: {'n_estimators': 3224, 'num_leaves': 1727, 'max_depth': 7, 'learning_rate': 0.0017335374926528424, 'min_child_samples': 142}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 02:44:39,619] Trial 87 finished with value: 0.2048780487804878 and parameters: {'n_estimators': 2857, 'num_leaves': 1987, 'max_depth': 65, 'learning_rate': 0.036717857085280824, 'min_child_samples': 177}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 02:47:47,821] Trial 88 finished with value: 0.1988571428571429 and parameters: {'n_estimators': 3000, 'num_leaves': 1647, 'max_depth': 26, 'learning_rate': 0.06510537718372832, 'min_child_samples': 157}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 02:50:09,992] Trial 89 finished with value: 0.22840409956076135 and parameters: {'n_estimators': 3099, 'num_leaves': 1768, 'max_depth': 13, 'learning_rate': 0.05051289837518902, 'min_child_samples': 168}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 02:53:38,364] Trial 90 finished with value: 0.192017259978425 and parameters: {'n_estimators': 2707, 'num_leaves': 2041, 'max_depth': 30, 'learning_rate': 0.07632204194908104, 'min_child_samples': 129}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 02:57:02,233] Trial 91 finished with value: 0.20924574209245742 and parameters: {'n_estimators': 3030, 'num_leaves': 1511, 'max_depth': 19, 'learning_rate': 0.04770982004142319, 'min_child_samples': 112}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 02:59:42,607] Trial 92 finished with value: 0.22404371584699453 and parameters: {'n_estimators': 2621, 'num_leaves': 1174, 'max_depth': 23, 'learning_rate': 0.032240793283112384, 'min_child_samples': 144}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:01:19,204] Trial 93 finished with value: 0.20805369127516776 and parameters: {'n_estimators': 2930, 'num_leaves': 1594, 'max_depth': 9, 'learning_rate': 0.045249300300937295, 'min_child_samples': 193}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:04:12,283] Trial 94 finished with value: 0.20640569395017794 and parameters: {'n_estimators': 3190, 'num_leaves': 1832, 'max_depth': 17, 'learning_rate': 0.08247599922949353, 'min_child_samples': 153}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:05:10,458] Trial 95 finished with value: 0.17486338797814205 and parameters: {'n_estimators': 3275, 'num_leaves': 1691, 'max_depth': 5, 'learning_rate': 0.056574564016049496, 'min_child_samples': 166}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:07:20,073] Trial 96 finished with value: 0.18914185639229422 and parameters: {'n_estimators': 2811, 'num_leaves': 1292, 'max_depth': 12, 'learning_rate': 0.01798185792837245, 'min_child_samples': 182}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:10:15,112] Trial 97 finished with value: 0.18988648090815272 and parameters: {'n_estimators': 2140, 'num_leaves': 1385, 'max_depth': 37, 'learning_rate': 0.1223851511723515, 'min_child_samples': 119}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:11:07,946] Trial 98 finished with value: 0.21987951807228914 and parameters: {'n_estimators': 2007, 'num_leaves': 1047, 'max_depth': 7, 'learning_rate': 0.1351050616845497, 'min_child_samples': 99}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:13:16,959] Trial 99 finished with value: 0.24113475177304963 and parameters: {'n_estimators': 2386, 'num_leaves': 1104, 'max_depth': 21, 'learning_rate': 0.04362751113970131, 'min_child_samples': 205}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:14:41,487] Trial 100 finished with value: 0.23180592991913748 and parameters: {'n_estimators': 2421, 'num_leaves': 1136, 'max_depth': 10, 'learning_rate': 0.1457748602452852, 'min_child_samples': 210}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:15:52,257] Trial 101 finished with value: 0.2308724832214765 and parameters: {'n_estimators': 2320, 'num_leaves': 1110, 'max_depth': 10, 'learning_rate': 0.15016648603420504, 'min_child_samples': 205}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:17:14,578] Trial 102 finished with value: 0.22865412445730823 and parameters: {'n_estimators': 2384, 'num_leaves': 1128, 'max_depth': 11, 'learning_rate': 0.10470524061347769, 'min_child_samples': 225}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:18:57,383] Trial 103 finished with value: 0.23388305847076463 and parameters: {'n_estimators': 2241, 'num_leaves': 1254, 'max_depth': 15, 'learning_rate': 0.0564751805214887, 'min_child_samples': 207}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:20:45,241] Trial 104 finished with value: 0.23372781065088755 and parameters: {'n_estimators': 2404, 'num_leaves': 1188, 'max_depth': 14, 'learning_rate': 0.05406319974752301, 'min_child_samples': 208}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:22:18,276] Trial 105 finished with value: 0.22119815668202764 and parameters: {'n_estimators': 2233, 'num_leaves': 1231, 'max_depth': 14, 'learning_rate': 0.054318171785996676, 'min_child_samples': 207}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:24:06,489] Trial 106 finished with value: 0.2222222222222222 and parameters: {'n_estimators': 2381, 'num_leaves': 1339, 'max_depth': 16, 'learning_rate': 0.04244147777370302, 'min_child_samples': 217}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:25:53,982] Trial 107 finished with value: 0.22849083215796898 and parameters: {'n_estimators': 2327, 'num_leaves': 1174, 'max_depth': 18, 'learning_rate': 0.06409620556844517, 'min_child_samples': 235}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:27:41,850] Trial 108 finished with value: 0.23201174743024963 and parameters: {'n_estimators': 2435, 'num_leaves': 1252, 'max_depth': 22, 'learning_rate': 0.03377548203955489, 'min_child_samples': 202}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:29:52,382] Trial 109 finished with value: 0.2347696879643388 and parameters: {'n_estimators': 2591, 'num_leaves': 1257, 'max_depth': 21, 'learning_rate': 0.034994506577741856, 'min_child_samples': 216}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:32:10,736] Trial 110 finished with value: 0.22929936305732482 and parameters: {'n_estimators': 2593, 'num_leaves': 1302, 'max_depth': 22, 'learning_rate': 0.023342456605558164, 'min_child_samples': 218}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:34:15,947] Trial 111 finished with value: 0.22603719599427755 and parameters: {'n_estimators': 2496, 'num_leaves': 2277, 'max_depth': 25, 'learning_rate': 0.03368623582627475, 'min_child_samples': 200}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:36:17,269] Trial 112 finished with value: 0.1547169811320755 and parameters: {'n_estimators': 2396, 'num_leaves': 1257, 'max_depth': 100, 'learning_rate': 0.007604013989880587, 'min_child_samples': 195}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:38:20,460] Trial 113 finished with value: 0.2274052478134111 and parameters: {'n_estimators': 2431, 'num_leaves': 2164, 'max_depth': 20, 'learning_rate': 0.04193302423650497, 'min_child_samples': 211}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:40:14,085] Trial 114 finished with value: 0.22652757078986588 and parameters: {'n_estimators': 2548, 'num_leaves': 1211, 'max_depth': 15, 'learning_rate': 0.055225950571831, 'min_child_samples': 221}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:42:21,100] Trial 115 finished with value: 0.23113964686998395 and parameters: {'n_estimators': 2588, 'num_leaves': 1465, 'max_depth': 22, 'learning_rate': 0.02480980178298374, 'min_child_samples': 229}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:44:55,344] Trial 116 finished with value: 0.20757020757020755 and parameters: {'n_estimators': 2733, 'num_leaves': 1407, 'max_depth': 31, 'learning_rate': 0.06768858886492801, 'min_child_samples': 256}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:46:43,311] Trial 117 finished with value: 0.21768707482993194 and parameters: {'n_estimators': 2259, 'num_leaves': 1348, 'max_depth': 13, 'learning_rate': 0.02954591289026565, 'min_child_samples': 206}. Best is trial 83 with value: 0.24242424242424243.
# [I 2024-08-22 03:48:48,120] Trial 118 finished with value: 0.24665676077265972 and parameters: {'n_estimators': 2475, 'num_leaves': 1263, 'max_depth': 17, 'learning_rate': 0.03832185150337141, 'min_child_samples': 186}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 03:51:00,831] Trial 119 finished with value: 0.24624624624624628 and parameters: {'n_estimators': 2498, 'num_leaves': 1250, 'max_depth': 17, 'learning_rate': 0.0374231901093284, 'min_child_samples': 188}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 03:53:17,857] Trial 120 finished with value: 0.23295454545454547 and parameters: {'n_estimators': 2468, 'num_leaves': 1549, 'max_depth': 24, 'learning_rate': 0.03472114341204385, 'min_child_samples': 188}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 03:55:26,258] Trial 121 finished with value: 0.22849083215796898 and parameters: {'n_estimators': 2494, 'num_leaves': 1548, 'max_depth': 24, 'learning_rate': 0.03571824176480135, 'min_child_samples': 188}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 03:57:47,261] Trial 122 finished with value: 0.22008253094910593 and parameters: {'n_estimators': 2461, 'num_leaves': 1406, 'max_depth': 27, 'learning_rate': 0.040037777329183094, 'min_child_samples': 201}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:00:38,616] Trial 123 finished with value: 0.16849816849816848 and parameters: {'n_estimators': 2674, 'num_leaves': 1259, 'max_depth': 18, 'learning_rate': 0.009061838510955308, 'min_child_samples': 179}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:03:00,894] Trial 124 finished with value: 0.23380726698262244 and parameters: {'n_estimators': 2538, 'num_leaves': 1206, 'max_depth': 21, 'learning_rate': 0.020546428233029067, 'min_child_samples': 187}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:05:25,320] Trial 125 finished with value: 0.21368948247078465 and parameters: {'n_estimators': 2526, 'num_leaves': 1194, 'max_depth': 20, 'learning_rate': 0.016576781491786156, 'min_child_samples': 186}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:07:53,590] Trial 126 finished with value: 0.22471910112359553 and parameters: {'n_estimators': 2576, 'num_leaves': 1598, 'max_depth': 16, 'learning_rate': 0.022803910227625956, 'min_child_samples': 173}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:10:09,303] Trial 127 finished with value: 0.22535211267605634 and parameters: {'n_estimators': 2216, 'num_leaves': 1309, 'max_depth': 19, 'learning_rate': 0.058205431695763685, 'min_child_samples': 194}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:12:20,541] Trial 128 finished with value: 0.2451994091580502 and parameters: {'n_estimators': 2307, 'num_leaves': 1516, 'max_depth': 16, 'learning_rate': 0.04600053885644145, 'min_child_samples': 185}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:14:14,856] Trial 129 finished with value: 0.23054755043227665 and parameters: {'n_estimators': 2292, 'num_leaves': 1703, 'max_depth': 17, 'learning_rate': 0.05227788807702986, 'min_child_samples': 183}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:16:50,206] Trial 130 finished with value: 0.21374045801526717 and parameters: {'n_estimators': 2350, 'num_leaves': 2973, 'max_depth': 34, 'learning_rate': 0.04033409685351438, 'min_child_samples': 172}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:18:46,529] Trial 131 finished with value: 0.23975720789074356 and parameters: {'n_estimators': 2500, 'num_leaves': 1529, 'max_depth': 14, 'learning_rate': 0.04696120058889499, 'min_child_samples': 192}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:20:53,314] Trial 132 finished with value: 0.23262411347517734 and parameters: {'n_estimators': 2162, 'num_leaves': 1518, 'max_depth': 21, 'learning_rate': 0.048779941443515676, 'min_child_samples': 190}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:23:22,812] Trial 133 finished with value: 0.20833333333333334 and parameters: {'n_estimators': 2515, 'num_leaves': 1350, 'max_depth': 24, 'learning_rate': 0.062006400036021314, 'min_child_samples': 178}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:25:18,136] Trial 134 finished with value: 0.20805369127516776 and parameters: {'n_estimators': 2624, 'num_leaves': 1191, 'max_depth': 12, 'learning_rate': 0.03061699668790157, 'min_child_samples': 195}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:27:09,132] Trial 135 finished with value: 0.21903520208604954 and parameters: {'n_estimators': 2340, 'num_leaves': 1549, 'max_depth': 16, 'learning_rate': 0.07890336083128668, 'min_child_samples': 186}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:28:54,063] Trial 136 finished with value: 0.20442930153321975 and parameters: {'n_estimators': 2254, 'num_leaves': 1622, 'max_depth': 14, 'learning_rate': 0.020931253780689836, 'min_child_samples': 171}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:31:27,452] Trial 137 finished with value: 0.21092757306226176 and parameters: {'n_estimators': 2486, 'num_leaves': 1792, 'max_depth': 56, 'learning_rate': 0.04477014944290172, 'min_child_samples': 200}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:33:22,151] Trial 138 finished with value: 0.16117216117216118 and parameters: {'n_estimators': 2395, 'num_leaves': 1430, 'max_depth': 18, 'learning_rate': 0.011486036155738243, 'min_child_samples': 216}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:35:43,686] Trial 139 finished with value: 0.23953823953823955 and parameters: {'n_estimators': 2558, 'num_leaves': 1132, 'max_depth': 20, 'learning_rate': 0.035684516136480195, 'min_child_samples': 178}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:37:39,037] Trial 140 finished with value: 0.20547945205479454 and parameters: {'n_estimators': 2560, 'num_leaves': 1141, 'max_depth': 12, 'learning_rate': 0.027649667328980176, 'min_child_samples': 177}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:40:04,863] Trial 141 finished with value: 0.23579545454545453 and parameters: {'n_estimators': 2666, 'num_leaves': 1102, 'max_depth': 20, 'learning_rate': 0.03724652061998742, 'min_child_samples': 191}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:42:42,966] Trial 142 finished with value: 0.21686746987951808 and parameters: {'n_estimators': 2677, 'num_leaves': 1053, 'max_depth': 20, 'learning_rate': 0.051130826393785356, 'min_child_samples': 195}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:45:15,682] Trial 143 finished with value: 0.24023154848046308 and parameters: {'n_estimators': 2625, 'num_leaves': 1103, 'max_depth': 16, 'learning_rate': 0.03908005711882751, 'min_child_samples': 168}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:47:50,124] Trial 144 finished with value: 0.2219215155615697 and parameters: {'n_estimators': 2732, 'num_leaves': 1101, 'max_depth': 17, 'learning_rate': 0.05966403011950089, 'min_child_samples': 182}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:50:17,953] Trial 145 finished with value: 0.23054755043227665 and parameters: {'n_estimators': 2641, 'num_leaves': 1208, 'max_depth': 21, 'learning_rate': 0.035898725001364706, 'min_child_samples': 207}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:52:49,924] Trial 146 finished with value: 0.21842105263157896 and parameters: {'n_estimators': 2535, 'num_leaves': 1164, 'max_depth': 19, 'learning_rate': 0.07115159390959236, 'min_child_samples': 223}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:55:18,305] Trial 147 finished with value: 0.23646723646723644 and parameters: {'n_estimators': 2589, 'num_leaves': 1282, 'max_depth': 15, 'learning_rate': 0.048283042023381725, 'min_child_samples': 163}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 04:57:38,231] Trial 148 finished with value: 0.2354651162790697 and parameters: {'n_estimators': 2602, 'num_leaves': 1007, 'max_depth': 16, 'learning_rate': 0.04047883585915752, 'min_child_samples': 163}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:00:53,117] Trial 149 finished with value: 0.19954128440366972 and parameters: {'n_estimators': 2761, 'num_leaves': 1032, 'max_depth': 73, 'learning_rate': 0.04652055421485726, 'min_child_samples': 162}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:03:07,736] Trial 150 finished with value: 0.23665223665223664 and parameters: {'n_estimators': 2599, 'num_leaves': 1002, 'max_depth': 16, 'learning_rate': 0.03928476855044932, 'min_child_samples': 151}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:05:31,932] Trial 151 finished with value: 0.23563218390804597 and parameters: {'n_estimators': 2599, 'num_leaves': 1014, 'max_depth': 17, 'learning_rate': 0.04143072997959238, 'min_child_samples': 169}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:07:54,578] Trial 152 finished with value: 0.23342939481268013 and parameters: {'n_estimators': 2613, 'num_leaves': 1025, 'max_depth': 17, 'learning_rate': 0.03856048428804406, 'min_child_samples': 167}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:09:47,237] Trial 153 finished with value: 0.22772277227722773 and parameters: {'n_estimators': 2672, 'num_leaves': 1002, 'max_depth': 12, 'learning_rate': 0.02952956051648182, 'min_child_samples': 148}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:12:00,385] Trial 154 finished with value: 0.2283236994219653 and parameters: {'n_estimators': 2608, 'num_leaves': 1128, 'max_depth': 16, 'learning_rate': 0.04163168810100262, 'min_child_samples': 154}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:14:36,474] Trial 155 finished with value: 0.21456953642384105 and parameters: {'n_estimators': 2576, 'num_leaves': 1087, 'max_depth': 19, 'learning_rate': 0.049653171449961404, 'min_child_samples': 160}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:16:57,892] Trial 156 finished with value: 0.2206896551724138 and parameters: {'n_estimators': 2486, 'num_leaves': 1075, 'max_depth': 79, 'learning_rate': 0.027516900966855936, 'min_child_samples': 174}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:18:16,656] Trial 157 finished with value: 0.18761061946902655 and parameters: {'n_estimators': 2697, 'num_leaves': 1004, 'max_depth': 8, 'learning_rate': 0.033622623208122954, 'min_child_samples': 163}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:20:23,302] Trial 158 finished with value: 0.22448979591836735 and parameters: {'n_estimators': 2446, 'num_leaves': 1116, 'max_depth': 15, 'learning_rate': 0.04468517112093325, 'min_child_samples': 150}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:22:12,054] Trial 159 finished with value: 0.2287390029325513 and parameters: {'n_estimators': 2848, 'num_leaves': 1061, 'max_depth': 11, 'learning_rate': 0.06559509029834462, 'min_child_samples': 167}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:24:06,307] Trial 160 finished with value: 0.23529411764705882 and parameters: {'n_estimators': 2639, 'num_leaves': 1150, 'max_depth': 13, 'learning_rate': 0.03821534574726786, 'min_child_samples': 177}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:26:22,566] Trial 161 finished with value: 0.23597122302158277 and parameters: {'n_estimators': 2637, 'num_leaves': 1150, 'max_depth': 18, 'learning_rate': 0.0388800986628031, 'min_child_samples': 177}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:28:13,587] Trial 162 finished with value: 0.22812500000000002 and parameters: {'n_estimators': 2663, 'num_leaves': 1144, 'max_depth': 13, 'learning_rate': 0.03931258290280012, 'min_child_samples': 177}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:30:26,446] Trial 163 finished with value: 0.22666666666666666 and parameters: {'n_estimators': 2625, 'num_leaves': 1087, 'max_depth': 18, 'learning_rate': 0.04892341300910707, 'min_child_samples': 157}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:32:39,869] Trial 164 finished with value: 0.23858615611192932 and parameters: {'n_estimators': 2773, 'num_leaves': 1050, 'max_depth': 15, 'learning_rate': 0.04159568304325558, 'min_child_samples': 170}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:34:58,807] Trial 165 finished with value: 0.2284122562674095 and parameters: {'n_estimators': 2724, 'num_leaves': 1048, 'max_depth': 16, 'learning_rate': 0.05519197120603282, 'min_child_samples': 170}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:37:04,443] Trial 166 finished with value: 0.22442244224422442 and parameters: {'n_estimators': 2537, 'num_leaves': 1105, 'max_depth': 15, 'learning_rate': 0.025742713194537862, 'min_child_samples': 180}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:39:29,984] Trial 167 finished with value: 0.2303370786516854 and parameters: {'n_estimators': 2788, 'num_leaves': 1053, 'max_depth': 18, 'learning_rate': 0.04142192533416429, 'min_child_samples': 170}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:40:54,670] Trial 168 finished with value: 0.21052631578947364 and parameters: {'n_estimators': 2574, 'num_leaves': 1008, 'max_depth': 10, 'learning_rate': 0.04616452307373975, 'min_child_samples': 162}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:43:07,933] Trial 169 finished with value: 0.2303206997084548 and parameters: {'n_estimators': 2498, 'num_leaves': 1170, 'max_depth': 23, 'learning_rate': 0.03014689743603308, 'min_child_samples': 183}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:44:20,947] Trial 170 finished with value: 0.2076124567474048 and parameters: {'n_estimators': 2751, 'num_leaves': 1305, 'max_depth': 7, 'learning_rate': 0.05862230459329184, 'min_child_samples': 152}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:46:26,636] Trial 171 finished with value: 0.23219814241486067 and parameters: {'n_estimators': 2641, 'num_leaves': 1148, 'max_depth': 13, 'learning_rate': 0.03722039522835249, 'min_child_samples': 176}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:48:24,664] Trial 172 finished with value: 0.23564954682779457 and parameters: {'n_estimators': 2695, 'num_leaves': 1102, 'max_depth': 13, 'learning_rate': 0.04970687705338492, 'min_child_samples': 193}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:50:42,458] Trial 173 finished with value: 0.23863636363636367 and parameters: {'n_estimators': 2700, 'num_leaves': 1099, 'max_depth': 17, 'learning_rate': 0.04803057168998143, 'min_child_samples': 189}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:53:08,272] Trial 174 finished with value: 0.22253129346314326 and parameters: {'n_estimators': 2707, 'num_leaves': 1224, 'max_depth': 17, 'learning_rate': 0.05182313574447081, 'min_child_samples': 191}. Best is trial 118 with value: 0.24665676077265972.
# [I 2024-08-22 05:55:37,340] Trial 175 finished with value: 0.223463687150838 and parameters: {'n_estimators': 2815, 'num_leaves': 1099, 'max_depth': 19, 'learning_rate': 0.045046278042210355, 'min_child_samples': 192}. Best is trial 118 with value: 0.24665676077265972.
# ...
# [I 2024-08-22 08:25:48,951] Trial 247 finished with value: 0.239880059970015 and parameters: {'n_estimators': 2387, 'num_leaves': 1110, 'max_depth': 19, 'learning_rate': 0.03190965897964562, 'min_child_samples': 183}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 08:27:37,386] Trial 248 finished with value: 0.21794871794871795 and parameters: {'n_estimators': 2378, 'num_leaves': 1171, 'max_depth': 20, 'learning_rate': 0.024526345555615767, 'min_child_samples': 186}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 08:29:30,262] Trial 249 finished with value: 0.23636363636363636 and parameters: {'n_estimators': 2160, 'num_leaves': 1116, 'max_depth': 19, 'learning_rate': 0.03592362503099894, 'min_child_samples': 182}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 08:31:33,401] Trial 250 finished with value: 0.18473895582329317 and parameters: {'n_estimators': 2256, 'num_leaves': 1194, 'max_depth': 26, 'learning_rate': 0.2950738659033705, 'min_child_samples': 177}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 08:33:26,143] Trial 251 finished with value: 0.2323529411764706 and parameters: {'n_estimators': 2308, 'num_leaves': 1132, 'max_depth': 23, 'learning_rate': 0.031194440683036857, 'min_child_samples': 186}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 08:35:18,852] Trial 252 finished with value: 0.22690437601296598 and parameters: {'n_estimators': 2395, 'num_leaves': 1090, 'max_depth': 19, 'learning_rate': 0.019455908507014945, 'min_child_samples': 173}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 08:37:41,329] Trial 253 finished with value: 0.22818791946308722 and parameters: {'n_estimators': 2355, 'num_leaves': 1099, 'max_depth': 21, 'learning_rate': 0.04937207082510396, 'min_child_samples': 179}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 08:39:44,222] Trial 254 finished with value: 0.2289655172413793 and parameters: {'n_estimators': 2312, 'num_leaves': 1187, 'max_depth': 19, 'learning_rate': 0.044775684663385155, 'min_child_samples': 172}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 08:41:32,442] Trial 255 finished with value: 0.2304147465437788 and parameters: {'n_estimators': 2428, 'num_leaves': 1085, 'max_depth': 17, 'learning_rate': 0.03357849416603387, 'min_child_samples': 189}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 08:43:09,130] Trial 256 finished with value: 0.22437673130193905 and parameters: {'n_estimators': 2214, 'num_leaves': 1153, 'max_depth': 18, 'learning_rate': 0.05565228821263885, 'min_child_samples': 181}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 08:44:46,177] Trial 257 finished with value: 0.22395023328149302 and parameters: {'n_estimators': 2100, 'num_leaves': 1228, 'max_depth': 22, 'learning_rate': 0.027557130967626256, 'min_child_samples': 170}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 08:46:08,816] Trial 258 finished with value: 0.2299212598425197 and parameters: {'n_estimators': 2138, 'num_leaves': 1069, 'max_depth': 14, 'learning_rate': 0.04589444782774469, 'min_child_samples': 176}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 08:48:33,635] Trial 259 finished with value: 0.2288135593220339 and parameters: {'n_estimators': 2378, 'num_leaves': 1131, 'max_depth': 20, 'learning_rate': 0.0357387857331468, 'min_child_samples': 158}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 08:50:17,578] Trial 260 finished with value: 0.23428571428571426 and parameters: {'n_estimators': 2257, 'num_leaves': 1066, 'max_depth': 18, 'learning_rate': 0.05132373394163056, 'min_child_samples': 184}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 08:52:05,086] Trial 261 finished with value: 0.23584905660377353 and parameters: {'n_estimators': 2464, 'num_leaves': 1177, 'max_depth': 14, 'learning_rate': 0.04063501982968442, 'min_child_samples': 189}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 08:54:04,146] Trial 262 finished with value: 0.23121387283236994 and parameters: {'n_estimators': 2432, 'num_leaves': 1121, 'max_depth': 24, 'learning_rate': 0.02928616886238273, 'min_child_samples': 170}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 08:56:22,857] Trial 263 finished with value: 0.23100303951367782 and parameters: {'n_estimators': 3100, 'num_leaves': 1912, 'max_depth': 12, 'learning_rate': 0.046850168186024777, 'min_child_samples': 177}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 08:58:26,201] Trial 264 finished with value: 0.24304538799414352 and parameters: {'n_estimators': 2345, 'num_leaves': 1223, 'max_depth': 17, 'learning_rate': 0.03687805745226259, 'min_child_samples': 159}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 09:00:30,073] Trial 265 finished with value: 0.23584905660377353 and parameters: {'n_estimators': 2300, 'num_leaves': 1225, 'max_depth': 20, 'learning_rate': 0.021508259332027116, 'min_child_samples': 159}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 09:02:27,910] Trial 266 finished with value: 0.22804314329738062 and parameters: {'n_estimators': 2360, 'num_leaves': 1205, 'max_depth': 17, 'learning_rate': 0.03380427552313962, 'min_child_samples': 182}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 09:04:33,491] Trial 267 finished with value: 0.20648259303721486 and parameters: {'n_estimators': 2243, 'num_leaves': 1341, 'max_depth': 38, 'learning_rate': 0.05636731089620716, 'min_child_samples': 193}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 09:06:15,463] Trial 268 finished with value: 0.234375 and parameters: {'n_estimators': 2321, 'num_leaves': 1150, 'max_depth': 14, 'learning_rate': 0.03705695483473892, 'min_child_samples': 157}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 09:08:18,988] Trial 269 finished with value: 0.2419601837672282 and parameters: {'n_estimators': 2361, 'num_leaves': 1268, 'max_depth': 18, 'learning_rate': 0.029269875527951763, 'min_child_samples': 163}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 09:10:25,030] Trial 270 finished with value: 0.21371610845295058 and parameters: {'n_estimators': 2191, 'num_leaves': 1280, 'max_depth': 21, 'learning_rate': 0.023924960925567895, 'min_child_samples': 166}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 09:12:19,454] Trial 271 finished with value: 0.20677966101694917 and parameters: {'n_estimators': 2273, 'num_leaves': 1382, 'max_depth': 18, 'learning_rate': 0.01675055745877558, 'min_child_samples': 174}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 09:14:28,362] Trial 272 finished with value: 0.24312590448625185 and parameters: {'n_estimators': 2498, 'num_leaves': 1261, 'max_depth': 22, 'learning_rate': 0.02788109832375841, 'min_child_samples': 161}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 09:16:38,503] Trial 273 finished with value: 0.2314540059347181 and parameters: {'n_estimators': 2495, 'num_leaves': 1280, 'max_depth': 23, 'learning_rate': 0.02917942049452771, 'min_child_samples': 188}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 09:18:41,653] Trial 274 finished with value: 0.22464898595943839 and parameters: {'n_estimators': 2409, 'num_leaves': 1241, 'max_depth': 20, 'learning_rate': 0.02210000372067572, 'min_child_samples': 162}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 09:20:34,928] Trial 275 finished with value: 0.23617339312406574 and parameters: {'n_estimators': 2329, 'num_leaves': 1329, 'max_depth': 22, 'learning_rate': 0.02962236867329487, 'min_child_samples': 181}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 09:22:48,485] Trial 276 finished with value: 0.23495702005730656 and parameters: {'n_estimators': 2491, 'num_leaves': 1274, 'max_depth': 19, 'learning_rate': 0.03469238342295397, 'min_child_samples': 163}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 09:24:44,228] Trial 277 finished with value: 0.1904761904761905 and parameters: {'n_estimators': 2162, 'num_leaves': 1237, 'max_depth': 24, 'learning_rate': 0.014931276630626208, 'min_child_samples': 174}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 09:26:41,452] Trial 278 finished with value: 0.234375 and parameters: {'n_estimators': 2366, 'num_leaves': 1197, 'max_depth': 17, 'learning_rate': 0.03040669362357737, 'min_child_samples': 185}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 09:28:21,608] Trial 279 finished with value: 0.20294599018003273 and parameters: {'n_estimators': 2225, 'num_leaves': 1341, 'max_depth': 21, 'learning_rate': 0.022828586083579835, 'min_child_samples': 195}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 09:30:24,886] Trial 280 finished with value: 0.21303258145363407 and parameters: {'n_estimators': 2414, 'num_leaves': 2216, 'max_depth': 52, 'learning_rate': 0.037679933770073865, 'min_child_samples': 176}. Best is trial 238 with value: 0.24886191198786037.
# [I 2024-08-22 09:32:16,633] Trial 281 finished with value: 0.24 and parameters: {'n_estimators': 2507, 'num_leaves': 1477, 'max_depth': 18, 'learning_rate': 0.03177969305245941, 'min_child_samples': 157}. Best is trial 238 with value: 0.24886191198786037.
# [W 2024-08-22 09:34:17,773] Trial 282 failed with parameters: {'n_estimators': 3035, 'num_leaves': 1480, 'max_depth': 17, 'learning_rate': 0.010298521326946291, 'min_child_samples': 156} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\juneh\AppData\Local\Temp\ipykernel_15924\2056574942.py", line 45, in <lambda>
#     study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=300)
#   File "C:\Users\juneh\AppData\Local\Temp\ipykernel_15924\2056574942.py", line 26, in objectiveLGBM_dart
#     model.fit(x_tr, y_tr)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py", line 1298, in fit
#     init_model=init_model,
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py", line 963, in fit
#     callbacks=callbacks,
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\engine.py", line 307, in train
#     booster.update(fobj=fobj)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\basic.py", line 4138, in update
#     ctypes.byref(is_finished),
# KeyboardInterrupt
# [W 2024-08-22 09:34:17,779] Trial 282 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15924\2056574942.py in <module>
#      43 # 하이퍼 파라미터 튜닝
#      44 study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# ---> 45 study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=300)
#      46
#      47 print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     458             callbacks=callbacks,
#     459             gc_after_trial=gc_after_trial,
# --> 460             show_progress_bar=show_progress_bar,
#     461         )
#     462
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      70                 reseed_sampler_rng=False,
#      71                 time_start=None,
# ---> 72                 progress_bar=progress_bar,
#      73             )
#      74         else:
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157
#     158         try:
# --> 159             frozen_trial = _run_trial(study, func, catch)
#     160         finally:
#     161             # The following line mitigates memory problems that can be occurred in some
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _run_trial(study, func, catch)
#     245         and not isinstance(func_err, catch)
#     246     ):
# --> 247         raise func_err
#     248     return frozen_trial
#     249
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _run_trial(study, func, catch)
#     194     with get_heartbeat_thread(trial._trial_id, study._storage):
#     195         try:
# --> 196             value_or_values = func(trial)
#     197         except exceptions.TrialPruned as e:
#     198             # TODO(mamu): Handle multi-objective cases.
#
# ~\AppData\Local\Temp\ipykernel_15924\2056574942.py in <lambda>(trial)
#      43 # 하이퍼 파라미터 튜닝
#      44 study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# ---> 45 study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=300)
#      46
#      47 print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
#
# ~\AppData\Local\Temp\ipykernel_15924\2056574942.py in objectiveLGBM_dart(trial, x_tr, y_tr, x_val, y_val)
#      24
#      25     model = LGBMClassifier(**param)
# ---> 26     model.fit(x_tr, y_tr)
#      27     pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
#      28     pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1296             categorical_feature=categorical_feature,
#    1297             callbacks=callbacks,
# -> 1298             init_model=init_model,
#    1299         )
#    1300         return self
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#     961             feval=eval_metrics_callable,  # type: ignore[arg-type]
#     962             init_model=init_model,
# --> 963             callbacks=callbacks,
#     964         )
#     965
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, feature_name, categorical_feature, keep_training_booster, callbacks)
#     305             )
#     306
# --> 307         booster.update(fobj=fobj)
#     308
#     309         evaluation_result_list: List[_LGBM_BoosterEvalMethodResultType] = []
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    4136                 _LIB.LGBM_BoosterUpdateOneIter(
#    4137                     self._handle,
# -> 4138                     ctypes.byref(is_finished),
#    4139                 )
#    4140             )
#
# KeyboardInterrupt:

# %% [markdown]
# .
