# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ## 1. 데이터 불러오기

# %% [markdown]
# ### 필수 라이브러리

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)

def get_clf_eval(y_test, y_pred_proba, threshold=0.5):
    # 확률을 기준으로 예측 레이블 생성
    y_pred = (y_pred_proba >= threshold).astype(int)  # 0.5 이상의 확률을 양성으로 간주

    confusion = confusion_matrix(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    print("Confusion Matrix:\n", confusion)
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")

# %% [markdown]
# ### 데이터 읽어오기

# %%
import pandas as pd

THRESHOLD = 0.3
RANDOM_STATE = 110

train_data = pd.read_csv("../../../data/train_data_0817.csv")
test_data = pd.read_csv("../../../data/test_data_0817.csv")

# %% [markdown]
# ---

# %% [markdown]
# ## 3. 모델 학습

# %% [markdown]
# ### 모델 정의

# %% [markdown]
# optuna

# %%
# import optuna
# from lightgbm import LGBMClassifier

# # 'Normal'과 'AbNormal'을 숫자로 변환
# train_data['target'] = train_data['target'].map({'Normal': 0, 'AbNormal': 1})

# # 스레드홀드 설정
# THRESHOLD = 0.3

# def objectiveLGBM_dart(trial, x_tr, y_tr, x_val, y_val):
#     param = {
#         'n_estimators': trial.suggest_int('n_estimators', 500, 3000),
#         'num_leaves': trial.suggest_int('num_leaves', 500, 3000),
#         'max_depth': trial.suggest_int('max_depth', 10, 300),
#         'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1),
#         'min_child_samples': trial.suggest_int('min_child_samples', 3, 300),
        
#         'boosting_type': 'dart',  # 'boosting'를 'boosting_type'으로 수정
#         'random_state': RANDOM_STATE,
#         'verbose': -1
#     }
       
#     model = LGBMClassifier(**param)
#     model.fit(x_tr, y_tr)
#     pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
#     pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
    
#     score = f1_score(y_val, pred, average="binary")
    
#     return score

# # 데이터셋 분할
# x_train, x_val, y_train, y_val = train_test_split(
#     train_data.drop("target", axis=1),
#     train_data["target"],
#     test_size=0.2,
#     shuffle=True,
#     random_state=RANDOM_STATE,
# )

# # 하이퍼 파라미터 튜닝
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=300)

# print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))

# %% [markdown]
#  Trial 42 finished with value: 0.24466571834992892
#  parameters: {'n_estimators': 2272, 'num_leaves': 2471, 'max_depth': 196,
#  'learning_rate': 0.05512536968464675, 'min_child_samples': 225}

# %%
# import optuna
# from lightgbm import LGBMClassifier

# # 'Normal'과 'AbNormal'을 숫자로 변환
# train_data['target'] = train_data['target'].map({'Normal': 0, 'AbNormal': 1})

# # 스레드홀드 설정
# THRESHOLD = 0.3

# def objectiveLGBM_dart(trial, x_tr, y_tr, x_val, y_val):
#     param = {
#         'n_estimators': trial.suggest_int('n_estimators', 1000, 3500),
#         'num_leaves': trial.suggest_int('num_leaves', 1500, 3500),
#         'max_depth': trial.suggest_int('max_depth', 50, 350),
#         'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1),
#         'min_child_samples': trial.suggest_int('min_child_samples', 3, 350),
        
#         'boosting_type': 'dart',  # 'boosting'를 'boosting_type'으로 수정
#         'random_state': RANDOM_STATE,
#         'verbose': -1
#     }
       
#     model = LGBMClassifier(**param)
#     model.fit(x_tr, y_tr)
#     pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
#     pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
    
#     score = f1_score(y_val, pred, average="binary")
    
#     return score

# # 데이터셋 분할
# x_train, x_val, y_train, y_val = train_test_split(
#     train_data.drop("target", axis=1),
#     train_data["target"],
#     test_size=0.2,
#     shuffle=True,
#     random_state=RANDOM_STATE,
# )

# # 하이퍼 파라미터 튜닝
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=300)

# print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))

# %% [markdown]
# Best trial: score 0.24709302325581395,
# params {'n_estimators': 2256, 'num_leaves': 2801, 'max_depth': 124, 'learning_rate': 0.05355814918697735, 'min_child_samples': 260}

# %%
# import optuna
# from lightgbm import LGBMClassifier

# # 'Normal'과 'AbNormal'을 숫자로 변환
# train_data['target'] = train_data['target'].map({'Normal': 0, 'AbNormal': 1})

# # 스레드홀드 설정
# THRESHOLD = 0.3

# def objectiveLGBM_dart(trial, x_tr, y_tr, x_val, y_val):
#     param = {
#         'n_estimators': trial.suggest_int('n_estimators', 1300, 3000),
#         'num_leaves': trial.suggest_int('num_leaves', 1800, 3500),
#         'max_depth': trial.suggest_int('max_depth', 70, 350),
#         'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1),
#         'min_child_samples': trial.suggest_int('min_child_samples', 60, 350),
        
#         'boosting_type': 'dart',  # 'boosting'를 'boosting_type'으로 수정
#         'random_state': RANDOM_STATE,
#         'verbose': -1
#     }
       
#     model = LGBMClassifier(**param)
#     model.fit(x_tr, y_tr)
#     pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
#     pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
    
#     score = f1_score(y_val, pred, average="binary")
    
#     return score

# # 데이터셋 분할
# x_train, x_val, y_train, y_val = train_test_split(
#     train_data.drop("target", axis=1),
#     train_data["target"],
#     test_size=0.2,
#     shuffle=True,
#     random_state=RANDOM_STATE,
# )

# # 하이퍼 파라미터 튜닝
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=300)

# print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))

# %% [markdown]
# Trial 162 finished with value: 0.24501424501424504
# parameters: {'n_estimators': 2383, 'num_leaves': 2528, 'max_depth': 343,
# 'learning_rate': 0.04661896043153508, 'min_child_samples': 209}

# %% [markdown]
# 한번더 옵튜나 돌려보았을때도 같은 성능나옴

# %%
import optuna
from lightgbm import LGBMClassifier

# 'Normal'과 'AbNormal'을 숫자로 변환
train_data['target'] = train_data['target'].map({'Normal': 0, 'AbNormal': 1})

# 스레드홀드 설정
THRESHOLD = 0.3

def objectiveLGBM_dart(trial, x_tr, y_tr, x_val, y_val):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 1300, 3300),
        'num_leaves': trial.suggest_int('num_leaves', 1800, 3800),
        'max_depth': trial.suggest_int('max_depth', 100, 450),
        'learning_rate': trial.suggest_float('learning_rate', 0.0003, 0.3),
        'min_child_samples': trial.suggest_int('min_child_samples', 50, 350),
        
        'boosting_type': 'dart',  # 'boosting'를 'boosting_type'으로 수정
        'random_state': RANDOM_STATE,
        'verbose': -1
    }
       
    model = LGBMClassifier(**param)
    model.fit(x_tr, y_tr)
    pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
    pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
    
    score = f1_score(y_val, pred, average="binary")
    
    return score

# 데이터셋 분할
x_train, x_val, y_train, y_val = train_test_split(
    train_data.drop("target", axis=1),
    train_data["target"],
    test_size=0.2,
    shuffle=True,
    random_state=RANDOM_STATE,
)

# 하이퍼 파라미터 튜닝
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=400)

print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# [I 2024-08-21 23:22:52,748] A new study created in memory with name: no-name-d1c9aed6-b3ee-492a-9cc4-f95b02d4b974
# [I 2024-08-21 23:23:26,256] Trial 0 finished with value: 0.21714285714285717 and parameters: {'n_estimators': 1532, 'num_leaves': 3117, 'max_depth': 231, 'learning_rate': 0.18395093969213586, 'min_child_samples': 254}. Best is trial 0 with value: 0.21714285714285717.
# [I 2024-08-21 23:25:11,305] Trial 1 finished with value: 0.20923076923076922 and parameters: {'n_estimators': 2665, 'num_leaves': 3710, 'max_depth': 323, 'learning_rate': 0.15402919924162803, 'min_child_samples': 75}. Best is trial 0 with value: 0.21714285714285717.
# [I 2024-08-21 23:25:51,077] Trial 2 finished with value: 0.18434782608695652 and parameters: {'n_estimators': 2075, 'num_leaves': 2381, 'max_depth': 147, 'learning_rate': 0.0033286437432812747, 'min_child_samples': 174}. Best is trial 0 with value: 0.21714285714285717.
# [I 2024-08-21 23:26:37,155] Trial 3 finished with value: 0.22720478325859492 and parameters: {'n_estimators': 2285, 'num_leaves': 1842, 'max_depth': 296, 'learning_rate': 0.023561721119973494, 'min_child_samples': 172}. Best is trial 3 with value: 0.22720478325859492.
# [I 2024-08-21 23:27:32,184] Trial 4 finished with value: 0.23262839879154076 and parameters: {'n_estimators': 1928, 'num_leaves': 3341, 'max_depth': 310, 'learning_rate': 0.12538224344127344, 'min_child_samples': 150}. Best is trial 4 with value: 0.23262839879154076.
# [I 2024-08-21 23:28:09,009] Trial 5 finished with value: 0.21823617339312407 and parameters: {'n_estimators': 1350, 'num_leaves': 1979, 'max_depth': 399, 'learning_rate': 0.1474860351915402, 'min_child_samples': 125}. Best is trial 4 with value: 0.23262839879154076.
# [I 2024-08-21 23:29:44,948] Trial 6 finished with value: 0.2137404580152672 and parameters: {'n_estimators': 2823, 'num_leaves': 2881, 'max_depth': 235, 'learning_rate': 0.19332900436168748, 'min_child_samples': 101}. Best is trial 4 with value: 0.23262839879154076.
# [I 2024-08-21 23:30:58,403] Trial 7 finished with value: 0.22526636225266364 and parameters: {'n_estimators': 2719, 'num_leaves': 1880, 'max_depth': 310, 'learning_rate': 0.06124285172137882, 'min_child_samples': 124}. Best is trial 4 with value: 0.23262839879154076.
# [I 2024-08-21 23:31:59,824] Trial 8 finished with value: 0.2127659574468085 and parameters: {'n_estimators': 2098, 'num_leaves': 3228, 'max_depth': 378, 'learning_rate': 0.26849303362178684, 'min_child_samples': 116}. Best is trial 4 with value: 0.23262839879154076.
# [I 2024-08-21 23:32:22,858] Trial 9 finished with value: 0.21606648199445982 and parameters: {'n_estimators': 1325, 'num_leaves': 3322, 'max_depth': 164, 'learning_rate': 0.2381283650041344, 'min_child_samples': 336}. Best is trial 4 with value: 0.23262839879154076.
# [I 2024-08-21 23:32:59,073] Trial 10 finished with value: 0.22695035460992907 and parameters: {'n_estimators': 1814, 'num_leaves': 3789, 'max_depth': 430, 'learning_rate': 0.08917790102147967, 'min_child_samples': 242}. Best is trial 4 with value: 0.23262839879154076.
# [I 2024-08-21 23:33:44,390] Trial 11 finished with value: 0.22187981510015412 and parameters: {'n_estimators': 2401, 'num_leaves': 2385, 'max_depth': 277, 'learning_rate': 0.01994885514912341, 'min_child_samples': 180}. Best is trial 4 with value: 0.23262839879154076.
# [I 2024-08-21 23:34:59,096] Trial 12 finished with value: 0.2190201729106628 and parameters: {'n_estimators': 3079, 'num_leaves': 2484, 'max_depth': 350, 'learning_rate': 0.09078523302313296, 'min_child_samples': 215}. Best is trial 4 with value: 0.23262839879154076.
# [I 2024-08-21 23:35:41,208] Trial 13 finished with value: 0.24347826086956517 and parameters: {'n_estimators': 1841, 'num_leaves': 3497, 'max_depth': 231, 'learning_rate': 0.0728836649780788, 'min_child_samples': 163}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:36:46,711] Trial 14 finished with value: 0.20833333333333334 and parameters: {'n_estimators': 1788, 'num_leaves': 3429, 'max_depth': 209, 'learning_rate': 0.12326586726426983, 'min_child_samples': 57}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:37:18,679] Trial 15 finished with value: 0.23222060957910012 and parameters: {'n_estimators': 1777, 'num_leaves': 3589, 'max_depth': 195, 'learning_rate': 0.06544085475940437, 'min_child_samples': 281}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:38:07,288] Trial 16 finished with value: 0.21791044776119403 and parameters: {'n_estimators': 1944, 'num_leaves': 2956, 'max_depth': 113, 'learning_rate': 0.11455009482978018, 'min_child_samples': 153}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:38:41,493] Trial 17 finished with value: 0.22158273381294963 and parameters: {'n_estimators': 1582, 'num_leaves': 3488, 'max_depth': 245, 'learning_rate': 0.20047670861596348, 'min_child_samples': 214}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:39:37,160] Trial 18 finished with value: 0.22965116279069767 and parameters: {'n_estimators': 2415, 'num_leaves': 3076, 'max_depth': 263, 'learning_rate': 0.045659204010001855, 'min_child_samples': 150}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:41:33,590] Trial 19 finished with value: 0.22188449848024316 and parameters: {'n_estimators': 3300, 'num_leaves': 2704, 'max_depth': 343, 'learning_rate': 0.1486270784694164, 'min_child_samples': 83}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:42:14,019] Trial 20 finished with value: 0.22585034013605443 and parameters: {'n_estimators': 2153, 'num_leaves': 3579, 'max_depth': 448, 'learning_rate': 0.2973722152251166, 'min_child_samples': 314}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:42:44,898] Trial 21 finished with value: 0.2354609929078014 and parameters: {'n_estimators': 1704, 'num_leaves': 3382, 'max_depth': 182, 'learning_rate': 0.07165319549509029, 'min_child_samples': 277}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:43:13,047] Trial 22 finished with value: 0.22031473533619458 and parameters: {'n_estimators': 1566, 'num_leaves': 3301, 'max_depth': 185, 'learning_rate': 0.09363966918461458, 'min_child_samples': 290}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:43:58,584] Trial 23 finished with value: 0.22031473533619458 and parameters: {'n_estimators': 1932, 'num_leaves': 2726, 'max_depth': 116, 'learning_rate': 0.11748135522141545, 'min_child_samples': 200}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:44:32,269] Trial 24 finished with value: 0.22998544395924309 and parameters: {'n_estimators': 1780, 'num_leaves': 3383, 'max_depth': 156, 'learning_rate': 0.05772653598106438, 'min_child_samples': 239}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:45:09,619] Trial 25 finished with value: 0.2328966521106259 and parameters: {'n_estimators': 1616, 'num_leaves': 3107, 'max_depth': 215, 'learning_rate': 0.08060142328842333, 'min_child_samples': 150}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:45:33,469] Trial 26 finished with value: 0.20504201680672268 and parameters: {'n_estimators': 1487, 'num_leaves': 3126, 'max_depth': 208, 'learning_rate': 0.032862333058705534, 'min_child_samples': 276}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:46:00,751] Trial 27 finished with value: 0.23209169054441262 and parameters: {'n_estimators': 1642, 'num_leaves': 3585, 'max_depth': 175, 'learning_rate': 0.0809579827727438, 'min_child_samples': 347}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:46:35,245] Trial 28 finished with value: 0.23953823953823955 and parameters: {'n_estimators': 1668, 'num_leaves': 2959, 'max_depth': 264, 'learning_rate': 0.07024696615771885, 'min_child_samples': 194}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:46:56,319] Trial 29 finished with value: 0.16501650165016502 and parameters: {'n_estimators': 1425, 'num_leaves': 2962, 'max_depth': 263, 'learning_rate': 0.0034693343165245194, 'min_child_samples': 258}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:47:29,563] Trial 30 finished with value: 0.23512336719883886 and parameters: {'n_estimators': 1699, 'num_leaves': 2619, 'max_depth': 239, 'learning_rate': 0.04785856776150249, 'min_child_samples': 197}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:48:01,765] Trial 31 finished with value: 0.23269513991163476 and parameters: {'n_estimators': 1671, 'num_leaves': 2546, 'max_depth': 238, 'learning_rate': 0.04419200710261331, 'min_child_samples': 193}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:48:29,660] Trial 32 finished with value: 0.22773722627737225 and parameters: {'n_estimators': 1457, 'num_leaves': 2166, 'max_depth': 270, 'learning_rate': 0.06749790006068576, 'min_child_samples': 213}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:49:05,844] Trial 33 finished with value: 0.23179791976225855 and parameters: {'n_estimators': 1959, 'num_leaves': 2675, 'max_depth': 226, 'learning_rate': 0.04395126062237037, 'min_child_samples': 241}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:49:59,291] Trial 34 finished with value: 0.20444444444444443 and parameters: {'n_estimators': 2227, 'num_leaves': 3199, 'max_depth': 146, 'learning_rate': 0.16730796517310242, 'min_child_samples': 179}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:50:33,941] Trial 35 finished with value: 0.22873082287308227 and parameters: {'n_estimators': 1687, 'num_leaves': 2206, 'max_depth': 288, 'learning_rate': 0.11021328634825858, 'min_child_samples': 224}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:51:11,367] Trial 36 finished with value: 0.21140939597315436 and parameters: {'n_estimators': 1991, 'num_leaves': 3715, 'max_depth': 249, 'learning_rate': 0.014186680113040043, 'min_child_samples': 166}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:51:52,034] Trial 37 finished with value: 0.22946175637393768 and parameters: {'n_estimators': 1825, 'num_leaves': 2851, 'max_depth': 188, 'learning_rate': 0.10216038529240301, 'min_child_samples': 198}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:52:36,976] Trial 38 finished with value: 0.22613803230543317 and parameters: {'n_estimators': 2052, 'num_leaves': 2572, 'max_depth': 136, 'learning_rate': 0.0311762802600278, 'min_child_samples': 133}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:53:30,161] Trial 39 finished with value: 0.2342606149341142 and parameters: {'n_estimators': 2373, 'num_leaves': 3510, 'max_depth': 312, 'learning_rate': 0.07367240284105608, 'min_child_samples': 186}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:54:28,744] Trial 40 finished with value: 0.217877094972067 and parameters: {'n_estimators': 2527, 'num_leaves': 3026, 'max_depth': 291, 'learning_rate': 0.13176881632171317, 'min_child_samples': 310}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:55:36,815] Trial 41 finished with value: 0.2274052478134111 and parameters: {'n_estimators': 2578, 'num_leaves': 3501, 'max_depth': 309, 'learning_rate': 0.07326810701382114, 'min_child_samples': 188}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:56:37,732] Trial 42 finished with value: 0.23357664233576642 and parameters: {'n_estimators': 2355, 'num_leaves': 3219, 'max_depth': 325, 'learning_rate': 0.05909437163404469, 'min_child_samples': 165}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:57:27,463] Trial 43 finished with value: 0.23988439306358378 and parameters: {'n_estimators': 2198, 'num_leaves': 3672, 'max_depth': 221, 'learning_rate': 0.04969163513016111, 'min_child_samples': 223}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:58:15,523] Trial 44 finished with value: 0.22287390029325516 and parameters: {'n_estimators': 2180, 'num_leaves': 3707, 'max_depth': 224, 'learning_rate': 0.0474947890283202, 'min_child_samples': 264}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:58:50,732] Trial 45 finished with value: 0.21405750798722048 and parameters: {'n_estimators': 1886, 'num_leaves': 3777, 'max_depth': 252, 'learning_rate': 0.026719876917025237, 'min_child_samples': 226}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-21 23:59:16,986] Trial 46 finished with value: 0.18322981366459629 and parameters: {'n_estimators': 1391, 'num_leaves': 3310, 'max_depth': 203, 'learning_rate': 0.003144239147979108, 'min_child_samples': 139}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:00:11,355] Trial 47 finished with value: 0.21913580246913583 and parameters: {'n_estimators': 1705, 'num_leaves': 3647, 'max_depth': 172, 'learning_rate': 0.13293897097908436, 'min_child_samples': 105}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:00:56,431] Trial 48 finished with value: 0.22816901408450704 and parameters: {'n_estimators': 2056, 'num_leaves': 2249, 'max_depth': 225, 'learning_rate': 0.0983522475115847, 'min_child_samples': 227}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:01:26,123] Trial 49 finished with value: 0.23248882265275708 and parameters: {'n_estimators': 1537, 'num_leaves': 3451, 'max_depth': 274, 'learning_rate': 0.05102713243694115, 'min_child_samples': 207}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:02:12,845] Trial 50 finished with value: 0.21084337349397592 and parameters: {'n_estimators': 1841, 'num_leaves': 2808, 'max_depth': 236, 'learning_rate': 0.22661959715806645, 'min_child_samples': 166}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:03:21,853] Trial 51 finished with value: 0.23338257016248154 and parameters: {'n_estimators': 2833, 'num_leaves': 3531, 'max_depth': 372, 'learning_rate': 0.07686746513619347, 'min_child_samples': 178}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:04:15,966] Trial 52 finished with value: 0.22766570605187317 and parameters: {'n_estimators': 2277, 'num_leaves': 3655, 'max_depth': 316, 'learning_rate': 0.08421464700353583, 'min_child_samples': 186}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:04:44,091] Trial 53 finished with value: 0.2287390029325513 and parameters: {'n_estimators': 1304, 'num_leaves': 3388, 'max_depth': 291, 'learning_rate': 0.0656337879349669, 'min_child_samples': 157}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:05:32,427] Trial 54 finished with value: 0.2274052478134111 and parameters: {'n_estimators': 2501, 'num_leaves': 3800, 'max_depth': 255, 'learning_rate': 0.032245817290465904, 'min_child_samples': 204}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:05:59,068] Trial 55 finished with value: 0.2 and parameters: {'n_estimators': 1740, 'num_leaves': 2419, 'max_depth': 347, 'learning_rate': 0.01505938082473135, 'min_child_samples': 299}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:06:51,701] Trial 56 finished with value: 0.2303370786516854 and parameters: {'n_estimators': 2651, 'num_leaves': 3283, 'max_depth': 196, 'learning_rate': 0.05568457216406232, 'min_child_samples': 247}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:07:32,614] Trial 57 finished with value: 0.22916666666666666 and parameters: {'n_estimators': 2123, 'num_leaves': 3418, 'max_depth': 217, 'learning_rate': 0.039389352546985085, 'min_child_samples': 228}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:08:19,472] Trial 58 finished with value: 0.22816901408450704 and parameters: {'n_estimators': 2323, 'num_leaves': 3553, 'max_depth': 334, 'learning_rate': 0.10619112842570227, 'min_child_samples': 274}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:09:07,901] Trial 59 finished with value: 0.22481751824817517 and parameters: {'n_estimators': 1878, 'num_leaves': 2610, 'max_depth': 306, 'learning_rate': 0.091221661085404, 'min_child_samples': 143}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:10:03,313] Trial 60 finished with value: 0.23943661971830987 and parameters: {'n_estimators': 2013, 'num_leaves': 2965, 'max_depth': 279, 'learning_rate': 0.07325967535999545, 'min_child_samples': 191}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:10:57,816] Trial 61 finished with value: 0.23163841807909605 and parameters: {'n_estimators': 2025, 'num_leaves': 2935, 'max_depth': 280, 'learning_rate': 0.07343369454855922, 'min_child_samples': 194}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:11:57,615] Trial 62 finished with value: 0.2337662337662338 and parameters: {'n_estimators': 2183, 'num_leaves': 2765, 'max_depth': 241, 'learning_rate': 0.05871141561957752, 'min_child_samples': 173}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:13:02,128] Trial 63 finished with value: 0.2222222222222222 and parameters: {'n_estimators': 2440, 'num_leaves': 3167, 'max_depth': 263, 'learning_rate': 0.09172700481183055, 'min_child_samples': 216}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:13:51,418] Trial 64 finished with value: 0.22840409956076135 and parameters: {'n_estimators': 1740, 'num_leaves': 3646, 'max_depth': 302, 'learning_rate': 0.06781085165638023, 'min_child_samples': 159}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:14:34,743] Trial 65 finished with value: 0.22253922967189727 and parameters: {'n_estimators': 1616, 'num_leaves': 3061, 'max_depth': 183, 'learning_rate': 0.08168920500965343, 'min_child_samples': 183}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:15:43,689] Trial 66 finished with value: 0.23088023088023088 and parameters: {'n_estimators': 2246, 'num_leaves': 3354, 'max_depth': 360, 'learning_rate': 0.04161281206881634, 'min_child_samples': 204}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:16:32,227] Trial 67 finished with value: 0.20774647887323944 and parameters: {'n_estimators': 1492, 'num_leaves': 2909, 'max_depth': 280, 'learning_rate': 0.020252238538427638, 'min_child_samples': 235}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:19:11,919] Trial 68 finished with value: 0.22187981510015412 and parameters: {'n_estimators': 1902, 'num_leaves': 3010, 'max_depth': 399, 'learning_rate': 0.17378963208841713, 'min_child_samples': 121}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:20:35,319] Trial 69 finished with value: 0.22123893805309736 and parameters: {'n_estimators': 1771, 'num_leaves': 3469, 'max_depth': 260, 'learning_rate': 0.05349404386509589, 'min_child_samples': 249}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:22:25,804] Trial 70 finished with value: 0.22603719599427755 and parameters: {'n_estimators': 2096, 'num_leaves': 2641, 'max_depth': 213, 'learning_rate': 0.06984136022807318, 'min_child_samples': 217}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:24:53,833] Trial 71 finished with value: 0.23613086770981503 and parameters: {'n_estimators': 2206, 'num_leaves': 2745, 'max_depth': 243, 'learning_rate': 0.05962551920230186, 'min_child_samples': 171}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:27:19,031] Trial 72 finished with value: 0.22965116279069767 and parameters: {'n_estimators': 1984, 'num_leaves': 2489, 'max_depth': 234, 'learning_rate': 0.08679544922402223, 'min_child_samples': 188}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:29:59,254] Trial 73 finished with value: 0.22781065088757393 and parameters: {'n_estimators': 2210, 'num_leaves': 2799, 'max_depth': 250, 'learning_rate': 0.11898639973397396, 'min_child_samples': 172}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:31:46,718] Trial 74 finished with value: 0.23275862068965517 and parameters: {'n_estimators': 2343, 'num_leaves': 2733, 'max_depth': 202, 'learning_rate': 0.06206175382637088, 'min_child_samples': 332}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:33:28,465] Trial 75 finished with value: 0.2420749279538905 and parameters: {'n_estimators': 1590, 'num_leaves': 3257, 'max_depth': 245, 'learning_rate': 0.052600674260905395, 'min_child_samples': 198}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:35:12,133] Trial 76 finished with value: 0.2163009404388715 and parameters: {'n_estimators': 1581, 'num_leaves': 2879, 'max_depth': 244, 'learning_rate': 0.03579626434683502, 'min_child_samples': 195}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:37:15,658] Trial 77 finished with value: 0.22478386167146977 and parameters: {'n_estimators': 1692, 'num_leaves': 3144, 'max_depth': 223, 'learning_rate': 0.05054714242455466, 'min_child_samples': 209}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:39:59,347] Trial 78 finished with value: 0.22518518518518518 and parameters: {'n_estimators': 1830, 'num_leaves': 3279, 'max_depth': 267, 'learning_rate': 0.09884791878951132, 'min_child_samples': 145}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:41:55,955] Trial 79 finished with value: 0.2091917591125198 and parameters: {'n_estimators': 1647, 'num_leaves': 2856, 'max_depth': 231, 'learning_rate': 0.025402117084865165, 'min_child_samples': 162}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:43:48,005] Trial 80 finished with value: 0.20701754385964913 and parameters: {'n_estimators': 1536, 'num_leaves': 2673, 'max_depth': 193, 'learning_rate': 0.013172253108279491, 'min_child_samples': 135}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:46:37,816] Trial 81 finished with value: 0.22349570200573066 and parameters: {'n_estimators': 2383, 'num_leaves': 3595, 'max_depth': 275, 'learning_rate': 0.07556014313373349, 'min_child_samples': 199}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:49:21,670] Trial 82 finished with value: 0.2339514978601997 and parameters: {'n_estimators': 2144, 'num_leaves': 3502, 'max_depth': 161, 'learning_rate': 0.06193711671750088, 'min_child_samples': 178}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:51:21,587] Trial 83 finished with value: 0.22418879056047197 and parameters: {'n_estimators': 1930, 'num_leaves': 3398, 'max_depth': 246, 'learning_rate': 0.04385624840720226, 'min_child_samples': 189}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:54:25,541] Trial 84 finished with value: 0.2280701754385965 and parameters: {'n_estimators': 2288, 'num_leaves': 2977, 'max_depth': 218, 'learning_rate': 0.07994010416883794, 'min_child_samples': 170}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:57:07,043] Trial 85 finished with value: 0.22608695652173913 and parameters: {'n_estimators': 2010, 'num_leaves': 3085, 'max_depth': 100, 'learning_rate': 0.04913437102647698, 'min_child_samples': 152}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 00:58:37,387] Trial 86 finished with value: 0.2342606149341142 and parameters: {'n_estimators': 1377, 'num_leaves': 3745, 'max_depth': 285, 'learning_rate': 0.06805590116255311, 'min_child_samples': 181}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:00:16,819] Trial 87 finished with value: 0.2288135593220339 and parameters: {'n_estimators': 1722, 'num_leaves': 3342, 'max_depth': 259, 'learning_rate': 0.11004512817547886, 'min_child_samples': 262}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:02:50,283] Trial 88 finished with value: 0.22727272727272727 and parameters: {'n_estimators': 2444, 'num_leaves': 3237, 'max_depth': 298, 'learning_rate': 0.054877573505184726, 'min_child_samples': 220}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:04:51,122] Trial 89 finished with value: 0.23388305847076463 and parameters: {'n_estimators': 1795, 'num_leaves': 3614, 'max_depth': 315, 'learning_rate': 0.037341135656612894, 'min_child_samples': 211}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:06:47,786] Trial 90 finished with value: 0.22 and parameters: {'n_estimators': 1465, 'num_leaves': 2555, 'max_depth': 208, 'learning_rate': 0.09705685214761607, 'min_child_samples': 196}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:08:45,089] Trial 91 finished with value: 0.23222060957910012 and parameters: {'n_estimators': 1351, 'num_leaves': 3730, 'max_depth': 286, 'learning_rate': 0.07278250783832589, 'min_child_samples': 183}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:10:38,867] Trial 92 finished with value: 0.23044096728307253 and parameters: {'n_estimators': 1405, 'num_leaves': 3733, 'max_depth': 270, 'learning_rate': 0.08586114743263576, 'min_child_samples': 202}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:12:43,476] Trial 93 finished with value: 0.22701149425287354 and parameters: {'n_estimators': 1592, 'num_leaves': 3541, 'max_depth': 322, 'learning_rate': 0.06292618372549244, 'min_child_samples': 177}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:15:08,433] Trial 94 finished with value: 0.23462088698140202 and parameters: {'n_estimators': 1862, 'num_leaves': 3672, 'max_depth': 230, 'learning_rate': 0.06712238036013646, 'min_child_samples': 168}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:17:48,799] Trial 95 finished with value: 0.2283236994219653 and parameters: {'n_estimators': 1864, 'num_leaves': 3445, 'max_depth': 257, 'learning_rate': 0.05607989109323895, 'min_child_samples': 159}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:20:31,656] Trial 96 finished with value: 0.23665223665223664 and parameters: {'n_estimators': 2082, 'num_leaves': 3684, 'max_depth': 233, 'learning_rate': 0.04677116568730529, 'min_child_samples': 168}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:23:13,272] Trial 97 finished with value: 0.2255192878338279 and parameters: {'n_estimators': 2072, 'num_leaves': 3681, 'max_depth': 229, 'learning_rate': 0.029646217267054607, 'min_child_samples': 169}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:25:38,007] Trial 98 finished with value: 0.23631123919308356 and parameters: {'n_estimators': 1662, 'num_leaves': 3569, 'max_depth': 239, 'learning_rate': 0.04650987974898502, 'min_child_samples': 154}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:27:49,497] Trial 99 finished with value: 0.23338257016248154 and parameters: {'n_estimators': 1643, 'num_leaves': 3550, 'max_depth': 241, 'learning_rate': 0.04713386581078542, 'min_child_samples': 127}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:29:53,109] Trial 100 finished with value: 0.2066772655007949 and parameters: {'n_estimators': 1753, 'num_leaves': 3624, 'max_depth': 252, 'learning_rate': 0.02186999762302549, 'min_child_samples': 153}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:32:24,108] Trial 101 finished with value: 0.22580645161290322 and parameters: {'n_estimators': 1813, 'num_leaves': 3703, 'max_depth': 237, 'learning_rate': 0.0398433450757865, 'min_child_samples': 147}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:35:08,205] Trial 102 finished with value: 0.23121387283236994 and parameters: {'n_estimators': 1961, 'num_leaves': 3587, 'max_depth': 220, 'learning_rate': 0.06380110225783771, 'min_child_samples': 163}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:37:19,343] Trial 103 finished with value: 0.2318840579710145 and parameters: {'n_estimators': 1692, 'num_leaves': 3763, 'max_depth': 233, 'learning_rate': 0.2686520567704351, 'min_child_samples': 190}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:39:19,812] Trial 104 finished with value: 0.23123123123123118 and parameters: {'n_estimators': 2035, 'num_leaves': 2765, 'max_depth': 199, 'learning_rate': 0.03442577041874181, 'min_child_samples': 233}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:43:56,451] Trial 105 finished with value: 0.21472392638036808 and parameters: {'n_estimators': 1889, 'num_leaves': 3668, 'max_depth': 208, 'learning_rate': 0.20350768953529763, 'min_child_samples': 53}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:45:50,041] Trial 106 finished with value: 0.22674418604651161 and parameters: {'n_estimators': 1525, 'num_leaves': 3460, 'max_depth': 176, 'learning_rate': 0.04756684603897824, 'min_child_samples': 154}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:47:54,420] Trial 107 finished with value: 0.2328966521106259 and parameters: {'n_estimators': 1623, 'num_leaves': 2593, 'max_depth': 241, 'learning_rate': 0.054271706374607764, 'min_child_samples': 173}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:51:00,799] Trial 108 finished with value: 0.2317596566523605 and parameters: {'n_estimators': 2112, 'num_leaves': 1918, 'max_depth': 228, 'learning_rate': 0.07611922078561728, 'min_child_samples': 167}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:53:08,068] Trial 109 finished with value: 0.23054755043227665 and parameters: {'n_estimators': 2184, 'num_leaves': 2818, 'max_depth': 266, 'learning_rate': 0.05937610491959742, 'min_child_samples': 302}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:56:37,138] Trial 110 finished with value: 0.2287390029325513 and parameters: {'n_estimators': 1922, 'num_leaves': 3368, 'max_depth': 147, 'learning_rate': 0.06863882552467439, 'min_child_samples': 138}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 01:59:10,763] Trial 111 finished with value: 0.2238163558106169 and parameters: {'n_estimators': 1771, 'num_leaves': 3506, 'max_depth': 250, 'learning_rate': 0.08170203940394646, 'min_child_samples': 186}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:01:59,914] Trial 112 finished with value: 0.2344428364688857 and parameters: {'n_estimators': 2247, 'num_leaves': 3522, 'max_depth': 227, 'learning_rate': 0.043304154727649674, 'min_child_samples': 194}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:04:09,884] Trial 113 finished with value: 0.22781065088757393 and parameters: {'n_estimators': 1851, 'num_leaves': 3565, 'max_depth': 221, 'learning_rate': 0.04299460157689361, 'min_child_samples': 207}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:06:21,195] Trial 114 finished with value: 0.1925133689839572 and parameters: {'n_estimators': 2239, 'num_leaves': 2514, 'max_depth': 211, 'learning_rate': 0.007100613831475103, 'min_child_samples': 194}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:08:45,152] Trial 115 finished with value: 0.2331838565022422 and parameters: {'n_estimators': 1656, 'num_leaves': 3262, 'max_depth': 248, 'learning_rate': 0.027217346259235033, 'min_child_samples': 111}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:11:17,368] Trial 116 finished with value: 0.22955523672883787 and parameters: {'n_estimators': 2257, 'num_leaves': 3419, 'max_depth': 229, 'learning_rate': 0.053175047273666336, 'min_child_samples': 176}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:12:58,834] Trial 117 finished with value: 0.228310502283105 and parameters: {'n_estimators': 1986, 'num_leaves': 3627, 'max_depth': 257, 'learning_rate': 0.04023207371826355, 'min_child_samples': 287}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:15:04,017] Trial 118 finished with value: 0.22733812949640286 and parameters: {'n_estimators': 1722, 'num_leaves': 3478, 'max_depth': 236, 'learning_rate': 0.06598435260989775, 'min_child_samples': 200}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:19:40,284] Trial 119 finished with value: 0.21556886227544908 and parameters: {'n_estimators': 3159, 'num_leaves': 2442, 'max_depth': 192, 'learning_rate': 0.08900858903035401, 'min_child_samples': 158}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:21:49,588] Trial 120 finished with value: 0.22998544395924309 and parameters: {'n_estimators': 2176, 'num_leaves': 2328, 'max_depth': 244, 'learning_rate': 0.04854604574339592, 'min_child_samples': 219}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:24:49,243] Trial 121 finished with value: 0.23109843081312412 and parameters: {'n_estimators': 2137, 'num_leaves': 3518, 'max_depth': 216, 'learning_rate': 0.07306964013078097, 'min_child_samples': 183}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:27:21,179] Trial 122 finished with value: 0.23579545454545453 and parameters: {'n_estimators': 2306, 'num_leaves': 2672, 'max_depth': 337, 'learning_rate': 0.06004917486832972, 'min_child_samples': 192}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:29:54,874] Trial 123 finished with value: 0.2374821173104435 and parameters: {'n_estimators': 2297, 'num_leaves': 2720, 'max_depth': 399, 'learning_rate': 0.060056565231377576, 'min_child_samples': 192}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:33:20,033] Trial 124 finished with value: 0.21984732824427483 and parameters: {'n_estimators': 1560, 'num_leaves': 2698, 'max_depth': 409, 'learning_rate': 0.058606215357406816, 'min_child_samples': 68}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:35:47,212] Trial 125 finished with value: 0.2354609929078014 and parameters: {'n_estimators': 2322, 'num_leaves': 2738, 'max_depth': 448, 'learning_rate': 0.061952327405534094, 'min_child_samples': 205}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:38:19,058] Trial 126 finished with value: 0.22096317280453256 and parameters: {'n_estimators': 2328, 'num_leaves': 2642, 'max_depth': 449, 'learning_rate': 0.07899879487575055, 'min_child_samples': 210}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:40:13,764] Trial 127 finished with value: 0.23428571428571426 and parameters: {'n_estimators': 2216, 'num_leaves': 2780, 'max_depth': 333, 'learning_rate': 0.060428083571022306, 'min_child_samples': 327}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:43:08,869] Trial 128 finished with value: 0.22571428571428573 and parameters: {'n_estimators': 2425, 'num_leaves': 2718, 'max_depth': 436, 'learning_rate': 0.052866278490173314, 'min_child_samples': 202}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:46:05,148] Trial 129 finished with value: 0.21270310192023634 and parameters: {'n_estimators': 2277, 'num_leaves': 2641, 'max_depth': 409, 'learning_rate': 0.15816581369032975, 'min_child_samples': 180}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:48:42,998] Trial 130 finished with value: 0.2344428364688857 and parameters: {'n_estimators': 2319, 'num_leaves': 2662, 'max_depth': 374, 'learning_rate': 0.033956399556137704, 'min_child_samples': 214}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:51:58,336] Trial 131 finished with value: 0.2328966521106259 and parameters: {'n_estimators': 2464, 'num_leaves': 2738, 'max_depth': 427, 'learning_rate': 0.06913810800886395, 'min_child_samples': 189}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:54:03,374] Trial 132 finished with value: 0.21613832853025933 and parameters: {'n_estimators': 1673, 'num_leaves': 2834, 'max_depth': 359, 'learning_rate': 0.06269606661192094, 'min_child_samples': 174}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:56:58,381] Trial 133 finished with value: 0.2347949080622348 and parameters: {'n_estimators': 2390, 'num_leaves': 2606, 'max_depth': 391, 'learning_rate': 0.05020422952538216, 'min_child_samples': 204}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 02:59:34,763] Trial 134 finished with value: 0.23209169054441262 and parameters: {'n_estimators': 2385, 'num_leaves': 2910, 'max_depth': 439, 'learning_rate': 0.052193368109845165, 'min_child_samples': 201}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:02:25,629] Trial 135 finished with value: 0.2298850574712644 and parameters: {'n_estimators': 2348, 'num_leaves': 2604, 'max_depth': 384, 'learning_rate': 0.03744128535650234, 'min_child_samples': 207}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:05:37,342] Trial 136 finished with value: 0.22285714285714286 and parameters: {'n_estimators': 2480, 'num_leaves': 2551, 'max_depth': 403, 'learning_rate': 0.05780628216274612, 'min_child_samples': 193}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:07:45,925] Trial 137 finished with value: 0.24198250728862974 and parameters: {'n_estimators': 2091, 'num_leaves': 3024, 'max_depth': 387, 'learning_rate': 0.04889796166567205, 'min_child_samples': 224}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:10:03,536] Trial 138 finished with value: 0.24137931034482762 and parameters: {'n_estimators': 2089, 'num_leaves': 3041, 'max_depth': 427, 'learning_rate': 0.04638632673736847, 'min_child_samples': 222}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:12:29,565] Trial 139 finished with value: 0.23762376237623764 and parameters: {'n_estimators': 2075, 'num_leaves': 2995, 'max_depth': 417, 'learning_rate': 0.07552519125478802, 'min_child_samples': 226}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:14:42,490] Trial 140 finished with value: 0.2285714285714286 and parameters: {'n_estimators': 2085, 'num_leaves': 3025, 'max_depth': 414, 'learning_rate': 0.07411562565771378, 'min_child_samples': 277}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:16:54,565] Trial 141 finished with value: 0.22191011235955058 and parameters: {'n_estimators': 2161, 'num_leaves': 2965, 'max_depth': 424, 'learning_rate': 0.0857133215050224, 'min_child_samples': 232}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:18:54,670] Trial 142 finished with value: 0.22733812949640286 and parameters: {'n_estimators': 2050, 'num_leaves': 3051, 'max_depth': 421, 'learning_rate': 0.06476885561601414, 'min_child_samples': 256}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:21:05,127] Trial 143 finished with value: 0.23088023088023088 and parameters: {'n_estimators': 2084, 'num_leaves': 3174, 'max_depth': 415, 'learning_rate': 0.044122537782378256, 'min_child_samples': 220}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:23:05,680] Trial 144 finished with value: 0.2407932011331445 and parameters: {'n_estimators': 2135, 'num_leaves': 3112, 'max_depth': 437, 'learning_rate': 0.07869796694873284, 'min_child_samples': 241}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:25:22,249] Trial 145 finished with value: 0.23328591749644378 and parameters: {'n_estimators': 2144, 'num_leaves': 2921, 'max_depth': 433, 'learning_rate': 0.09285029901416605, 'min_child_samples': 243}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:27:35,033] Trial 146 finished with value: 0.23762376237623764 and parameters: {'n_estimators': 2212, 'num_leaves': 3085, 'max_depth': 431, 'learning_rate': 0.07951131835321894, 'min_child_samples': 227}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:29:52,945] Trial 147 finished with value: 0.23728813559322035 and parameters: {'n_estimators': 2201, 'num_leaves': 3109, 'max_depth': 439, 'learning_rate': 0.07778810393263685, 'min_child_samples': 228}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:32:12,617] Trial 148 finished with value: 0.22913719943422914 and parameters: {'n_estimators': 2194, 'num_leaves': 3118, 'max_depth': 443, 'learning_rate': 0.07898410989199656, 'min_child_samples': 225}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:34:22,382] Trial 149 finished with value: 0.22792022792022792 and parameters: {'n_estimators': 2114, 'num_leaves': 2996, 'max_depth': 429, 'learning_rate': 0.09778026737132581, 'min_child_samples': 238}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:36:26,381] Trial 150 finished with value: 0.22096317280453256 and parameters: {'n_estimators': 2030, 'num_leaves': 3078, 'max_depth': 419, 'learning_rate': 0.085005084173567, 'min_child_samples': 247}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:39:00,252] Trial 151 finished with value: 0.2244318181818182 and parameters: {'n_estimators': 2214, 'num_leaves': 3131, 'max_depth': 399, 'learning_rate': 0.07095477544791239, 'min_child_samples': 227}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:41:12,564] Trial 152 finished with value: 0.23055555555555554 and parameters: {'n_estimators': 2122, 'num_leaves': 3051, 'max_depth': 441, 'learning_rate': 0.07923295985854811, 'min_child_samples': 241}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:43:44,654] Trial 153 finished with value: 0.22792022792022792 and parameters: {'n_estimators': 2285, 'num_leaves': 3198, 'max_depth': 393, 'learning_rate': 0.057007701347524434, 'min_child_samples': 232}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:46:10,450] Trial 154 finished with value: 0.21428571428571427 and parameters: {'n_estimators': 2153, 'num_leaves': 2949, 'max_depth': 433, 'learning_rate': 0.10575105404063598, 'min_child_samples': 252}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:48:28,762] Trial 155 finished with value: 0.22824536376604848 and parameters: {'n_estimators': 2073, 'num_leaves': 3002, 'max_depth': 423, 'learning_rate': 0.138209480991886, 'min_child_samples': 221}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:50:29,337] Trial 156 finished with value: 0.23579545454545453 and parameters: {'n_estimators': 1980, 'num_leaves': 3099, 'max_depth': 429, 'learning_rate': 0.06646743289191426, 'min_child_samples': 230}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:52:56,809] Trial 157 finished with value: 0.2158273381294964 and parameters: {'n_estimators': 2212, 'num_leaves': 2863, 'max_depth': 359, 'learning_rate': 0.07305097988820028, 'min_child_samples': 216}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:54:55,580] Trial 158 finished with value: 0.2303206997084548 and parameters: {'n_estimators': 2010, 'num_leaves': 3156, 'max_depth': 410, 'learning_rate': 0.047451300350408517, 'min_child_samples': 236}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:57:20,128] Trial 159 finished with value: 0.22720897615708274 and parameters: {'n_estimators': 2258, 'num_leaves': 3035, 'max_depth': 383, 'learning_rate': 0.05635157730516885, 'min_child_samples': 222}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 03:59:40,290] Trial 160 finished with value: 0.22865853658536586 and parameters: {'n_estimators': 2096, 'num_leaves': 2890, 'max_depth': 404, 'learning_rate': 0.030394572272965308, 'min_child_samples': 211}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 04:01:46,048] Trial 161 finished with value: 0.2306569343065693 and parameters: {'n_estimators': 1959, 'num_leaves': 3106, 'max_depth': 432, 'learning_rate': 0.06729575657641321, 'min_child_samples': 234}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 04:04:06,251] Trial 162 finished with value: 0.23011363636363638 and parameters: {'n_estimators': 2045, 'num_leaves': 3103, 'max_depth': 440, 'learning_rate': 0.07784013410270701, 'min_child_samples': 229}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 04:06:35,741] Trial 163 finished with value: 0.21870503597122304 and parameters: {'n_estimators': 2179, 'num_leaves': 2977, 'max_depth': 419, 'learning_rate': 0.06486418851696302, 'min_child_samples': 225}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 04:08:47,306] Trial 164 finished with value: 0.22784810126582278 and parameters: {'n_estimators': 1993, 'num_leaves': 3074, 'max_depth': 426, 'learning_rate': 0.0883922370149054, 'min_child_samples': 243}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 04:11:26,465] Trial 165 finished with value: 0.2244318181818182 and parameters: {'n_estimators': 2132, 'num_leaves': 3171, 'max_depth': 450, 'learning_rate': 0.07095782858910014, 'min_child_samples': 226}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 04:13:36,529] Trial 166 finished with value: 0.2293178519593614 and parameters: {'n_estimators': 1946, 'num_leaves': 3235, 'max_depth': 441, 'learning_rate': 0.0514986125127367, 'min_child_samples': 214}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 04:16:22,423] Trial 167 finished with value: 0.22773722627737225 and parameters: {'n_estimators': 2074, 'num_leaves': 3015, 'max_depth': 391, 'learning_rate': 0.04052814478329747, 'min_child_samples': 162}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 04:18:37,639] Trial 168 finished with value: 0.2330935251798561 and parameters: {'n_estimators': 2235, 'num_leaves': 2925, 'max_depth': 429, 'learning_rate': 0.06192322801382454, 'min_child_samples': 263}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 04:21:20,241] Trial 169 finished with value: 0.2277777777777778 and parameters: {'n_estimators': 2296, 'num_leaves': 3047, 'max_depth': 414, 'learning_rate': 0.08394245297980721, 'min_child_samples': 238}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 04:23:53,030] Trial 170 finished with value: 0.2339514978601997 and parameters: {'n_estimators': 2173, 'num_leaves': 3095, 'max_depth': 239, 'learning_rate': 0.04630502337094235, 'min_child_samples': 214}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 04:25:54,262] Trial 171 finished with value: 0.23529411764705882 and parameters: {'n_estimators': 1588, 'num_leaves': 3203, 'max_depth': 130, 'learning_rate': 0.07269203650394643, 'min_child_samples': 185}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 04:28:04,660] Trial 172 finished with value: 0.2285714285714286 and parameters: {'n_estimators': 2004, 'num_leaves': 3325, 'max_depth': 436, 'learning_rate': 0.05587296933773227, 'min_child_samples': 197}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 04:31:03,367] Trial 173 finished with value: 0.22448979591836735 and parameters: {'n_estimators': 2107, 'num_leaves': 2956, 'max_depth': 272, 'learning_rate': 0.06639923029878736, 'min_child_samples': 147}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 04:32:31,256] Trial 174 finished with value: 0.23209169054441262 and parameters: {'n_estimators': 1505, 'num_leaves': 3135, 'max_depth': 253, 'learning_rate': 0.07779066655794328, 'min_child_samples': 267}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 04:34:14,710] Trial 175 finished with value: 0.22889842632331903 and parameters: {'n_estimators': 1620, 'num_leaves': 3271, 'max_depth': 420, 'learning_rate': 0.06019271525416428, 'min_child_samples': 219}. Best is trial 13 with value: 0.24347826086956517.
# [I 2024-08-22 04:36:17,076] Trial 176 finished with value: 0.22254335260115607 and parameters: {'n_estimators': 2048, 'num_leaves': 3024, 'max_depth': 245, 'learning_rate': 0.051826016293084955, 'min_child_samples': 247}. Best is trial 13 with value: 0.24347826086956517.
# ...
# [I 2024-08-22 08:17:10,325] Trial 268 finished with value: 0.2432045779685265 and parameters: {'n_estimators': 2198, 'num_leaves': 3059, 'max_depth': 438, 'learning_rate': 0.05887822382199991, 'min_child_samples': 203}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 08:18:37,195] Trial 269 finished with value: 0.2354651162790697 and parameters: {'n_estimators': 1448, 'num_leaves': 3073, 'max_depth': 440, 'learning_rate': 0.059233523311982214, 'min_child_samples': 203}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 08:20:55,147] Trial 270 finished with value: 0.22031473533619458 and parameters: {'n_estimators': 2189, 'num_leaves': 3138, 'max_depth': 450, 'learning_rate': 0.06428880502417086, 'min_child_samples': 205}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 08:23:21,179] Trial 271 finished with value: 0.2222222222222222 and parameters: {'n_estimators': 2234, 'num_leaves': 3133, 'max_depth': 422, 'learning_rate': 0.05637549607820437, 'min_child_samples': 198}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 08:25:29,266] Trial 272 finished with value: 0.24022346368715083 and parameters: {'n_estimators': 2179, 'num_leaves': 3092, 'max_depth': 433, 'learning_rate': 0.0692811090271057, 'min_child_samples': 221}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 08:27:50,029] Trial 273 finished with value: 0.22784810126582278 and parameters: {'n_estimators': 2267, 'num_leaves': 3061, 'max_depth': 430, 'learning_rate': 0.07078954900076237, 'min_child_samples': 217}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 08:30:06,033] Trial 274 finished with value: 0.23196605374823195 and parameters: {'n_estimators': 2193, 'num_leaves': 2974, 'max_depth': 436, 'learning_rate': 0.0695613536541358, 'min_child_samples': 222}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 08:31:54,086] Trial 275 finished with value: 0.21103896103896103 and parameters: {'n_estimators': 2168, 'num_leaves': 3071, 'max_depth': 420, 'learning_rate': 0.02184809961709984, 'min_child_samples': 229}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 08:33:51,143] Trial 276 finished with value: 0.22026431718061676 and parameters: {'n_estimators': 2230, 'num_leaves': 2923, 'max_depth': 430, 'learning_rate': 0.03611421821365289, 'min_child_samples': 213}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 08:36:03,618] Trial 277 finished with value: 0.21968616262482166 and parameters: {'n_estimators': 2186, 'num_leaves': 3032, 'max_depth': 439, 'learning_rate': 0.06492466832048807, 'min_child_samples': 220}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 08:38:39,905] Trial 278 finished with value: 0.22784810126582278 and parameters: {'n_estimators': 2124, 'num_leaves': 2999, 'max_depth': 424, 'learning_rate': 0.07179773305472906, 'min_child_samples': 228}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 08:40:13,316] Trial 279 finished with value: 0.2302158273381295 and parameters: {'n_estimators': 1804, 'num_leaves': 3099, 'max_depth': 411, 'learning_rate': 0.061297138170634397, 'min_child_samples': 234}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 08:41:57,824] Trial 280 finished with value: 0.23338257016248154 and parameters: {'n_estimators': 2054, 'num_leaves': 2943, 'max_depth': 281, 'learning_rate': 0.043486778497096805, 'min_child_samples': 246}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 08:45:19,580] Trial 281 finished with value: 0.2198142414860681 and parameters: {'n_estimators': 1967, 'num_leaves': 3048, 'max_depth': 293, 'learning_rate': 0.07673863590947944, 'min_child_samples': 83}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 08:47:31,771] Trial 282 finished with value: 0.23665223665223664 and parameters: {'n_estimators': 2270, 'num_leaves': 3175, 'max_depth': 435, 'learning_rate': 0.20241715318898987, 'min_child_samples': 224}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 08:49:45,520] Trial 283 finished with value: 0.2306569343065693 and parameters: {'n_estimators': 2158, 'num_leaves': 3009, 'max_depth': 440, 'learning_rate': 0.048530119812807276, 'min_child_samples': 232}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 08:51:52,051] Trial 284 finished with value: 0.20790629575402636 and parameters: {'n_estimators': 1879, 'num_leaves': 3083, 'max_depth': 428, 'learning_rate': 0.2881162951759043, 'min_child_samples': 210}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 08:53:51,044] Trial 285 finished with value: 0.2225475841874085 and parameters: {'n_estimators': 2206, 'num_leaves': 2970, 'max_depth': 442, 'learning_rate': 0.03675577585557355, 'min_child_samples': 219}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 08:56:14,827] Trial 286 finished with value: 0.2420749279538905 and parameters: {'n_estimators': 2115, 'num_leaves': 2898, 'max_depth': 433, 'learning_rate': 0.05303110727772867, 'min_child_samples': 195}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 08:58:29,346] Trial 287 finished with value: 0.22603719599427755 and parameters: {'n_estimators': 2024, 'num_leaves': 2942, 'max_depth': 420, 'learning_rate': 0.053596113214472635, 'min_child_samples': 196}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 09:01:37,237] Trial 288 finished with value: 0.22507122507122507 and parameters: {'n_estimators': 2912, 'num_leaves': 2923, 'max_depth': 431, 'learning_rate': 0.06183933946891872, 'min_child_samples': 194}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 09:03:56,139] Trial 289 finished with value: 0.2302158273381295 and parameters: {'n_estimators': 2131, 'num_leaves': 2877, 'max_depth': 407, 'learning_rate': 0.043496264215834246, 'min_child_samples': 187}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 09:06:09,258] Trial 290 finished with value: 0.22891566265060243 and parameters: {'n_estimators': 2307, 'num_leaves': 2831, 'max_depth': 450, 'learning_rate': 0.028929984645959767, 'min_child_samples': 211}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 09:10:10,839] Trial 291 finished with value: 0.21470588235294116 and parameters: {'n_estimators': 3299, 'num_leaves': 2894, 'max_depth': 440, 'learning_rate': 0.12807270177109875, 'min_child_samples': 199}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 09:12:11,119] Trial 292 finished with value: 0.2322946175637394 and parameters: {'n_estimators': 2244, 'num_leaves': 2977, 'max_depth': 396, 'learning_rate': 0.051423248708971435, 'min_child_samples': 224}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 09:14:14,968] Trial 293 finished with value: 0.2302158273381295 and parameters: {'n_estimators': 2172, 'num_leaves': 3140, 'max_depth': 426, 'learning_rate': 0.057336242688949726, 'min_child_samples': 229}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 09:15:50,284] Trial 294 finished with value: 0.23600605143721634 and parameters: {'n_estimators': 1605, 'num_leaves': 3049, 'max_depth': 443, 'learning_rate': 0.04696309932944987, 'min_child_samples': 218}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 09:17:55,137] Trial 295 finished with value: 0.23154848046309698 and parameters: {'n_estimators': 2056, 'num_leaves': 3098, 'max_depth': 433, 'learning_rate': 0.04188493355176699, 'min_child_samples': 191}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 09:19:51,737] Trial 296 finished with value: 0.2378223495702006 and parameters: {'n_estimators': 2106, 'num_leaves': 3025, 'max_depth': 384, 'learning_rate': 0.06062067265449383, 'min_child_samples': 236}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 09:21:53,057] Trial 297 finished with value: 0.23209169054441262 and parameters: {'n_estimators': 2103, 'num_leaves': 3018, 'max_depth': 403, 'learning_rate': 0.06199704806339454, 'min_child_samples': 236}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 09:23:50,765] Trial 298 finished with value: 0.2293178519593614 and parameters: {'n_estimators': 1988, 'num_leaves': 3302, 'max_depth': 387, 'learning_rate': 0.05427507748757835, 'min_child_samples': 244}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 09:25:57,163] Trial 299 finished with value: 0.22190611664295876 and parameters: {'n_estimators': 2053, 'num_leaves': 2974, 'max_depth': 380, 'learning_rate': 0.05792753529923592, 'min_child_samples': 205}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 09:28:12,466] Trial 300 finished with value: 0.22189781021897811 and parameters: {'n_estimators': 2113, 'num_leaves': 2931, 'max_depth': 373, 'learning_rate': 0.04922053701616859, 'min_child_samples': 197}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 09:30:04,927] Trial 301 finished with value: 0.22031473533619458 and parameters: {'n_estimators': 2028, 'num_leaves': 3052, 'max_depth': 413, 'learning_rate': 0.1399676888478474, 'min_child_samples': 235}. Best is trial 212 with value: 0.24501424501424504.
# [I 2024-08-22 09:32:11,299] Trial 302 finished with value: 0.23661971830985915 and parameters: {'n_estimators': 2076, 'num_leaves': 3004, 'max_depth': 267, 'learning_rate': 0.06732299996166273, 'min_child_samples': 183}. Best is trial 212 with value: 0.24501424501424504.
# [W 2024-08-22 09:33:40,120] Trial 303 failed with parameters: {'n_estimators': 2141, 'num_leaves': 3398, 'max_depth': 220, 'learning_rate': 0.038539633585979505, 'min_child_samples': 251} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\juneh\AppData\Local\Temp\ipykernel_3680\3856132583.py", line 43, in <lambda>
#     study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=400)
#   File "C:\Users\juneh\AppData\Local\Temp\ipykernel_3680\3856132583.py", line 24, in objectiveLGBM_dart
#     model.fit(x_tr, y_tr)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py", line 1298, in fit
#     init_model=init_model,
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py", line 963, in fit
#     callbacks=callbacks,
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\engine.py", line 307, in train
#     booster.update(fobj=fobj)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\basic.py", line 4138, in update
#     ctypes.byref(is_finished),
# KeyboardInterrupt
# [W 2024-08-22 09:33:40,197] Trial 303 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3680\3856132583.py in <module>
#      41 # 하이퍼 파라미터 튜닝
#      42 study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# ---> 43 study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=400)
#      44
#      45 print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     458             callbacks=callbacks,
#     459             gc_after_trial=gc_after_trial,
# --> 460             show_progress_bar=show_progress_bar,
#     461         )
#     462
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      70                 reseed_sampler_rng=False,
#      71                 time_start=None,
# ---> 72                 progress_bar=progress_bar,
#      73             )
#      74         else:
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157
#     158         try:
# --> 159             frozen_trial = _run_trial(study, func, catch)
#     160         finally:
#     161             # The following line mitigates memory problems that can be occurred in some
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _run_trial(study, func, catch)
#     245         and not isinstance(func_err, catch)
#     246     ):
# --> 247         raise func_err
#     248     return frozen_trial
#     249
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _run_trial(study, func, catch)
#     194     with get_heartbeat_thread(trial._trial_id, study._storage):
#     195         try:
# --> 196             value_or_values = func(trial)
#     197         except exceptions.TrialPruned as e:
#     198             # TODO(mamu): Handle multi-objective cases.
#
# ~\AppData\Local\Temp\ipykernel_3680\3856132583.py in <lambda>(trial)
#      41 # 하이퍼 파라미터 튜닝
#      42 study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# ---> 43 study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=400)
#      44
#      45 print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
#
# ~\AppData\Local\Temp\ipykernel_3680\3856132583.py in objectiveLGBM_dart(trial, x_tr, y_tr, x_val, y_val)
#      22
#      23     model = LGBMClassifier(**param)
# ---> 24     model.fit(x_tr, y_tr)
#      25     pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
#      26     pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1296             categorical_feature=categorical_feature,
#    1297             callbacks=callbacks,
# -> 1298             init_model=init_model,
#    1299         )
#    1300         return self
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#     961             feval=eval_metrics_callable,  # type: ignore[arg-type]
#     962             init_model=init_model,
# --> 963             callbacks=callbacks,
#     964         )
#     965
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, feature_name, categorical_feature, keep_training_booster, callbacks)
#     305             )
#     306
# --> 307         booster.update(fobj=fobj)
#     308
#     309         evaluation_result_list: List[_LGBM_BoosterEvalMethodResultType] = []
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    4136                 _LIB.LGBM_BoosterUpdateOneIter(
#    4137                     self._handle,
# -> 4138                     ctypes.byref(is_finished),
#    4139                 )
#    4140             )
#
# KeyboardInterrupt:

# %% [markdown]
# .
