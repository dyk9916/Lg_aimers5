# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ### 데이터 읽어오기

# %%
import os
from pprint import pprint

import optuna
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import pandas as pd

RANDOM_STATE = 110

train_data = pd.read_csv("C:/Users/KimDongyoung/Desktop/git_LGaimers5/Lg_aimers5/data/train_data_0817.csv")
test_data = pd.read_csv("C:/Users/KimDongyoung/Desktop/git_LGaimers5/Lg_aimers5/data/test_data_0817.csv")

# %%
# dam, fill1, fill2 공통 변수
var_dam_fill = [
    'Equipment_same_num',
    'PalletID_Collect_Result_encoded',
    'Production_Qty_Collect_Result',
    'WorkMode Collect Result'
]

# %%
# 전체 공통 변수
### correlation 확인을 위한 변수 리스트
var_all_corr = [
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### train
var_all_train = [
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### test
var_all_test = [
    'Set ID',
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

# %%
# '_Dam'을 포함하는 변수 선택
dam_variables = [var for var in train_data.columns if '_Dam' in var]

# train
final_columns_train = var_dam_fill + var_all_train + dam_variables
train_data_dam = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + dam_variables
test_data_dam = test_data[final_columns_test]

# %%
# '_Fill1'을 포함하는 변수 선택
fill1_variables = [var for var in train_data.columns if '_Fill1' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill1_variables
train_data_fill1 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill1_variables
test_data_fill1 = test_data[final_columns_test]

# %%
# '_Fill2'을 포함하는 변수 선택
fill2_variables = [var for var in train_data.columns if '_Fill2' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill2_variables
train_data_fill2 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill2_variables
test_data_fill2 = test_data[final_columns_test]

# %%
# '_AutoClave'을 포함하는 변수 선택
autoclave_variables = [var for var in train_data.columns if '_AutoClave' in var]

# train
final_columns_train = var_all_train + autoclave_variables
train_data_autoclave = train_data[final_columns_train]

# test 
final_columns_test = var_all_test + autoclave_variables
test_data_autoclave = test_data[final_columns_test]

# %%
# 각 DataFrame의 칼럼 수 계산
num_columns_train_data = train_data.shape[1]
num_columns_train_data_dam = train_data_dam.shape[1]
num_columns_train_data_autoclave = train_data_autoclave.shape[1]
num_columns_train_data_fill1 = train_data_fill1.shape[1]
num_columns_train_data_fill2 = train_data_fill2.shape[1]

num_columns_test_data = test_data.shape[1]
num_columns_test_data_dam = test_data_dam.shape[1]
num_columns_test_data_autoclave = test_data_autoclave.shape[1]
num_columns_test_data_fill1 = test_data_fill1.shape[1]
num_columns_test_data_fill2 = test_data_fill2.shape[1]

# 각 DataFrame의 칼럼 수 출력
print("----train data-----")
print(f"train_data DataFrame의 칼럼 수: {num_columns_train_data}")
print(f"train_data_dam DataFrame의 칼럼 수: {num_columns_train_data_dam}")
print(f"train_data_autoclave DataFrame의 칼럼 수: {num_columns_train_data_autoclave}")
print(f"train_data_fill1 DataFrame의 칼럼 수: {num_columns_train_data_fill1}")
print(f"train_data_fill2 DataFrame의 칼럼 수: {num_columns_train_data_fill2}")
print("----test data-----")
print(f"test_data DataFrame의 칼럼 수: {num_columns_test_data}")
print(f"test_data_dam DataFrame의 칼럼 수: {num_columns_test_data_dam}")
print(f"test_data_autoclave DataFrame의 칼럼 수: {num_columns_test_data_autoclave}")
print(f"test_data_fill1 DataFrame의 칼럼 수: {num_columns_test_data_fill1}")
print(f"test_data_fill2 DataFrame의 칼럼 수: {num_columns_test_data_fill2}")
# Out:
# ----train data-----
# train_data DataFrame의 칼럼 수: 38
# train_data_dam DataFrame의 칼럼 수: 21
# train_data_autoclave DataFrame의 칼럼 수: 8
# train_data_fill1 DataFrame의 칼럼 수: 13
# train_data_fill2 DataFrame의 칼럼 수: 13
# ----test data-----
# test_data DataFrame의 칼럼 수: 39
# test_data_dam DataFrame의 칼럼 수: 22
# test_data_autoclave DataFrame의 칼럼 수: 9
# test_data_fill1 DataFrame의 칼럼 수: 14
# test_data_fill2 DataFrame의 칼럼 수: 14

# %% [markdown]
# ---

# %% [markdown]
# ## Optuna

# %% [markdown]
# 스레스홀드 0.3으로 맞춘상태에서 튜닝 진행한 것

# %%
import optuna
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# # 'Normal'과 'AbNormal'을 숫자로 변환
# train_data_autoclave['target'] = train_data_autoclave['target'].map({'Normal': 0, 'AbNormal': 1})

# # 스레드홀드 설정
# THRESHOLD = 0.3

# def objectiveCatBoost(trial, x_tr, y_tr, x_val, y_val):
#     param = {
#         'iterations': trial.suggest_int('iterations', 400, 1500),
#         'learning_rate': trial.suggest_float('learning_rate', 0.05, 0.4),
#         'depth': trial.suggest_int('depth', 3, 14),
#         'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 0.05, 5.0, log=True),
#         'random_strength': trial.suggest_float('random_strength', 0.1, 10.0),
#         'bagging_temperature': trial.suggest_float('bagging_temperature', 0.1, 10.0),
#         'border_count': trial.suggest_int('border_count', 70, 270),
#         'scale_pos_weight': trial.suggest_float('scale_pos_weight', 0.5, 1.2),

#         'random_seed': RANDOM_STATE,
#         'eval_metric': 'F1',
#         'logging_level': 'Silent',
#         'boosting_type': 'Plain'
#     }

#     model = CatBoostClassifier(**param)
#     model.fit(x_tr, y_tr)
#     pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
#     pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
    
#     score = f1_score(y_val, pred, average="binary")
    
#     return score

# # 데이터셋 분할
# x_train, x_val, y_train, y_val = train_test_split(
#     train_data_autoclave.drop("target", axis=1),
#     train_data_autoclave["target"],
#     test_size=0.2,
#     shuffle=True,
#     random_state=RANDOM_STATE,
# )

# # 하이퍼 파라미터 튜닝
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# study.optimize(lambda trial: objectiveCatBoost(trial, x_train, y_train, x_val, y_val), n_trials=400)

# print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))

# %% [markdown]
# Best trial: score 0.24064171122994654
#
# params {'iterations': 450, 'learning_rate': 0.06854262717305015, 'depth': 13, 'l2_leaf_reg': 2.970970133660733, 'random_strength': 7.94120999246848, 'bagging_temperature': 4.986780027003433, 'border_count': 266, 'scale_pos_weight': 1.1850883939124812}

# %%
# 스레드홀드 설정
THRESHOLD = 0.3

# 모델 설정 및 하이퍼파라미터
models = {
    'et': ExtraTreesClassifier(),
    'rf': RandomForestClassifier(),
    'cat': CatBoostClassifier(),
    'lgbm': LGBMClassifier(),
    'xgb': XGBClassifier(),
    'dt': DecisionTreeClassifier()
}

def train_and_evaluate_model(model_name, data, **params):
    if model_name not in models:
        print(f"{model_name}은(는) 지원되지 않는 모델입니다.")
        return
    
    # 데이터셋 분할
    x_train, x_val, y_train, y_val = train_test_split(
        data.drop("target", axis=1),
        data["target"].map({'Normal': 0, 'AbNormal': 1}),
        test_size=0.2,
        shuffle=True,
        random_state=RANDOM_STATE,
    )

    # 모델 선택
    model = models[model_name]

    # 하이퍼파라미터 설정
    model.set_params(**params)

    # 모델 학습
    model.fit(x_train, y_train)

    # 데이터 이름을 자동으로 추출하기 위한 래퍼 함수
    data_name = [name for name in globals() if globals()[name] is data][0]

    # 예측
    y_val_pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
    y_val_pred = (y_val_pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측

    # 평가지표 계산
    f1 = f1_score(y_val, y_val_pred, average="binary")
    accuracy = accuracy_score(y_val, y_val_pred)
    precision = precision_score(y_val, y_val_pred)
    recall = recall_score(y_val, y_val_pred)
    conf_matrix = confusion_matrix(y_val, y_val_pred)
    
    # 결과 출력
    print(f'{model_name} 모델이 {data_name} 데이터로 학습한 결과:')
    print(f'F1 Score: {f1}')
    #print('---')
    #print('Confusion Matrix:')
    #print(conf_matrix)
    #print('---')
    #print(f'Accuracy: {accuracy}')
    #print(f'Precision: {precision}')
    #print(f'Recall: {recall}')
    #print('\n')

# %%
train_and_evaluate_model(
    'cat', train_data_autoclave,
    iterations = 450, 
    learning_rate = 0.06854262717305015, 
    depth = 13, 
    l2_leaf_reg = 2.970970133660733, 
    random_strength = 7.94120999246848, 
    bagging_temperature = 4.986780027003433, 
    border_count = 266, 
    scale_pos_weight = 1.1850883939124812,
    random_state=RANDOM_STATE
)
# Out:
# 0:	learn: 0.6069902	total: 289ms	remaining: 2m 9s
# 1:	learn: 0.5378393	total: 579ms	remaining: 2m 9s
# 2:	learn: 0.4876653	total: 652ms	remaining: 1m 37s
# 3:	learn: 0.4413528	total: 917ms	remaining: 1m 42s
# 4:	learn: 0.4068939	total: 1.19s	remaining: 1m 46s
# 5:	learn: 0.3761855	total: 1.47s	remaining: 1m 48s
# 6:	learn: 0.3513734	total: 1.75s	remaining: 1m 50s
# 7:	learn: 0.3305050	total: 2.03s	remaining: 1m 52s
# 8:	learn: 0.3115350	total: 2.29s	remaining: 1m 52s
# 9:	learn: 0.2987197	total: 2.55s	remaining: 1m 52s
# 10:	learn: 0.2868160	total: 2.81s	remaining: 1m 52s
# 11:	learn: 0.2769495	total: 3.08s	remaining: 1m 52s
# 12:	learn: 0.2686519	total: 3.19s	remaining: 1m 47s
# 13:	learn: 0.2625327	total: 3.47s	remaining: 1m 47s
# 14:	learn: 0.2561043	total: 3.75s	remaining: 1m 48s
# 15:	learn: 0.2511724	total: 4.02s	remaining: 1m 49s
# 16:	learn: 0.2464907	total: 4.28s	remaining: 1m 48s
# 17:	learn: 0.2430534	total: 4.53s	remaining: 1m 48s
# 18:	learn: 0.2397752	total: 4.74s	remaining: 1m 47s
# 19:	learn: 0.2370414	total: 5.01s	remaining: 1m 47s
# 20:	learn: 0.2347959	total: 5.06s	remaining: 1m 43s
# 21:	learn: 0.2332950	total: 5.33s	remaining: 1m 43s
# 22:	learn: 0.2316323	total: 5.62s	remaining: 1m 44s
# 23:	learn: 0.2302852	total: 5.65s	remaining: 1m 40s
# 24:	learn: 0.2291513	total: 5.72s	remaining: 1m 37s
# 25:	learn: 0.2281252	total: 5.77s	remaining: 1m 34s
# 26:	learn: 0.2274910	total: 5.8s	remaining: 1m 30s
# 27:	learn: 0.2261988	total: 6.07s	remaining: 1m 31s
# 28:	learn: 0.2255334	total: 6.1s	remaining: 1m 28s
# 29:	learn: 0.2249655	total: 6.37s	remaining: 1m 29s
# 30:	learn: 0.2242102	total: 6.47s	remaining: 1m 27s
# 31:	learn: 0.2234314	total: 6.75s	remaining: 1m 28s
# 32:	learn: 0.2229299	total: 7.03s	remaining: 1m 28s
# 33:	learn: 0.2222797	total: 7.29s	remaining: 1m 29s
# 34:	learn: 0.2218291	total: 7.57s	remaining: 1m 29s
# 35:	learn: 0.2214648	total: 7.67s	remaining: 1m 28s
# 36:	learn: 0.2210614	total: 7.93s	remaining: 1m 28s
# 37:	learn: 0.2207968	total: 8.22s	remaining: 1m 29s
# 38:	learn: 0.2205055	total: 8.32s	remaining: 1m 27s
# 39:	learn: 0.2202677	total: 8.35s	remaining: 1m 25s
# 40:	learn: 0.2199956	total: 8.64s	remaining: 1m 26s
# 41:	learn: 0.2197125	total: 8.91s	remaining: 1m 26s
# 42:	learn: 0.2196625	total: 8.94s	remaining: 1m 24s
# 43:	learn: 0.2195096	total: 9.23s	remaining: 1m 25s
# 44:	learn: 0.2191016	total: 9.51s	remaining: 1m 25s
# 45:	learn: 0.2188730	total: 9.77s	remaining: 1m 25s
# 46:	learn: 0.2186616	total: 10s	remaining: 1m 25s
# 47:	learn: 0.2184469	total: 10.3s	remaining: 1m 26s
# 48:	learn: 0.2183273	total: 10.3s	remaining: 1m 24s
# 49:	learn: 0.2182047	total: 10.6s	remaining: 1m 24s
# 50:	learn: 0.2179097	total: 10.9s	remaining: 1m 24s
# 51:	learn: 0.2178329	total: 11.1s	remaining: 1m 24s
# 52:	learn: 0.2176302	total: 11.3s	remaining: 1m 24s
# 53:	learn: 0.2173522	total: 11.6s	remaining: 1m 24s
# 54:	learn: 0.2171829	total: 11.8s	remaining: 1m 25s
# 55:	learn: 0.2169864	total: 12.1s	remaining: 1m 25s
# 56:	learn: 0.2167829	total: 12.4s	remaining: 1m 25s
# 57:	learn: 0.2167588	total: 12.4s	remaining: 1m 23s
# 58:	learn: 0.2164588	total: 12.7s	remaining: 1m 24s
# 59:	learn: 0.2162484	total: 12.7s	remaining: 1m 22s
# 60:	learn: 0.2158131	total: 13s	remaining: 1m 22s
# 61:	learn: 0.2157168	total: 13.3s	remaining: 1m 22s
# 62:	learn: 0.2155890	total: 13.5s	remaining: 1m 23s
# 63:	learn: 0.2155147	total: 13.9s	remaining: 1m 23s
# 64:	learn: 0.2154812	total: 13.9s	remaining: 1m 22s
# 65:	learn: 0.2153607	total: 14.2s	remaining: 1m 22s
# 66:	learn: 0.2152738	total: 14.5s	remaining: 1m 23s
# 67:	learn: 0.2149121	total: 14.8s	remaining: 1m 23s
# 68:	learn: 0.2146676	total: 15.1s	remaining: 1m 23s
# 69:	learn: 0.2145019	total: 15.4s	remaining: 1m 23s
# 70:	learn: 0.2144729	total: 15.4s	remaining: 1m 22s
# 71:	learn: 0.2142925	total: 15.7s	remaining: 1m 22s
# 72:	learn: 0.2141759	total: 15.8s	remaining: 1m 21s
# 73:	learn: 0.2141257	total: 16.1s	remaining: 1m 21s
# 74:	learn: 0.2140521	total: 16.1s	remaining: 1m 20s
# 75:	learn: 0.2139942	total: 16.4s	remaining: 1m 20s
# 76:	learn: 0.2138852	total: 16.7s	remaining: 1m 21s
# 77:	learn: 0.2137163	total: 17.1s	remaining: 1m 21s
# 78:	learn: 0.2136654	total: 17.1s	remaining: 1m 20s
# 79:	learn: 0.2135551	total: 17.2s	remaining: 1m 19s
# 80:	learn: 0.2135285	total: 17.4s	remaining: 1m 19s
# 81:	learn: 0.2134379	total: 17.7s	remaining: 1m 19s
# 82:	learn: 0.2131652	total: 18s	remaining: 1m 19s
# 83:	learn: 0.2131480	total: 18.1s	remaining: 1m 18s
# 84:	learn: 0.2130931	total: 18.2s	remaining: 1m 18s
# 85:	learn: 0.2130521	total: 18.4s	remaining: 1m 18s
# 86:	learn: 0.2128462	total: 18.7s	remaining: 1m 18s
# 87:	learn: 0.2127893	total: 19s	remaining: 1m 18s
# 88:	learn: 0.2127017	total: 19.3s	remaining: 1m 18s
# 89:	learn: 0.2122340	total: 19.6s	remaining: 1m 18s
# 90:	learn: 0.2118626	total: 19.9s	remaining: 1m 18s
# 91:	learn: 0.2117447	total: 20.1s	remaining: 1m 18s
# 92:	learn: 0.2117233	total: 20.3s	remaining: 1m 18s
# 93:	learn: 0.2116064	total: 20.6s	remaining: 1m 18s
# 94:	learn: 0.2115977	total: 20.6s	remaining: 1m 17s
# 95:	learn: 0.2113583	total: 20.9s	remaining: 1m 17s
# 96:	learn: 0.2112796	total: 21.2s	remaining: 1m 17s
# 97:	learn: 0.2111600	total: 21.4s	remaining: 1m 17s
# 98:	learn: 0.2108758	total: 21.7s	remaining: 1m 17s
# 99:	learn: 0.2108025	total: 22s	remaining: 1m 17s
# 100:	learn: 0.2104329	total: 22.3s	remaining: 1m 17s
# 101:	learn: 0.2102895	total: 22.6s	remaining: 1m 17s
# 102:	learn: 0.2100343	total: 22.9s	remaining: 1m 17s
# 103:	learn: 0.2099894	total: 23s	remaining: 1m 16s
# 104:	learn: 0.2099623	total: 23.2s	remaining: 1m 16s
# 105:	learn: 0.2097848	total: 23.4s	remaining: 1m 16s
# 106:	learn: 0.2097807	total: 23.4s	remaining: 1m 15s
# 107:	learn: 0.2097670	total: 23.5s	remaining: 1m 14s
# 108:	learn: 0.2094600	total: 23.6s	remaining: 1m 13s
# 109:	learn: 0.2093599	total: 23.9s	remaining: 1m 13s
# 110:	learn: 0.2093204	total: 24.2s	remaining: 1m 13s
# 111:	learn: 0.2091850	total: 24.5s	remaining: 1m 13s
# 112:	learn: 0.2091248	total: 24.7s	remaining: 1m 13s
# 113:	learn: 0.2090316	total: 25s	remaining: 1m 13s
# 114:	learn: 0.2090120	total: 25.2s	remaining: 1m 13s
# 115:	learn: 0.2089444	total: 25.5s	remaining: 1m 13s
# 116:	learn: 0.2088856	total: 25.8s	remaining: 1m 13s
# 117:	learn: 0.2088587	total: 25.9s	remaining: 1m 12s
# 118:	learn: 0.2088393	total: 26s	remaining: 1m 12s
# 119:	learn: 0.2087144	total: 26.2s	remaining: 1m 12s
# 120:	learn: 0.2086607	total: 26.5s	remaining: 1m 12s
# 121:	learn: 0.2085513	total: 26.8s	remaining: 1m 12s
# 122:	learn: 0.2085493	total: 26.8s	remaining: 1m 11s
# 123:	learn: 0.2084880	total: 27.1s	remaining: 1m 11s
# 124:	learn: 0.2084395	total: 27.3s	remaining: 1m 11s
# 125:	learn: 0.2082640	total: 27.6s	remaining: 1m 10s
# 126:	learn: 0.2081399	total: 27.6s	remaining: 1m 10s
# 127:	learn: 0.2080691	total: 27.9s	remaining: 1m 10s
# 128:	learn: 0.2079637	total: 28.1s	remaining: 1m 9s
# 129:	learn: 0.2078692	total: 28.4s	remaining: 1m 9s
# 130:	learn: 0.2076338	total: 28.6s	remaining: 1m 9s
# 131:	learn: 0.2074251	total: 28.9s	remaining: 1m 9s
# 132:	learn: 0.2073187	total: 29.2s	remaining: 1m 9s
# 133:	learn: 0.2072076	total: 29.4s	remaining: 1m 9s
# 134:	learn: 0.2069085	total: 29.7s	remaining: 1m 9s
# 135:	learn: 0.2068496	total: 30s	remaining: 1m 9s
# 136:	learn: 0.2065898	total: 30.2s	remaining: 1m 9s
# 137:	learn: 0.2065545	total: 30.3s	remaining: 1m 8s
# 138:	learn: 0.2064967	total: 30.5s	remaining: 1m 8s
# 139:	learn: 0.2061825	total: 30.8s	remaining: 1m 8s
# 140:	learn: 0.2061241	total: 30.8s	remaining: 1m 7s
# 141:	learn: 0.2060483	total: 31.1s	remaining: 1m 7s
# 142:	learn: 0.2059347	total: 31.4s	remaining: 1m 7s
# 143:	learn: 0.2055357	total: 31.7s	remaining: 1m 7s
# 144:	learn: 0.2055041	total: 31.9s	remaining: 1m 7s
# 145:	learn: 0.2053414	total: 32.2s	remaining: 1m 7s
# 146:	learn: 0.2052645	total: 32.5s	remaining: 1m 6s
# 147:	learn: 0.2052241	total: 32.7s	remaining: 1m 6s
# 148:	learn: 0.2051621	total: 33s	remaining: 1m 6s
# 149:	learn: 0.2050544	total: 33.3s	remaining: 1m 6s
# 150:	learn: 0.2049573	total: 33.6s	remaining: 1m 6s
# 151:	learn: 0.2049343	total: 33.8s	remaining: 1m 6s
# 152:	learn: 0.2048639	total: 34.1s	remaining: 1m 6s
# 153:	learn: 0.2048186	total: 34.4s	remaining: 1m 6s
# 154:	learn: 0.2047619	total: 34.7s	remaining: 1m 6s
# 155:	learn: 0.2045773	total: 35s	remaining: 1m 5s
# 156:	learn: 0.2045615	total: 35s	remaining: 1m 5s
# 157:	learn: 0.2044558	total: 35.3s	remaining: 1m 5s
# 158:	learn: 0.2041349	total: 35.6s	remaining: 1m 5s
# 159:	learn: 0.2040746	total: 35.9s	remaining: 1m 5s
# 160:	learn: 0.2039668	total: 36.1s	remaining: 1m 4s
# 161:	learn: 0.2031606	total: 36.4s	remaining: 1m 4s
# 162:	learn: 0.2029948	total: 36.7s	remaining: 1m 4s
# 163:	learn: 0.2029927	total: 36.7s	remaining: 1m 4s
# 164:	learn: 0.2027378	total: 37s	remaining: 1m 3s
# 165:	learn: 0.2026939	total: 37.2s	remaining: 1m 3s
# 166:	learn: 0.2025902	total: 37.5s	remaining: 1m 3s
# 167:	learn: 0.2025630	total: 37.8s	remaining: 1m 3s
# 168:	learn: 0.2025594	total: 37.8s	remaining: 1m 2s
# 169:	learn: 0.2024147	total: 38.1s	remaining: 1m 2s
# 170:	learn: 0.2021552	total: 38.3s	remaining: 1m 2s
# 171:	learn: 0.2018122	total: 38.6s	remaining: 1m 2s
# 172:	learn: 0.2016957	total: 38.9s	remaining: 1m 2s
# 173:	learn: 0.2010772	total: 39.2s	remaining: 1m 2s
# 174:	learn: 0.2010018	total: 39.4s	remaining: 1m 1s
# 175:	learn: 0.2008916	total: 39.7s	remaining: 1m 1s
# 176:	learn: 0.2002108	total: 40s	remaining: 1m 1s
# 177:	learn: 0.1998582	total: 40.3s	remaining: 1m 1s
# 178:	learn: 0.1991469	total: 40.6s	remaining: 1m 1s
# 179:	learn: 0.1988049	total: 40.8s	remaining: 1m 1s
# 180:	learn: 0.1985937	total: 41.1s	remaining: 1m 1s
# 181:	learn: 0.1977969	total: 41.4s	remaining: 1m
# 182:	learn: 0.1975413	total: 41.6s	remaining: 1m
# 183:	learn: 0.1973692	total: 41.9s	remaining: 1m
# 184:	learn: 0.1973659	total: 41.9s	remaining: 1m
# 185:	learn: 0.1968378	total: 42.2s	remaining: 59.9s
# 186:	learn: 0.1964688	total: 42.5s	remaining: 59.8s
# 187:	learn: 0.1963441	total: 42.8s	remaining: 59.7s
# 188:	learn: 0.1962060	total: 43.1s	remaining: 59.5s
# 189:	learn: 0.1958302	total: 43.4s	remaining: 59.4s
# 190:	learn: 0.1955309	total: 43.7s	remaining: 59.2s
# 191:	learn: 0.1951102	total: 43.9s	remaining: 59s
# 192:	learn: 0.1947290	total: 44.2s	remaining: 58.8s
# 193:	learn: 0.1944641	total: 44.5s	remaining: 58.7s
# 194:	learn: 0.1941281	total: 44.8s	remaining: 58.5s
# 195:	learn: 0.1935536	total: 45.1s	remaining: 58.4s
# 196:	learn: 0.1930527	total: 45.3s	remaining: 58.2s
# 197:	learn: 0.1929563	total: 45.6s	remaining: 58s
# 198:	learn: 0.1925689	total: 45.9s	remaining: 57.9s
# 199:	learn: 0.1920814	total: 46.2s	remaining: 57.7s
# 200:	learn: 0.1913760	total: 46.5s	remaining: 57.6s
# 201:	learn: 0.1908705	total: 46.8s	remaining: 57.4s
# 202:	learn: 0.1906366	total: 46.9s	remaining: 57s
# 203:	learn: 0.1902443	total: 47.2s	remaining: 56.9s
# 204:	learn: 0.1898103	total: 47.5s	remaining: 56.7s
# 205:	learn: 0.1895059	total: 47.8s	remaining: 56.6s
# 206:	learn: 0.1889284	total: 48s	remaining: 56.4s
# 207:	learn: 0.1885692	total: 48.3s	remaining: 56.2s
# 208:	learn: 0.1883906	total: 48.6s	remaining: 56s
# 209:	learn: 0.1877309	total: 48.9s	remaining: 55.9s
# 210:	learn: 0.1872586	total: 49.2s	remaining: 55.7s
# 211:	learn: 0.1869584	total: 49.4s	remaining: 55.5s
# 212:	learn: 0.1864509	total: 49.7s	remaining: 55.3s
# 213:	learn: 0.1861920	total: 50s	remaining: 55.1s
# 214:	learn: 0.1857446	total: 50.3s	remaining: 54.9s
# 215:	learn: 0.1852694	total: 50.6s	remaining: 54.8s
# 216:	learn: 0.1847349	total: 50.9s	remaining: 54.7s
# 217:	learn: 0.1843652	total: 51.2s	remaining: 54.4s
# 218:	learn: 0.1840901	total: 51.4s	remaining: 54.2s
# 219:	learn: 0.1835571	total: 51.7s	remaining: 54.1s
# 220:	learn: 0.1830196	total: 52s	remaining: 53.9s
# 221:	learn: 0.1826883	total: 52.2s	remaining: 53.6s
# 222:	learn: 0.1821540	total: 52.5s	remaining: 53.5s
# 223:	learn: 0.1817881	total: 52.8s	remaining: 53.3s
# 224:	learn: 0.1814313	total: 53.1s	remaining: 53.1s
# 225:	learn: 0.1809603	total: 53.3s	remaining: 52.9s
# 226:	learn: 0.1804999	total: 53.6s	remaining: 52.7s
# 227:	learn: 0.1797109	total: 54s	remaining: 52.5s
# 228:	learn: 0.1792777	total: 54.3s	remaining: 52.4s
# 229:	learn: 0.1789149	total: 54.6s	remaining: 52.3s
# 230:	learn: 0.1785276	total: 54.9s	remaining: 52.1s
# 231:	learn: 0.1780114	total: 55.2s	remaining: 51.9s
# 232:	learn: 0.1778010	total: 55.5s	remaining: 51.7s
# 233:	learn: 0.1775565	total: 55.8s	remaining: 51.5s
# 234:	learn: 0.1770753	total: 56.1s	remaining: 51.3s
# 235:	learn: 0.1766726	total: 56.3s	remaining: 51.1s
# 236:	learn: 0.1761739	total: 56.6s	remaining: 50.9s
# 237:	learn: 0.1760757	total: 56.9s	remaining: 50.7s
# 238:	learn: 0.1756902	total: 57.2s	remaining: 50.5s
# 239:	learn: 0.1753740	total: 57.5s	remaining: 50.3s
# 240:	learn: 0.1750176	total: 57.8s	remaining: 50.1s
# 241:	learn: 0.1744947	total: 58.1s	remaining: 49.9s
# 242:	learn: 0.1742360	total: 58.3s	remaining: 49.7s
# 243:	learn: 0.1737317	total: 58.6s	remaining: 49.5s
# 244:	learn: 0.1734930	total: 58.9s	remaining: 49.3s
# 245:	learn: 0.1732088	total: 59.2s	remaining: 49.1s
# 246:	learn: 0.1728466	total: 59.4s	remaining: 48.8s
# 247:	learn: 0.1725586	total: 59.7s	remaining: 48.6s
# 248:	learn: 0.1722027	total: 60s	remaining: 48.4s
# 249:	learn: 0.1720739	total: 1m	remaining: 48.2s
# 250:	learn: 0.1720039	total: 1m	remaining: 48s
# 251:	learn: 0.1717628	total: 1m	remaining: 47.7s
# 252:	learn: 0.1713423	total: 1m 1s	remaining: 47.5s
# 253:	learn: 0.1710736	total: 1m 1s	remaining: 47.3s
# 254:	learn: 0.1707845	total: 1m 1s	remaining: 47.1s
# 255:	learn: 0.1705457	total: 1m 1s	remaining: 46.9s
# 256:	learn: 0.1702561	total: 1m 2s	remaining: 46.7s
# 257:	learn: 0.1699933	total: 1m 2s	remaining: 46.5s
# 258:	learn: 0.1696587	total: 1m 2s	remaining: 46.3s
# 259:	learn: 0.1693796	total: 1m 2s	remaining: 46s
# 260:	learn: 0.1690847	total: 1m 3s	remaining: 45.8s
# 261:	learn: 0.1687726	total: 1m 3s	remaining: 45.6s
# 262:	learn: 0.1683550	total: 1m 3s	remaining: 45.4s
# 263:	learn: 0.1679694	total: 1m 4s	remaining: 45.1s
# 264:	learn: 0.1675162	total: 1m 4s	remaining: 44.9s
# 265:	learn: 0.1671794	total: 1m 4s	remaining: 44.7s
# 266:	learn: 0.1668094	total: 1m 4s	remaining: 44.5s
# 267:	learn: 0.1664709	total: 1m 5s	remaining: 44.3s
# 268:	learn: 0.1660881	total: 1m 5s	remaining: 44.1s
# 269:	learn: 0.1658262	total: 1m 5s	remaining: 43.9s
# 270:	learn: 0.1656387	total: 1m 6s	remaining: 43.7s
# 271:	learn: 0.1651759	total: 1m 6s	remaining: 43.5s
# 272:	learn: 0.1648860	total: 1m 6s	remaining: 43.2s
# 273:	learn: 0.1648584	total: 1m 6s	remaining: 43s
# 274:	learn: 0.1643975	total: 1m 7s	remaining: 42.8s
# 275:	learn: 0.1641813	total: 1m 7s	remaining: 42.6s
# 276:	learn: 0.1638573	total: 1m 7s	remaining: 42.4s
# 277:	learn: 0.1634890	total: 1m 8s	remaining: 42.1s
# 278:	learn: 0.1632138	total: 1m 8s	remaining: 41.9s
# 279:	learn: 0.1629358	total: 1m 8s	remaining: 41.7s
# 280:	learn: 0.1627240	total: 1m 8s	remaining: 41.5s
# 281:	learn: 0.1623434	total: 1m 9s	remaining: 41.2s
# 282:	learn: 0.1621277	total: 1m 9s	remaining: 41s
# 283:	learn: 0.1617628	total: 1m 9s	remaining: 40.8s
# 284:	learn: 0.1614173	total: 1m 10s	remaining: 40.6s
# 285:	learn: 0.1611781	total: 1m 10s	remaining: 40.4s
# 286:	learn: 0.1609687	total: 1m 10s	remaining: 40.2s
# 287:	learn: 0.1607692	total: 1m 10s	remaining: 39.9s
# 288:	learn: 0.1603137	total: 1m 11s	remaining: 39.7s
# 289:	learn: 0.1599740	total: 1m 11s	remaining: 39.5s
# 290:	learn: 0.1598147	total: 1m 11s	remaining: 39.3s
# 291:	learn: 0.1595817	total: 1m 12s	remaining: 39s
# 292:	learn: 0.1592399	total: 1m 12s	remaining: 38.8s
# 293:	learn: 0.1590744	total: 1m 12s	remaining: 38.6s
# 294:	learn: 0.1589150	total: 1m 13s	remaining: 38.4s
# 295:	learn: 0.1585585	total: 1m 13s	remaining: 38.1s
# 296:	learn: 0.1580992	total: 1m 13s	remaining: 38s
# 297:	learn: 0.1579264	total: 1m 13s	remaining: 37.7s
# 298:	learn: 0.1577666	total: 1m 14s	remaining: 37.5s
# 299:	learn: 0.1576097	total: 1m 14s	remaining: 37.2s
# 300:	learn: 0.1574006	total: 1m 14s	remaining: 37s
# 301:	learn: 0.1570474	total: 1m 15s	remaining: 36.8s
# 302:	learn: 0.1565817	total: 1m 15s	remaining: 36.6s
# 303:	learn: 0.1563327	total: 1m 15s	remaining: 36.3s
# 304:	learn: 0.1561333	total: 1m 15s	remaining: 36.1s
# 305:	learn: 0.1559317	total: 1m 16s	remaining: 35.9s
# 306:	learn: 0.1558337	total: 1m 16s	remaining: 35.7s
# 307:	learn: 0.1557320	total: 1m 16s	remaining: 35.4s
# 308:	learn: 0.1556950	total: 1m 17s	remaining: 35.2s
# 309:	learn: 0.1555474	total: 1m 17s	remaining: 35s
# 310:	learn: 0.1553758	total: 1m 17s	remaining: 34.7s
# 311:	learn: 0.1551138	total: 1m 17s	remaining: 34.5s
# 312:	learn: 0.1550894	total: 1m 18s	remaining: 34.2s
# 313:	learn: 0.1548103	total: 1m 18s	remaining: 34s
# 314:	learn: 0.1546040	total: 1m 18s	remaining: 33.8s
# 315:	learn: 0.1545095	total: 1m 19s	remaining: 33.5s
# 316:	learn: 0.1541788	total: 1m 19s	remaining: 33.3s
# 317:	learn: 0.1540751	total: 1m 19s	remaining: 33.1s
# 318:	learn: 0.1539642	total: 1m 19s	remaining: 32.8s
# 319:	learn: 0.1537121	total: 1m 20s	remaining: 32.6s
# 320:	learn: 0.1532914	total: 1m 20s	remaining: 32.4s
# 321:	learn: 0.1530967	total: 1m 20s	remaining: 32.1s
# 322:	learn: 0.1528305	total: 1m 21s	remaining: 31.9s
# 323:	learn: 0.1525864	total: 1m 21s	remaining: 31.6s
# 324:	learn: 0.1523816	total: 1m 21s	remaining: 31.4s
# 325:	learn: 0.1521322	total: 1m 21s	remaining: 31.2s
# 326:	learn: 0.1519216	total: 1m 22s	remaining: 30.9s
# 327:	learn: 0.1517620	total: 1m 22s	remaining: 30.7s
# 328:	learn: 0.1517556	total: 1m 22s	remaining: 30.4s
# 329:	learn: 0.1515603	total: 1m 22s	remaining: 30.1s
# 330:	learn: 0.1514719	total: 1m 23s	remaining: 29.9s
# 331:	learn: 0.1513498	total: 1m 23s	remaining: 29.6s
# 332:	learn: 0.1511958	total: 1m 23s	remaining: 29.4s
# 333:	learn: 0.1510155	total: 1m 23s	remaining: 29.2s
# 334:	learn: 0.1507946	total: 1m 24s	remaining: 28.9s
# 335:	learn: 0.1503896	total: 1m 24s	remaining: 28.7s
# 336:	learn: 0.1502084	total: 1m 24s	remaining: 28.5s
# 337:	learn: 0.1500316	total: 1m 25s	remaining: 28.2s
# 338:	learn: 0.1499230	total: 1m 25s	remaining: 28s
# 339:	learn: 0.1498655	total: 1m 25s	remaining: 27.7s
# 340:	learn: 0.1496219	total: 1m 25s	remaining: 27.5s
# 341:	learn: 0.1492720	total: 1m 26s	remaining: 27.2s
# 342:	learn: 0.1491585	total: 1m 26s	remaining: 27s
# 343:	learn: 0.1491223	total: 1m 26s	remaining: 26.7s
# 344:	learn: 0.1489923	total: 1m 27s	remaining: 26.5s
# 345:	learn: 0.1488046	total: 1m 27s	remaining: 26.3s
# 346:	learn: 0.1485800	total: 1m 27s	remaining: 26s
# 347:	learn: 0.1484941	total: 1m 27s	remaining: 25.8s
# 348:	learn: 0.1484897	total: 1m 27s	remaining: 25.5s
# 349:	learn: 0.1482386	total: 1m 28s	remaining: 25.2s
# 350:	learn: 0.1482255	total: 1m 28s	remaining: 25s
# 351:	learn: 0.1481527	total: 1m 28s	remaining: 24.7s
# 352:	learn: 0.1481486	total: 1m 28s	remaining: 24.4s
# 353:	learn: 0.1479887	total: 1m 29s	remaining: 24.2s
# 354:	learn: 0.1478187	total: 1m 29s	remaining: 23.9s
# 355:	learn: 0.1477245	total: 1m 29s	remaining: 23.7s
# 356:	learn: 0.1473286	total: 1m 30s	remaining: 23.5s
# 357:	learn: 0.1471578	total: 1m 30s	remaining: 23.2s
# 358:	learn: 0.1470210	total: 1m 30s	remaining: 23s
# 359:	learn: 0.1466959	total: 1m 31s	remaining: 22.8s
# 360:	learn: 0.1465315	total: 1m 31s	remaining: 22.5s
# 361:	learn: 0.1463525	total: 1m 31s	remaining: 22.3s
# 362:	learn: 0.1463370	total: 1m 31s	remaining: 22s
# 363:	learn: 0.1460380	total: 1m 32s	remaining: 21.8s
# 364:	learn: 0.1457656	total: 1m 32s	remaining: 21.6s
# 365:	learn: 0.1457033	total: 1m 32s	remaining: 21.3s
# 366:	learn: 0.1453699	total: 1m 33s	remaining: 21.1s
# 367:	learn: 0.1450310	total: 1m 33s	remaining: 20.8s
# 368:	learn: 0.1449685	total: 1m 33s	remaining: 20.6s
# 369:	learn: 0.1447122	total: 1m 34s	remaining: 20.4s
# 370:	learn: 0.1445572	total: 1m 34s	remaining: 20.2s
# 371:	learn: 0.1444352	total: 1m 35s	remaining: 20s
# 372:	learn: 0.1442448	total: 1m 35s	remaining: 19.7s
# 373:	learn: 0.1441782	total: 1m 35s	remaining: 19.5s
# 374:	learn: 0.1438362	total: 1m 36s	remaining: 19.2s
# 375:	learn: 0.1436047	total: 1m 36s	remaining: 19s
# 376:	learn: 0.1431950	total: 1m 36s	remaining: 18.7s
# 377:	learn: 0.1430472	total: 1m 37s	remaining: 18.5s
# 378:	learn: 0.1426619	total: 1m 37s	remaining: 18.2s
# 379:	learn: 0.1424278	total: 1m 37s	remaining: 18s
# 380:	learn: 0.1421603	total: 1m 37s	remaining: 17.7s
# 381:	learn: 0.1419816	total: 1m 38s	remaining: 17.5s
# 382:	learn: 0.1418954	total: 1m 38s	remaining: 17.2s
# 383:	learn: 0.1416639	total: 1m 38s	remaining: 17s
# 384:	learn: 0.1415479	total: 1m 38s	remaining: 16.7s
# 385:	learn: 0.1414486	total: 1m 39s	remaining: 16.4s
# 386:	learn: 0.1413424	total: 1m 39s	remaining: 16.2s
# 387:	learn: 0.1413031	total: 1m 39s	remaining: 15.9s
# 388:	learn: 0.1408706	total: 1m 40s	remaining: 15.7s
# 389:	learn: 0.1407432	total: 1m 40s	remaining: 15.4s
# 390:	learn: 0.1405598	total: 1m 40s	remaining: 15.2s
# 391:	learn: 0.1404169	total: 1m 40s	remaining: 14.9s
# 392:	learn: 0.1402610	total: 1m 41s	remaining: 14.7s
# 393:	learn: 0.1400664	total: 1m 41s	remaining: 14.4s
# 394:	learn: 0.1399380	total: 1m 41s	remaining: 14.2s
# 395:	learn: 0.1396574	total: 1m 41s	remaining: 13.9s
# 396:	learn: 0.1396464	total: 1m 42s	remaining: 13.6s
# 397:	learn: 0.1394383	total: 1m 42s	remaining: 13.4s
# 398:	learn: 0.1393226	total: 1m 42s	remaining: 13.1s
# 399:	learn: 0.1390612	total: 1m 43s	remaining: 12.9s
# 400:	learn: 0.1389891	total: 1m 43s	remaining: 12.6s
# 401:	learn: 0.1388929	total: 1m 43s	remaining: 12.4s
# 402:	learn: 0.1386653	total: 1m 43s	remaining: 12.1s
# 403:	learn: 0.1386515	total: 1m 44s	remaining: 11.9s
# 404:	learn: 0.1385059	total: 1m 44s	remaining: 11.6s
# 405:	learn: 0.1381965	total: 1m 44s	remaining: 11.3s
# 406:	learn: 0.1381847	total: 1m 44s	remaining: 11.1s
# 407:	learn: 0.1380630	total: 1m 45s	remaining: 10.8s
# 408:	learn: 0.1377292	total: 1m 45s	remaining: 10.6s
# 409:	learn: 0.1376483	total: 1m 45s	remaining: 10.3s
# 410:	learn: 0.1375295	total: 1m 46s	remaining: 10.1s
# 411:	learn: 0.1372592	total: 1m 46s	remaining: 9.81s
# 412:	learn: 0.1369874	total: 1m 46s	remaining: 9.56s
# 413:	learn: 0.1368841	total: 1m 46s	remaining: 9.3s
# 414:	learn: 0.1366371	total: 1m 47s	remaining: 9.05s
# 415:	learn: 0.1364812	total: 1m 47s	remaining: 8.79s
# 416:	learn: 0.1363207	total: 1m 47s	remaining: 8.54s
# 417:	learn: 0.1362025	total: 1m 48s	remaining: 8.28s
# 418:	learn: 0.1361114	total: 1m 48s	remaining: 8.02s
# 419:	learn: 0.1359281	total: 1m 48s	remaining: 7.76s
# 420:	learn: 0.1357468	total: 1m 49s	remaining: 7.51s
# 421:	learn: 0.1355367	total: 1m 49s	remaining: 7.25s
# 422:	learn: 0.1353785	total: 1m 49s	remaining: 6.99s
# 423:	learn: 0.1353070	total: 1m 49s	remaining: 6.74s
# 424:	learn: 0.1351657	total: 1m 50s	remaining: 6.48s
# 425:	learn: 0.1351182	total: 1m 50s	remaining: 6.22s
# 426:	learn: 0.1349745	total: 1m 50s	remaining: 5.96s
# 427:	learn: 0.1348843	total: 1m 50s	remaining: 5.7s
# 428:	learn: 0.1348483	total: 1m 51s	remaining: 5.45s
# 429:	learn: 0.1347523	total: 1m 51s	remaining: 5.19s
# 430:	learn: 0.1344175	total: 1m 51s	remaining: 4.93s
# 431:	learn: 0.1342488	total: 1m 52s	remaining: 4.67s
# 432:	learn: 0.1341023	total: 1m 52s	remaining: 4.41s
# 433:	learn: 0.1340198	total: 1m 52s	remaining: 4.16s
# 434:	learn: 0.1340061	total: 1m 53s	remaining: 3.9s
# 435:	learn: 0.1339507	total: 1m 53s	remaining: 3.64s
# 436:	learn: 0.1337791	total: 1m 53s	remaining: 3.38s
# 437:	learn: 0.1337493	total: 1m 53s	remaining: 3.12s
# 438:	learn: 0.1336248	total: 1m 54s	remaining: 2.86s
# 439:	learn: 0.1334854	total: 1m 54s	remaining: 2.6s
# 440:	learn: 0.1332720	total: 1m 54s	remaining: 2.34s
# 441:	learn: 0.1331659	total: 1m 55s	remaining: 2.08s
# 442:	learn: 0.1330087	total: 1m 55s	remaining: 1.82s
# 443:	learn: 0.1329506	total: 1m 55s	remaining: 1.56s
# 444:	learn: 0.1329303	total: 1m 55s	remaining: 1.3s
# 445:	learn: 0.1327799	total: 1m 56s	remaining: 1.04s
# 446:	learn: 0.1325253	total: 1m 56s	remaining: 781ms
# 447:	learn: 0.1324513	total: 1m 56s	remaining: 521ms
# 448:	learn: 0.1324384	total: 1m 56s	remaining: 260ms
# 449:	learn: 0.1322168	total: 1m 57s	remaining: 0us
# cat 모델이 train_data_autoclave 데이터로 학습한 결과:
# F1 Score: 0.24064171122994654

# %% [markdown]
# cat 모델이 train_data_autoclave 데이터로 학습한 결과:
# F1 Score: 0.24064171122994654

# %% [markdown]
# .
