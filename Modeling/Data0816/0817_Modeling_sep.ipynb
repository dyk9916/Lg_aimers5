# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ## 1. 데이터 불러오기

# %% [markdown]
# ### 필수 라이브러리

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import os
from pprint import pprint

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %% [markdown]
# ### 데이터 읽어오기

# %%
import pandas as pd

RANDOM_STATE = 110

train_data = pd.read_csv("C:/Users/KimDongyoung/Desktop/git_LGaimers5/Lg_aimers5/Lg_aimers5-1/data/train_data_0816.csv")
test_data = pd.read_csv("C:/Users/KimDongyoung/Desktop/git_LGaimers5/Lg_aimers5/Lg_aimers5-1/data/test_data_0816.csv")

# %%
# 공통 변수 리스트
com_variables_train = [
    'target', 'Model.Suffix', 'Workorder', 'WorkMode Collect Result'
    , 'Dispenser_1', 'Dispenser_2', 'Receip_No_Collect_Result'
    , 'Production_Qty_Collect_Result', 'Judge_Value_OK'
    , 'Workorder_0.9', 'Workorder_0.6'
]

com_variables_test = [
    'target', 'Set ID', 'Model.Suffix', 'Workorder'
    , 'WorkMode Collect Result', 'Dispenser_1'
    , 'Dispenser_2', 'Receip_No_Collect_Result'
    , 'Production_Qty_Collect_Result', 'Judge_Value_OK'
    , 'Workorder_0.9', 'Workorder_0.6'
]

# %%
# 공정 이름 필터링 후 공통 변수와 결합
def create_dataset(train_data, test_data, process_name, com_variables_train, com_variables_test):
    # 열 이름 필터링
    Process_Desc_col = train_data.filter(like=process_name).columns
    
    # train 데이터셋 생성
    final_columns_train = list(Process_Desc_col) + com_variables_train
    train_dataset = train_data[final_columns_train]
    
    # test 데이터셋 생성
    final_columns_test = list(Process_Desc_col) + com_variables_test
    test_dataset = test_data[final_columns_test]
    
    return train_dataset, test_dataset

# 공통 변수 정의
## com_variables_train = [...]  -> 이전 코드에서 정의한 변수 사용
## com_variables_test = [...]   -> 이전 코드에서 정의한 변수 사용

# 데이터셋 생성
train_data_dam, test_data_dam = create_dataset(train_data, test_data, '_Dam', com_variables_train, com_variables_test)
train_data_fill1, test_data_fill1 = create_dataset(train_data, test_data, '_Fill1', com_variables_train, com_variables_test)
train_data_fill2, test_data_fill2 = create_dataset(train_data, test_data, '_Fill2', com_variables_train, com_variables_test)
train_data_autoclave, test_data_autoclave = create_dataset(train_data, test_data, '_AutoClave', com_variables_train, com_variables_test)

# %% [markdown]
# ---

# %% [markdown]
# ## 3. 모델 학습

# %% [markdown]
# ### 모델 정의

# %%
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix, accuracy_score, precision_score, recall_score

# 스레드홀드 설정
THRESHOLD = 0.3


def train_and_evaluate_model(model_name, data):
    if model_name not in models:
        print(f"{model_name}은(는) 지원되지 않는 모델입니다.")
        return
    
    # 데이터셋 분할
    x_train, x_val, y_train, y_val = train_test_split(
        data.drop("target", axis=1),
        data["target"].map({'Normal': 0, 'AbNormal': 1}),  # y_val도 숫자로 변환
        test_size=0.2,
        shuffle=True,
        random_state=RANDOM_STATE,
    )

    # 모델 선택
    model = models[model_name]

    # 모델 학습
    model.fit(x_train, y_train)

    # 예측
    y_val_pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
    y_val_pred = (y_val_pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측

    # 평가지표 계산
    f1 = f1_score(y_val, y_val_pred, average="binary")
    accuracy = accuracy_score(y_val, y_val_pred)
    precision = precision_score(y_val, y_val_pred)
    recall = recall_score(y_val, y_val_pred)
    conf_matrix = confusion_matrix(y_val, y_val_pred)

    # 결과 출력
    print(f'{model_name} 결과:')
    print(f'F1 Score: {f1}')
    print('---')
    print('Confusion Matrix:')
    print(conf_matrix)
    print('---')
    print(f'Accuracy: {accuracy}')
    print(f'Precision: {precision}')
    print(f'Recall: {recall}')
    print('\n')

# %% [markdown]
# 아래 모델 목록에서 공정별로 해당하는거로 가져가서 학습

# %%
# 모델 설정 및 하이퍼파라미터
#models = {
#     'ExtraTreesClassifier': ExtraTreesClassifier(
#         n_estimators=1645,
#         max_depth=32,
#         min_samples_split=8,
#         min_samples_leaf=1,
#         criterion='entropy',
#         bootstrap=False,
#         random_state=RANDOM_STATE
#     ),
    
#     'RandomForestClassifier': RandomForestClassifier(
#         n_estimators = 1959, 
#         max_depth = 48, 
#         min_samples_split = 5, 
#         min_samples_leaf= 1, 
#         criterion = 'entropy', 
#         class_weight = 'balanced',
#         random_state=RANDOM_STATE
 #    )
    
#     'CatBoostClassifier': CatBoostClassifier(
#         iterations=757,
#         learning_rate=0.050198665725373286,
#         depth=9,
#         l2_leaf_reg=1.4245312044811413,
#         random_strength=9.361327508234833,
#         bagging_temperature=4.80588064825688,
#         border_count=99,
#         scale_pos_weight=1.1403833705864026,
#         random_seed=RANDOM_STATE,
#         eval_metric='F1',
#         logging_level='Silent',
#         boosting_type='Plain'
#     ),
    
#     'LGBMClassifier': LGBMClassifier(
#         n_estimators=979,
#         num_leaves=1565,
#         max_depth=34,
#         learning_rate=0.04888906225539191,
#         min_child_samples=36,
#         boosting_type='dart',
#         random_state=RANDOM_STATE,
#         verbose=-1
#     ),
    
#     'XGBClassifier': XGBClassifier(
#         n_estimators=2213,
#         learning_rate=0.11735028445102921,
#         max_depth=5,
#         alpha=0.008053553080773119,
#         gamma=0.0006061064433044652,
#         reg_alpha=0.5380410453451789,
#         reg_lambda=0.8278020434040504,
#         colsample_bytree=0.8672296781322193,
#         subsample=0.3694461716611997,
#         random_state=RANDOM_STATE
#     ),
    
#     'DecisionTreeClassifier': DecisionTreeClassifier(
#         max_depth=122,
#         min_samples_split=30,
#         min_samples_leaf=21,
#         max_features=None,
#         splitter='best',
#         criterion='gini',
#         random_state=RANDOM_STATE
#     )
#}

# # 사용 예시
#train_and_evaluate_model('RandomForestClassifier', data)
#train_and_evaluate_model('XGBClassifier', train_data_fill1)
# Out:
# RandomForestClassifier 결과:
# F1 Score: 0.1927525057825752
# ---
# Confusion Matrix:
# [[6930  732]
#  [ 315  125]]
# ---
# Accuracy: 0.870772648728709
# Precision: 0.14585764294049008
# Recall: 0.2840909090909091

# %% [markdown]
# Dam 모델

# %%
# 모델 설정 및 하이퍼파라미터
models = {
    'LGBMClassifier': LGBMClassifier(
        n_estimators=2748,
        num_leaves=657,
        max_depth=256,
        learning_rate=0.001043279508273329,
        min_child_samples=58,
        boosting_type='dart',
        random_state=RANDOM_STATE,
        verbose=-1
    )
}

# 학습
train_and_evaluate_model('LGBMClassifier', train_data_dam)
# Out:
# LGBMClassifier 결과:
# F1 Score: 0.25119617224880386
# ---
# Confusion Matrix:
# [[7371  291]
#  [ 335  105]]
# ---
# Accuracy: 0.9227351271291039
# Precision: 0.26515151515151514
# Recall: 0.23863636363636365

# %%
# 모델 설정 및 하이퍼파라미터
models = {
    'CatBoostClassifier': CatBoostClassifier(
        iterations= 755, 
        depth= 7, 
        learning_rate= 0.19866742206648758, 
        l2_leaf_reg= 0.24483628170369134, 
        border_count= 95,
        random_state=RANDOM_STATE,
        # verbose=-1
    )
}

# 학습
train_and_evaluate_model('CatBoostClassifier', train_data_dam)
# Out:
# 0:	learn: 0.4821751	total: 13.1ms	remaining: 9.91s
# 1:	learn: 0.3549734	total: 25.9ms	remaining: 9.75s
# 2:	learn: 0.2939218	total: 38.6ms	remaining: 9.68s
# 3:	learn: 0.2548974	total: 51.4ms	remaining: 9.65s
# 4:	learn: 0.2309913	total: 63.8ms	remaining: 9.57s
# 5:	learn: 0.2190122	total: 77.2ms	remaining: 9.64s
# 6:	learn: 0.2109658	total: 90.6ms	remaining: 9.68s
# 7:	learn: 0.2053156	total: 104ms	remaining: 9.69s
# 8:	learn: 0.2012307	total: 114ms	remaining: 9.44s
# 9:	learn: 0.1997075	total: 123ms	remaining: 9.15s
# 10:	learn: 0.1982408	total: 133ms	remaining: 8.97s
# 11:	learn: 0.1964299	total: 143ms	remaining: 8.86s
# 12:	learn: 0.1957812	total: 156ms	remaining: 8.91s
# 13:	learn: 0.1950974	total: 168ms	remaining: 8.9s
# 14:	learn: 0.1942744	total: 181ms	remaining: 8.91s
# 15:	learn: 0.1936921	total: 192ms	remaining: 8.87s
# 16:	learn: 0.1927233	total: 205ms	remaining: 8.9s
# 17:	learn: 0.1924132	total: 219ms	remaining: 8.95s
# 18:	learn: 0.1921630	total: 232ms	remaining: 8.97s
# 19:	learn: 0.1919067	total: 246ms	remaining: 9.05s
# 20:	learn: 0.1914974	total: 258ms	remaining: 9s
# 21:	learn: 0.1912693	total: 269ms	remaining: 8.95s
# 22:	learn: 0.1912239	total: 276ms	remaining: 8.79s
# 23:	learn: 0.1907270	total: 287ms	remaining: 8.73s
# 24:	learn: 0.1904897	total: 297ms	remaining: 8.68s
# 25:	learn: 0.1898665	total: 310ms	remaining: 8.69s
# 26:	learn: 0.1896207	total: 322ms	remaining: 8.67s
# 27:	learn: 0.1893603	total: 334ms	remaining: 8.68s
# 28:	learn: 0.1891954	total: 345ms	remaining: 8.64s
# 29:	learn: 0.1888974	total: 355ms	remaining: 8.57s
# 30:	learn: 0.1886599	total: 365ms	remaining: 8.53s
# 31:	learn: 0.1884023	total: 377ms	remaining: 8.51s
# 32:	learn: 0.1882336	total: 387ms	remaining: 8.46s
# 33:	learn: 0.1879696	total: 398ms	remaining: 8.43s
# 34:	learn: 0.1877939	total: 409ms	remaining: 8.41s
# 35:	learn: 0.1876940	total: 419ms	remaining: 8.37s
# 36:	learn: 0.1875662	total: 430ms	remaining: 8.35s
# 37:	learn: 0.1873188	total: 441ms	remaining: 8.32s
# 38:	learn: 0.1872943	total: 452ms	remaining: 8.29s
# 39:	learn: 0.1870943	total: 464ms	remaining: 8.3s
# 40:	learn: 0.1869631	total: 476ms	remaining: 8.29s
# 41:	learn: 0.1868278	total: 488ms	remaining: 8.29s
# 42:	learn: 0.1864944	total: 499ms	remaining: 8.26s
# 43:	learn: 0.1864127	total: 510ms	remaining: 8.24s
# 44:	learn: 0.1863076	total: 520ms	remaining: 8.2s
# 45:	learn: 0.1860185	total: 530ms	remaining: 8.16s
# 46:	learn: 0.1857739	total: 541ms	remaining: 8.14s
# 47:	learn: 0.1855790	total: 550ms	remaining: 8.1s
# 48:	learn: 0.1853615	total: 562ms	remaining: 8.09s
# 49:	learn: 0.1850787	total: 573ms	remaining: 8.08s
# 50:	learn: 0.1848926	total: 585ms	remaining: 8.07s
# 51:	learn: 0.1846373	total: 596ms	remaining: 8.05s
# 52:	learn: 0.1842859	total: 606ms	remaining: 8.03s
# 53:	learn: 0.1840311	total: 617ms	remaining: 8s
# 54:	learn: 0.1836349	total: 628ms	remaining: 7.99s
# 55:	learn: 0.1833721	total: 641ms	remaining: 8.01s
# 56:	learn: 0.1830344	total: 655ms	remaining: 8.02s
# 57:	learn: 0.1827772	total: 669ms	remaining: 8.04s
# 58:	learn: 0.1824840	total: 683ms	remaining: 8.05s
# 59:	learn: 0.1821460	total: 693ms	remaining: 8.03s
# 60:	learn: 0.1818258	total: 704ms	remaining: 8.01s
# 61:	learn: 0.1814294	total: 715ms	remaining: 7.99s
# 62:	learn: 0.1810659	total: 725ms	remaining: 7.97s
# 63:	learn: 0.1807445	total: 736ms	remaining: 7.94s
# 64:	learn: 0.1805222	total: 749ms	remaining: 7.95s
# 65:	learn: 0.1801993	total: 763ms	remaining: 7.96s
# 66:	learn: 0.1799521	total: 775ms	remaining: 7.95s
# 67:	learn: 0.1796277	total: 787ms	remaining: 7.95s
# 68:	learn: 0.1792961	total: 799ms	remaining: 7.94s
# 69:	learn: 0.1791721	total: 809ms	remaining: 7.92s
# 70:	learn: 0.1789842	total: 820ms	remaining: 7.9s
# 71:	learn: 0.1787567	total: 830ms	remaining: 7.87s
# 72:	learn: 0.1783691	total: 841ms	remaining: 7.86s
# 73:	learn: 0.1781465	total: 855ms	remaining: 7.87s
# 74:	learn: 0.1778048	total: 868ms	remaining: 7.87s
# 75:	learn: 0.1777005	total: 881ms	remaining: 7.87s
# 76:	learn: 0.1774323	total: 892ms	remaining: 7.86s
# 77:	learn: 0.1771040	total: 903ms	remaining: 7.83s
# 78:	learn: 0.1768265	total: 914ms	remaining: 7.82s
# 79:	learn: 0.1764103	total: 925ms	remaining: 7.81s
# 80:	learn: 0.1760006	total: 937ms	remaining: 7.79s
# 81:	learn: 0.1756639	total: 948ms	remaining: 7.78s
# 82:	learn: 0.1753968	total: 958ms	remaining: 7.76s
# 83:	learn: 0.1752129	total: 968ms	remaining: 7.73s
# 84:	learn: 0.1749099	total: 980ms	remaining: 7.73s
# 85:	learn: 0.1744560	total: 994ms	remaining: 7.73s
# 86:	learn: 0.1743068	total: 1.01s	remaining: 7.73s
# 87:	learn: 0.1739366	total: 1.02s	remaining: 7.72s
# 88:	learn: 0.1736089	total: 1.03s	remaining: 7.71s
# 89:	learn: 0.1733359	total: 1.04s	remaining: 7.7s
# 90:	learn: 0.1729938	total: 1.05s	remaining: 7.7s
# 91:	learn: 0.1726014	total: 1.07s	remaining: 7.68s
# 92:	learn: 0.1722573	total: 1.08s	remaining: 7.67s
# 93:	learn: 0.1719212	total: 1.09s	remaining: 7.66s
# 94:	learn: 0.1717113	total: 1.1s	remaining: 7.64s
# 95:	learn: 0.1714922	total: 1.11s	remaining: 7.63s
# 96:	learn: 0.1711487	total: 1.13s	remaining: 7.64s
# 97:	learn: 0.1708942	total: 1.14s	remaining: 7.63s
# 98:	learn: 0.1705622	total: 1.15s	remaining: 7.63s
# 99:	learn: 0.1703408	total: 1.16s	remaining: 7.61s
# 100:	learn: 0.1700079	total: 1.17s	remaining: 7.6s
# 101:	learn: 0.1698334	total: 1.18s	remaining: 7.58s
# 102:	learn: 0.1696200	total: 1.2s	remaining: 7.57s
# 103:	learn: 0.1694080	total: 1.21s	remaining: 7.55s
# 104:	learn: 0.1691209	total: 1.22s	remaining: 7.53s
# 105:	learn: 0.1688933	total: 1.23s	remaining: 7.51s
# 106:	learn: 0.1686582	total: 1.24s	remaining: 7.5s
# 107:	learn: 0.1683527	total: 1.25s	remaining: 7.48s
# 108:	learn: 0.1680790	total: 1.26s	remaining: 7.46s
# 109:	learn: 0.1678919	total: 1.27s	remaining: 7.45s
# 110:	learn: 0.1676203	total: 1.28s	remaining: 7.43s
# 111:	learn: 0.1672266	total: 1.29s	remaining: 7.41s
# 112:	learn: 0.1670242	total: 1.3s	remaining: 7.39s
# 113:	learn: 0.1668690	total: 1.31s	remaining: 7.38s
# 114:	learn: 0.1666135	total: 1.32s	remaining: 7.36s
# 115:	learn: 0.1663877	total: 1.33s	remaining: 7.34s
# 116:	learn: 0.1661989	total: 1.34s	remaining: 7.33s
# 117:	learn: 0.1658820	total: 1.35s	remaining: 7.31s
# 118:	learn: 0.1656966	total: 1.36s	remaining: 7.3s
# 119:	learn: 0.1653442	total: 1.38s	remaining: 7.29s
# 120:	learn: 0.1652056	total: 1.39s	remaining: 7.28s
# 121:	learn: 0.1650175	total: 1.4s	remaining: 7.26s
# 122:	learn: 0.1648324	total: 1.41s	remaining: 7.25s
# 123:	learn: 0.1645856	total: 1.42s	remaining: 7.23s
# 124:	learn: 0.1643084	total: 1.43s	remaining: 7.21s
# 125:	learn: 0.1641383	total: 1.44s	remaining: 7.2s
# 126:	learn: 0.1638100	total: 1.45s	remaining: 7.18s
# 127:	learn: 0.1636144	total: 1.47s	remaining: 7.18s
# 128:	learn: 0.1634279	total: 1.48s	remaining: 7.18s
# 129:	learn: 0.1631934	total: 1.49s	remaining: 7.18s
# 130:	learn: 0.1629081	total: 1.5s	remaining: 7.17s
# 131:	learn: 0.1627022	total: 1.52s	remaining: 7.17s
# 132:	learn: 0.1623662	total: 1.53s	remaining: 7.17s
# 133:	learn: 0.1621518	total: 1.54s	remaining: 7.16s
# 134:	learn: 0.1619671	total: 1.56s	remaining: 7.15s
# 135:	learn: 0.1618717	total: 1.57s	remaining: 7.13s
# 136:	learn: 0.1615956	total: 1.58s	remaining: 7.11s
# 137:	learn: 0.1614150	total: 1.59s	remaining: 7.1s
# 138:	learn: 0.1612144	total: 1.6s	remaining: 7.1s
# 139:	learn: 0.1609323	total: 1.61s	remaining: 7.09s
# 140:	learn: 0.1607550	total: 1.63s	remaining: 7.08s
# 141:	learn: 0.1605578	total: 1.64s	remaining: 7.08s
# 142:	learn: 0.1602829	total: 1.65s	remaining: 7.07s
# 143:	learn: 0.1600274	total: 1.67s	remaining: 7.07s
# 144:	learn: 0.1598585	total: 1.68s	remaining: 7.06s
# 145:	learn: 0.1596485	total: 1.69s	remaining: 7.05s
# 146:	learn: 0.1594359	total: 1.7s	remaining: 7.04s
# 147:	learn: 0.1592003	total: 1.71s	remaining: 7.02s
# 148:	learn: 0.1590833	total: 1.72s	remaining: 7s
# 149:	learn: 0.1588302	total: 1.73s	remaining: 6.99s
# 150:	learn: 0.1586328	total: 1.74s	remaining: 6.97s
# 151:	learn: 0.1585157	total: 1.75s	remaining: 6.96s
# 152:	learn: 0.1584241	total: 1.77s	remaining: 6.95s
# 153:	learn: 0.1580451	total: 1.78s	remaining: 6.93s
# 154:	learn: 0.1577982	total: 1.79s	remaining: 6.92s
# 155:	learn: 0.1575030	total: 1.8s	remaining: 6.9s
# 156:	learn: 0.1571746	total: 1.81s	remaining: 6.88s
# 157:	learn: 0.1570060	total: 1.82s	remaining: 6.87s
# 158:	learn: 0.1567622	total: 1.83s	remaining: 6.86s
# 159:	learn: 0.1565621	total: 1.84s	remaining: 6.84s
# 160:	learn: 0.1562996	total: 1.85s	remaining: 6.83s
# 161:	learn: 0.1560182	total: 1.86s	remaining: 6.82s
# 162:	learn: 0.1557849	total: 1.87s	remaining: 6.81s
# 163:	learn: 0.1556189	total: 1.89s	remaining: 6.79s
# 164:	learn: 0.1553411	total: 1.9s	remaining: 6.8s
# 165:	learn: 0.1551783	total: 1.91s	remaining: 6.79s
# 166:	learn: 0.1550072	total: 1.93s	remaining: 6.79s
# 167:	learn: 0.1547854	total: 1.94s	remaining: 6.78s
# 168:	learn: 0.1546022	total: 1.95s	remaining: 6.76s
# 169:	learn: 0.1543692	total: 1.96s	remaining: 6.75s
# 170:	learn: 0.1541364	total: 1.97s	remaining: 6.73s
# 171:	learn: 0.1539444	total: 1.98s	remaining: 6.72s
# 172:	learn: 0.1536162	total: 1.99s	remaining: 6.7s
# 173:	learn: 0.1535573	total: 2s	remaining: 6.68s
# 174:	learn: 0.1534357	total: 2.01s	remaining: 6.67s
# 175:	learn: 0.1531964	total: 2.02s	remaining: 6.65s
# 176:	learn: 0.1530322	total: 2.03s	remaining: 6.64s
# 177:	learn: 0.1528337	total: 2.04s	remaining: 6.62s
# 178:	learn: 0.1526693	total: 2.05s	remaining: 6.61s
# 179:	learn: 0.1524797	total: 2.06s	remaining: 6.59s
# 180:	learn: 0.1521626	total: 2.08s	remaining: 6.58s
# 181:	learn: 0.1518616	total: 2.09s	remaining: 6.57s
# 182:	learn: 0.1516520	total: 2.15s	remaining: 6.72s
# 183:	learn: 0.1514440	total: 2.16s	remaining: 6.71s
# 184:	learn: 0.1512573	total: 2.17s	remaining: 6.7s
# 185:	learn: 0.1510968	total: 2.19s	remaining: 6.69s
# 186:	learn: 0.1509532	total: 2.2s	remaining: 6.68s
# 187:	learn: 0.1508234	total: 2.21s	remaining: 6.67s
# 188:	learn: 0.1506476	total: 2.22s	remaining: 6.66s
# 189:	learn: 0.1504206	total: 2.23s	remaining: 6.64s
# 190:	learn: 0.1502347	total: 2.24s	remaining: 6.63s
# 191:	learn: 0.1499331	total: 2.26s	remaining: 6.62s
# 192:	learn: 0.1497191	total: 2.27s	remaining: 6.61s
# 193:	learn: 0.1496290	total: 2.28s	remaining: 6.6s
# 194:	learn: 0.1492639	total: 2.29s	remaining: 6.59s
# 195:	learn: 0.1489393	total: 2.31s	remaining: 6.58s
# 196:	learn: 0.1487493	total: 2.32s	remaining: 6.57s
# 197:	learn: 0.1484244	total: 2.33s	remaining: 6.55s
# 198:	learn: 0.1483381	total: 2.34s	remaining: 6.54s
# 199:	learn: 0.1480953	total: 2.35s	remaining: 6.53s
# 200:	learn: 0.1479016	total: 2.36s	remaining: 6.52s
# 201:	learn: 0.1477415	total: 2.38s	remaining: 6.5s
# 202:	learn: 0.1474719	total: 2.39s	remaining: 6.49s
# 203:	learn: 0.1473234	total: 2.4s	remaining: 6.48s
# 204:	learn: 0.1471999	total: 2.41s	remaining: 6.46s
# 205:	learn: 0.1470249	total: 2.42s	remaining: 6.45s
# 206:	learn: 0.1468875	total: 2.43s	remaining: 6.43s
# 207:	learn: 0.1467903	total: 2.44s	remaining: 6.41s
# 208:	learn: 0.1465170	total: 2.45s	remaining: 6.4s
# 209:	learn: 0.1462096	total: 2.46s	remaining: 6.39s
# 210:	learn: 0.1460548	total: 2.47s	remaining: 6.37s
# 211:	learn: 0.1457546	total: 2.48s	remaining: 6.36s
# 212:	learn: 0.1455418	total: 2.49s	remaining: 6.35s
# 213:	learn: 0.1453656	total: 2.5s	remaining: 6.33s
# 214:	learn: 0.1451104	total: 2.52s	remaining: 6.32s
# 215:	learn: 0.1449484	total: 2.53s	remaining: 6.3s
# 216:	learn: 0.1446352	total: 2.54s	remaining: 6.29s
# 217:	learn: 0.1443708	total: 2.55s	remaining: 6.28s
# 218:	learn: 0.1442291	total: 2.56s	remaining: 6.27s
# 219:	learn: 0.1440657	total: 2.57s	remaining: 6.25s
# 220:	learn: 0.1439297	total: 2.58s	remaining: 6.24s
# 221:	learn: 0.1437229	total: 2.59s	remaining: 6.22s
# 222:	learn: 0.1435240	total: 2.6s	remaining: 6.21s
# 223:	learn: 0.1432817	total: 2.61s	remaining: 6.19s
# 224:	learn: 0.1430728	total: 2.62s	remaining: 6.18s
# 225:	learn: 0.1428968	total: 2.63s	remaining: 6.16s
# 226:	learn: 0.1427412	total: 2.64s	remaining: 6.15s
# 227:	learn: 0.1425338	total: 2.65s	remaining: 6.13s
# 228:	learn: 0.1423300	total: 2.66s	remaining: 6.11s
# 229:	learn: 0.1421342	total: 2.67s	remaining: 6.1s
# 230:	learn: 0.1418070	total: 2.69s	remaining: 6.09s
# 231:	learn: 0.1415089	total: 2.7s	remaining: 6.08s
# 232:	learn: 0.1412380	total: 2.71s	remaining: 6.08s
# 233:	learn: 0.1411567	total: 2.73s	remaining: 6.07s
# 234:	learn: 0.1410673	total: 2.74s	remaining: 6.05s
# 235:	learn: 0.1408922	total: 2.75s	remaining: 6.04s
# 236:	learn: 0.1405234	total: 2.76s	remaining: 6.03s
# 237:	learn: 0.1403308	total: 2.77s	remaining: 6.02s
# 238:	learn: 0.1401247	total: 2.79s	remaining: 6.01s
# 239:	learn: 0.1398957	total: 2.8s	remaining: 6s
# 240:	learn: 0.1396605	total: 2.81s	remaining: 6s
# 241:	learn: 0.1395535	total: 2.82s	remaining: 5.99s
# 242:	learn: 0.1393723	total: 2.84s	remaining: 5.97s
# 243:	learn: 0.1391219	total: 2.85s	remaining: 5.97s
# 244:	learn: 0.1389970	total: 2.86s	remaining: 5.96s
# 245:	learn: 0.1388304	total: 2.87s	remaining: 5.94s
# 246:	learn: 0.1386916	total: 2.88s	remaining: 5.93s
# 247:	learn: 0.1385296	total: 2.89s	remaining: 5.92s
# 248:	learn: 0.1382859	total: 2.9s	remaining: 5.9s
# 249:	learn: 0.1380049	total: 2.92s	remaining: 5.9s
# 250:	learn: 0.1378252	total: 2.93s	remaining: 5.89s
# 251:	learn: 0.1376982	total: 2.94s	remaining: 5.88s
# 252:	learn: 0.1375317	total: 2.96s	remaining: 5.87s
# 253:	learn: 0.1373164	total: 2.97s	remaining: 5.86s
# 254:	learn: 0.1372359	total: 2.98s	remaining: 5.85s
# 255:	learn: 0.1370820	total: 3s	remaining: 5.84s
# 256:	learn: 0.1368854	total: 3.01s	remaining: 5.83s
# 257:	learn: 0.1366325	total: 3.02s	remaining: 5.82s
# 258:	learn: 0.1364328	total: 3.03s	remaining: 5.81s
# 259:	learn: 0.1361532	total: 3.04s	remaining: 5.8s
# 260:	learn: 0.1358514	total: 3.06s	remaining: 5.79s
# 261:	learn: 0.1356762	total: 3.07s	remaining: 5.78s
# 262:	learn: 0.1354989	total: 3.08s	remaining: 5.76s
# 263:	learn: 0.1353705	total: 3.09s	remaining: 5.75s
# 264:	learn: 0.1352134	total: 3.1s	remaining: 5.74s
# 265:	learn: 0.1350244	total: 3.11s	remaining: 5.72s
# 266:	learn: 0.1349203	total: 3.13s	remaining: 5.72s
# 267:	learn: 0.1347847	total: 3.14s	remaining: 5.71s
# 268:	learn: 0.1345944	total: 3.16s	remaining: 5.7s
# 269:	learn: 0.1345204	total: 3.17s	remaining: 5.7s
# 270:	learn: 0.1343266	total: 3.18s	remaining: 5.68s
# 271:	learn: 0.1341521	total: 3.19s	remaining: 5.67s
# 272:	learn: 0.1340107	total: 3.2s	remaining: 5.65s
# 273:	learn: 0.1339004	total: 3.21s	remaining: 5.64s
# 274:	learn: 0.1338255	total: 3.22s	remaining: 5.63s
# 275:	learn: 0.1337403	total: 3.24s	remaining: 5.62s
# 276:	learn: 0.1335867	total: 3.25s	remaining: 5.61s
# 277:	learn: 0.1333444	total: 3.26s	remaining: 5.6s
# 278:	learn: 0.1331644	total: 3.27s	remaining: 5.58s
# 279:	learn: 0.1330575	total: 3.29s	remaining: 5.57s
# 280:	learn: 0.1327991	total: 3.3s	remaining: 5.56s
# 281:	learn: 0.1325635	total: 3.31s	remaining: 5.55s
# 282:	learn: 0.1324015	total: 3.32s	remaining: 5.54s
# 283:	learn: 0.1321502	total: 3.33s	remaining: 5.52s
# 284:	learn: 0.1320247	total: 3.34s	remaining: 5.5s
# 285:	learn: 0.1319132	total: 3.35s	remaining: 5.49s
# 286:	learn: 0.1316849	total: 3.36s	remaining: 5.47s
# 287:	learn: 0.1315330	total: 3.37s	remaining: 5.46s
# 288:	learn: 0.1313958	total: 3.38s	remaining: 5.44s
# 289:	learn: 0.1313194	total: 3.38s	remaining: 5.43s
# 290:	learn: 0.1311910	total: 3.4s	remaining: 5.41s
# 291:	learn: 0.1310943	total: 3.4s	remaining: 5.4s
# 292:	learn: 0.1308577	total: 3.42s	remaining: 5.39s
# 293:	learn: 0.1307026	total: 3.43s	remaining: 5.37s
# 294:	learn: 0.1305665	total: 3.44s	remaining: 5.36s
# 295:	learn: 0.1304069	total: 3.45s	remaining: 5.35s
# 296:	learn: 0.1301690	total: 3.46s	remaining: 5.34s
# 297:	learn: 0.1300168	total: 3.47s	remaining: 5.32s
# 298:	learn: 0.1298132	total: 3.48s	remaining: 5.31s
# 299:	learn: 0.1296447	total: 3.49s	remaining: 5.3s
# 300:	learn: 0.1293795	total: 3.5s	remaining: 5.29s
# 301:	learn: 0.1292339	total: 3.52s	remaining: 5.28s
# 302:	learn: 0.1289972	total: 3.53s	remaining: 5.26s
# 303:	learn: 0.1288612	total: 3.54s	remaining: 5.25s
# 304:	learn: 0.1285531	total: 3.55s	remaining: 5.24s
# 305:	learn: 0.1283398	total: 3.56s	remaining: 5.23s
# 306:	learn: 0.1282342	total: 3.58s	remaining: 5.22s
# 307:	learn: 0.1280632	total: 3.59s	remaining: 5.21s
# 308:	learn: 0.1278781	total: 3.6s	remaining: 5.19s
# 309:	learn: 0.1277103	total: 3.61s	remaining: 5.18s
# 310:	learn: 0.1275678	total: 3.62s	remaining: 5.17s
# 311:	learn: 0.1273742	total: 3.63s	remaining: 5.15s
# 312:	learn: 0.1270846	total: 3.64s	remaining: 5.14s
# 313:	learn: 0.1269363	total: 3.65s	remaining: 5.13s
# 314:	learn: 0.1267871	total: 3.66s	remaining: 5.11s
# 315:	learn: 0.1265631	total: 3.67s	remaining: 5.1s
# 316:	learn: 0.1263327	total: 3.68s	remaining: 5.09s
# 317:	learn: 0.1261364	total: 3.69s	remaining: 5.07s
# 318:	learn: 0.1260348	total: 3.7s	remaining: 5.06s
# 319:	learn: 0.1259249	total: 3.71s	remaining: 5.04s
# 320:	learn: 0.1258461	total: 3.72s	remaining: 5.03s
# 321:	learn: 0.1257125	total: 3.73s	remaining: 5.02s
# 322:	learn: 0.1256024	total: 3.74s	remaining: 5s
# 323:	learn: 0.1254694	total: 3.75s	remaining: 4.99s
# 324:	learn: 0.1252678	total: 3.76s	remaining: 4.98s
# 325:	learn: 0.1250639	total: 3.78s	remaining: 4.97s
# 326:	learn: 0.1249177	total: 3.79s	remaining: 4.96s
# 327:	learn: 0.1248171	total: 3.8s	remaining: 4.95s
# 328:	learn: 0.1246680	total: 3.81s	remaining: 4.93s
# 329:	learn: 0.1245388	total: 3.82s	remaining: 4.92s
# 330:	learn: 0.1244087	total: 3.83s	remaining: 4.91s
# 331:	learn: 0.1243452	total: 3.84s	remaining: 4.9s
# 332:	learn: 0.1241932	total: 3.85s	remaining: 4.88s
# 333:	learn: 0.1241015	total: 3.87s	remaining: 4.87s
# 334:	learn: 0.1240478	total: 3.88s	remaining: 4.86s
# 335:	learn: 0.1238939	total: 3.89s	remaining: 4.85s
# 336:	learn: 0.1237483	total: 3.9s	remaining: 4.84s
# 337:	learn: 0.1236233	total: 3.91s	remaining: 4.82s
# 338:	learn: 0.1234609	total: 3.92s	remaining: 4.81s
# 339:	learn: 0.1233620	total: 3.93s	remaining: 4.8s
# 340:	learn: 0.1231819	total: 3.94s	remaining: 4.78s
# 341:	learn: 0.1230808	total: 3.95s	remaining: 4.77s
# 342:	learn: 0.1229496	total: 3.96s	remaining: 4.76s
# 343:	learn: 0.1227451	total: 3.97s	remaining: 4.75s
# 344:	learn: 0.1226289	total: 3.98s	remaining: 4.74s
# 345:	learn: 0.1224565	total: 4s	remaining: 4.72s
# 346:	learn: 0.1223108	total: 4.01s	remaining: 4.71s
# 347:	learn: 0.1221258	total: 4.02s	remaining: 4.7s
# 348:	learn: 0.1219603	total: 4.03s	remaining: 4.69s
# 349:	learn: 0.1217661	total: 4.04s	remaining: 4.67s
# 350:	learn: 0.1215227	total: 4.05s	remaining: 4.66s
# 351:	learn: 0.1214449	total: 4.06s	remaining: 4.65s
# 352:	learn: 0.1212808	total: 4.07s	remaining: 4.64s
# 353:	learn: 0.1210965	total: 4.08s	remaining: 4.63s
# 354:	learn: 0.1209301	total: 4.1s	remaining: 4.62s
# 355:	learn: 0.1207522	total: 4.11s	remaining: 4.61s
# 356:	learn: 0.1205447	total: 4.12s	remaining: 4.59s
# 357:	learn: 0.1204327	total: 4.13s	remaining: 4.58s
# 358:	learn: 0.1202923	total: 4.14s	remaining: 4.57s
# 359:	learn: 0.1201890	total: 4.16s	remaining: 4.56s
# 360:	learn: 0.1199611	total: 4.17s	remaining: 4.55s
# 361:	learn: 0.1198028	total: 4.18s	remaining: 4.54s
# 362:	learn: 0.1196425	total: 4.19s	remaining: 4.52s
# 363:	learn: 0.1194558	total: 4.2s	remaining: 4.51s
# 364:	learn: 0.1193515	total: 4.21s	remaining: 4.5s
# 365:	learn: 0.1192309	total: 4.22s	remaining: 4.49s
# 366:	learn: 0.1191518	total: 4.24s	remaining: 4.48s
# 367:	learn: 0.1190463	total: 4.25s	remaining: 4.46s
# 368:	learn: 0.1189090	total: 4.26s	remaining: 4.45s
# 369:	learn: 0.1187140	total: 4.27s	remaining: 4.44s
# 370:	learn: 0.1186133	total: 4.28s	remaining: 4.43s
# 371:	learn: 0.1184451	total: 4.29s	remaining: 4.42s
# 372:	learn: 0.1182856	total: 4.3s	remaining: 4.4s
# 373:	learn: 0.1181929	total: 4.31s	remaining: 4.39s
# 374:	learn: 0.1181084	total: 4.32s	remaining: 4.38s
# 375:	learn: 0.1180058	total: 4.33s	remaining: 4.37s
# 376:	learn: 0.1178613	total: 4.34s	remaining: 4.36s
# 377:	learn: 0.1177205	total: 4.36s	remaining: 4.34s
# 378:	learn: 0.1176171	total: 4.37s	remaining: 4.33s
# 379:	learn: 0.1174249	total: 4.37s	remaining: 4.32s
# 380:	learn: 0.1172696	total: 4.38s	remaining: 4.3s
# 381:	learn: 0.1170920	total: 4.39s	remaining: 4.29s
# 382:	learn: 0.1170129	total: 4.4s	remaining: 4.28s
# 383:	learn: 0.1168985	total: 4.41s	remaining: 4.26s
# 384:	learn: 0.1168612	total: 4.42s	remaining: 4.25s
# 385:	learn: 0.1167509	total: 4.44s	remaining: 4.24s
# 386:	learn: 0.1166610	total: 4.45s	remaining: 4.23s
# 387:	learn: 0.1164689	total: 4.46s	remaining: 4.21s
# 388:	learn: 0.1163478	total: 4.47s	remaining: 4.2s
# 389:	learn: 0.1161677	total: 4.48s	remaining: 4.19s
# 390:	learn: 0.1160536	total: 4.49s	remaining: 4.18s
# 391:	learn: 0.1159162	total: 4.5s	remaining: 4.17s
# 392:	learn: 0.1157394	total: 4.51s	remaining: 4.16s
# 393:	learn: 0.1156288	total: 4.52s	remaining: 4.14s
# 394:	learn: 0.1155298	total: 4.53s	remaining: 4.13s
# 395:	learn: 0.1154083	total: 4.55s	remaining: 4.12s
# 396:	learn: 0.1153215	total: 4.56s	remaining: 4.11s
# 397:	learn: 0.1151859	total: 4.57s	remaining: 4.1s
# 398:	learn: 0.1151051	total: 4.58s	remaining: 4.09s
# 399:	learn: 0.1149578	total: 4.59s	remaining: 4.08s
# 400:	learn: 0.1148403	total: 4.6s	remaining: 4.06s
# 401:	learn: 0.1146367	total: 4.61s	remaining: 4.05s
# 402:	learn: 0.1145174	total: 4.63s	remaining: 4.04s
# 403:	learn: 0.1144447	total: 4.64s	remaining: 4.03s
# 404:	learn: 0.1143533	total: 4.65s	remaining: 4.02s
# 405:	learn: 0.1142565	total: 4.66s	remaining: 4.01s
# 406:	learn: 0.1141915	total: 4.67s	remaining: 3.99s
# 407:	learn: 0.1140750	total: 4.68s	remaining: 3.98s
# 408:	learn: 0.1139097	total: 4.7s	remaining: 3.97s
# 409:	learn: 0.1137808	total: 4.71s	remaining: 3.96s
# 410:	learn: 0.1136589	total: 4.71s	remaining: 3.95s
# 411:	learn: 0.1135192	total: 4.72s	remaining: 3.93s
# 412:	learn: 0.1134337	total: 4.74s	remaining: 3.92s
# 413:	learn: 0.1132462	total: 4.75s	remaining: 3.91s
# 414:	learn: 0.1131397	total: 4.76s	remaining: 3.9s
# 415:	learn: 0.1130065	total: 4.77s	remaining: 3.89s
# 416:	learn: 0.1128508	total: 4.78s	remaining: 3.88s
# 417:	learn: 0.1127218	total: 4.79s	remaining: 3.86s
# 418:	learn: 0.1125925	total: 4.8s	remaining: 3.85s
# 419:	learn: 0.1124505	total: 4.82s	remaining: 3.84s
# 420:	learn: 0.1122889	total: 4.83s	remaining: 3.83s
# 421:	learn: 0.1122027	total: 4.84s	remaining: 3.82s
# 422:	learn: 0.1120543	total: 4.85s	remaining: 3.81s
# 423:	learn: 0.1119460	total: 4.86s	remaining: 3.79s
# 424:	learn: 0.1118396	total: 4.87s	remaining: 3.78s
# 425:	learn: 0.1117108	total: 4.88s	remaining: 3.77s
# 426:	learn: 0.1116096	total: 4.89s	remaining: 3.76s
# 427:	learn: 0.1115529	total: 4.9s	remaining: 3.75s
# 428:	learn: 0.1114587	total: 4.91s	remaining: 3.73s
# 429:	learn: 0.1113626	total: 4.92s	remaining: 3.72s
# 430:	learn: 0.1112621	total: 4.93s	remaining: 3.71s
# 431:	learn: 0.1111941	total: 4.94s	remaining: 3.69s
# 432:	learn: 0.1110778	total: 4.95s	remaining: 3.68s
# 433:	learn: 0.1109647	total: 4.96s	remaining: 3.67s
# 434:	learn: 0.1108609	total: 4.97s	remaining: 3.66s
# 435:	learn: 0.1107624	total: 4.98s	remaining: 3.65s
# 436:	learn: 0.1105921	total: 4.99s	remaining: 3.63s
# 437:	learn: 0.1104363	total: 5s	remaining: 3.62s
# 438:	learn: 0.1103777	total: 5.01s	remaining: 3.61s
# 439:	learn: 0.1102739	total: 5.03s	remaining: 3.6s
# 440:	learn: 0.1101795	total: 5.04s	remaining: 3.59s
# 441:	learn: 0.1100710	total: 5.05s	remaining: 3.58s
# 442:	learn: 0.1099863	total: 5.06s	remaining: 3.56s
# 443:	learn: 0.1098863	total: 5.07s	remaining: 3.55s
# 444:	learn: 0.1097797	total: 5.08s	remaining: 3.54s
# 445:	learn: 0.1096622	total: 5.09s	remaining: 3.53s
# 446:	learn: 0.1094612	total: 5.1s	remaining: 3.52s
# 447:	learn: 0.1093931	total: 5.12s	remaining: 3.5s
# 448:	learn: 0.1092073	total: 5.13s	remaining: 3.49s
# 449:	learn: 0.1090430	total: 5.14s	remaining: 3.48s
# 450:	learn: 0.1088787	total: 5.15s	remaining: 3.47s
# 451:	learn: 0.1087361	total: 5.16s	remaining: 3.46s
# 452:	learn: 0.1086197	total: 5.17s	remaining: 3.44s
# 453:	learn: 0.1084744	total: 5.18s	remaining: 3.43s
# 454:	learn: 0.1082883	total: 5.19s	remaining: 3.42s
# 455:	learn: 0.1081983	total: 5.2s	remaining: 3.41s
# 456:	learn: 0.1079293	total: 5.22s	remaining: 3.4s
# 457:	learn: 0.1078001	total: 5.23s	remaining: 3.39s
# 458:	learn: 0.1077089	total: 5.24s	remaining: 3.38s
# 459:	learn: 0.1075559	total: 5.25s	remaining: 3.37s
# 460:	learn: 0.1074705	total: 5.26s	remaining: 3.35s
# 461:	learn: 0.1073789	total: 5.27s	remaining: 3.34s
# 462:	learn: 0.1072960	total: 5.28s	remaining: 3.33s
# 463:	learn: 0.1071458	total: 5.3s	remaining: 3.32s
# 464:	learn: 0.1069621	total: 5.31s	remaining: 3.31s
# 465:	learn: 0.1069161	total: 5.32s	remaining: 3.3s
# 466:	learn: 0.1068124	total: 5.33s	remaining: 3.29s
# 467:	learn: 0.1066531	total: 5.35s	remaining: 3.28s
# 468:	learn: 0.1064766	total: 5.36s	remaining: 3.27s
# 469:	learn: 0.1063124	total: 5.37s	remaining: 3.25s
# 470:	learn: 0.1062004	total: 5.38s	remaining: 3.24s
# 471:	learn: 0.1061030	total: 5.39s	remaining: 3.23s
# 472:	learn: 0.1059492	total: 5.4s	remaining: 3.22s
# 473:	learn: 0.1057918	total: 5.42s	remaining: 3.21s
# 474:	learn: 0.1056597	total: 5.43s	remaining: 3.2s
# 475:	learn: 0.1054995	total: 5.44s	remaining: 3.19s
# 476:	learn: 0.1053744	total: 5.46s	remaining: 3.18s
# 477:	learn: 0.1052305	total: 5.47s	remaining: 3.17s
# 478:	learn: 0.1051822	total: 5.48s	remaining: 3.16s
# 479:	learn: 0.1050066	total: 5.5s	remaining: 3.15s
# 480:	learn: 0.1048905	total: 5.51s	remaining: 3.14s
# 481:	learn: 0.1048090	total: 5.52s	remaining: 3.13s
# 482:	learn: 0.1046775	total: 5.53s	remaining: 3.11s
# 483:	learn: 0.1045954	total: 5.54s	remaining: 3.1s
# 484:	learn: 0.1044795	total: 5.55s	remaining: 3.09s
# 485:	learn: 0.1044201	total: 5.57s	remaining: 3.08s
# 486:	learn: 0.1042941	total: 5.58s	remaining: 3.07s
# 487:	learn: 0.1042204	total: 5.59s	remaining: 3.06s
# 488:	learn: 0.1041203	total: 5.61s	remaining: 3.05s
# 489:	learn: 0.1039950	total: 5.62s	remaining: 3.04s
# 490:	learn: 0.1037608	total: 5.63s	remaining: 3.03s
# 491:	learn: 0.1036502	total: 5.64s	remaining: 3.02s
# 492:	learn: 0.1035546	total: 5.65s	remaining: 3s
# 493:	learn: 0.1034782	total: 5.66s	remaining: 2.99s
# 494:	learn: 0.1034046	total: 5.67s	remaining: 2.98s
# 495:	learn: 0.1032155	total: 5.68s	remaining: 2.97s
# 496:	learn: 0.1031546	total: 5.7s	remaining: 2.96s
# 497:	learn: 0.1030814	total: 5.71s	remaining: 2.95s
# 498:	learn: 0.1029807	total: 5.72s	remaining: 2.93s
# 499:	learn: 0.1028792	total: 5.73s	remaining: 2.92s
# 500:	learn: 0.1027067	total: 5.75s	remaining: 2.91s
# 501:	learn: 0.1025857	total: 5.76s	remaining: 2.9s
# 502:	learn: 0.1024938	total: 5.77s	remaining: 2.89s
# 503:	learn: 0.1023772	total: 5.78s	remaining: 2.88s
# 504:	learn: 0.1022308	total: 5.79s	remaining: 2.87s
# 505:	learn: 0.1021198	total: 5.8s	remaining: 2.85s
# 506:	learn: 0.1020219	total: 5.81s	remaining: 2.84s
# 507:	learn: 0.1019148	total: 5.83s	remaining: 2.83s
# 508:	learn: 0.1017992	total: 5.84s	remaining: 2.82s
# 509:	learn: 0.1017097	total: 5.85s	remaining: 2.81s
# 510:	learn: 0.1016509	total: 5.86s	remaining: 2.8s
# 511:	learn: 0.1015544	total: 5.87s	remaining: 2.79s
# 512:	learn: 0.1014746	total: 5.88s	remaining: 2.77s
# 513:	learn: 0.1013057	total: 5.89s	remaining: 2.76s
# 514:	learn: 0.1011528	total: 5.9s	remaining: 2.75s
# 515:	learn: 0.1009845	total: 5.91s	remaining: 2.74s
# 516:	learn: 0.1008390	total: 5.92s	remaining: 2.73s
# 517:	learn: 0.1007784	total: 5.93s	remaining: 2.71s
# 518:	learn: 0.1006300	total: 5.95s	remaining: 2.7s
# 519:	learn: 0.1005419	total: 5.96s	remaining: 2.69s
# 520:	learn: 0.1003478	total: 5.98s	remaining: 2.68s
# 521:	learn: 0.1000952	total: 5.99s	remaining: 2.67s
# 522:	learn: 0.1000315	total: 6s	remaining: 2.66s
# 523:	learn: 0.0999474	total: 6.01s	remaining: 2.65s
# 524:	learn: 0.0998673	total: 6.03s	remaining: 2.64s
# 525:	learn: 0.0997854	total: 6.04s	remaining: 2.63s
# 526:	learn: 0.0996391	total: 6.05s	remaining: 2.62s
# 527:	learn: 0.0994931	total: 6.07s	remaining: 2.61s
# 528:	learn: 0.0993464	total: 6.08s	remaining: 2.6s
# 529:	learn: 0.0992683	total: 6.09s	remaining: 2.58s
# 530:	learn: 0.0991766	total: 6.1s	remaining: 2.57s
# 531:	learn: 0.0990888	total: 6.11s	remaining: 2.56s
# 532:	learn: 0.0989365	total: 6.12s	remaining: 2.55s
# 533:	learn: 0.0988125	total: 6.13s	remaining: 2.54s
# 534:	learn: 0.0987424	total: 6.15s	remaining: 2.53s
# 535:	learn: 0.0984593	total: 6.16s	remaining: 2.52s
# 536:	learn: 0.0983410	total: 6.17s	remaining: 2.5s
# 537:	learn: 0.0981441	total: 6.18s	remaining: 2.49s
# 538:	learn: 0.0980614	total: 6.19s	remaining: 2.48s
# 539:	learn: 0.0978501	total: 6.21s	remaining: 2.47s
# 540:	learn: 0.0977922	total: 6.22s	remaining: 2.46s
# 541:	learn: 0.0976706	total: 6.23s	remaining: 2.45s
# 542:	learn: 0.0975886	total: 6.25s	remaining: 2.44s
# 543:	learn: 0.0974331	total: 6.26s	remaining: 2.43s
# 544:	learn: 0.0973928	total: 6.27s	remaining: 2.42s
# 545:	learn: 0.0973572	total: 6.28s	remaining: 2.4s
# 546:	learn: 0.0972709	total: 6.29s	remaining: 2.39s
# 547:	learn: 0.0971619	total: 6.3s	remaining: 2.38s
# 548:	learn: 0.0970774	total: 6.32s	remaining: 2.37s
# 549:	learn: 0.0969977	total: 6.33s	remaining: 2.36s
# 550:	learn: 0.0968475	total: 6.34s	remaining: 2.35s
# 551:	learn: 0.0967087	total: 6.35s	remaining: 2.34s
# 552:	learn: 0.0966191	total: 6.36s	remaining: 2.32s
# 553:	learn: 0.0965279	total: 6.37s	remaining: 2.31s
# 554:	learn: 0.0964212	total: 6.39s	remaining: 2.3s
# 555:	learn: 0.0963724	total: 6.4s	remaining: 2.29s
# 556:	learn: 0.0962772	total: 6.41s	remaining: 2.28s
# 557:	learn: 0.0962208	total: 6.42s	remaining: 2.27s
# 558:	learn: 0.0961208	total: 6.44s	remaining: 2.26s
# 559:	learn: 0.0960791	total: 6.45s	remaining: 2.25s
# 560:	learn: 0.0959309	total: 6.46s	remaining: 2.23s
# 561:	learn: 0.0957954	total: 6.47s	remaining: 2.22s
# 562:	learn: 0.0956735	total: 6.48s	remaining: 2.21s
# 563:	learn: 0.0955618	total: 6.49s	remaining: 2.2s
# 564:	learn: 0.0954506	total: 6.5s	remaining: 2.19s
# 565:	learn: 0.0953596	total: 6.51s	remaining: 2.17s
# 566:	learn: 0.0952465	total: 6.53s	remaining: 2.16s
# 567:	learn: 0.0951070	total: 6.54s	remaining: 2.15s
# 568:	learn: 0.0950169	total: 6.55s	remaining: 2.14s
# 569:	learn: 0.0949484	total: 6.56s	remaining: 2.13s
# 570:	learn: 0.0948777	total: 6.57s	remaining: 2.12s
# 571:	learn: 0.0947651	total: 6.58s	remaining: 2.1s
# 572:	learn: 0.0947127	total: 6.59s	remaining: 2.09s
# 573:	learn: 0.0946020	total: 6.6s	remaining: 2.08s
# 574:	learn: 0.0945131	total: 6.61s	remaining: 2.07s
# 575:	learn: 0.0944202	total: 6.62s	remaining: 2.06s
# 576:	learn: 0.0943539	total: 6.64s	remaining: 2.05s
# 577:	learn: 0.0942513	total: 6.66s	remaining: 2.04s
# 578:	learn: 0.0941529	total: 6.67s	remaining: 2.03s
# 579:	learn: 0.0941003	total: 6.68s	remaining: 2.02s
# 580:	learn: 0.0939547	total: 6.69s	remaining: 2s
# 581:	learn: 0.0938983	total: 6.7s	remaining: 1.99s
# 582:	learn: 0.0938276	total: 6.71s	remaining: 1.98s
# 583:	learn: 0.0937285	total: 6.73s	remaining: 1.97s
# 584:	learn: 0.0936441	total: 6.74s	remaining: 1.96s
# 585:	learn: 0.0934830	total: 6.76s	remaining: 1.95s
# 586:	learn: 0.0933944	total: 6.77s	remaining: 1.94s
# 587:	learn: 0.0932842	total: 6.78s	remaining: 1.93s
# 588:	learn: 0.0931418	total: 6.79s	remaining: 1.91s
# 589:	learn: 0.0930185	total: 6.8s	remaining: 1.9s
# 590:	learn: 0.0928892	total: 6.81s	remaining: 1.89s
# 591:	learn: 0.0927594	total: 6.83s	remaining: 1.88s
# 592:	learn: 0.0926780	total: 6.84s	remaining: 1.87s
# 593:	learn: 0.0925279	total: 6.85s	remaining: 1.86s
# 594:	learn: 0.0923880	total: 6.86s	remaining: 1.84s
# 595:	learn: 0.0921635	total: 6.87s	remaining: 1.83s
# 596:	learn: 0.0920379	total: 6.88s	remaining: 1.82s
# 597:	learn: 0.0919569	total: 6.9s	remaining: 1.81s
# 598:	learn: 0.0919052	total: 6.91s	remaining: 1.8s
# 599:	learn: 0.0918400	total: 6.92s	remaining: 1.79s
# 600:	learn: 0.0917271	total: 6.93s	remaining: 1.78s
# 601:	learn: 0.0915994	total: 6.94s	remaining: 1.76s
# 602:	learn: 0.0915086	total: 6.95s	remaining: 1.75s
# 603:	learn: 0.0914499	total: 6.96s	remaining: 1.74s
# 604:	learn: 0.0913470	total: 6.98s	remaining: 1.73s
# 605:	learn: 0.0912517	total: 6.99s	remaining: 1.72s
# 606:	learn: 0.0911742	total: 7s	remaining: 1.71s
# 607:	learn: 0.0909811	total: 7.02s	remaining: 1.7s
# 608:	learn: 0.0908849	total: 7.03s	remaining: 1.69s
# 609:	learn: 0.0908524	total: 7.05s	remaining: 1.68s
# 610:	learn: 0.0906911	total: 7.06s	remaining: 1.66s
# 611:	learn: 0.0905387	total: 7.07s	remaining: 1.65s
# 612:	learn: 0.0904016	total: 7.08s	remaining: 1.64s
# 613:	learn: 0.0902357	total: 7.09s	remaining: 1.63s
# 614:	learn: 0.0901369	total: 7.11s	remaining: 1.62s
# 615:	learn: 0.0900403	total: 7.12s	remaining: 1.61s
# 616:	learn: 0.0899842	total: 7.13s	remaining: 1.59s
# 617:	learn: 0.0898904	total: 7.14s	remaining: 1.58s
# 618:	learn: 0.0898352	total: 7.16s	remaining: 1.57s
# 619:	learn: 0.0897115	total: 7.17s	remaining: 1.56s
# 620:	learn: 0.0896474	total: 7.18s	remaining: 1.55s
# 621:	learn: 0.0896147	total: 7.19s	remaining: 1.54s
# 622:	learn: 0.0895559	total: 7.2s	remaining: 1.52s
# 623:	learn: 0.0894091	total: 7.21s	remaining: 1.51s
# 624:	learn: 0.0893449	total: 7.21s	remaining: 1.5s
# 625:	learn: 0.0892432	total: 7.23s	remaining: 1.49s
# 626:	learn: 0.0891671	total: 7.24s	remaining: 1.48s
# 627:	learn: 0.0890644	total: 7.25s	remaining: 1.47s
# 628:	learn: 0.0890208	total: 7.26s	remaining: 1.45s
# 629:	learn: 0.0889075	total: 7.27s	remaining: 1.44s
# 630:	learn: 0.0888620	total: 7.28s	remaining: 1.43s
# 631:	learn: 0.0887082	total: 7.29s	remaining: 1.42s
# 632:	learn: 0.0886514	total: 7.3s	remaining: 1.41s
# 633:	learn: 0.0884933	total: 7.31s	remaining: 1.39s
# 634:	learn: 0.0884445	total: 7.32s	remaining: 1.38s
# 635:	learn: 0.0883525	total: 7.33s	remaining: 1.37s
# 636:	learn: 0.0882564	total: 7.34s	remaining: 1.36s
# 637:	learn: 0.0881426	total: 7.35s	remaining: 1.35s
# 638:	learn: 0.0879994	total: 7.36s	remaining: 1.33s
# 639:	learn: 0.0878657	total: 7.37s	remaining: 1.32s
# 640:	learn: 0.0877640	total: 7.38s	remaining: 1.31s
# 641:	learn: 0.0876836	total: 7.39s	remaining: 1.3s
# 642:	learn: 0.0876194	total: 7.4s	remaining: 1.29s
# 643:	learn: 0.0875526	total: 7.41s	remaining: 1.28s
# 644:	learn: 0.0874344	total: 7.42s	remaining: 1.27s
# 645:	learn: 0.0873057	total: 7.43s	remaining: 1.25s
# 646:	learn: 0.0871984	total: 7.45s	remaining: 1.24s
# 647:	learn: 0.0870888	total: 7.46s	remaining: 1.23s
# 648:	learn: 0.0869752	total: 7.47s	remaining: 1.22s
# 649:	learn: 0.0868210	total: 7.48s	remaining: 1.21s
# 650:	learn: 0.0867266	total: 7.5s	remaining: 1.2s
# 651:	learn: 0.0865930	total: 7.51s	remaining: 1.19s
# 652:	learn: 0.0865059	total: 7.52s	remaining: 1.18s
# 653:	learn: 0.0863749	total: 7.54s	remaining: 1.16s
# 654:	learn: 0.0863182	total: 7.55s	remaining: 1.15s
# 655:	learn: 0.0861829	total: 7.56s	remaining: 1.14s
# 656:	learn: 0.0861509	total: 7.57s	remaining: 1.13s
# 657:	learn: 0.0860509	total: 7.58s	remaining: 1.12s
# 658:	learn: 0.0859831	total: 7.59s	remaining: 1.1s
# 659:	learn: 0.0859154	total: 7.6s	remaining: 1.09s
# 660:	learn: 0.0857951	total: 7.61s	remaining: 1.08s
# 661:	learn: 0.0857309	total: 7.62s	remaining: 1.07s
# 662:	learn: 0.0856740	total: 7.63s	remaining: 1.06s
# 663:	learn: 0.0856257	total: 7.64s	remaining: 1.05s
# 664:	learn: 0.0855138	total: 7.65s	remaining: 1.03s
# 665:	learn: 0.0853818	total: 7.66s	remaining: 1.02s
# 666:	learn: 0.0852703	total: 7.67s	remaining: 1.01s
# 667:	learn: 0.0852000	total: 7.68s	remaining: 1s
# 668:	learn: 0.0851367	total: 7.69s	remaining: 989ms
# 669:	learn: 0.0850370	total: 7.71s	remaining: 978ms
# 670:	learn: 0.0849847	total: 7.72s	remaining: 966ms
# 671:	learn: 0.0849088	total: 7.73s	remaining: 955ms
# 672:	learn: 0.0848172	total: 7.74s	remaining: 943ms
# 673:	learn: 0.0847486	total: 7.75s	remaining: 932ms
# 674:	learn: 0.0847139	total: 7.76s	remaining: 920ms
# 675:	learn: 0.0846781	total: 7.77s	remaining: 909ms
# 676:	learn: 0.0845967	total: 7.79s	remaining: 897ms
# 677:	learn: 0.0845449	total: 7.8s	remaining: 886ms
# 678:	learn: 0.0844936	total: 7.81s	remaining: 874ms
# 679:	learn: 0.0844035	total: 7.82s	remaining: 863ms
# 680:	learn: 0.0842666	total: 7.83s	remaining: 851ms
# 681:	learn: 0.0841732	total: 7.84s	remaining: 840ms
# 682:	learn: 0.0840400	total: 7.86s	remaining: 828ms
# 683:	learn: 0.0839630	total: 7.87s	remaining: 817ms
# 684:	learn: 0.0838335	total: 7.88s	remaining: 806ms
# 685:	learn: 0.0837265	total: 7.89s	remaining: 794ms
# 686:	learn: 0.0836140	total: 7.91s	remaining: 782ms
# 687:	learn: 0.0835052	total: 7.92s	remaining: 771ms
# 688:	learn: 0.0834304	total: 7.93s	remaining: 759ms
# 689:	learn: 0.0833588	total: 7.94s	remaining: 748ms
# 690:	learn: 0.0832797	total: 7.95s	remaining: 736ms
# 691:	learn: 0.0831718	total: 7.96s	remaining: 725ms
# 692:	learn: 0.0830481	total: 7.97s	remaining: 713ms
# 693:	learn: 0.0829172	total: 7.98s	remaining: 702ms
# 694:	learn: 0.0828076	total: 7.99s	remaining: 690ms
# 695:	learn: 0.0827502	total: 8s	remaining: 679ms
# 696:	learn: 0.0827062	total: 8.02s	remaining: 667ms
# 697:	learn: 0.0826086	total: 8.03s	remaining: 656ms
# 698:	learn: 0.0825166	total: 8.04s	remaining: 644ms
# 699:	learn: 0.0824139	total: 8.05s	remaining: 632ms
# 700:	learn: 0.0823593	total: 8.06s	remaining: 621ms
# 701:	learn: 0.0823024	total: 8.07s	remaining: 610ms
# 702:	learn: 0.0821783	total: 8.09s	remaining: 598ms
# 703:	learn: 0.0820780	total: 8.1s	remaining: 587ms
# 704:	learn: 0.0820406	total: 8.11s	remaining: 575ms
# 705:	learn: 0.0819027	total: 8.13s	remaining: 564ms
# 706:	learn: 0.0818257	total: 8.13s	remaining: 552ms
# 707:	learn: 0.0817822	total: 8.14s	remaining: 541ms
# 708:	learn: 0.0816572	total: 8.15s	remaining: 529ms
# 709:	learn: 0.0816078	total: 8.16s	remaining: 518ms
# 710:	learn: 0.0815491	total: 8.18s	remaining: 506ms
# 711:	learn: 0.0814803	total: 8.18s	remaining: 494ms
# 712:	learn: 0.0814509	total: 8.19s	remaining: 483ms
# 713:	learn: 0.0813854	total: 8.2s	remaining: 471ms
# 714:	learn: 0.0813132	total: 8.21s	remaining: 459ms
# 715:	learn: 0.0812622	total: 8.22s	remaining: 448ms
# 716:	learn: 0.0812061	total: 8.23s	remaining: 436ms
# 717:	learn: 0.0811357	total: 8.24s	remaining: 425ms
# 718:	learn: 0.0809860	total: 8.25s	remaining: 413ms
# 719:	learn: 0.0808848	total: 8.26s	remaining: 402ms
# 720:	learn: 0.0808305	total: 8.27s	remaining: 390ms
# 721:	learn: 0.0807027	total: 8.28s	remaining: 379ms
# 722:	learn: 0.0806594	total: 8.29s	remaining: 367ms
# 723:	learn: 0.0806062	total: 8.3s	remaining: 356ms
# 724:	learn: 0.0804931	total: 8.31s	remaining: 344ms
# 725:	learn: 0.0804002	total: 8.32s	remaining: 332ms
# 726:	learn: 0.0803379	total: 8.33s	remaining: 321ms
# 727:	learn: 0.0802413	total: 8.34s	remaining: 309ms
# 728:	learn: 0.0801675	total: 8.36s	remaining: 298ms
# 729:	learn: 0.0801023	total: 8.37s	remaining: 287ms
# 730:	learn: 0.0800294	total: 8.38s	remaining: 275ms
# 731:	learn: 0.0799633	total: 8.39s	remaining: 264ms
# 732:	learn: 0.0799135	total: 8.4s	remaining: 252ms
# 733:	learn: 0.0798410	total: 8.41s	remaining: 241ms
# 734:	learn: 0.0798210	total: 8.42s	remaining: 229ms
# 735:	learn: 0.0797386	total: 8.43s	remaining: 218ms
# 736:	learn: 0.0796360	total: 8.44s	remaining: 206ms
# 737:	learn: 0.0795039	total: 8.45s	remaining: 195ms
# 738:	learn: 0.0794157	total: 8.46s	remaining: 183ms
# 739:	learn: 0.0793673	total: 8.47s	remaining: 172ms
# 740:	learn: 0.0793051	total: 8.48s	remaining: 160ms
# 741:	learn: 0.0792326	total: 8.49s	remaining: 149ms
# 742:	learn: 0.0791395	total: 8.5s	remaining: 137ms
# 743:	learn: 0.0790595	total: 8.51s	remaining: 126ms
# 744:	learn: 0.0790009	total: 8.52s	remaining: 114ms
# 745:	learn: 0.0789460	total: 8.53s	remaining: 103ms
# 746:	learn: 0.0788742	total: 8.55s	remaining: 91.5ms
# 747:	learn: 0.0787943	total: 8.56s	remaining: 80.1ms
# 748:	learn: 0.0786409	total: 8.57s	remaining: 68.6ms
# 749:	learn: 0.0785573	total: 8.58s	remaining: 57.2ms
# 750:	learn: 0.0785051	total: 8.59s	remaining: 45.7ms
# 751:	learn: 0.0784141	total: 8.6s	remaining: 34.3ms
# 752:	learn: 0.0783237	total: 8.61s	remaining: 22.9ms
# 753:	learn: 0.0782505	total: 8.62s	remaining: 11.4ms
# 754:	learn: 0.0781460	total: 8.63s	remaining: 0us
# CatBoostClassifier 결과:
# F1 Score: 0.22941970310391363
# ---
# Confusion Matrix:
# [[7446  216]
#  [ 355   85]]
# ---
# Accuracy: 0.9295235744260676
# Precision: 0.2823920265780731
# Recall: 0.19318181818181818

# %% [markdown]
# AutoClave 모델

# %%
# 모델 설정 및 하이퍼파라미터
models = {
    'LGBMClassifier': LGBMClassifier(
        n_estimators=1205,
        num_leaves=1880,
        max_depth=53,
        learning_rate=0.0877525670484991,
        min_child_samples=288,
        boosting_type='dart',
        random_state=RANDOM_STATE,
        verbose=-1
    )
}

# 학습
train_and_evaluate_model('LGBMClassifier', train_data_autoclave)
# Out:
# LGBMClassifier 결과:
# F1 Score: 0.25271739130434784
# ---
# Confusion Matrix:
# [[7459  203]
#  [ 347   93]]
# ---
# Accuracy: 0.9321155270303628
# Precision: 0.3141891891891892
# Recall: 0.21136363636363636

# %% [markdown]
# Fill1 모델

# %%
# 모델 설정 및 하이퍼파라미터
models = {
    'LGBMClassifier': LGBMClassifier(
        n_estimators=979,
        num_leaves=1565,
        max_depth=34,
        learning_rate=0.04888906225539191,
        min_child_samples=36,
        boosting_type='dart',
        random_state=RANDOM_STATE,
        verbose=-1
    )
}

# 학습
train_and_evaluate_model('LGBMClassifier', train_data_fill1)
# Out:
# LGBMClassifier 결과:
# F1 Score: 0.25299600532623173
# ---
# Confusion Matrix:
# [[7446  216]
#  [ 345   95]]
# ---
# Accuracy: 0.9307578375709701
# Precision: 0.3054662379421222
# Recall: 0.2159090909090909

# %% [markdown]
# Fill2 모델

# %%
# 모델 설정 및 하이퍼파라미터
models = {
    'LGBMClassifier': LGBMClassifier(
        n_estimators=1308,
        num_leaves=1813,
        max_depth=105,
        learning_rate=0.0026995515108598628,
        min_child_samples=37,
        boosting_type='dart',
        random_state=RANDOM_STATE,
        verbose=-1
    )
}

# 학습
train_and_evaluate_model('LGBMClassifier', train_data_fill2)
# Out:
# LGBMClassifier 결과:
# F1 Score: 0.2562189054726368
# ---
# Confusion Matrix:
# [[7401  261]
#  [ 337  103]]
# ---
# Accuracy: 0.9261910639348309
# Precision: 0.28296703296703296
# Recall: 0.2340909090909091

# %% [markdown]
# ---

# %% [markdown]
# (작성중)

# %% [markdown]
# ---

# %% [markdown]
# ## 모델 학습

# %%
from sklearn.model_selection import train_test_split

def split_data(data, target, test_size=0.2):
    return train_test_split(data, test_size=test_size, stratify=target, random_state=RANDOM_STATE)

df_train_dam, df_val_dam = split_data(train_data_dam, train_data["target"])
df_train_fill1, df_val_fill1 = split_data(train_data_fill1, train_data["target"])
df_train_fill2, df_val_fill2 = split_data(train_data_fill2, train_data["target"])
df_train_autoclave, df_val_autoclave = split_data(train_data_autoclave, train_data["target"])

# %% [markdown]
# 공정별로 모델 학습 진행

# %% [markdown]
# 분할한 데이터 -> 원래의 데이터(train data)로 학습한 새 모델 생성

# %%
# SettingWithCopyWarning 경고 무시
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# 모델 학습
preprocess_and_train(train_data_dam, model_Dam)
preprocess_and_train(train_data_fill1, model_Fill1)
preprocess_and_train(train_data_fill2, model_Fill2)
preprocess_and_train(train_data_autoclave, model_AutoClave)

# %%
# 예측에 필요한 데이터 분리
x_test_dam = test_data_dam.drop(["target", "Set ID"], axis=1)
x_test_fill1 = test_data_fill1.drop(["target", "Set ID"], axis=1)
x_test_fill2 = test_data_fill2.drop(["target", "Set ID"], axis=1)
x_test_autoclave = test_data_autoclave.drop(["target", "Set ID"], axis=1)

# 각 공정의 예측 확률 계산
probs = [
    model_Dam.predict_proba(x_test_dam)[:, 1]
    , model_Fill1.predict_proba(x_test_fill1)[:, 1]
    , model_Fill2.predict_proba(x_test_fill2)[:, 1]
    , model_AutoClave.predict_proba(x_test_autoclave)[:, 1]
]

# %%
# 소프트 보팅: 각 모델의 확률 평균 계산
soft_voting_probs = np.mean(probs, axis=0)

# 최종 예측: 평균 확률에 대해 스레드 홀드 0.3 적용
final_predictions = (soft_voting_probs >= 0.23).astype(int)

# 최종 예측 결과 출력
print(sum(final_predictions))
# Out:
# 1058

# %%
# 소프트 보팅: 각 모델의 확률 평균 계산
soft_voting_probs = np.mean(probs, axis=0)

# 최종 예측: 평균 확률에 대해 스레드 홀드 0.3 적용
final_predictions = (soft_voting_probs >= 0.3).astype(int)

# 최종 예측 결과 출력
print(sum(final_predictions))
# Out:
# 572

# %%
# 4개의 예측 중 확률값이 0.3 이상이면 1(AbNormal)로 예측
threshold = 0.3
final_predictions = (np.any([prob > threshold for prob in probs], axis=0)).astype(int)

print(sum(final_predictions))
# Out:
# 1783

# %% [markdown]
# ## 4. 제출하기

# %% [markdown]
# ### 제출 파일 작성

# %%
# 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
df_sub = pd.read_csv("submission.csv")
df_sub["target"] = final_predictions

# df_sub['target'] 값을 문자열 레이블로 변환
df_sub['target'] = df_sub['target'].apply(lambda x: 'AbNormal' if x == 1 else 'Normal')

# 제출 파일 저장
df_sub.to_csv("submission.csv", index=False)

# %%
df_sub['target'].value_counts()
# Out:
# Normal      16303
# AbNormal     1058
# Name: target, dtype: int64

# %%
df_sub.head(10)
# Out:
#                              Set ID  target
# 0  0001be084fbc4aaa9d921f39e595961b  Normal
# 1  0005bbd180064abd99e63f9ed3e1ac80  Normal
# 2  000948934c4140d883d670adcb609584  Normal
# 3  000a6bfd02874c6296dc7b2e9c5678a7  Normal
# 4  0018e78ce91343678716e2ea27a51c95  Normal
# 5  001fda4596f545d0a3b0ce85fbea77d2  Normal
# 6  0020734a7b29472298358ad58645a0c9  Normal
# 7  00234c5914cd4c4a888d13f8b3773135  Normal
# 8  00297b6c93e44d49ac534758a23dc74e  Normal
# 9  002d904240d84b188d410d16383a9c3a  Normal

# %% [markdown]
# **우측 상단의 제출 버튼을 클릭해 결과를 확인하세요**
