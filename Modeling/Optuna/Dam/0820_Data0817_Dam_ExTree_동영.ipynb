# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ### 데이터 읽어오기

# %%
import os
from pprint import pprint

import optuna
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import pandas as pd

RANDOM_STATE = 110

train_data = pd.read_csv("C:/Users/KimDongyoung/Desktop/git_LGaimers5/Lg_aimers5/data/train_data_0817.csv")
test_data = pd.read_csv("C:/Users/KimDongyoung/Desktop/git_LGaimers5/Lg_aimers5/data/test_data_0817.csv")

# %% [markdown]
# ---

# %%
# dam, fill1, fill2 공통 변수
var_dam_fill = [
    'Equipment_same_num',
    'PalletID_Collect_Result_encoded',
    'Production_Qty_Collect_Result',
    'WorkMode Collect Result'
]

# %%
# 전체 공통 변수
### correlation 확인을 위한 변수 리스트
var_all_corr = [
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### train
var_all_train = [
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### test
var_all_test = [
    'Set ID',
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

# %%
# '_Dam'을 포함하는 변수 선택
dam_variables = [var for var in train_data.columns if '_Dam' in var]

# train
final_columns_train = var_dam_fill + var_all_train + dam_variables
train_data_dam = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + dam_variables
test_data_dam = test_data[final_columns_test]

# %%
# '_Fill1'을 포함하는 변수 선택
fill1_variables = [var for var in train_data.columns if '_Fill1' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill1_variables
train_data_fill1 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill1_variables
test_data_fill1 = test_data[final_columns_test]

# %%
# '_Fill2'을 포함하는 변수 선택
fill2_variables = [var for var in train_data.columns if '_Fill2' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill2_variables
train_data_fill2 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill2_variables
test_data_fill2 = test_data[final_columns_test]

# %%
# '_AutoClave'을 포함하는 변수 선택
autoclave_variables = [var for var in train_data.columns if '_AutoClave' in var]

# train
final_columns_train = var_all_train + autoclave_variables
train_data_autoclave = train_data[final_columns_train]

# test 
final_columns_test = var_all_test + autoclave_variables
test_data_autoclave = test_data[final_columns_test]

# %%
# 각 DataFrame의 칼럼 수 계산
num_columns_train_data = train_data.shape[1]
num_columns_train_data_dam = train_data_dam.shape[1]
num_columns_train_data_autoclave = train_data_autoclave.shape[1]
num_columns_train_data_fill1 = train_data_fill1.shape[1]
num_columns_train_data_fill2 = train_data_fill2.shape[1]

num_columns_test_data = test_data.shape[1]
num_columns_test_data_dam = test_data_dam.shape[1]
num_columns_test_data_autoclave = test_data_autoclave.shape[1]
num_columns_test_data_fill1 = test_data_fill1.shape[1]
num_columns_test_data_fill2 = test_data_fill2.shape[1]

# 각 DataFrame의 칼럼 수 출력
print("----train data-----")
print(f"train_data DataFrame의 칼럼 수: {num_columns_train_data}")
print(f"train_data_dam DataFrame의 칼럼 수: {num_columns_train_data_dam}")
print(f"train_data_autoclave DataFrame의 칼럼 수: {num_columns_train_data_autoclave}")
print(f"train_data_fill1 DataFrame의 칼럼 수: {num_columns_train_data_fill1}")
print(f"train_data_fill2 DataFrame의 칼럼 수: {num_columns_train_data_fill2}")
print("----test data-----")
print(f"test_data DataFrame의 칼럼 수: {num_columns_test_data}")
print(f"test_data_dam DataFrame의 칼럼 수: {num_columns_test_data_dam}")
print(f"test_data_autoclave DataFrame의 칼럼 수: {num_columns_test_data_autoclave}")
print(f"test_data_fill1 DataFrame의 칼럼 수: {num_columns_test_data_fill1}")
print(f"test_data_fill2 DataFrame의 칼럼 수: {num_columns_test_data_fill2}")
# Out:
# ----train data-----
# train_data DataFrame의 칼럼 수: 38
# train_data_dam DataFrame의 칼럼 수: 21
# train_data_autoclave DataFrame의 칼럼 수: 8
# train_data_fill1 DataFrame의 칼럼 수: 13
# train_data_fill2 DataFrame의 칼럼 수: 13
# ----test data-----
# test_data DataFrame의 칼럼 수: 39
# test_data_dam DataFrame의 칼럼 수: 22
# test_data_autoclave DataFrame의 칼럼 수: 9
# test_data_fill1 DataFrame의 칼럼 수: 14
# test_data_fill2 DataFrame의 칼럼 수: 14

# %% [markdown]
# ## Optuna

# %% [markdown]
# 스레스홀드 0.3으로 맞춘상태에서 튜닝 진행한 것

# %%
# 'Normal'과 'AbNormal'을 숫자로 변환
train_data_dam['target'] = train_data_dam['target'].map({'Normal': 0, 'AbNormal': 1})

# 스레드홀드 설정
THRESHOLD = 0.3

def objectiveExtraTreesClassifier(trial, x_tr, y_tr, x_val, y_val):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 1000, 2700)
        , 'max_depth': trial.suggest_int('max_depth', 2, 40)
        , 'min_samples_split': trial.suggest_int('min_samples_split', 2, 5)
        , 'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 7)
        , 'criterion': trial.suggest_categorical('criterion', ['entropy'])
        , 'bootstrap': trial.suggest_categorical('bootstrap', [False])
        , 'random_state': RANDOM_STATE
    }
    
    model = ExtraTreesClassifier(**param)
    model.fit(x_tr, y_tr)
    pred = model.predict(x_val)
    score = f1_score(y_val, pred, average="binary")
    
    return score

# 데이터셋 분할
x_train, x_val, y_train, y_val = train_test_split(
    train_data_dam.drop("target", axis=1),
    train_data_dam["target"],
    test_size=0.2,
    shuffle=True,
    random_state=RANDOM_STATE,
)

# 하이퍼 파라미터 튜닝
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
study.optimize(lambda trial: objectiveExtraTreesClassifier(trial, x_train, y_train, x_val, y_val), n_trials=400)

print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# C:\Users\KimDongyoung\AppData\Local\Temp\ipykernel_19800\1447992300.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data_dam['target'] = train_data_dam['target'].map({'Normal': 0, 'AbNormal': 1})
# [I 2024-08-22 18:41:05,520] A new study created in memory with name: no-name-d20b174a-4476-4f79-9136-bee0fa94b2ea
# [I 2024-08-22 18:41:24,674] Trial 0 finished with value: 0.15416666666666667 and parameters: {'n_estimators': 1197, 'max_depth': 27, 'min_samples_split': 3, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.15416666666666667.
# [I 2024-08-22 18:42:01,657] Trial 1 finished with value: 0.158004158004158 and parameters: {'n_estimators': 2155, 'max_depth': 28, 'min_samples_split': 5, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 1 with value: 0.158004158004158.
# [I 2024-08-22 18:42:13,983] Trial 2 finished with value: 0.1271186440677966 and parameters: {'n_estimators': 1872, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 1 with value: 0.158004158004158.
# [I 2024-08-22 18:42:18,807] Trial 3 finished with value: 0.04878048780487806 and parameters: {'n_estimators': 1230, 'max_depth': 2, 'min_samples_split': 3, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 1 with value: 0.158004158004158.
# [I 2024-08-22 18:42:37,905] Trial 4 finished with value: 0.1697722567287785 and parameters: {'n_estimators': 1036, 'max_depth': 23, 'min_samples_split': 2, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 4 with value: 0.1697722567287785.
# [I 2024-08-22 18:43:07,515] Trial 5 finished with value: 0.17355371900826447 and parameters: {'n_estimators': 1534, 'max_depth': 32, 'min_samples_split': 4, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 5 with value: 0.17355371900826447.
# [I 2024-08-22 18:43:13,271] Trial 6 finished with value: 0.04878048780487806 and parameters: {'n_estimators': 1569, 'max_depth': 2, 'min_samples_split': 2, 'min_samples_leaf': 6, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 5 with value: 0.17355371900826447.
# [I 2024-08-22 18:43:33,617] Trial 7 finished with value: 0.15031315240083507 and parameters: {'n_estimators': 1835, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 5 with value: 0.17355371900826447.
# [I 2024-08-22 18:43:59,612] Trial 8 finished with value: 0.15416666666666667 and parameters: {'n_estimators': 1655, 'max_depth': 27, 'min_samples_split': 2, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 5 with value: 0.17355371900826447.
# [I 2024-08-22 18:44:20,287] Trial 9 finished with value: 0.17731958762886596 and parameters: {'n_estimators': 1068, 'max_depth': 25, 'min_samples_split': 2, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 9 with value: 0.17731958762886596.
# [I 2024-08-22 18:45:23,318] Trial 10 finished with value: 0.1859582542694497 and parameters: {'n_estimators': 2440, 'max_depth': 40, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.1859582542694497.
# [I 2024-08-22 18:46:32,907] Trial 11 finished with value: 0.18216318785578745 and parameters: {'n_estimators': 2671, 'max_depth': 39, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.1859582542694497.
# [I 2024-08-22 18:47:42,719] Trial 12 finished with value: 0.1859582542694497 and parameters: {'n_estimators': 2696, 'max_depth': 40, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.1859582542694497.
# [I 2024-08-22 18:48:51,295] Trial 13 finished with value: 0.18320610687022898 and parameters: {'n_estimators': 2627, 'max_depth': 38, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.1859582542694497.
# [I 2024-08-22 18:49:30,384] Trial 14 finished with value: 0.16597510373443985 and parameters: {'n_estimators': 2364, 'max_depth': 16, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.1859582542694497.
# [I 2024-08-22 18:50:18,856] Trial 15 finished with value: 0.17731958762886596 and parameters: {'n_estimators': 2381, 'max_depth': 35, 'min_samples_split': 5, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.1859582542694497.
# [I 2024-08-22 18:50:55,005] Trial 16 finished with value: 0.15 and parameters: {'n_estimators': 2391, 'max_depth': 33, 'min_samples_split': 4, 'min_samples_leaf': 7, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.1859582542694497.
# [I 2024-08-22 18:51:38,477] Trial 17 finished with value: 0.17731958762886596 and parameters: {'n_estimators': 2141, 'max_depth': 40, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.1859582542694497.
# [I 2024-08-22 18:52:27,696] Trial 18 finished with value: 0.17586912065439672 and parameters: {'n_estimators': 2525, 'max_depth': 19, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.1859582542694497.
# [I 2024-08-22 18:53:12,933] Trial 19 finished with value: 0.17731958762886596 and parameters: {'n_estimators': 2153, 'max_depth': 35, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.1859582542694497.
# [I 2024-08-22 18:54:02,240] Trial 20 finished with value: 0.17355371900826447 and parameters: {'n_estimators': 2515, 'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.1859582542694497.
# [I 2024-08-22 18:55:16,268] Trial 21 finished with value: 0.1856060606060606 and parameters: {'n_estimators': 2685, 'max_depth': 40, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.1859582542694497.
# [I 2024-08-22 18:56:29,366] Trial 22 finished with value: 0.1839080459770115 and parameters: {'n_estimators': 2683, 'max_depth': 36, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.1859582542694497.
# [I 2024-08-22 18:57:17,795] Trial 23 finished with value: 0.17731958762886596 and parameters: {'n_estimators': 2282, 'max_depth': 40, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.1859582542694497.
# [I 2024-08-22 18:58:23,364] Trial 24 finished with value: 0.18253968253968253 and parameters: {'n_estimators': 2491, 'max_depth': 36, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.1859582542694497.
# [I 2024-08-22 18:59:18,753] Trial 25 finished with value: 0.17731958762886596 and parameters: {'n_estimators': 2567, 'max_depth': 31, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.1859582542694497.
# [I 2024-08-22 19:00:23,462] Trial 26 finished with value: 0.18279569892473116 and parameters: {'n_estimators': 2253, 'max_depth': 37, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.1859582542694497.
# [I 2024-08-22 19:01:04,338] Trial 27 finished with value: 0.17731958762886596 and parameters: {'n_estimators': 1915, 'max_depth': 40, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.1859582542694497.
# [I 2024-08-22 19:01:57,546] Trial 28 finished with value: 0.1861386138613861 and parameters: {'n_estimators': 2024, 'max_depth': 33, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:02:37,464] Trial 29 finished with value: 0.17355371900826447 and parameters: {'n_estimators': 2074, 'max_depth': 29, 'min_samples_split': 5, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:03:09,744] Trial 30 finished with value: 0.15 and parameters: {'n_estimators': 2058, 'max_depth': 33, 'min_samples_split': 5, 'min_samples_leaf': 7, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:04:23,005] Trial 31 finished with value: 0.18320610687022898 and parameters: {'n_estimators': 2694, 'max_depth': 34, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:05:27,363] Trial 32 finished with value: 0.18253968253968253 and parameters: {'n_estimators': 2439, 'max_depth': 38, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:06:15,415] Trial 33 finished with value: 0.17731958762886596 and parameters: {'n_estimators': 2281, 'max_depth': 37, 'min_samples_split': 5, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:07:28,457] Trial 34 finished with value: 0.18345323741007194 and parameters: {'n_estimators': 2574, 'max_depth': 40, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:07:56,300] Trial 35 finished with value: 0.17731958762886596 and parameters: {'n_estimators': 1372, 'max_depth': 25, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:08:29,539] Trial 36 finished with value: 0.158004158004158 and parameters: {'n_estimators': 1990, 'max_depth': 32, 'min_samples_split': 3, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:08:50,069] Trial 37 finished with value: 0.15062761506276148 and parameters: {'n_estimators': 1726, 'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:09:40,970] Trial 38 finished with value: 0.17355371900826447 and parameters: {'n_estimators': 2602, 'max_depth': 38, 'min_samples_split': 4, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:10:19,125] Trial 39 finished with value: 0.15 and parameters: {'n_estimators': 2449, 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 6, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:10:58,262] Trial 40 finished with value: 0.16597510373443985 and parameters: {'n_estimators': 2233, 'max_depth': 34, 'min_samples_split': 5, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:12:11,481] Trial 41 finished with value: 0.1839080459770115 and parameters: {'n_estimators': 2691, 'max_depth': 36, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:13:22,743] Trial 42 finished with value: 0.18320610687022898 and parameters: {'n_estimators': 2624, 'max_depth': 37, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:14:32,511] Trial 43 finished with value: 0.18285714285714283 and parameters: {'n_estimators': 2548, 'max_depth': 38, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:15:10,548] Trial 44 finished with value: 0.17731958762886596 and parameters: {'n_estimators': 1803, 'max_depth': 28, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:16:23,327] Trial 45 finished with value: 0.18248175182481752 and parameters: {'n_estimators': 2631, 'max_depth': 31, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:17:27,438] Trial 46 finished with value: 0.1804222648752399 and parameters: {'n_estimators': 2362, 'max_depth': 35, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:17:54,609] Trial 47 finished with value: 0.17355371900826447 and parameters: {'n_estimators': 1424, 'max_depth': 40, 'min_samples_split': 4, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:18:44,655] Trial 48 finished with value: 0.17731958762886596 and parameters: {'n_estimators': 2455, 'max_depth': 25, 'min_samples_split': 2, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:19:09,171] Trial 49 finished with value: 0.15062761506276148 and parameters: {'n_estimators': 2688, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:19:42,310] Trial 50 finished with value: 0.15416666666666667 and parameters: {'n_estimators': 2340, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:20:54,608] Trial 51 finished with value: 0.1839080459770115 and parameters: {'n_estimators': 2639, 'max_depth': 36, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:22:08,046] Trial 52 finished with value: 0.1839080459770115 and parameters: {'n_estimators': 2690, 'max_depth': 36, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:23:16,427] Trial 53 finished with value: 0.18216318785578745 and parameters: {'n_estimators': 2509, 'max_depth': 39, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:24:14,060] Trial 54 finished with value: 0.17731958762886596 and parameters: {'n_estimators': 2698, 'max_depth': 33, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:25:27,176] Trial 55 finished with value: 0.1831238779174147 and parameters: {'n_estimators': 2583, 'max_depth': 38, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:26:06,273] Trial 56 finished with value: 0.15 and parameters: {'n_estimators': 2429, 'max_depth': 35, 'min_samples_split': 4, 'min_samples_leaf': 6, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:27:00,290] Trial 57 finished with value: 0.17731958762886596 and parameters: {'n_estimators': 2532, 'max_depth': 39, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:28:15,667] Trial 58 finished with value: 0.18279569892473116 and parameters: {'n_estimators': 2617, 'max_depth': 36, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1861386138613861.
# [I 2024-08-22 19:29:08,237] Trial 59 finished with value: 0.17731958762886596 and parameters: {'n_estimators': 2484, 'max_depth': 31, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial
 'max_depth': 32, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 287 with value: 0.20031796502384738.
# [I 2024-08-23 00:36:16,625] Trial 390 finished with value: 0.19395866454689986 and parameters: {'n_estimators': 2160, 'max_depth': 33, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 287 with value: 0.20031796502384738.
# [I 2024-08-23 00:37:29,360] Trial 391 finished with value: 0.19092331768388107 and parameters: {'n_estimators': 2125, 'max_depth': 34, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 287 with value: 0.20031796502384738.
# [I 2024-08-23 00:38:44,536] Trial 392 finished with value: 0.19582664526484753 and parameters: {'n_estimators': 2241, 'max_depth': 31, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 287 with value: 0.20031796502384738.
# [I 2024-08-23 00:39:56,896] Trial 393 finished with value: 0.19704433497536944 and parameters: {'n_estimators': 2179, 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 287 with value: 0.20031796502384738.
# [I 2024-08-23 00:41:09,366] Trial 394 finished with value: 0.2 and parameters: {'n_estimators': 2138, 'max_depth': 32, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 287 with value: 0.20031796502384738.
# [I 2024-08-23 00:42:22,548] Trial 395 finished with value: 0.2 and parameters: {'n_estimators': 2138, 'max_depth': 32, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 287 with value: 0.20031796502384738.
# [I 2024-08-23 00:43:37,906] Trial 396 finished with value: 0.19614147909967847 and parameters: {'n_estimators': 2208, 'max_depth': 31, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 287 with value: 0.20031796502384738.
# [I 2024-08-23 00:44:29,681] Trial 397 finished with value: 0.17731958762886596 and parameters: {'n_estimators': 2144, 'max_depth': 33, 'min_samples_split': 2, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 287 with value: 0.20031796502384738.
# [I 2024-08-23 00:45:41,418] Trial 398 finished with value: 0.1781818181818182 and parameters: {'n_estimators': 2176, 'max_depth': 32, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 287 with value: 0.20031796502384738.
# [I 2024-08-23 00:46:52,718] Trial 399 finished with value: 0.19582664526484753 and parameters: {'n_estimators': 2122, 'max_depth': 31, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 287 with value: 0.20031796502384738.
# Best trial: score 0.20031796502384738,
# params {'n_estimators': 2100, 'max_depth': 32, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}

# %% [markdown]
# Best trial: score 0.20063694267515925,
# params {'n_estimators': 2242, 'max_depth': 32, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}

# %%
# 스레드홀드 설정
THRESHOLD = 0.3

# 모델 설정 및 하이퍼파라미터
models = {
    'et': ExtraTreesClassifier(),
    'rf': RandomForestClassifier(),
    'cat': CatBoostClassifier(),
    'lgbm': LGBMClassifier(),
    'xgb': XGBClassifier(),
    'dt': DecisionTreeClassifier()
}

def train_and_evaluate_model(model_name, data, **params):
    if model_name not in models:
        print(f"{model_name}은(는) 지원되지 않는 모델입니다.")
        return
    
    # 데이터셋 분할
    x_train, x_val, y_train, y_val = train_test_split(
        data.drop("target", axis=1),
        data["target"].map({'Normal': 0, 'AbNormal': 1}),
        test_size=0.2,
        shuffle=True,
        random_state=RANDOM_STATE,
    )

    # 모델 선택
    model = models[model_name]

    # 하이퍼파라미터 설정
    model.set_params(**params)

    # 모델 학습
    model.fit(x_train, y_train)

    # 데이터 이름을 자동으로 추출하기 위한 래퍼 함수
    data_name = [name for name in globals() if globals()[name] is data][0]

    # 예측
    y_val_pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
    y_val_pred = (y_val_pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측

    # 평가지표 계산
    f1 = f1_score(y_val, y_val_pred, average="binary")
    accuracy = accuracy_score(y_val, y_val_pred)
    precision = precision_score(y_val, y_val_pred)
    recall = recall_score(y_val, y_val_pred)
    conf_matrix = confusion_matrix(y_val, y_val_pred)
    
    # 결과 출력
    print(f'{model_name} 모델이 {data_name} 데이터로 학습한 결과:')
    print(f'F1 Score: {f1}')
    print('---')
    print('Confusion Matrix:')
    print(conf_matrix)
    print('---')
    print(f'Accuracy: {accuracy}')
    print(f'Precision: {precision}')
    print(f'Recall: {recall}')
    print('\n')

# %%
# train_and_evaluate_model(
#     'et', train_data_dam,
#     n_estimators = 2242,
#     max_depth = 32,
#     min_samples_split = 2,
#     min_samples_leaf = 1,
#     criterion = 'entropy',
#     bootstrap = False,
#     random_state=RANDOM_STATE
# )

# %%
# 5-2. Dam
train_model_Dam = train_and_evaluate_model(
    'et', train_data_dam
    , n_estimators = 2242
    , max_depth = 32
    , min_samples_split = 2
    , min_samples_leaf = 1
    , criterion = 'entropy'
    , bootstrap = False
    , random_state=RANDOM_STATE
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 # 5-2. Dam
# ----> 2 train_model_Dam = train_and_evaluate_model(
#       3     'et', train_data_dam
#       4     , n_estimators = 2242
#       5     , max_depth = 32
#       6     , min_samples_split = 2
#       7     , min_samples_leaf = 1
#       8     , criterion = 'entropy'
#       9     , bootstrap = False
#      10     , random_state=RANDOM_STATE
#      11 )
#
# Cell In[21], line 35, in train_and_evaluate_model(model_name, data, **params)
#      32 model.set_params(**params)
#      34 # 모델 학습
# ---> 35 model.fit(x_train, y_train)
#      37 # 데이터 이름을 자동으로 추출하기 위한 래퍼 함수
#      38 data_name = [name for name in globals() if globals()[name] is data][0]
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_forest.py:348, in BaseForest.fit(self, X, y, sample_weight)
#     346 if issparse(y):
#     347     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 348 X, y = self._validate_data(
#     349     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     350 )
#     351 if sample_weight is not None:
#     352     sample_weight = _check_sample_weight(sample_weight, X)
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:622, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     620         y = check_array(y, input_name="y", **check_y_params)
#     621     else:
# --> 622         X, y = check_X_y(X, y, **check_params)
#     623     out = X, y
#     625 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1162, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1142     raise ValueError(
#    1143         f"{estimator_name} requires y to be passed, but the target y is None"
#    1144     )
#    1146 X = check_array(
#    1147     X,
#    1148     accept_sparse=accept_sparse,
#    (...)
#    1159     input_name="X",
#    1160 )
# -> 1162 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1164 check_consistent_length(X, y)
#    1166 return X, y
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1172, in _check_y(y, multi_output, y_numeric, estimator)
#    1170 """Isolated part of check_X_y dedicated to y validation"""
#    1171 if multi_output:
# -> 1172     y = check_array(
#    1173         y,
#    1174         accept_sparse="csr",
#    1175         force_all_finite=True,
#    1176         ensure_2d=False,
#    1177         dtype=None,
#    1178         input_name="y",
#    1179         estimator=estimator,
#    1180     )
#    1181 else:
#    1182     estimator_name = _check_estimator_name(estimator)
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:957, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     951         raise ValueError(
#     952             "Found array with dim %d. %s expected <= 2."
#     953             % (array.ndim, estimator_name)
#     954         )
#     956     if force_all_finite:
# --> 957         _assert_all_finite(
#     958             array,
#     959             input_name=input_name,
#     960             estimator_name=estimator_name,
#     961             allow_nan=force_all_finite == "allow-nan",
#     962         )
#     964 if ensure_min_samples > 0:
#     965     n_samples = _num_samples(array)
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:122, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     119 if first_pass_isfinite:
#     120     return
# --> 122 _assert_all_finite_element_wise(
#     123     X,
#     124     xp=xp,
#     125     allow_nan=allow_nan,
#     126     msg_dtype=msg_dtype,
#     127     estimator_name=estimator_name,
#     128     input_name=input_name,
#     129 )
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:171, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     154 if estimator_name and input_name == "X" and has_nan_error:
#     155     # Improve the error message on how to handle missing values in
#     156     # scikit-learn.
#     157     msg_err += (
#     158         f"\n{estimator_name} does not accept missing values"
#     159         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     169         "#estimators-that-handle-nan-values"
#     170     )
# --> 171 raise ValueError(msg_err)
#
# ValueError: Input y contains NaN.

# %% [markdown]
# et 모델이 train_data_dam 데이터로 학습한 결과:
#
# F1 Score: 0.18757062146892653
#
# Confusion Matrix:
# [[7300  362]
#  [ 357   83]]
#
# Accuracy: 0.9112564798815107
# Precision: 0.18651685393258427
# Recall: 0.18863636363636363

# %% [markdown]
# .
