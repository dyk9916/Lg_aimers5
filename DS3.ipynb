# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

s = pd.Series([1, 3, 5, 4, 6, 8])
print(s)
# Out:
# 0    1
# 1    3
# 2    5
# 3    4
# 4    6
# 5    8
# dtype: int64

# %% [markdown]
# **인덱스 지정하기**

# %%
import pandas as pd

s = pd.Series([1, 3.5, 5, 4, 6.2, 8], index=['a', 'b', 'c', 'd', 'e', 'f'])
print(s)
# Out:
# a    1.0
# b    3.5
# c    5.0
# d    4.0
# e    6.2
# f    8.0
# dtype: float64

# %%
import pandas as pd
import numpy as np

dates = pd.date_range('20130101', periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
ㄴㅇㅁㅇㄴㅇㄴ
print(dates)
print(df)
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')
#                    A         B         C         D
# 2013-01-01 -0.666736 -0.591898 -1.399899 -1.107414
# 2013-01-02 -1.170428 -0.083079  1.515956  0.360400
# 2013-01-03 -0.648271 -1.110632  1.412867  1.059568
# 2013-01-04 -1.092659 -0.010633 -1.677545 -1.390827
# 2013-01-05 -0.886114 -0.217130 -0.657898  1.050012
# 2013-01-06  1.139885 -0.166365  0.633401  0.267871

# %% [markdown]
# 예제1. header=None

# %%
import pandas as pd

df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/pandas_ex01.csv', header=None)

print(df1)
# Out:
#    0  1
# 0  a  1
# 1  b  2
# 2  c  3
# 3  d  4

# %% [markdown]
# 예제2.헤더 지정하기기

# %%
import pandas as pd

df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/pandas_ex02.csv', header=0)

print(df2)
# Out:
#   string  number
# 0      a       1
# 1      b       2
# 2      c       3
# 3      d       4

# %% [markdown]
# 예제3.인덱스 지정하기기

# %%
import pandas as pd

df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/pandas_ex02.csv', index_col=0)

print(df2)
# Out:
#         number
# string
# a            1
# b            2
# c            3
# d            4

# %% [markdown]
# **Pandas 데이터 보기 (Viewing data)**
# ![viewing_data_00.png](data:image/png;base64,...)

# %% [markdown]
# * df.head() / df.tail()

# %%
import pandas as pd
import numpy as np

dates = pd.date_range('20130101', periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))

print(df.head(2))
print(df.tail(3))
# Out:
#                    A         B         C         D
# 2013-01-01  1.792342 -0.584750 -1.325549 -0.422642
# 2013-01-02 -0.317679  0.070628 -0.880281 -0.461035
#                    A         B         C         D
# 2013-01-04 -0.155477 -0.367118 -0.786074  2.148505
# 2013-01-05 -0.604301 -0.100236  0.672350 -0.610729
# 2013-01-06  1.390517 -0.525357  0.066795 -0.220212

# %% [markdown]
# ![viewing_data_02.png](data:image/png;base64,...)

# %% [markdown]
# *  df.index / df.columns

# %%
print(df.index)
print(df.columns)
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %% [markdown]
# ![viewing_data_03.png](data:image/png;base64,...)

# %% [markdown]
# * df.to_numpy()

# %%
print(df.to_numpy())
# Out:
# [[ 1.06466942 -0.2028681  -1.94704531 -0.81814119]
#  [ 0.59069559  0.75350105  1.73815011 -0.4157287 ]
#  [ 0.03768894  0.73450891 -0.29812335  0.6953032 ]
#  [ 0.15219769 -0.8915796   0.488929    0.25020418]
#  [ 1.90401447  0.10738154 -1.01717005 -0.64964104]
#  [-0.09366304 -1.227014    0.04228811  0.35271197]]

# %% [markdown]
# * df.describe()

# %%
print(df.describe())
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.609267 -0.121012 -0.165495 -0.097549
# std    0.763391  0.821288  1.265873  0.612793
# min   -0.093663 -1.227014 -1.947045 -0.818141
# 25%    0.066316 -0.719402 -0.837408 -0.591163
# 50%    0.371447 -0.047743 -0.127918 -0.082762
# 75%    0.946176  0.577727  0.377269  0.327085
# max    1.904014  0.753501  1.738150  0.695303

# %% [markdown]
# * df.sort_index()

# %%
print(df.sort_index(axis=1, ascending=False))
# Out:
#                    D         C         B         A
# 2013-01-01 -0.422642 -1.325549 -0.584750  1.792342
# 2013-01-02 -0.461035 -0.880281  0.070628 -0.317679
# 2013-01-03  1.020122 -0.508549  0.142693 -0.535582
# 2013-01-04  2.148505 -0.786074 -0.367118 -0.155477
# 2013-01-05 -0.610729  0.672350 -0.100236 -0.604301
# 2013-01-06 -0.220212  0.066795 -0.525357  1.390517

# %% [markdown]
# * df.sort_values()

# %%
print(df.sort_values(by='B'))

# %% [markdown]
# ## **Pandas 데이터 선택하기 (Selection)**
#
# ![selection_00.png](data:image/png;base64,...)

# %% [markdown]
# * DataFrame 만들기

# %%
import pandas as pd
import numpy as np

np.random.seed(0)

dates = pd.date_range('20130101', periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))

print(df)
# Out:
#                    A         B         C         D
# 2013-01-01  1.764052  0.400157  0.978738  2.240893
# 2013-01-02  1.867558 -0.977278  0.950088 -0.151357
# 2013-01-03 -0.103219  0.410599  0.144044  1.454274
# 2013-01-04  0.761038  0.121675  0.443863  0.333674
# 2013-01-05  1.494079 -0.205158  0.313068 -0.854096
# 2013-01-06 -2.552990  0.653619  0.864436 -0.742165

# %% [markdown]
# * 열 선택하기

# %%
print(df['A'])
#print(df.A)
print(type(df['A']))
#print(type(df.A))
# Out:
# 2013-01-01    1.764052
# 2013-01-02    1.867558
# 2013-01-03   -0.103219
# 2013-01-04    0.761038
# 2013-01-05    1.494079
# 2013-01-06   -2.552990
# Freq: D, Name: A, dtype: float64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# * 행 선택하기
# ![selection_03.png](data:image/png;base64,...)

# %%
print(df[0:3])
# Out:
#                    A         B         C         D
# 2013-01-01  1.764052  0.400157  0.978738  2.240893
# 2013-01-02  1.867558 -0.977278  0.950088 -0.151357
# 2013-01-03 -0.103219  0.410599  0.144044  1.454274

# %% [markdown]
# ![selection_04.png](data:image/png;base64,...)

# %%
print(df['20130102':'20130104'])
# Out:
#                    A         B         C         D
# 2013-01-02  1.867558 -0.977278  0.950088 -0.151357
# 2013-01-03 -0.103219  0.410599  0.144044  1.454274
# 2013-01-04  0.761038  0.121675  0.443863  0.333674

# %% [markdown]
# * 레이블로 선택하기 (df.loc)

# %%
print(df.loc[:, ['A', 'B']])

# %% [markdown]
# ![selection_06.png](data:image/png;base64,...)

# %%
print(df.loc['20130102':'20130104', ['A', 'B']])

# %% [markdown]
# ![selection_07.png](data:image/png;base64,...)

# %% [markdown]
# * 위치로 선택하기 (df.iloc)

# %%
print(df.iloc[3])

# %% [markdown]
# ![selection_11.png](data:image/png;base64,...)

# %%
print(df.iloc[3:5, 0:2])

# %% [markdown]
# ![selection_12.png](data:image/png;base64,...)

# %% [markdown]
# * 불 인덱싱

# %%
#print(df[df.A > 0])
print(df[df['A'] > 0])

# %% [markdown]
# ![selection_18.png](data:image/png;base64,...)

# %%
df2 = df.copy()
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three']

print(df2)
print(df2[df2['E'].isin(['two', 'four'])])

# %% [markdown]
# ![selection_20.png](data:image/png;base64,...)

# %%
df.at[dates[0], 'A'] = 0

print(df)

# %% [markdown]
# ![selection_22.png](data:image/png;base64,...)

# %% [markdown]
# ## Pandas 연산 (Operations)
#
# * DataFrame 만들기

# %%
import pandas as pd
import numpy as np

np.random.seed(0)

dates = pd.date_range('20130101', periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))

s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20130102', periods=6))
df['F'] = s1
df.loc[:, 'D'] = np.array([5.0] * len(df))

print(df)
# Out:
#                    A         B         C    D    F
# 2013-01-01  1.764052  0.400157  0.978738  5.0  NaN
# 2013-01-02  1.867558 -0.977278  0.950088  5.0  1.0
# 2013-01-03 -0.103219  0.410599  0.144044  5.0  2.0
# 2013-01-04  0.761038  0.121675  0.443863  5.0  3.0
# 2013-01-05  1.494079 -0.205158  0.313068  5.0  4.0
# 2013-01-06 -2.552990  0.653619  0.864436  5.0  5.0

# %% [markdown]
# * 통계적 분석

# %%
print(df.mean())
# Out:
# A    0.538420
# B    0.067269
# C    0.615706
# D    5.000000
# F    3.000000
# dtype: float64

# %%
print(df.mean(1))
# Out:
# 2013-01-01    2.035737
# 2013-01-02    1.568074
# 2013-01-03    1.490285
# 2013-01-04    1.865315
# 2013-01-05    2.120398
# 2013-01-06    1.793013
# Freq: D, dtype: float64

# %% [markdown]
# ## Pandas 그룹 (Grouping)

# %% [markdown]
# 1) DataFrame 만들기

# %%
import pandas as pd
import numpy as np

np.random.seed(0)

df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
                      'foo', 'bar', 'foo', 'foo'],
                 'B': ['one', 'one', 'two', 'three',
                      'two', 'two', 'one', 'three'],
                 'C': np.random.randn(8),
                 'D': np.random.randn(8)})

print(df)
# Out:
#      A      B         C         D
# 0  foo    one  1.764052 -0.103219
# 1  bar    one  0.400157  0.410599
# 2  foo    two  0.978738  0.144044
# 3  bar  three  2.240893  1.454274
# 4  foo    two  1.867558  0.761038
# 5  bar    two -0.977278  0.121675
# 6  foo    one  0.950088  0.443863
# 7  foo  three -0.151357  0.333674

# %% [markdown]
# 2) 한 열을 기준으로 그룹화하기

# %%
print(df.groupby('A').sum())
# Out:
#             C         D
# A
# bar  1.663773  1.986547
# foo  5.409080  1.579400
# <ipython-input-21-45a0c353b993>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(df.groupby('A').sum())

# %% [markdown]
# 3) 여러 열을 기준으로 그룹화하기

# %%
print(df.groupby(['A', 'B']).sum())
# Out:
#                   C         D
# A   B
# bar one    0.400157  0.410599
#     three  2.240893  1.454274
#     two   -0.977278  0.121675
# foo one    2.714141  0.340644
#     three -0.151357  0.333674
#     two    2.846296  0.905081

# %% [markdown]
# ## 실습하기

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/csv_exam.csv', header=0, index_col=0 )
print(df)
# Out:
#     class  math  english  science
# id
# 1       1    50       98       50
# 2       1    60       97       60
# 3       1    45       86       78
# 4       1    30       98       58
# 5       2    25       80       65
# 6       2    50       89       98
# 7       2    80       90       45
# 8       2    90       78       25
# 9       3    20       98       15
# 10      3    50       98       45
# 11      3    65       65       65
# 12      3    45       85       32
# 13      4    46       98       65
# 14      4    48       87       12
# 15      4    75       56       78
# 16      4    58       98       65
# 17      5    65       68       98
# 18      5    80       78       90
# 19      5    89       68       87
# 20      5    78       83       58

# %% [markdown]
# * 학생별 총점과 평균 구하기

# %%
df['total'] = df['math']+df['english']+df['science']
df['mean'] = round(df['total']/3, 1)
print(df)
# Out:
#     class  math  english  science  total  mean
# id
# 1       1    50       98       50    198  66.0
# 2       1    60       97       60    217  72.3
# 3       1    45       86       78    209  69.7
# 4       1    30       98       58    186  62.0
# 5       2    25       80       65    170  56.7
# 6       2    50       89       98    237  79.0
# 7       2    80       90       45    215  71.7
# 8       2    90       78       25    193  64.3
# 9       3    20       98       15    133  44.3
# 10      3    50       98       45    193  64.3
# 11      3    65       65       65    195  65.0
# 12      3    45       85       32    162  54.0
# 13      4    46       98       65    209  69.7
# 14      4    48       87       12    147  49.0
# 15      4    75       56       78    209  69.7
# 16      4    58       98       65    221  73.7
# 17      5    65       68       98    231  77.0
# 18      5    80       78       90    248  82.7
# 19      5    89       68       87    244  81.3
# ...

# %% [markdown]
# * 반별 수학 평균 구하기

# %%
print(df.groupby(['class']).mean()['math'])
# Out:
# class
# 1    46.25
# 2    61.25
# 3    45.00
# 4    56.75
# 5    78.00
# Name: math, dtype: float64

# %%
print(df.groupby(['class']).mean())
# Out:
#         math  english  science   total    mean
# class
# 1      46.25    94.75    61.50  202.50  67.500
# 2      61.25    84.25    58.25  203.75  67.925
# 3      45.00    86.50    39.25  170.75  56.900
# 4      56.75    84.75    55.00  196.50  65.525
# 5      78.00    74.25    83.25  235.50  78.500

# %%
print(df['total'].max())
# Out:
# 248

# %%
print(df.groupby(['class']).max())
# Out:
#        math  english  science  total  mean
# class
# 1        60       98       78    217  72.3
# 2        90       90       98    237  79.0
# 3        65       98       65    195  65.0
# 4        75       98       78    221  73.7
# 5        89       83       98    248  82.7

# %% [markdown]
# ## 타이타닉 생존 여부 예측하기

# %%
import pandas as pd
import numpy as np

train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/train.csv')
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/test.csv')
print(train.shape)
print(test.shape)
# Out:
# (891, 12)
# (418, 11)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# !pip install missingno

# %%
import missingno as msno
import matplotlib.pyplot as plt

msno.matrix(train)
plt.show()

# %%
train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# * 성별에 따른 생존률

# %%
train.groupby('Sex')[['Survived']].mean()

# %%
train.pivot_table(values=['Survived'], index=['Sex'], aggfunc=np.mean)

# %%
# 성별, 선실등급별 생존률
train.pivot_table('Survived', ['Sex', 'Pclass'], aggfunc=np.mean)

# %%
import pandas as pd
df = pd.DataFrame(
    {
        "Gender" : ['Male','Male','Female','Female','Female' ],
        "Team" : [1,2,3,3,1]
    }
)
print(df)
# Out:
#    Gender  Team
# 0    Male     1
# 1    Male     2
# 2  Female     3
# 3  Female     3
# 4  Female     1

# %%
print(pd.crosstab(df.Gender, df.Team))
# Out:
# Team    1  2  3
# Gender
# Female  1  0  2
# Male    1  1  0

# %%
import pandas as pd

# %%
data = {
    '이름' : ['홍길동','이순신','유관순','김유신'],
    '나이' : [20,22,24,25],
    '고향' : ['서울', '부산', '대구', '대구']
}
df = pd.DataFrame(data)
df
# Out:
#     이름  나이  고향
# 0  홍길동  20  서울
# 1  이순신  22  부산
# 2  유관순  24  대구
# 3  김유신  25  대구

# %%
df.iloc[2]
# Out:
# 이름    유관순
# 나이     24
# 고향     대구
# Name: 2, dtype: object

# %%
df.loc[2]
# Out:
# 이름    유관순
# 나이     24
# 고향     대구
# Name: 2, dtype: object

# %%
df = pd.DataFrame(columns=['Name', 'Age', 'Hometown'])
print(len(df))
df
# Out:
# 0
# Empty DataFrame
# Columns: [Name, Age, Hometown]
# Index: []

# %%
df.loc[20] = ['이순신', 25, '서울']
df.loc[30] = ['유관순', 30, '대구']
df
# Out:
#    Name  Age Hometown
# 20  이순신   25       서울
# 30  유관순   30       대구

# %%
df.iloc[0]
# Out:
# Name        이순신
# Age          25
# Hometown     서울
# Name: 20, dtype: object

# %%
df.loc[20]
# Out:
# Name        이순신
# Age          25
# Hometown     서울
# Name: 20, dtype: object

# %%
#UPDATE
df.loc[30] = ['엄홍길', 30, '대구']
print(len(df))
df
# Out:
# 2
#    Name  Age Hometown
# 20  이순신   25       서울
# 30  엄홍길   30       대구

# %%
for i in range(20):
    df.loc[len(df)] = ['이순신_'+ str(i), 25+i*5, '서울']
print(len(df))
df
# Out:
# 20
#       Name  Age Hometown
# 20  이순신_19  120       서울
# 30     엄홍길   30       대구
# 2    이순신_0   25       서울
# 3    이순신_1   30       서울
# 4    이순신_2   35       서울
# 5    이순신_3   40       서울
# 6    이순신_4   45       서울
# 7    이순신_5   50       서울
# 8    이순신_6   55       서울
# 9    이순신_7   60       서울
# 10   이순신_8   65       서울
# 11   이순신_9   70       서울
# 12  이순신_10   75       서울
# 13  이순신_11   80       서울
# 14  이순신_12   85       서울
# 15  이순신_13   90       서울
# 16  이순신_14   95       서울
# 17  이순신_15  100       서울
# 18  이순신_16  105       서울
# 19  이순신_17  110       서울

# %%
df
# Out:
#       Name  Age Hometown
# 20  이순신_19  120       서울
# 30     엄홍길   30       대구
# 2    이순신_0   25       서울
# 3    이순신_1   30       서울
# 4    이순신_2   35       서울
# 5    이순신_3   40       서울
# 6    이순신_4   45       서울
# 7    이순신_5   50       서울
# 8    이순신_6   55       서울
# 9    이순신_7   60       서울
# 10   이순신_8   65       서울
# 11   이순신_9   70       서울
# 12  이순신_10   75       서울
# 13  이순신_11   80       서울
# 14  이순신_12   85       서울
# 15  이순신_13   90       서울
# 16  이순신_14   95       서울
# 17  이순신_15  100       서울
# 18  이순신_16  105       서울
# 19  이순신_17  110       서울

# %%
df = df.drop([20, 2, 4, 6])
df
# Out:
#       Name  Age Hometown
# 30     엄홍길   30       대구
# 3    이순신_1   30       서울
# 5    이순신_3   40       서울
# 7    이순신_5   50       서울
# 8    이순신_6   55       서울
# 9    이순신_7   60       서울
# 10   이순신_8   65       서울
# 11   이순신_9   70       서울
# 12  이순신_10   75       서울
# 13  이순신_11   80       서울
# 14  이순신_12   85       서울
# 15  이순신_13   90       서울
# 16  이순신_14   95       서울
# 17  이순신_15  100       서울
# 18  이순신_16  105       서울
# 19  이순신_17  110       서울

# %%
df[2:4]
# Out:
#     Name  Age Hometown
# 5  이순신_3   40       서울
# 7  이순신_5   50       서울

# %%
df.iloc[2:4]
# Out:
#     Name  Age Hometown
# 5  이순신_3   40       서울
# 7  이순신_5   50       서울

# %%
df.loc[3:10]
# Out:
#      Name  Age Hometown
# 3   이순신_1   30       서울
# 5   이순신_3   40       서울
# 7   이순신_5   50       서울
# 8   이순신_6   55       서울
# 9   이순신_7   60       서울
# 10  이순신_8   65       서울

# %%
df.head()
# Out:
#      Name  Age Hometown
# 30    엄홍길   30       대구
# 3   이순신_1   30       서울
# 5   이순신_3   40       서울
# 7   이순신_5   50       서울
# 8   이순신_6   55       서울

# %%
df.tail()
# Out:
#       Name  Age Hometown
# 15  이순신_13   90       서울
# 16  이순신_14   95       서울
# 17  이순신_15  100       서울
# 18  이순신_16  105       서울
# 19  이순신_17  110       서울

# %% [markdown]
# # DATA 정제 및 준비
#
#
# *   결측데이터 여부 확인

# %%
df = pd.DataFrame({
    'T1' : [10, None, 30, 40],
    'T2' : [81, 93, None, 97]
})
df
# Out:
#      T1    T2
# 0  10.0  81.0
# 1   NaN  93.0
# 2  30.0   NaN
# 3  40.0  97.0

# %%
a = pd.isnull(df)
a
# Out:
#       T1     T2
# 0  False  False
# 1   True  False
# 2  False   True
# 3  False  False

# %%
c = pd.notnull(df)
c
# Out:
#       T1     T2
# 0   True   True
# 1  False   True
# 2   True  False
# 3   True   True

# %%
d = df.isnull().sum()  # 각 column 당 결측치 갯수
d
# Out:
# T1    1
# T2    1
# dtype: int64

# %%
df_0 = df.fillna(0) # 결측값을 0으로 채우기
df_0
# Out:
#      T1    T2
# 0  10.0  81.0
# 1   0.0  93.0
# 2  30.0   0.0
# 3  40.0  97.0

# %%
df_mean = df.fillna(df.mean())
df_mean
# Out:
#           T1         T2
# 0  10.000000  81.000000
# 1  26.666667  93.000000
# 2  30.000000  90.333333
# 3  40.000000  97.000000

# %% [markdown]
# *   누락된 데이터 골라내기

# %%
data = pd.Series([1, None, 3.5, None, 7])
data.dropna()
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
df
# Out:
#      T1    T2
# 0  10.0  81.0
# 1   NaN  93.0
# 2  30.0   NaN
# 3  40.0  97.0

# %%
df.dropna()
# Out:
#      T1    T2
# 0  10.0  81.0
# 3  40.0  97.0

# %% [markdown]
# *   데이터 변형, 중복 데이터 처리하기

# %%
data = pd.DataFrame({ 'k1' : ['one', 'two']*3 + ['two'],
                     'k2' : [1, 1, 2, 3, 3, 4, 4]})
data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4

# %% [markdown]
# *   데이터 치환

# %%
data = pd.Series([1., -999., 2., -999., -1000., 3.])
data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
# 누락값 -> Nan값
data.replace(-999, np.nan)
# Out:
# 0       1.0
# 1       NaN
# 2       2.0
# 3       NaN
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
# 치환값도 지정 가능
data.replace([-999, -1000], [np.nan, 0])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    0.0
# 5    3.0
# dtype: float64
