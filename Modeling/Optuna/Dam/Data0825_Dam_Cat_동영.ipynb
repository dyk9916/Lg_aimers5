# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ### 데이터 읽어오기

# %%
import pandas as pd

THRESHOLD = 0.3
RANDOM_STATE = 110

train_data = pd.read_csv("../../../data/train_data_0817.csv")
test_data = pd.read_csv("../../../data/test_data_0817.csv")

# %%
# dam, fill1, fill2 공통 변수
var_dam_fill = [
    'Equipment_same_num',
    'PalletID_Collect_Result_encoded',
    'Production_Qty_Collect_Result',
    'WorkMode Collect Result'
]

# %%
# 전체 공통 변수
### correlation 확인을 위한 변수 리스트
var_all_corr = [
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### train
var_all_train = [
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### test
var_all_test = [
    'Set ID',
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

# %%
# '_Dam'을 포함하는 변수 선택
dam_variables = [var for var in train_data.columns if '_Dam' in var]

# train
final_columns_train = var_dam_fill + var_all_train + dam_variables
train_data_dam = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + dam_variables
test_data_dam = test_data[final_columns_test]

# %%
# '_Fill1'을 포함하는 변수 선택
fill1_variables = [var for var in train_data.columns if '_Fill1' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill1_variables
train_data_fill1 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill1_variables
test_data_fill1 = test_data[final_columns_test]

# %%
# '_Fill2'을 포함하는 변수 선택
fill2_variables = [var for var in train_data.columns if '_Fill2' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill2_variables
train_data_fill2 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill2_variables
test_data_fill2 = test_data[final_columns_test]

# %%
# '_AutoClave'을 포함하는 변수 선택
autoclave_variables = [var for var in train_data.columns if '_AutoClave' in var]

# train
final_columns_train = var_all_train + autoclave_variables
train_data_autoclave = train_data[final_columns_train]

# test 
final_columns_test = var_all_test + autoclave_variables
test_data_autoclave = test_data[final_columns_test]

# %%
# 각 DataFrame의 칼럼 수 계산
num_columns_train_data = train_data.shape[1]
num_columns_train_data_dam = train_data_dam.shape[1]
num_columns_train_data_autoclave = train_data_autoclave.shape[1]
num_columns_train_data_fill1 = train_data_fill1.shape[1]
num_columns_train_data_fill2 = train_data_fill2.shape[1]

num_columns_test_data = test_data.shape[1]
num_columns_test_data_dam = test_data_dam.shape[1]
num_columns_test_data_autoclave = test_data_autoclave.shape[1]
num_columns_test_data_fill1 = test_data_fill1.shape[1]
num_columns_test_data_fill2 = test_data_fill2.shape[1]

# 각 DataFrame의 칼럼 수 출력
print("----train data-----")
print(f"train_data DataFrame의 칼럼 수: {num_columns_train_data}")
print(f"train_data_dam DataFrame의 칼럼 수: {num_columns_train_data_dam}")
print(f"train_data_autoclave DataFrame의 칼럼 수: {num_columns_train_data_autoclave}")
print(f"train_data_fill1 DataFrame의 칼럼 수: {num_columns_train_data_fill1}")
print(f"train_data_fill2 DataFrame의 칼럼 수: {num_columns_train_data_fill2}")
print("----test data-----")
print(f"test_data DataFrame의 칼럼 수: {num_columns_test_data}")
print(f"test_data_dam DataFrame의 칼럼 수: {num_columns_test_data_dam}")
print(f"test_data_autoclave DataFrame의 칼럼 수: {num_columns_test_data_autoclave}")
print(f"test_data_fill1 DataFrame의 칼럼 수: {num_columns_test_data_fill1}")
print(f"test_data_fill2 DataFrame의 칼럼 수: {num_columns_test_data_fill2}")
# Out:
# ----train data-----
# train_data DataFrame의 칼럼 수: 38
# train_data_dam DataFrame의 칼럼 수: 21
# train_data_autoclave DataFrame의 칼럼 수: 8
# train_data_fill1 DataFrame의 칼럼 수: 13
# train_data_fill2 DataFrame의 칼럼 수: 13
# ----test data-----
# test_data DataFrame의 칼럼 수: 39
# test_data_dam DataFrame의 칼럼 수: 22
# test_data_autoclave DataFrame의 칼럼 수: 9
# test_data_fill1 DataFrame의 칼럼 수: 14
# test_data_fill2 DataFrame의 칼럼 수: 14

# %% [markdown]
# ---

# %% [markdown]
# ## Optuna

# %% [markdown]
# 스레스홀드 0.3으로 맞춘상태에서 튜닝 진행한 것

# %%
import optuna
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# 'Normal'과 'AbNormal'을 숫자로 변환
train_data_dam['target'] = train_data_dam['target'].map({'Normal': 0, 'AbNormal': 1})

# 스레드홀드 설정
THRESHOLD = 0.3

def objectiveCatBoost(trial, x_tr, y_tr, x_val, y_val):
    param = {
        'iterations': trial.suggest_int('iterations', 400, 1500),
        'learning_rate': trial.suggest_float('learning_rate', 0.05, 0.4),
        'depth': trial.suggest_int('depth', 3, 14),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 0.05, 5.0, log=True),
        'random_strength': trial.suggest_float('random_strength', 0.1, 10.0),
        'bagging_temperature': trial.suggest_float('bagging_temperature', 0.1, 10.0),
        'border_count': trial.suggest_int('border_count', 70, 270),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 0.5, 1.2),

        'random_seed': RANDOM_STATE,
        'eval_metric': 'F1',
        'logging_level': 'Silent',
        'boosting_type': 'Plain'
    }

    model = CatBoostClassifier(**param)
    model.fit(x_tr, y_tr)
    pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
    pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
    
    score = f1_score(y_val, pred, average="binary")
    
    return score

# 데이터셋 분할
x_train, x_val, y_train, y_val = train_test_split(
    train_data_dam.drop("target", axis=1),
    train_data_dam["target"],
    test_size=0.2,
    shuffle=True,
    random_state=RANDOM_STATE,
)

# 하이퍼 파라미터 튜닝
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
study.optimize(lambda trial: objectiveCatBoost(trial, x_train, y_train, x_val, y_val), n_trials=100)

print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# C:\Users\juneh\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# [I 2024-08-19 09:10:38,022] A new study created in memory with name: no-name-a50c2dcb-0a42-47ec-bd8e-93dd16e57be5
# [I 2024-08-19 09:10:44,675] Trial 0 finished with value: 0.19822485207100593 and parameters: {'iterations': 527, 'learning_rate': 0.2804593836111537, 'depth': 7, 'l2_leaf_reg': 0.8404950643051162, 'random_strength': 6.826956469952126, 'bagging_temperature': 6.85638497930364, 'border_count': 261, 'scale_pos_weight': 0.9460560575741956}. Best is trial 0 with value: 0.19822485207100593.
# [I 2024-08-19 09:10:54,820] Trial 1 finished with value: 0.21476510067114093 and parameters: {'iterations': 964, 'learning_rate': 0.08016171509650169, 'depth': 7, 'l2_leaf_reg': 0.19048347725606002, 'random_strength': 1.4404705911514528, 'bagging_temperature': 0.20004528881709918, 'border_count': 152, 'scale_pos_weight': 0.844813629486711}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:10:57,969] Trial 2 finished with value: 0.19672131147540986 and parameters: {'iterations': 423, 'learning_rate': 0.24582852433725222, 'depth': 3, 'l2_leaf_reg': 0.3268155584239249, 'random_strength': 3.2096391755877125, 'bagging_temperature': 7.728453151327917, 'border_count': 190, 'scale_pos_weight': 0.7921507187483865}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:11:03,925] Trial 3 finished with value: 0.19961612284069097 and parameters: {'iterations': 768, 'learning_rate': 0.05876555421557462, 'depth': 4, 'l2_leaf_reg': 2.5535167782493318, 'random_strength': 4.96200116248331, 'bagging_temperature': 2.5710844249446487, 'border_count': 223, 'scale_pos_weight': 0.8781630850877211}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:11:10,689] Trial 4 finished with value: 0.20257234726688106 and parameters: {'iterations': 824, 'learning_rate': 0.2754259310196551, 'depth': 5, 'l2_leaf_reg': 1.3102111209505352, 'random_strength': 0.49813981541744445, 'bagging_temperature': 6.039260026994052, 'border_count': 110, 'scale_pos_weight': 0.6742578373332273}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:15:26,537] Trial 5 finished with value: 0.21225710014947682 and parameters: {'iterations': 839, 'learning_rate': 0.29985111766715355, 'depth': 12, 'l2_leaf_reg': 3.081153288159938, 'random_strength': 2.283440573995146, 'bagging_temperature': 0.22843635802495488, 'border_count': 222, 'scale_pos_weight': 0.6278635128714384}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:15:38,117] Trial 6 finished with value: 0.21368948247078465 and parameters: {'iterations': 1273, 'learning_rate': 0.38276338647257035, 'depth': 3, 'l2_leaf_reg': 3.1299365365685374, 'random_strength': 8.875351318648416, 'bagging_temperature': 9.870708353305885, 'border_count': 242, 'scale_pos_weight': 0.7031450844795675}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:16:00,019] Trial 7 finished with value: 0.20305980528511827 and parameters: {'iterations': 1382, 'learning_rate': 0.22043830563585048, 'depth': 8, 'l2_leaf_reg': 3.2459262964367377, 'random_strength': 7.7534714252966035, 'bagging_temperature': 6.65112034774484, 'border_count': 150, 'scale_pos_weight': 1.0870550427614065}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:16:31,051] Trial 8 finished with value: 0.20481927710843373 and parameters: {'iterations': 846, 'learning_rate': 0.07333766019501724, 'depth': 10, 'l2_leaf_reg': 0.10935408095423858, 'random_strength': 8.80760544970916, 'bagging_temperature': 2.350327566035022, 'border_count': 86, 'scale_pos_weight': 0.8895547449404857}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:20:06,777] Trial 9 finished with value: 0.209106239460371 and parameters: {'iterations': 1337, 'learning_rate': 0.0665682174072002, 'depth': 11, 'l2_leaf_reg': 0.5278446061765084, 'random_strength': 0.603125104825544, 'bagging_temperature': 7.101215391968, 'border_count': 253, 'scale_pos_weight': 0.5040050080957333}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:40:23,649] Trial 10 finished with value: 0.20314735336194567 and parameters: {'iterations': 1132, 'learning_rate': 0.13456679174519115, 'depth': 14, 'l2_leaf_reg': 0.07227745173825706, 'random_strength': 3.8669169725645016, 'bagging_temperature': 3.6433649786562645, 'border_count': 148, 'scale_pos_weight': 1.1988547846542048}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:40:40,102] Trial 11 finished with value: 0.20670391061452514 and parameters: {'iterations': 1119, 'learning_rate': 0.37279185197092674, 'depth': 6, 'l2_leaf_reg': 0.22276665602662585, 'random_strength': 6.346736131842573, 'bagging_temperature': 4.403597585619511, 'border_count': 181, 'scale_pos_weight': 0.7472042260664779}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:40:53,125] Trial 12 finished with value: 0.19865319865319866 and parameters: {'iterations': 1153, 'learning_rate': 0.1691744434699528, 'depth': 3, 'l2_leaf_reg': 0.16276532728677084, 'random_strength': 9.943110151616406, 'bagging_temperature': 9.930731165852421, 'border_count': 122, 'scale_pos_weight': 1.0126004653352745}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:41:20,218] Trial 13 finished with value: 0.20238095238095236 and parameters: {'iterations': 1030, 'learning_rate': 0.38901967085793493, 'depth': 9, 'l2_leaf_reg': 1.1520288343502676, 'random_strength': 2.065128309644617, 'bagging_temperature': 9.141144996116477, 'border_count': 210, 'scale_pos_weight': 0.5780836899706057}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:41:41,981] Trial 14 finished with value: 0.1965006729475101 and parameters: {'iterations': 1477, 'learning_rate': 0.337157338681763, 'depth': 6, 'l2_leaf_reg': 0.41874913063212565, 'random_strength': 5.220641331853101, 'bagging_temperature': 0.1700752879391434, 'border_count': 155, 'scale_pos_weight': 0.7565363670650043}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:41:58,505] Trial 15 finished with value: 0.20745542949756884 and parameters: {'iterations': 1269, 'learning_rate': 0.15203760011232043, 'depth': 5, 'l2_leaf_reg': 0.05170399366391226, 'random_strength': 9.682081972426968, 'bagging_temperature': 1.7191407732803763, 'border_count': 125, 'scale_pos_weight': 0.720388621066234}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:42:09,921] Trial 16 finished with value: 0.21159420289855072 and parameters: {'iterations': 656, 'learning_rate': 0.19241711055137165, 'depth': 8, 'l2_leaf_reg': 0.18995770379714316, 'random_strength': 7.561770298389536, 'bagging_temperature': 5.162592508529986, 'border_count': 70, 'scale_pos_weight': 0.8301104833909353}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:42:21,527] Trial 17 finished with value: 0.20138888888888887 and parameters: {'iterations': 991, 'learning_rate': 0.1163909737954672, 'depth': 4, 'l2_leaf_reg': 4.723853103667104, 'random_strength': 5.080945521720252, 'bagging_temperature': 8.465263692381145, 'border_count': 247, 'scale_pos_weight': 0.99934811469707}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:53:43,122] Trial 18 finished with value: 0.1964809384164223 and parameters: {'iterations': 1211, 'learning_rate': 0.340692253561827, 'depth': 13, 'l2_leaf_reg': 0.6215854592511111, 'random_strength': 1.30581751356815, 'bagging_temperature': 5.144034618057185, 'border_count': 195, 'scale_pos_weight': 0.5911086069822834}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:54:04,203] Trial 19 finished with value: 0.20854700854700858 and parameters: {'iterations': 1469, 'learning_rate': 0.10140438090896933, 'depth': 7, 'l2_leaf_reg': 1.6947609282825131, 'random_strength': 3.866464232148976, 'bagging_temperature': 1.3186224257148997, 'border_count': 168, 'scale_pos_weight': 0.6642912683292582}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:55:03,650] Trial 20 finished with value: 0.20700636942675157 and parameters: {'iterations': 931, 'learning_rate': 0.19986426470747923, 'depth': 10, 'l2_leaf_reg': 0.2804148780263887, 'random_strength': 8.574468050911236, 'bagging_temperature': 3.048515311326984, 'border_count': 233, 'scale_pos_weight': 0.5022283599880681}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 09:58:45,842] Trial 21 finished with value: 0.19667170953101362 and parameters: {'iterations': 687, 'learning_rate': 0.3144192678111274, 'depth': 12, 'l2_leaf_reg': 2.230650334913793, 'random_strength': 2.4501805662898137, 'bagging_temperature': 0.4346857965042341, 'border_count': 270, 'scale_pos_weight': 0.6131125774146323}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 10:02:44,253] Trial 22 finished with value: 0.2038404726735598 and parameters: {'iterations': 920, 'learning_rate': 0.2941503426287837, 'depth': 12, 'l2_leaf_reg': 3.97858788849817, 'random_strength': 1.707373844039379, 'bagging_temperature': 0.9275986811724243, 'border_count': 217, 'scale_pos_weight': 0.680058986663997}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 10:17:50,619] Trial 23 finished with value: 0.1923076923076923 and parameters: {'iterations': 1070, 'learning_rate': 0.36130675681970836, 'depth': 14, 'l2_leaf_reg': 0.12930176164960297, 'random_strength': 3.1316683141413364, 'bagging_temperature': 1.5317734755232135, 'border_count': 234, 'scale_pos_weight': 0.8169669809014916}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 10:18:03,851] Trial 24 finished with value: 0.20307692307692304 and parameters: {'iterations': 680, 'learning_rate': 0.2524261447567536, 'depth': 9, 'l2_leaf_reg': 2.0861688625854478, 'random_strength': 0.15233364364042523, 'bagging_temperature': 3.3729591172609332, 'border_count': 203, 'scale_pos_weight': 0.6261173395110288}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 10:19:12,040] Trial 25 finished with value: 0.20719424460431654 and parameters: {'iterations': 857, 'learning_rate': 0.3276674936686902, 'depth': 11, 'l2_leaf_reg': 0.9875443868543795, 'random_strength': 2.885171152184385, 'bagging_temperature': 2.1108219654945595, 'border_count': 168, 'scale_pos_weight': 0.728347901292589}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 10:19:20,162] Trial 26 finished with value: 0.19666666666666666 and parameters: {'iterations': 587, 'learning_rate': 0.3056074142210081, 'depth': 7, 'l2_leaf_reg': 0.7185850979731606, 'random_strength': 1.1331213428840412, 'bagging_temperature': 4.351325526663096, 'border_count': 243, 'scale_pos_weight': 0.5567831678022039}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 10:19:33,482] Trial 27 finished with value: 0.18926553672316385 and parameters: {'iterations': 1228, 'learning_rate': 0.3934405321990065, 'depth': 5, 'l2_leaf_reg': 3.4423046752232054, 'random_strength': 4.256544241470149, 'bagging_temperature': 0.12097738809827518, 'border_count': 181, 'scale_pos_weight': 0.9112475730978785}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 10:20:31,923] Trial 28 finished with value: 0.20809248554913293 and parameters: {'iterations': 1352, 'learning_rate': 0.3504792625750437, 'depth': 10, 'l2_leaf_reg': 1.5266533654414807, 'random_strength': 6.133744707302163, 'bagging_temperature': 0.9413653677340271, 'border_count': 226, 'scale_pos_weight': 0.7852365312219823}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 10:20:41,740] Trial 29 finished with value: 0.1991465149359886 and parameters: {'iterations': 733, 'learning_rate': 0.27207465302681616, 'depth': 6, 'l2_leaf_reg': 0.37742259239269504, 'random_strength': 2.4403264481754703, 'bagging_temperature': 5.708386325648113, 'border_count': 260, 'scale_pos_weight': 0.9378339470802334}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 10:23:09,271] Trial 30 finished with value: 0.20086083213773312 and parameters: {'iterations': 540, 'learning_rate': 0.239785821070621, 'depth': 13, 'l2_leaf_reg': 0.8154302303590298, 'random_strength': 5.843118449114539, 'bagging_temperature': 8.276963142303616, 'border_count': 141, 'scale_pos_weight': 0.8541276024310597}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 10:23:17,027] Trial 31 finished with value: 0.20512820512820512 and parameters: {'iterations': 618, 'learning_rate': 0.18211142038921938, 'depth': 8, 'l2_leaf_reg': 0.16287080315705788, 'random_strength': 7.607840649732101, 'bagging_temperature': 9.885048817283915, 'border_count': 102, 'scale_pos_weight': 0.8218007297963068}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 10:23:23,647] Trial 32 finished with value: 0.20819112627986347 and parameters: {'iterations': 456, 'learning_rate': 0.09529464701499207, 'depth': 9, 'l2_leaf_reg': 0.21327170274362078, 'random_strength': 7.359953473303488, 'bagging_temperature': 7.234815710732201, 'border_count': 86, 'scale_pos_weight': 0.7013227801106763}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 10:23:32,714] Trial 33 finished with value: 0.21008403361344535 and parameters: {'iterations': 765, 'learning_rate': 0.21517343891015192, 'depth': 8, 'l2_leaf_reg': 0.09267521133289544, 'random_strength': 8.843829962607597, 'bagging_temperature': 4.28596924133657, 'border_count': 79, 'scale_pos_weight': 0.7777459901157249}. Best is trial 1 with value: 0.21476510067114093.
# [I 2024-08-19 10:23:40,598] Trial 34 finished with value: 0.21761658031088085 and parameters: {'iterations': 887, 'learning_rate': 0.1935455767397666, 'depth': 4, 'l2_leaf_reg': 0.2994204101603269, 'random_strength': 6.866659626115882, 'bagging_temperature': 5.713510739790113, 'border_count': 72, 'scale_pos_weight': 0.8328211269381731}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:23:48,766] Trial 35 finished with value: 0.19765494137353434 and parameters: {'iterations': 971, 'learning_rate': 0.27851569330242476, 'depth': 3, 'l2_leaf_reg': 2.75045879595846, 'random_strength': 6.771696231655304, 'bagging_temperature': 6.31606720949644, 'border_count': 104, 'scale_pos_weight': 0.9840231991441627}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:23:56,495] Trial 36 finished with value: 0.21333333333333335 and parameters: {'iterations': 885, 'learning_rate': 0.2557100452500338, 'depth': 4, 'l2_leaf_reg': 0.30958135491942723, 'random_strength': 8.223163410616996, 'bagging_temperature': 7.734518268324669, 'border_count': 134, 'scale_pos_weight': 0.6495724143151517}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:24:04,439] Trial 37 finished with value: 0.20603907637655416 and parameters: {'iterations': 902, 'learning_rate': 0.14181596297863022, 'depth': 4, 'l2_leaf_reg': 0.30577729346133287, 'random_strength': 8.281608862384365, 'bagging_temperature': 8.098976714437844, 'border_count': 128, 'scale_pos_weight': 0.6556732748915645}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:24:12,931] Trial 38 finished with value: 0.19863013698630133 and parameters: {'iterations': 1056, 'learning_rate': 0.24668278273104327, 'depth': 3, 'l2_leaf_reg': 0.4624583560526495, 'random_strength': 9.366283862566904, 'bagging_temperature': 8.889574976875446, 'border_count': 140, 'scale_pos_weight': 0.86078856955347}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:24:20,108] Trial 39 finished with value: 0.18627450980392157 and parameters: {'iterations': 828, 'learning_rate': 0.1667634590022644, 'depth': 4, 'l2_leaf_reg': 0.25595432388663464, 'random_strength': 7.005831560567921, 'bagging_temperature': 7.669933800176589, 'border_count': 159, 'scale_pos_weight': 1.0467204284841782}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:24:29,523] Trial 40 finished with value: 0.21071428571428574 and parameters: {'iterations': 1008, 'learning_rate': 0.05074924867803346, 'depth': 5, 'l2_leaf_reg': 0.3709272388931067, 'random_strength': 9.208600837081645, 'bagging_temperature': 9.255579505401808, 'border_count': 95, 'scale_pos_weight': 0.8934275723798495}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:24:36,004] Trial 41 finished with value: 0.19813084112149532 and parameters: {'iterations': 806, 'learning_rate': 0.22567074865334075, 'depth': 3, 'l2_leaf_reg': 0.5286535622318413, 'random_strength': 8.408326955787789, 'bagging_temperature': 6.541116991754415, 'border_count': 177, 'scale_pos_weight': 0.5293626969156405}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:24:43,436] Trial 42 finished with value: 0.2052117263843648 and parameters: {'iterations': 879, 'learning_rate': 0.295774482382635, 'depth': 4, 'l2_leaf_reg': 0.12791853409057666, 'random_strength': 8.148649873002562, 'bagging_temperature': 5.628998819624373, 'border_count': 113, 'scale_pos_weight': 0.7081515263205304}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:24:51,278] Trial 43 finished with value: 0.1897106109324759 and parameters: {'iterations': 777, 'learning_rate': 0.26326668038048295, 'depth': 6, 'l2_leaf_reg': 0.32694108599149746, 'random_strength': 0.8456941198666801, 'bagging_temperature': 7.176774992673096, 'border_count': 191, 'scale_pos_weight': 0.6243820502914873}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:25:01,412] Trial 44 finished with value: 0.21245421245421242 and parameters: {'iterations': 1093, 'learning_rate': 0.08210535553481368, 'depth': 5, 'l2_leaf_reg': 4.895611767991462, 'random_strength': 7.998963150044567, 'bagging_temperature': 9.486759474058701, 'border_count': 137, 'scale_pos_weight': 0.7662491786108466}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:25:11,573] Trial 45 finished with value: 0.19424460431654675 and parameters: {'iterations': 1086, 'learning_rate': 0.08962905226690432, 'depth': 5, 'l2_leaf_reg': 3.8612907677845767, 'random_strength': 7.127762734239578, 'bagging_temperature': 9.398893023450045, 'border_count': 142, 'scale_pos_weight': 0.7660604183225412}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:25:21,205] Trial 46 finished with value: 0.18773946360153257 and parameters: {'iterations': 1172, 'learning_rate': 0.07183626915238854, 'depth': 3, 'l2_leaf_reg': 4.891711128994231, 'random_strength': 8.095338292780994, 'bagging_temperature': 8.865094361900764, 'border_count': 132, 'scale_pos_weight': 0.8121287511654044}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:25:33,318] Trial 47 finished with value: 0.200339558573854 and parameters: {'iterations': 1314, 'learning_rate': 0.11812018750587455, 'depth': 5, 'l2_leaf_reg': 0.1800028726448603, 'random_strength': 6.518816585185765, 'bagging_temperature': 9.69868159654793, 'border_count': 118, 'scale_pos_weight': 0.7445011959646789}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:25:41,464] Trial 48 finished with value: 0.20701168614357263 and parameters: {'iterations': 956, 'learning_rate': 0.0823916470822942, 'depth': 4, 'l2_leaf_reg': 0.24113898531262012, 'random_strength': 5.756138482449389, 'bagging_temperature': 7.709302471335505, 'border_count': 147, 'scale_pos_weight': 1.1792905840691983}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:25:55,465] Trial 49 finished with value: 0.20820189274447948 and parameters: {'iterations': 1424, 'learning_rate': 0.11818855078561787, 'depth': 6, 'l2_leaf_reg': 0.08541308728509393, 'random_strength': 9.03634912617325, 'bagging_temperature': 8.648893858827158, 'border_count': 160, 'scale_pos_weight': 0.7989650401757417}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:26:07,341] Trial 50 finished with value: 0.20700636942675157 and parameters: {'iterations': 1120, 'learning_rate': 0.1482106274230681, 'depth': 7, 'l2_leaf_reg': 0.6609896419779724, 'random_strength': 7.876331398703612, 'bagging_temperature': 6.7671830110071305, 'border_count': 135, 'scale_pos_weight': 0.6874122626068061}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:26:15,246] Trial 51 finished with value: 0.2 and parameters: {'iterations': 1018, 'learning_rate': 0.226277957640366, 'depth': 3, 'l2_leaf_reg': 2.7632368176651507, 'random_strength': 9.577010203378162, 'bagging_temperature': 2.6913218041969977, 'border_count': 209, 'scale_pos_weight': 0.6481417316055468}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:26:22,645] Trial 52 finished with value: 0.2007042253521127 and parameters: {'iterations': 876, 'learning_rate': 0.20611584222981802, 'depth': 4, 'l2_leaf_reg': 2.0063987814823867, 'random_strength': 4.397658565176046, 'bagging_temperature': 9.550605441417895, 'border_count': 251, 'scale_pos_weight': 0.7342388912954928}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:26:31,087] Trial 53 finished with value: 0.20875420875420875 and parameters: {'iterations': 938, 'learning_rate': 0.38359997161922305, 'depth': 5, 'l2_leaf_reg': 2.9025625782914326, 'random_strength': 1.8088725178161067, 'bagging_temperature': 0.8549326994282601, 'border_count': 235, 'scale_pos_weight': 0.569880643402881}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:26:37,189] Trial 54 finished with value: 0.2174629324546952 and parameters: {'iterations': 734, 'learning_rate': 0.36463484446814104, 'depth': 4, 'l2_leaf_reg': 3.9216038316633686, 'random_strength': 9.988314532345019, 'bagging_temperature': 7.90304636148757, 'border_count': 157, 'scale_pos_weight': 0.8384679319875225}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:26:42,886] Trial 55 finished with value: 0.1909722222222222 and parameters: {'iterations': 728, 'learning_rate': 0.3750109354634791, 'depth': 3, 'l2_leaf_reg': 3.6125347431588763, 'random_strength': 9.955038799192437, 'bagging_temperature': 8.018385675080502, 'border_count': 152, 'scale_pos_weight': 0.8429580662561352}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:26:53,368] Trial 56 finished with value: 0.2052877138413686 and parameters: {'iterations': 1284, 'learning_rate': 0.32796941034637556, 'depth': 4, 'l2_leaf_reg': 4.7484942019788825, 'random_strength': 8.5950000997669, 'bagging_temperature': 9.995045110534853, 'border_count': 175, 'scale_pos_weight': 0.9279730301026504}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:27:03,926] Trial 57 finished with value: 0.1970149253731343 and parameters: {'iterations': 1189, 'learning_rate': 0.3607760185440021, 'depth': 5, 'l2_leaf_reg': 4.089482575602253, 'random_strength': 8.96694247065069, 'bagging_temperature': 7.437840076348321, 'border_count': 164, 'scale_pos_weight': 0.8764396275666981}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:27:14,313] Trial 58 finished with value: 0.20446096654275092 and parameters: {'iterations': 1254, 'learning_rate': 0.0597988982964339, 'depth': 4, 'l2_leaf_reg': 0.19986396766988013, 'random_strength': 9.447481061412198, 'bagging_temperature': 4.710363558901298, 'border_count': 154, 'scale_pos_weight': 0.7654907241017415}. Best is trial 34 with value: 0.21761658031088085.
# [I 2024-08-19 10:27:21,994] Trial 59 finished with value: 0.22036727879799664 and parameters: {'iterations': 803, 'learning_rate': 0.11008712227529457, 'depth': 6, 'l2_leaf_reg': 0.13111266566679286, 'random_strength': 9.779861000134886, 'bagging_temperature': 3.7525800770911175, 'border_count': 119, 'scale_pos_weight': 0.7928651007586947}. Best is trial 59 with value: 0.22036727879799664.
# [I 2024-08-19 10:27:30,439] Trial 60 finished with value: 0.1891891891891892 and parameters: {'iterations': 807, 'learning_rate': 0.16232371823396158, 'depth': 7, 'l2_leaf_reg': 0.13559270147024052, 'random_strength': 9.73745577839678, 'bagging_temperature': 3.7479847846173424, 'border_count': 125, 'scale_pos_weight': 0.8714828102576302}. Best is trial 59 with value: 0.22036727879799664.
# [I 2024-08-19 10:27:37,506] Trial 61 finished with value: 0.20504201680672268 and parameters: {'iterations': 733, 'learning_rate': 0.1098424512817343, 'depth': 6, 'l2_leaf_reg': 0.16421572040941246, 'random_strength': 8.666502360212306, 'bagging_temperature': 5.835270428582993, 'border_count': 117, 'scale_pos_weight': 0.7959367639216177}. Best is trial 59 with value: 0.22036727879799664.
# [I 2024-08-19 10:27:45,125] Trial 62 finished with value: 0.20819112627986347 and parameters: {'iterations': 905, 'learning_rate': 0.13109331957494316, 'depth': 4, 'l2_leaf_reg': 0.2714394588186684, 'random_strength': 9.22681788845518, 'bagging_temperature': 9.135201634830587, 'border_count': 146, 'scale_pos_weight': 0.9590955801507463}. Best is trial 59 with value: 0.22036727879799664.
# [I 2024-08-19 10:27:53,863] Trial 63 finished with value: 0.20240137221269297 and parameters: {'iterations': 976, 'learning_rate': 0.0787173842821304, 'depth': 5, 'l2_leaf_reg': 0.05348482533814908, 'random_strength': 9.97635951847272, 'bagging_temperature': 5.2625489252056274, 'border_count': 133, 'scale_pos_weight': 0.8286400254885087}. Best is trial 59 with value: 0.22036727879799664.
# [I 2024-08-19 10:28:01,986] Trial 64 finished with value: 0.2164048865619546 and parameters: {'iterations': 842, 'learning_rate': 0.10155271809271837, 'depth': 6, 'l2_leaf_reg': 0.14580952639774925, 'random_strength': 8.01670345466079, 'bagging_temperature': 6.175908845413142, 'border_count': 71, 'scale_pos_weight': 0.7491118894728782}. Best is trial 59 with value: 0.22036727879799664.
# [I 2024-08-19 10:28:09,998] Trial 65 finished with value: 0.23232323232323232 and parameters: {'iterations': 845, 'learning_rate': 0.12560723899727444, 'depth': 6, 'l2_leaf_reg': 0.11681629069236026, 'random_strength': 7.382448311645474, 'bagging_temperature': 6.190402604308831, 'border_count': 75, 'scale_pos_weight': 0.7197343250860875}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:28:16,464] Trial 66 finished with value: 0.2124183006535948 and parameters: {'iterations': 637, 'learning_rate': 0.10468755581155648, 'depth': 7, 'l2_leaf_reg': 0.11042711849072122, 'random_strength': 7.291673239421131, 'bagging_temperature': 6.250782096785668, 'border_count': 72, 'scale_pos_weight': 0.9022466379216084}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:28:23,647] Trial 67 finished with value: 0.21818181818181814 and parameters: {'iterations': 761, 'learning_rate': 0.1323226907113249, 'depth': 6, 'l2_leaf_reg': 0.07708162289634937, 'random_strength': 5.608689908198093, 'bagging_temperature': 5.425451484534481, 'border_count': 92, 'scale_pos_weight': 0.8451664265856149}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:28:30,372] Trial 68 finished with value: 0.2251655629139073 and parameters: {'iterations': 708, 'learning_rate': 0.12944736215952884, 'depth': 6, 'l2_leaf_reg': 0.0654808520612243, 'random_strength': 5.600283041960262, 'bagging_temperature': 5.435822807226897, 'border_count': 89, 'scale_pos_weight': 0.8014224279409033}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:28:36,984] Trial 69 finished with value: 0.21368948247078465 and parameters: {'iterations': 698, 'learning_rate': 0.1237458993296515, 'depth': 6, 'l2_leaf_reg': 0.07315784983119314, 'random_strength': 5.469217952449198, 'bagging_temperature': 4.704018052942743, 'border_count': 89, 'scale_pos_weight': 0.8431315782962405}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:28:44,365] Trial 70 finished with value: 0.21895424836601304 and parameters: {'iterations': 778, 'learning_rate': 0.13646033568433216, 'depth': 6, 'l2_leaf_reg': 0.06280945163277116, 'random_strength': 6.223899520119281, 'bagging_temperature': 5.478324149768817, 'border_count': 79, 'scale_pos_weight': 0.8010380742004075}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:28:51,561] Trial 71 finished with value: 0.2204968944099379 and parameters: {'iterations': 769, 'learning_rate': 0.18601844868598905, 'depth': 6, 'l2_leaf_reg': 0.05926957431669501, 'random_strength': 6.132706570608549, 'bagging_temperature': 5.464563311278685, 'border_count': 77, 'scale_pos_weight': 0.8068530879398159}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:28:58,806] Trial 72 finished with value: 0.2080745341614907 and parameters: {'iterations': 760, 'learning_rate': 0.17452201196346595, 'depth': 6, 'l2_leaf_reg': 0.06155954101285265, 'random_strength': 6.270363940208316, 'bagging_temperature': 5.377411773897076, 'border_count': 83, 'scale_pos_weight': 0.8054868202681115}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:29:06,994] Trial 73 finished with value: 0.2002945508100147 and parameters: {'iterations': 793, 'learning_rate': 0.15717003326436849, 'depth': 7, 'l2_leaf_reg': 0.06677450669472758, 'random_strength': 4.799685693505284, 'bagging_temperature': 4.788772370906953, 'border_count': 95, 'scale_pos_weight': 0.7903995874075563}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:29:13,548] Trial 74 finished with value: 0.215429403202329 and parameters: {'iterations': 587, 'learning_rate': 0.1838710475615748, 'depth': 8, 'l2_leaf_reg': 0.08322525789584063, 'random_strength': 5.940061037740219, 'bagging_temperature': 5.91487301279288, 'border_count': 76, 'scale_pos_weight': 0.8364834076637533}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:29:20,394] Trial 75 finished with value: 0.2146341463414634 and parameters: {'iterations': 715, 'learning_rate': 0.13595856823151073, 'depth': 6, 'l2_leaf_reg': 0.10575682334768893, 'random_strength': 5.636979846543996, 'bagging_temperature': 3.881908879894827, 'border_count': 95, 'scale_pos_weight': 0.8600318222659593}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:29:28,308] Trial 76 finished with value: 0.19488817891373802 and parameters: {'iterations': 761, 'learning_rate': 0.1481009879188372, 'depth': 7, 'l2_leaf_reg': 0.05876266119478706, 'random_strength': 6.502327726214258, 'bagging_temperature': 4.120533801169659, 'border_count': 106, 'scale_pos_weight': 0.7149228352045784}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:29:35,205] Trial 77 finished with value: 0.20679012345679013 and parameters: {'iterations': 657, 'learning_rate': 0.1261296598347393, 'depth': 7, 'l2_leaf_reg': 0.07411253337945604, 'random_strength': 6.787085173458271, 'bagging_temperature': 5.478458522628827, 'border_count': 79, 'scale_pos_weight': 0.9215265699715605}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:29:43,540] Trial 78 finished with value: 0.21460506706408347 and parameters: {'iterations': 826, 'learning_rate': 0.19244575609998354, 'depth': 6, 'l2_leaf_reg': 0.09504467541934009, 'random_strength': 5.3709950054509825, 'bagging_temperature': 5.012973216972903, 'border_count': 82, 'scale_pos_weight': 0.8837530814717136}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:29:53,250] Trial 79 finished with value: 0.19676945668135098 and parameters: {'iterations': 854, 'learning_rate': 0.13856224508290685, 'depth': 8, 'l2_leaf_reg': 0.05068275321806187, 'random_strength': 4.892430934145426, 'bagging_temperature': 4.967721481594439, 'border_count': 89, 'scale_pos_weight': 0.7763999248246835}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:29:59,747] Trial 80 finished with value: 0.20949263502454987 and parameters: {'iterations': 670, 'learning_rate': 0.1537367713611521, 'depth': 6, 'l2_leaf_reg': 0.11343628467021007, 'random_strength': 6.0204950330523435, 'bagging_temperature': 6.43284319262699, 'border_count': 100, 'scale_pos_weight': 0.8155119657323335}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:30:07,868] Trial 81 finished with value: 0.20557491289198607 and parameters: {'iterations': 840, 'learning_rate': 0.09514508187549672, 'depth': 6, 'l2_leaf_reg': 0.141869143246531, 'random_strength': 6.5475745026815, 'bagging_temperature': 6.068744788104986, 'border_count': 72, 'scale_pos_weight': 0.747749634311337}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:30:14,933] Trial 82 finished with value: 0.21015761821366022 and parameters: {'iterations': 797, 'learning_rate': 0.10839271995161084, 'depth': 5, 'l2_leaf_reg': 0.06482341630715431, 'random_strength': 7.457364481984177, 'bagging_temperature': 6.124014535127843, 'border_count': 76, 'scale_pos_weight': 0.7315462894907717}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:30:21,997] Trial 83 finished with value: 0.2204724409448819 and parameters: {'iterations': 756, 'learning_rate': 0.17230968345566314, 'depth': 6, 'l2_leaf_reg': 0.08110763795183057, 'random_strength': 7.06890852334949, 'bagging_temperature': 6.870769372512266, 'border_count': 70, 'scale_pos_weight': 0.7805996682336342}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:30:29,568] Trial 84 finished with value: 0.19590643274853803 and parameters: {'iterations': 753, 'learning_rate': 0.17450416992228215, 'depth': 7, 'l2_leaf_reg': 0.08124718073318572, 'random_strength': 6.964130273793633, 'bagging_temperature': 6.914424429769628, 'border_count': 90, 'scale_pos_weight': 0.7920188638751332}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:30:35,647] Trial 85 finished with value: 0.22690437601296598 and parameters: {'iterations': 703, 'learning_rate': 0.21053839687261083, 'depth': 5, 'l2_leaf_reg': 0.0985017378485394, 'random_strength': 6.270820690551645, 'bagging_temperature': 5.564629943078813, 'border_count': 84, 'scale_pos_weight': 0.8230134142064137}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:30:42,128] Trial 86 finished with value: 0.21406727828746175 and parameters: {'iterations': 698, 'learning_rate': 0.21423840970058045, 'depth': 6, 'l2_leaf_reg': 0.09712443733158374, 'random_strength': 6.318904490479211, 'bagging_temperature': 5.648253095218373, 'border_count': 84, 'scale_pos_weight': 0.8130308511908793}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:30:47,342] Trial 87 finished with value: 0.21775544388609716 and parameters: {'iterations': 598, 'learning_rate': 0.18656518346466533, 'depth': 5, 'l2_leaf_reg': 0.058077087153838206, 'random_strength': 5.161047201701601, 'bagging_temperature': 4.503130777345393, 'border_count': 77, 'scale_pos_weight': 0.8509014241791564}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:30:51,818] Trial 88 finished with value: 0.22448979591836732 and parameters: {'iterations': 516, 'learning_rate': 0.20279109947607832, 'depth': 5, 'l2_leaf_reg': 0.056752481336105755, 'random_strength': 4.53444032412683, 'bagging_temperature': 4.363867693276592, 'border_count': 110, 'scale_pos_weight': 0.6943039740109452}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:30:55,545] Trial 89 finished with value: 0.22260869565217387 and parameters: {'iterations': 424, 'learning_rate': 0.20289180093856088, 'depth': 5, 'l2_leaf_reg': 0.07236705405888649, 'random_strength': 3.927878944105985, 'bagging_temperature': 3.471501072837486, 'border_count': 108, 'scale_pos_weight': 0.6777030415332721}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:30:59,358] Trial 90 finished with value: 0.20677966101694917 and parameters: {'iterations': 431, 'learning_rate': 0.23647930629951314, 'depth': 5, 'l2_leaf_reg': 0.06960059210934977, 'random_strength': 3.327398715683124, 'bagging_temperature': 4.0569690227563076, 'border_count': 107, 'scale_pos_weight': 0.6949413754748772}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:31:03,649] Trial 91 finished with value: 0.2188034188034188 and parameters: {'iterations': 494, 'learning_rate': 0.20761592185687686, 'depth': 5, 'l2_leaf_reg': 0.08816077098990112, 'random_strength': 4.634691494166885, 'bagging_temperature': 3.4853968218720333, 'border_count': 112, 'scale_pos_weight': 0.6636648667242566}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:31:08,040] Trial 92 finished with value: 0.2162162162162162 and parameters: {'iterations': 505, 'learning_rate': 0.2122273130329995, 'depth': 5, 'l2_leaf_reg': 0.0902153202544656, 'random_strength': 3.910224491950416, 'bagging_temperature': 2.780311011542379, 'border_count': 113, 'scale_pos_weight': 0.6806342302997049}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:31:12,360] Trial 93 finished with value: 0.22340425531914895 and parameters: {'iterations': 497, 'learning_rate': 0.19568882053618242, 'depth': 5, 'l2_leaf_reg': 0.11888496441520977, 'random_strength': 4.54526725491173, 'bagging_temperature': 3.4708388454946224, 'border_count': 99, 'scale_pos_weight': 0.6103247668580328}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:31:16,254] Trial 94 finished with value: 0.20757825370675453 and parameters: {'iterations': 414, 'learning_rate': 0.1954897439838834, 'depth': 6, 'l2_leaf_reg': 0.0572077163582318, 'random_strength': 4.121208472487379, 'bagging_temperature': 3.4256052233480023, 'border_count': 101, 'scale_pos_weight': 0.7237610608073324}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:31:20,979] Trial 95 finished with value: 0.21761658031088085 and parameters: {'iterations': 538, 'learning_rate': 0.2040708487823659, 'depth': 5, 'l2_leaf_reg': 0.11481838917016443, 'random_strength': 6.1746349006465575, 'bagging_temperature': 2.426259263091863, 'border_count': 95, 'scale_pos_weight': 0.5983016943371572}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:31:25,379] Trial 96 finished with value: 0.20926243567753 and parameters: {'iterations': 465, 'learning_rate': 0.18039551437279214, 'depth': 6, 'l2_leaf_reg': 0.12289813978121253, 'random_strength': 3.4115658659918786, 'bagging_temperature': 3.120501411527065, 'border_count': 81, 'scale_pos_weight': 0.7724389794093534}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:31:29,557] Trial 97 finished with value: 0.20833333333333331 and parameters: {'iterations': 446, 'learning_rate': 0.22855113580703856, 'depth': 5, 'l2_leaf_reg': 0.1026484797385392, 'random_strength': 4.5827417267239525, 'bagging_temperature': 6.610884181815596, 'border_count': 100, 'scale_pos_weight': 0.6045676034781257}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:31:33,773] Trial 98 finished with value: 0.22483221476510068 and parameters: {'iterations': 400, 'learning_rate': 0.17339468810437525, 'depth': 7, 'l2_leaf_reg': 0.0663832714324444, 'random_strength': 3.5942756935191964, 'bagging_temperature': 3.236006196401293, 'border_count': 87, 'scale_pos_weight': 0.642685967311013}. Best is trial 65 with value: 0.23232323232323232.
# [I 2024-08-19 10:31:39,526] Trial 99 finished with value: 0.21359223300970873 and parameters: {'iterations': 554, 'learning_rate': 0.17125333393209038, 'depth': 7, 'l2_leaf_reg': 0.07654617400622622, 'random_strength': 3.4972920361124644, 'bagging_temperature': 3.2083745667389416, 'border_count': 88, 'scale_pos_weight': 0.636473732502344}. Best is trial 65 with value: 0.23232323232323232.
# Best trial: score 0.23232323232323232,
# params {'iterations': 845, 'learning_rate': 0.12560723899727444, 'depth': 6, 'l2_leaf_reg': 0.11681629069236026, 'random_strength': 7.382448311645474, 'bagging_temperature': 6.190402604308831, 'border_count': 75, 'scale_pos_weight': 0.7197343250860875}

# %% [markdown]
# Best trial: score 0.23232323232323232,
# params {'iterations': 845, 'learning_rate': 0.12560723899727444, 'depth': 6, 'l2_leaf_reg': 0.11681629069236026,
# 'random_strength': 7.382448311645474, 'bagging_temperature': 6.190402604308831, 'border_count': 75, 'scale_pos_weight': 0.7197343250860875}

# %%
# 스레드홀드 설정
THRESHOLD = 0.3

# 모델 설정 및 하이퍼파라미터
models = {
    'et': ExtraTreesClassifier(),
    'rf': RandomForestClassifier(),
    'cat': CatBoostClassifier(),
    'lgbm': LGBMClassifier(),
    'xgb': XGBClassifier(),
    'dt': DecisionTreeClassifier()
}

def train_and_evaluate_model(model_name, data, **params):
    if model_name not in models:
        print(f"{model_name}은(는) 지원되지 않는 모델입니다.")
        return
    
    # 데이터셋 분할
    x_train, x_val, y_train, y_val = train_test_split(
        data.drop("target", axis=1),
        data["target"].map({'Normal': 0, 'AbNormal': 1}),
        test_size=0.2,
        shuffle=True,
        random_state=RANDOM_STATE,
    )

    # 모델 선택
    model = models[model_name]

    # 하이퍼파라미터 설정
    model.set_params(**params)

    # 모델 학습
    model.fit(x_train, y_train)

    # 데이터 이름을 자동으로 추출하기 위한 래퍼 함수
    data_name = [name for name in globals() if globals()[name] is data][0]

    # 예측
    y_val_pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
    y_val_pred = (y_val_pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측

    # 평가지표 계산
    f1 = f1_score(y_val, y_val_pred, average="binary")
    accuracy = accuracy_score(y_val, y_val_pred)
    precision = precision_score(y_val, y_val_pred)
    recall = recall_score(y_val, y_val_pred)
    conf_matrix = confusion_matrix(y_val, y_val_pred)
    
    # 결과 출력
    print(f'{model_name} 모델이 {data_name} 데이터로 학습한 결과:')
    print(f'F1 Score: {f1}')
    print('---')
    print('Confusion Matrix:')
    print(conf_matrix)
    print('---')
    print(f'Accuracy: {accuracy}')
    print(f'Precision: {precision}')
    print(f'Recall: {recall}')
    print('\n')

# %%
train_model_Dam = train_and_evaluate_model(
    'cat', train_data_dam,
    iterations=2083,
    learning_rate=0.023925705983940986,
    depth=11,
    l2_leaf_reg=0.05919257514332274,
    random_strength=7.259397831551647,
    bagging_temperature=5.39094676652102,
    border_count=234,
    scale_pos_weight=1.776413991309166,
    grow_policy='Lossguide',
    random_seed=RANDOM_STATE,
    eval_metric='F1',
    logging_level='Silent',
    boosting_type='Plain'
)

# %% [markdown]
# .
