# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ### 데이터 읽어오기

# %%
import os
from pprint import pprint

import optuna
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import pandas as pd

RANDOM_STATE = 110

train_data = pd.read_csv("C:/Users/KimDongyoung/Desktop/git_LGaimers5/Lg_aimers5/data/train_data_0817.csv")
test_data = pd.read_csv("C:/Users/KimDongyoung/Desktop/git_LGaimers5/Lg_aimers5/data/test_data_0817.csv")

# %% [markdown]
# ---

# %%
# dam, fill1, fill2 공통 변수
var_dam_fill = [
    'Equipment_same_num',
    'PalletID_Collect_Result_encoded',
    'Production_Qty_Collect_Result',
    'WorkMode Collect Result'
]

# %%
# 전체 공통 변수
### correlation 확인을 위한 변수 리스트
var_all_corr = [
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### train
var_all_train = [
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### test
var_all_test = [
    'Set ID',
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

# %%
# '_Dam'을 포함하는 변수 선택
dam_variables = [var for var in train_data.columns if '_Dam' in var]

# train
final_columns_train = var_dam_fill + var_all_train + dam_variables
train_data_dam = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + dam_variables
test_data_dam = test_data[final_columns_test]

# %%
# '_Fill1'을 포함하는 변수 선택
fill1_variables = [var for var in train_data.columns if '_Fill1' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill1_variables
train_data_fill1 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill1_variables
test_data_fill1 = test_data[final_columns_test]

# %%
# '_Fill2'을 포함하는 변수 선택
fill2_variables = [var for var in train_data.columns if '_Fill2' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill2_variables
train_data_fill2 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill2_variables
test_data_fill2 = test_data[final_columns_test]

# %%
# '_AutoClave'을 포함하는 변수 선택
autoclave_variables = [var for var in train_data.columns if '_AutoClave' in var]

# train
final_columns_train = var_all_train + autoclave_variables
train_data_autoclave = train_data[final_columns_train]

# test 
final_columns_test = var_all_test + autoclave_variables
test_data_autoclave = test_data[final_columns_test]

# %%
# 각 DataFrame의 칼럼 수 계산
num_columns_train_data = train_data.shape[1]
num_columns_train_data_dam = train_data_dam.shape[1]
num_columns_train_data_autoclave = train_data_autoclave.shape[1]
num_columns_train_data_fill1 = train_data_fill1.shape[1]
num_columns_train_data_fill2 = train_data_fill2.shape[1]

num_columns_test_data = test_data.shape[1]
num_columns_test_data_dam = test_data_dam.shape[1]
num_columns_test_data_autoclave = test_data_autoclave.shape[1]
num_columns_test_data_fill1 = test_data_fill1.shape[1]
num_columns_test_data_fill2 = test_data_fill2.shape[1]

# 각 DataFrame의 칼럼 수 출력
print("----train data-----")
print(f"train_data DataFrame의 칼럼 수: {num_columns_train_data}")
print(f"train_data_dam DataFrame의 칼럼 수: {num_columns_train_data_dam}")
print(f"train_data_autoclave DataFrame의 칼럼 수: {num_columns_train_data_autoclave}")
print(f"train_data_fill1 DataFrame의 칼럼 수: {num_columns_train_data_fill1}")
print(f"train_data_fill2 DataFrame의 칼럼 수: {num_columns_train_data_fill2}")
print("----test data-----")
print(f"test_data DataFrame의 칼럼 수: {num_columns_test_data}")
print(f"test_data_dam DataFrame의 칼럼 수: {num_columns_test_data_dam}")
print(f"test_data_autoclave DataFrame의 칼럼 수: {num_columns_test_data_autoclave}")
print(f"test_data_fill1 DataFrame의 칼럼 수: {num_columns_test_data_fill1}")
print(f"test_data_fill2 DataFrame의 칼럼 수: {num_columns_test_data_fill2}")
# Out:
# ----train data-----
# train_data DataFrame의 칼럼 수: 38
# train_data_dam DataFrame의 칼럼 수: 21
# train_data_autoclave DataFrame의 칼럼 수: 8
# train_data_fill1 DataFrame의 칼럼 수: 13
# train_data_fill2 DataFrame의 칼럼 수: 13
# ----test data-----
# test_data DataFrame의 칼럼 수: 39
# test_data_dam DataFrame의 칼럼 수: 22
# test_data_autoclave DataFrame의 칼럼 수: 9
# test_data_fill1 DataFrame의 칼럼 수: 14
# test_data_fill2 DataFrame의 칼럼 수: 14

# %% [markdown]
# ## Optuna

# %% [markdown]
# 스레스홀드 0.3으로 맞춘상태에서 튜닝 진행한 것

# %%
# 'Normal'과 'AbNormal'을 숫자로 변환
train_data_fill2['target'] = train_data_fill2['target'].map({'Normal': 0, 'AbNormal': 1})

# 스레드홀드 설정
THRESHOLD = 0.3

def objectiveExtraTreesClassifier(trial, x_tr, y_tr, x_val, y_val):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 500, 1500)
        , 'max_depth': trial.suggest_int('max_depth', 2, 60)
        , 'min_samples_split': trial.suggest_int('min_samples_split', 2, 5)
        , 'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 7)
        , 'criterion': trial.suggest_categorical('criterion', ['entropy'])
        , 'bootstrap': trial.suggest_categorical('bootstrap', [False])
        , 'random_state': RANDOM_STATE
    }
    
    model = ExtraTreesClassifier(**param)
    model.fit(x_tr, y_tr)
    pred = model.predict(x_val)
    score = f1_score(y_val, pred, average="binary")
    
    return score

# 데이터셋 분할
x_train, x_val, y_train, y_val = train_test_split(
    train_data_fill2.drop("target", axis=1),
    train_data_fill2["target"],
    test_size=0.2,
    shuffle=True,
    random_state=RANDOM_STATE,
)

# 하이퍼 파라미터 튜닝
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
study.optimize(lambda trial: objectiveExtraTreesClassifier(trial, x_train, y_train, x_val, y_val), n_trials=500)

print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# C:\Users\KimDongyoung\AppData\Local\Temp\ipykernel_30436\302596479.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data_fill2['target'] = train_data_fill2['target'].map({'Normal': 0, 'AbNormal': 1})
# [I 2024-08-22 18:41:31,316] A new study created in memory with name: no-name-ee343a00-dc8e-4ba2-a8ba-2426cc4e13d2
# [I 2024-08-22 18:41:39,819] Trial 0 finished with value: 0.15416666666666667 and parameters: {'n_estimators': 616, 'max_depth': 40, 'min_samples_split': 3, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.15416666666666667.
# [I 2024-08-22 18:41:55,365] Trial 1 finished with value: 0.15031315240083507 and parameters: {'n_estimators': 1180, 'max_depth': 42, 'min_samples_split': 5, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.15416666666666667.
# [I 2024-08-22 18:42:02,017] Trial 2 finished with value: 0.15031315240083507 and parameters: {'n_estimators': 1013, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.15416666666666667.
# [I 2024-08-22 18:42:04,233] Trial 3 finished with value: 0.053097345132743355 and parameters: {'n_estimators': 635, 'max_depth': 2, 'min_samples_split': 3, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.15416666666666667.
# [I 2024-08-22 18:42:12,294] Trial 4 finished with value: 0.15416666666666667 and parameters: {'n_estimators': 521, 'max_depth': 35, 'min_samples_split': 2, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.15416666666666667.
# [I 2024-08-22 18:42:24,808] Trial 5 finished with value: 0.15416666666666667 and parameters: {'n_estimators': 814, 'max_depth': 47, 'min_samples_split': 4, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.15416666666666667.
# [I 2024-08-22 18:42:28,295] Trial 6 finished with value: 0.08695652173913045 and parameters: {'n_estimators': 835, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 6, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.15416666666666667.
# [I 2024-08-22 18:42:39,515] Trial 7 finished with value: 0.15416666666666667 and parameters: {'n_estimators': 991, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.15416666666666667.
# [I 2024-08-22 18:42:51,252] Trial 8 finished with value: 0.15031315240083507 and parameters: {'n_estimators': 886, 'max_depth': 40, 'min_samples_split': 2, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.15416666666666667.
# [I 2024-08-22 18:43:00,739] Trial 9 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 540, 'max_depth': 37, 'min_samples_split': 2, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 9 with value: 0.15767634854771787.
# [I 2024-08-22 18:43:30,839] Trial 10 finished with value: 0.16122840690978887 and parameters: {'n_estimators': 1347, 'max_depth': 60, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.16122840690978887.
# [I 2024-08-22 18:44:03,998] Trial 11 finished with value: 0.15769230769230771 and parameters: {'n_estimators': 1483, 'max_depth': 59, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.16122840690978887.
# [I 2024-08-22 18:44:37,463] Trial 12 finished with value: 0.15769230769230771 and parameters: {'n_estimators': 1498, 'max_depth': 59, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.16122840690978887.
# [I 2024-08-22 18:45:10,227] Trial 13 finished with value: 0.15769230769230771 and parameters: {'n_estimators': 1455, 'max_depth': 58, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.16122840690978887.
# [I 2024-08-22 18:45:35,521] Trial 14 finished with value: 0.15810276679841898 and parameters: {'n_estimators': 1305, 'max_depth': 24, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.16122840690978887.
# [I 2024-08-22 18:45:55,252] Trial 15 finished with value: 0.15384615384615383 and parameters: {'n_estimators': 1255, 'max_depth': 24, 'min_samples_split': 5, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.16122840690978887.
# [I 2024-08-22 18:46:09,943] Trial 16 finished with value: 0.15031315240083507 and parameters: {'n_estimators': 1291, 'max_depth': 25, 'min_samples_split': 4, 'min_samples_leaf': 7, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.16122840690978887.
# [I 2024-08-22 18:46:31,371] Trial 17 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 1332, 'max_depth': 26, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.16122840690978887.
# [I 2024-08-22 18:46:56,302] Trial 18 finished with value: 0.1550695825049702 and parameters: {'n_estimators': 1150, 'max_depth': 50, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.16122840690978887.
# [I 2024-08-22 18:47:09,893] Trial 19 finished with value: 0.15416666666666667 and parameters: {'n_estimators': 1380, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.16122840690978887.
# [I 2024-08-22 18:47:23,231] Trial 20 finished with value: 0.15416666666666667 and parameters: {'n_estimators': 1125, 'max_depth': 17, 'min_samples_split': 3, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.16122840690978887.
# [I 2024-08-22 18:47:54,885] Trial 21 finished with value: 0.15738963531669867 and parameters: {'n_estimators': 1409, 'max_depth': 54, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.16122840690978887.
# [I 2024-08-22 18:48:22,517] Trial 22 finished with value: 0.16122840690978887 and parameters: {'n_estimators': 1241, 'max_depth': 51, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.16122840690978887.
# [I 2024-08-22 18:48:43,815] Trial 23 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 1254, 'max_depth': 47, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.16122840690978887.
# [I 2024-08-22 18:49:06,990] Trial 24 finished with value: 0.156 and parameters: {'n_estimators': 1078, 'max_depth': 30, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.16122840690978887.
# [I 2024-08-22 18:49:27,479] Trial 25 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 1227, 'max_depth': 53, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.16122840690978887.
# [I 2024-08-22 18:49:57,697] Trial 26 finished with value: 0.16216216216216217 and parameters: {'n_estimators': 1351, 'max_depth': 31, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 26 with value: 0.16216216216216217.
# [I 2024-08-22 18:50:21,605] Trial 27 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 1390, 'max_depth': 32, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 26 with value: 0.16216216216216217.
# [I 2024-08-22 18:50:49,433] Trial 28 finished with value: 0.1762589928057554 and parameters: {'n_estimators': 1193, 'max_depth': 45, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1762589928057554.
# [I 2024-08-22 18:51:04,502] Trial 29 finished with value: 0.15416666666666667 and parameters: {'n_estimators': 1038, 'max_depth': 45, 'min_samples_split': 3, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1762589928057554.
# [I 2024-08-22 18:51:20,071] Trial 30 finished with value: 0.15031315240083507 and parameters: {'n_estimators': 1349, 'max_depth': 41, 'min_samples_split': 3, 'min_samples_leaf': 7, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 28 with value: 0.1762589928057554.
# [I 2024-08-22 18:51:47,285] Trial 31 finished with value: 0.17857142857142858 and parameters: {'n_estimators': 1176, 'max_depth': 52, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 31 with value: 0.17857142857142858.
# [I 2024-08-22 18:52:14,464] Trial 32 finished with value: 0.17857142857142858 and parameters: {'n_estimators': 1162, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 31 with value: 0.17857142857142858.
# [I 2024-08-22 18:52:33,415] Trial 33 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 1122, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 31 with value: 0.17857142857142858.
# [I 2024-08-22 18:52:56,967] Trial 34 finished with value: 0.1779359430604982 and parameters: {'n_estimators': 966, 'max_depth': 43, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 31 with value: 0.17857142857142858.
# [I 2024-08-22 18:53:13,519] Trial 35 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 943, 'max_depth': 45, 'min_samples_split': 2, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 31 with value: 0.17857142857142858.
# [I 2024-08-22 18:53:28,957] Trial 36 finished with value: 0.15031315240083507 and parameters: {'n_estimators': 1170, 'max_depth': 49, 'min_samples_split': 3, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 31 with value: 0.17857142857142858.
# [I 2024-08-22 18:53:45,052] Trial 37 finished with value: 0.15416666666666667 and parameters: {'n_estimators': 1064, 'max_depth': 37, 'min_samples_split': 3, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 31 with value: 0.17857142857142858.
# [I 2024-08-22 18:53:53,633] Trial 38 finished with value: 0.15031315240083507 and parameters: {'n_estimators': 680, 'max_depth': 44, 'min_samples_split': 2, 'min_samples_leaf': 6, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 31 with value: 0.17857142857142858.
# [I 2024-08-22 18:54:12,045] Trial 39 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 733, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 39 with value: 0.17953321364452424.
# [I 2024-08-22 18:54:23,142] Trial 40 finished with value: 0.15416666666666667 and parameters: {'n_estimators': 742, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 39 with value: 0.17953321364452424.
# [I 2024-08-22 18:54:47,362] Trial 41 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 969, 'max_depth': 52, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 39 with value: 0.17953321364452424.
# [I 2024-08-22 18:55:10,268] Trial 42 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 942, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 39 with value: 0.17953321364452424.
# [I 2024-08-22 18:55:31,768] Trial 43 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 893, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 39 with value: 0.17953321364452424.
# [I 2024-08-22 18:55:47,266] Trial 44 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 893, 'max_depth': 52, 'min_samples_split': 2, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 39 with value: 0.17953321364452424.
# [I 2024-08-22 18:56:06,371] Trial 45 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 784, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 39 with value: 0.17953321364452424.
# [I 2024-08-22 18:56:25,692] Trial 46 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 776, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 18:56:37,865] Trial 47 finished with value: 0.15416666666666667 and parameters: {'n_estimators': 783, 'max_depth': 60, 'min_samples_split': 2, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 18:56:48,727] Trial 48 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 625, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 18:57:05,841] Trial 49 finished with value: 0.17825311942959002 and parameters: {'n_estimators': 702, 'max_depth': 49, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 18:57:17,529] Trial 50 finished with value: 0.15416666666666667 and parameters: {'n_estimators': 831, 'max_depth': 60, 'min_samples_split': 2, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 18:57:39,063] Trial 51 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 882, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 18:58:00,745] Trial 52 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 886, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 18:58:22,130] Trial 53 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 874, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 18:58:35,725] Trial 54 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 779, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 18:58:56,653] Trial 55 finished with value: 0.17857142857142858 and parameters: {'n_estimators': 860, 'max_depth': 54, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 18:59:10,569] Trial 56 finished with value: 0.17857142857142858 and parameters: {'n_estimators': 544, 'max_depth': 48, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 18:59:23,956] Trial 57 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 741, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 18:59:46,973] Trial 58 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 923, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:00:07,888] Trial 59 finished with value: 0.17177914110429449 and parameters: {'n_estimators': 800, 'max_depth': 54, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:00:18,698] Trial 60 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 587, 'max_depth': 50, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:00:43,059] Trial 61 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 985, 'max_depth': 52, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:00:59,427] Trial 62 finished with value: 0.17761989342806392 and parameters: {'n_estimators': 674, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:01:20,500] Trial 63 finished with value: 0.17857142857142858 and parameters: {'n_estimators': 849, 'max_depth': 53, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:01:42,662] Trial 64 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 896, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:02:07,425] Trial 65 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1007, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:02:25,085] Trial 66 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 1015, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:02:42,653] Trial 67 finished with value: 0.16122840690978887 and parameters: {'n_estimators': 739, 'max_depth': 60, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:02:52,966] Trial 68 finished with value: 0.15031315240083507 and parameters: {'n_estimators': 821, 'max_depth': 47, 'min_samples_split': 3, 'min_samples_leaf': 6, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:03:08,909] Trial 69 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 918, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:03:13,026] Trial 70 finished with value: 0.15062761506276148 and parameters: {'n_estimators': 764, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:03:37,620] Trial 71 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1014, 'max_depth': 51, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:04:02,994] Trial 72 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 1030, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:04:23,007] Trial 73 finished with value: 0.17857142857142858 and parameters: {'n_estimators': 812, 'max_depth': 50, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:04:49,708] Trial 74 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1091, 'max_depth': 54, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:05:16,450] Trial 75 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 1082, 'max_depth': 54, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:05:26,680] Trial 76 finished with value: 0.15416666666666667 and parameters: {'n_estimators': 1058, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:05:43,485] Trial 77 finished with value: 0.16122840690978887 and parameters: {'n_estimators': 701, 'max_depth': 51, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:06:02,920] Trial 78 finished with value: 0.156 and parameters: {'n_estimators': 1100, 'max_depth': 20, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:06:20,071] Trial 79 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 988, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:06:45,027] Trial 80 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1012, 'max_depth': 53, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:07:09,905] Trial 81 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 1005, 'max_depth': 53, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:07:35,403] Trial 82 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 1048, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:07:58,607] Trial 83 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 947, 'max_depth': 51, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:08:26,058] Trial 84 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 1122, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:08:45,458] Trial 85 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 1093, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:09:06,283] Trial 86 finished with value: 0.17825311942959002 and parameters: {'n_estimators': 849, 'max_depth': 47, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:09:29,210] Trial 87 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 924, 'max_depth': 49, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:09:53,933] Trial 88 finished with value: 0.1728395061728395 and parameters: {'n_estimators': 976, 'max_depth': 53, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:10:02,621] Trial 89 finished with value: 0.15416666666666667 and parameters: {'n_estimators': 663, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:10:22,548] Trial 90 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 1143, 'max_depth': 38, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:10:46,895] Trial 91 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 1004, 'max_depth': 53, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:11:04,430] Trial 92 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 718, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:11:28,958] Trial 93 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1008, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:11:54,694] Trial 94 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 1033, 'max_depth': 53, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:12:17,807] Trial 95 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 955, 'max_depth': 51, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:12:35,909] Trial 96 finished with value: 0.17454545454545456 and parameters: {'n_estimators': 790, 'max_depth': 28, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:12:54,309] Trial 97 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 757, 'max_depth': 54, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:13:20,318] Trial 98 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 1073, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:13:37,574] Trial 99 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 995, 'max_depth': 59, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:13:58,545] Trial 100 finished with value: 0.1746880570409982 and parameters: {'n_estimators': 869, 'max_depth': 34, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:14:23,839] Trial 101 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 1026, 'max_depth': 53, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:14:49,265] Trial 102 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 1009, 'max_depth': 52, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:15:11,845] Trial 103 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 923, 'max_depth': 48, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:15:35,459] Trial 104 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 965, 'max_depth': 52, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:16:02,829] Trial 105 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1102, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:16:24,800] Trial 106 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 903, 'max_depth': 50, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:16:49,127] Trial 107 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 997, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:17:07,445] Trial 108 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 1050, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:17:27,655] Trial 109 finished with value: 0.1779359430604982 and parameters: {'n_estimators': 833, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:17:50,740] Trial 110 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 935, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:18:15,415] Trial 111 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1010, 'max_depth': 54, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:18:45,315] Trial 112 finished with value: 0.17857142857142858 and parameters: {'n_estimators': 1217, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:19:01,329] Trial 113 finished with value: 0.17825311942959002 and parameters: {'n_estimators': 652, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:19:16,399] Trial 114 finished with value: 0.15416666666666667 and parameters: {'n_estimators': 984, 'max_depth': 54, 'min_samples_split': 3, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:19:40,746] Trial 115 finished with value: 0.1550695825049702 and parameters: {'n_estimators': 1066, 'max_depth': 52, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:20:04,356] Trial 116 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 959, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:20:14,129] Trial 117 finished with value: 0.15031315240083507 and parameters: {'n_estimators': 809, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 7, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:20:32,012] Trial 118 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 720, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:20:57,605] Trial 119 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 1040, 'max_depth': 48, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:21:16,454] Trial 120 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 771, 'max_depth': 46, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:21:41,723] Trial 121 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 1025, 'max_depth': 49, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:22:07,380] Trial 122 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 1041, 'max_depth': 52, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:22:32,125] Trial 123 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1001, 'max_depth': 51, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:22:59,697] Trial 124 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 1123, 'max_depth': 50, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:23:25,574] Trial 125 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 1057, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:23:49,407] Trial 126 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 971, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:24:15,416] Trial 127 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 1059, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:24:39,855] Trial 128 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 989, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:24:50,401] Trial 129 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 605, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:25:12,467] Trial 130 finished with value: 0.17730496453900707 and parameters: {'n_estimators': 904, 'max_depth': 42, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:25:39,174] Trial 131 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 1074, 'max_depth': 53, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:26:04,687] Trial 132 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 1046, 'max_depth': 54, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:26:31,475] Trial 133 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1099, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:26:56,598] Trial 134 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 1025, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:27:25,795] Trial 135 finished with value: 0.17857142857142858 and parameters: {'n_estimators': 1147, 'max_depth': 54, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:27:50,587] Trial 136 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1015, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:28:08,347] Trial 137 finished with value: 0.1779359430604982 and parameters: {'n_estimators': 694, 'max_depth': 51, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:28:20,155] Trial 138 finished with value: 0.15031315240083507 and parameters: {'n_estimators': 944, 'max_depth': 48, 'min_samples_split': 3, 'min_samples_leaf': 6, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:28:38,007] Trial 139 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 727, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:29:04,510] Trial 140 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 1083, 'max_depth': 53, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:29:28,935] Trial 141 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1000, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:29:53,949] Trial 142 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 1017, 'max_depth': 52, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:30:21,981] Trial 143 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 1050, 'max_depth': 53, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:30:40,390] Trial 144 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 755, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:31:04,431] Trial 145 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 974, 'max_depth': 50, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:31:15,995] Trial 146 finished with value: 0.15031315240083507 and parameters: {'n_estimators': 878, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:31:41,674] Trial 147 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 1037, 'max_depth': 54, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:32:09,544] Trial 148 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 1110, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:32:29,039] Trial 149 finished with value: 0.15717092337917485 and parameters: {'n_estimators': 988, 'max_depth': 22, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:32:48,409] Trial 150 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 788, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:33:13,104] Trial 151 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1007, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:33:39,058] Trial 152 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1065, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:34:03,615] Trial 153 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 1002, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:34:27,472] Trial 154 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 949, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:34:49,748] Trial 155 finished with value: 0.17857142857142858 and parameters: {'n_estimators': 848, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:35:15,638] Trial 156 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 1026, 'max_depth': 53, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:35:39,961] Trial 157 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 988, 'max_depth': 52, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:35:59,711] Trial 158 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 1087, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:36:23,822] Trial 159 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 962, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:36:49,249] Trial 160 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 1039, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:37:13,861] Trial 161 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 1003, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:37:27,771] Trial 162 finished with value: 0.15416666666666667 and parameters: {'n_estimators': 1003, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:37:52,523] Trial 163 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1011, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:38:16,293] Trial 164 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 972, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:38:42,046] Trial 165 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1058, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:39:05,161] Trial 166 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 923, 'max_depth': 51, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:39:30,830] Trial 167 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 1038, 'max_depth': 54, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:39:55,000] Trial 168 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 980, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:40:15,238] Trial 169 finished with value: 0.17857142857142858 and parameters: {'n_estimators': 821, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:40:24,526] Trial 170 finished with value: 0.15448851774530273 and parameters: {'n_estimators': 1072, 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# [I 2024-08-22 19:40:49,147] Trial 171 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 1006, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 46 with value: 0.17985611510791363.
# ...
# [I 2024-08-22 21:27:43,577] Trial 443 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 1018, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:28:06,094] Trial 444 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 909, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:28:33,079] Trial 445 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1104, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:28:56,761] Trial 446 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 953, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:29:22,169] Trial 447 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 1037, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:29:46,172] Trial 448 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 980, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:30:10,827] Trial 449 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 1003, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:30:35,784] Trial 450 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1022, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:31:01,578] Trial 451 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 1056, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:31:25,496] Trial 452 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 962, 'max_depth': 52, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:31:50,048] Trial 453 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 995, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:32:15,329] Trial 454 finished with value: 0.1728395061728395 and parameters: {'n_estimators': 977, 'max_depth': 56, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:32:40,211] Trial 455 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 1011, 'max_depth': 48, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:33:03,134] Trial 456 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 929, 'max_depth': 51, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:33:28,561] Trial 457 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 1036, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:33:55,068] Trial 458 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1070, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:34:10,266] Trial 459 finished with value: 0.17825311942959002 and parameters: {'n_estimators': 617, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:34:35,113] Trial 460 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 1002, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:34:59,494] Trial 461 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 985, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:35:24,926] Trial 462 finished with value: 0.17857142857142858 and parameters: {'n_estimators': 1025, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:35:36,621] Trial 463 finished with value: 0.15031315240083507 and parameters: {'n_estimators': 961, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 7, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:36:02,104] Trial 464 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1009, 'max_depth': 54, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:36:20,549] Trial 465 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 1048, 'max_depth': 47, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:36:45,751] Trial 466 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 987, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:37:09,199] Trial 467 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 945, 'max_depth': 50, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:37:26,918] Trial 468 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 712, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:37:53,378] Trial 469 finished with value: 0.17857142857142858 and parameters: {'n_estimators': 1027, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:38:11,760] Trial 470 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 744, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:38:31,325] Trial 471 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 802, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:39:06,722] Trial 472 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 1404, 'max_depth': 53, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:39:30,995] Trial 473 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 976, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:39:55,800] Trial 474 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1003, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:40:20,851] Trial 475 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1019, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:40:47,495] Trial 476 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1092, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:41:03,936] Trial 477 finished with value: 0.15416666666666667 and parameters: {'n_estimators': 1059, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:41:28,222] Trial 478 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 992, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:41:53,457] Trial 479 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 1032, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:42:17,418] Trial 480 finished with value: 0.17173524150268335 and parameters: {'n_estimators': 966, 'max_depth': 35, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:42:22,154] Trial 481 finished with value: 0.1271186440677966 and parameters: {'n_estimators': 1013, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:42:42,695] Trial 482 finished with value: 0.17825311942959002 and parameters: {'n_estimators': 836, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:43:07,209] Trial 483 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 989, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:43:32,486] Trial 484 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 1037, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:43:56,076] Trial 485 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 956, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:44:21,116] Trial 486 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 1006, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:44:45,179] Trial 487 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 986, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:44:58,742] Trial 488 finished with value: 0.15031315240083507 and parameters: {'n_estimators': 1048, 'max_depth': 52, 'min_samples_split': 3, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:45:21,408] Trial 489 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 936, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:45:33,504] Trial 490 finished with value: 0.15031315240083507 and parameters: {'n_estimators': 972, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 6, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:45:58,615] Trial 491 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1017, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:46:23,172] Trial 492 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 999, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:46:46,881] Trial 493 finished with value: 0.17889087656529518 and parameters: {'n_estimators': 969, 'max_depth': 49, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:47:13,635] Trial 494 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 1077, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:47:31,512] Trial 495 finished with value: 0.15767634854771787 and parameters: {'n_estimators': 1023, 'max_depth': 54, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:47:55,816] Trial 496 finished with value: 0.17985611510791363 and parameters: {'n_estimators': 995, 'max_depth': 51, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:48:21,875] Trial 497 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 1035, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:48:48,098] Trial 498 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1058, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# [I 2024-08-22 21:49:13,001] Trial 499 finished with value: 0.17953321364452424 and parameters: {'n_estimators': 1008, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 315 with value: 0.1801801801801802.
# Best trial: score 0.1801801801801802,
# params {'n_estimators': 996, 'max_depth': 49, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}

# %% [markdown]
# Best trial: score 0.1801801801801802
#
# params {'n_estimators': 1001, 'max_depth': 45, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}

# %%
# 스레드홀드 설정
THRESHOLD = 0.3

# 모델 설정 및 하이퍼파라미터
models = {
    'et': ExtraTreesClassifier(),
    'rf': RandomForestClassifier(),
    'cat': CatBoostClassifier(),
    'lgbm': LGBMClassifier(),
    'xgb': XGBClassifier(),
    'dt': DecisionTreeClassifier()
}

def train_and_evaluate_model(model_name, data, **params):
    if model_name not in models:
        print(f"{model_name}은(는) 지원되지 않는 모델입니다.")
        return
    
    # 데이터셋 분할
    x_train, x_val, y_train, y_val = train_test_split(
        data.drop("target", axis=1),
        data["target"].map({'Normal': 0, 'AbNormal': 1}),
        test_size=0.2,
        shuffle=True,
        random_state=RANDOM_STATE,
    )

    # 모델 선택
    model = models[model_name]

    # 하이퍼파라미터 설정
    model.set_params(**params)

    # 모델 학습
    model.fit(x_train, y_train)

    # 데이터 이름을 자동으로 추출하기 위한 래퍼 함수
    data_name = [name for name in globals() if globals()[name] is data][0]

    # 예측
    y_val_pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
    y_val_pred = (y_val_pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측

    # 평가지표 계산
    f1 = f1_score(y_val, y_val_pred, average="binary")
    accuracy = accuracy_score(y_val, y_val_pred)
    precision = precision_score(y_val, y_val_pred)
    recall = recall_score(y_val, y_val_pred)
    conf_matrix = confusion_matrix(y_val, y_val_pred)
    
    # 결과 출력
    print(f'{model_name} 모델이 {data_name} 데이터로 학습한 결과:')
    print(f'F1 Score: {f1}')
    print('---')
    print('Confusion Matrix:')
    print(conf_matrix)
    print('---')
    print(f'Accuracy: {accuracy}')
    print(f'Precision: {precision}')
    print(f'Recall: {recall}')
    print('\n')

# %%
# 5-5. Fill2
train_model_Fill2 = train_and_evaluate_model(
    'et', train_data_fill2
    , n_estimators = 1001
    , max_depth = 45
    , min_samples_split = 3
    , min_samples_leaf = 1
    , criterion = 'entropy'
    , bootstrap = False
    , random_state=RANDOM_STATE
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 # 5-5. Fill2
# ----> 2 train_model_Fill2 = train_and_evaluate_model(
#       3     'et', train_data_fill2
#       4     , n_estimators = 1001
#       5     , max_depth = 45
#       6     , min_samples_split = 3
#       7     , min_samples_leaf = 1
#       8     , criterion = 'entropy'
#       9     , bootstrap = False
#      10     , random_state=RANDOM_STATE
#      11 )
#
# Cell In[21], line 35, in train_and_evaluate_model(model_name, data, **params)
#      32 model.set_params(**params)
#      34 # 모델 학습
# ---> 35 model.fit(x_train, y_train)
#      37 # 데이터 이름을 자동으로 추출하기 위한 래퍼 함수
#      38 data_name = [name for name in globals() if globals()[name] is data][0]
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_forest.py:348, in BaseForest.fit(self, X, y, sample_weight)
#     346 if issparse(y):
#     347     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 348 X, y = self._validate_data(
#     349     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     350 )
#     351 if sample_weight is not None:
#     352     sample_weight = _check_sample_weight(sample_weight, X)
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:622, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     620         y = check_array(y, input_name="y", **check_y_params)
#     621     else:
# --> 622         X, y = check_X_y(X, y, **check_params)
#     623     out = X, y
#     625 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1162, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1142     raise ValueError(
#    1143         f"{estimator_name} requires y to be passed, but the target y is None"
#    1144     )
#    1146 X = check_array(
#    1147     X,
#    1148     accept_sparse=accept_sparse,
#    (...)
#    1159     input_name="X",
#    1160 )
# -> 1162 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1164 check_consistent_length(X, y)
#    1166 return X, y
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1172, in _check_y(y, multi_output, y_numeric, estimator)
#    1170 """Isolated part of check_X_y dedicated to y validation"""
#    1171 if multi_output:
# -> 1172     y = check_array(
#    1173         y,
#    1174         accept_sparse="csr",
#    1175         force_all_finite=True,
#    1176         ensure_2d=False,
#    1177         dtype=None,
#    1178         input_name="y",
#    1179         estimator=estimator,
#    1180     )
#    1181 else:
#    1182     estimator_name = _check_estimator_name(estimator)
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:957, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     951         raise ValueError(
#     952             "Found array with dim %d. %s expected <= 2."
#     953             % (array.ndim, estimator_name)
#     954         )
#     956     if force_all_finite:
# --> 957         _assert_all_finite(
#     958             array,
#     959             input_name=input_name,
#     960             estimator_name=estimator_name,
#     961             allow_nan=force_all_finite == "allow-nan",
#     962         )
#     964 if ensure_min_samples > 0:
#     965     n_samples = _num_samples(array)
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:122, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     119 if first_pass_isfinite:
#     120     return
# --> 122 _assert_all_finite_element_wise(
#     123     X,
#     124     xp=xp,
#     125     allow_nan=allow_nan,
#     126     msg_dtype=msg_dtype,
#     127     estimator_name=estimator_name,
#     128     input_name=input_name,
#     129 )
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:171, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     154 if estimator_name and input_name == "X" and has_nan_error:
#     155     # Improve the error message on how to handle missing values in
#     156     # scikit-learn.
#     157     msg_err += (
#     158         f"\n{estimator_name} does not accept missing values"
#     159         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     169         "#estimators-that-handle-nan-values"
#     170     )
# --> 171 raise ValueError(msg_err)
#
# ValueError: Input y contains NaN.

# %% [markdown]
# et 모델이 train_data_fill2 데이터로 학습한 결과:
#
# F1 Score: 0.17269544924154023

# %%
# train_and_evaluate_model(
#     'et', train_data_dam,
#     n_estimators = 2708,
#     max_depth = 41,
#     min_samples_split = 8,
#     min_samples_leaf = 1,
#     criterion = 'entropy',
#     bootstrap = False,
#     random_state=RANDOM_STATE
# )

# %% [markdown]
# .
