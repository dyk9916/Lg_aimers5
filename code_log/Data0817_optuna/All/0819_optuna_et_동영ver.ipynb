# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ## 1. 데이터 불러오기

# %% [markdown]
# ### 필수 라이브러리

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)

def get_clf_eval(y_test, y_pred_proba, threshold=0.5):
    # 확률을 기준으로 예측 레이블 생성
    y_pred = (y_pred_proba >= threshold).astype(int)  # 0.5 이상의 확률을 양성으로 간주

    confusion = confusion_matrix(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    print("Confusion Matrix:\n", confusion)
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")

# %% [markdown]
# ### 데이터 읽어오기

# %%
RANDOM_STATE = 110

# csv 불러오기
train_data = pd.read_csv('C:/Users/KimDongyoung/Desktop/git_LGaimers5/Lg_aimers5/data/train_data_0817.csv')
test_data  = pd.read_csv('C:/Users/KimDongyoung/Desktop/git_LGaimers5/Lg_aimers5/data/test_data_0817.csv')

# %% [markdown]
# ---

# %% [markdown]
# ## 데이터 분할

# %%
df_train, df_val = train_test_split(
    train_data,
    test_size=0.2,
    stratify=train_data["target"],
    shuffle=True,
    random_state=RANDOM_STATE,
)

def print_stats(df: pd.DataFrame):
    num_normal = len(df[df["target"] == "Normal"])
    num_abnormal = len(df[df["target"] == "AbNormal"])

    print(f"  Total: Normal: {num_normal}, AbNormal: {num_abnormal}" + f" ratio: {num_abnormal/num_normal}")


# Print statistics
print(f"  \tAbnormal\tNormal")
print_stats(df_train)
print_stats(df_val)
# Out:
#   	Abnormal	Normal
#   Total: Normal: 30524, AbNormal: 1880 ratio: 0.06159087930808544
#   Total: Normal: 7632, AbNormal: 470 ratio: 0.061582809224318656

# %% [markdown]
# ## 3. 모델 학습

# %% [markdown]
# ### 모델 정의

# %% [markdown]
# optuna

# %%
import optuna
from sklearn.ensemble import ExtraTreesClassifier 

# 'Normal'과 'AbNormal'을 숫자로 변환
train_data['target'] = train_data['target'].map({'Normal': 0, 'AbNormal': 1})

# 스레드홀드 설정
THRESHOLD = 0.3

def objectiveExtraTreesClassifier(trial, x_tr, y_tr, x_val, y_val):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 2500, 3500)
        , 'max_depth': trial.suggest_int('max_depth', 50, 70)
        , 'min_samples_split': trial.suggest_int('min_samples_split', 2, 10)
        , 'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 7)
        , 'criterion': trial.suggest_categorical('criterion', ['entropy'])
        , 'bootstrap': trial.suggest_categorical('bootstrap', [False])
        , 'random_state': RANDOM_STATE
    }
    
    model = ExtraTreesClassifier(**param)
    model.fit(x_tr, y_tr)
    pred = model.predict(x_val)
    score = f1_score(y_val, pred, average="binary")
    
    return score

# 데이터셋 분할
x_train, x_val, y_train, y_val = train_test_split(
    train_data.drop("target", axis=1),
    train_data["target"],
    test_size=0.2,
    shuffle=True,
    random_state=RANDOM_STATE,
)

# 하이퍼 파라미터 튜닝
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
study.optimize(lambda trial: objectiveExtraTreesClassifier(trial, x_train, y_train, x_val, y_val), n_trials=500)

print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# [I 2024-08-22 22:35:03,484] A new study created in memory with name: no-name-21f93f6c-ce62-489a-803f-af46367e0c08
# [I 2024-08-22 22:36:10,694] Trial 0 finished with value: 0.16216216216216214 and parameters: {'n_estimators': 2616, 'max_depth': 63, 'min_samples_split': 5, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.16216216216216214.
# [I 2024-08-22 22:37:32,076] Trial 1 finished with value: 0.16216216216216214 and parameters: {'n_estimators': 3180, 'max_depth': 64, 'min_samples_split': 10, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.16216216216216214.
# [I 2024-08-22 22:38:56,397] Trial 2 finished with value: 0.1810699588477366 and parameters: {'n_estimators': 3013, 'max_depth': 51, 'min_samples_split': 5, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 2 with value: 0.1810699588477366.
# [I 2024-08-22 22:40:08,276] Trial 3 finished with value: 0.17355371900826447 and parameters: {'n_estimators': 2635, 'max_depth': 50, 'min_samples_split': 5, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 2 with value: 0.1810699588477366.
# [I 2024-08-22 22:41:18,795] Trial 4 finished with value: 0.1810699588477366 and parameters: {'n_estimators': 2521, 'max_depth': 61, 'min_samples_split': 2, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 2 with value: 0.1810699588477366.
# [I 2024-08-22 22:42:37,607] Trial 5 finished with value: 0.1810699588477366 and parameters: {'n_estimators': 2814, 'max_depth': 66, 'min_samples_split': 7, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 2 with value: 0.1810699588477366.
# [I 2024-08-22 22:43:47,135] Trial 6 finished with value: 0.15448851774530273 and parameters: {'n_estimators': 2835, 'max_depth': 50, 'min_samples_split': 2, 'min_samples_leaf': 6, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 2 with value: 0.1810699588477366.
# [I 2024-08-22 22:45:07,142] Trial 7 finished with value: 0.17355371900826447 and parameters: {'n_estimators': 2991, 'max_depth': 55, 'min_samples_split': 8, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 2 with value: 0.1810699588477366.
# [I 2024-08-22 22:46:21,850] Trial 8 finished with value: 0.16216216216216214 and parameters: {'n_estimators': 2886, 'max_depth': 63, 'min_samples_split': 3, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 2 with value: 0.1810699588477366.
# [I 2024-08-22 22:47:42,213] Trial 9 finished with value: 0.1806981519507187 and parameters: {'n_estimators': 2540, 'max_depth': 62, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 2 with value: 0.1810699588477366.
# [I 2024-08-22 22:49:40,169] Trial 10 finished with value: 0.19066937119675456 and parameters: {'n_estimators': 3347, 'max_depth': 70, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.19066937119675456.
# [I 2024-08-22 22:51:40,755] Trial 11 finished with value: 0.19066937119675456 and parameters: {'n_estimators': 3483, 'max_depth': 70, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.19066937119675456.
# [I 2024-08-22 22:53:40,483] Trial 12 finished with value: 0.19066937119675456 and parameters: {'n_estimators': 3498, 'max_depth': 70, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.19066937119675456.
# [I 2024-08-22 22:55:42,750] Trial 13 finished with value: 0.19066937119675456 and parameters: {'n_estimators': 3455, 'max_depth': 69, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.19066937119675456.
# [I 2024-08-22 22:57:40,636] Trial 14 finished with value: 0.19354838709677416 and parameters: {'n_estimators': 3305, 'max_depth': 67, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 14 with value: 0.19354838709677416.
# [I 2024-08-22
finished with value: 0.20306513409961682 and parameters: {'n_estimators': 2973, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:03:14,232] Trial 122 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3153, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:04:48,435] Trial 123 finished with value: 0.19999999999999998 and parameters: {'n_estimators': 3147, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:06:33,549] Trial 124 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3083, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:08:21,416] Trial 125 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3056, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:10:13,915] Trial 126 finished with value: 0.19607843137254902 and parameters: {'n_estimators': 2998, 'max_depth': 59, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:12:02,229] Trial 127 finished with value: 0.19961612284069097 and parameters: {'n_estimators': 2504, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:14:10,584] Trial 128 finished with value: 0.19424460431654675 and parameters: {'n_estimators': 2945, 'max_depth': 60, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:15:55,539] Trial 129 finished with value: 0.19961612284069097 and parameters: {'n_estimators': 2592, 'max_depth': 61, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:17:56,735] Trial 130 finished with value: 0.1806981519507187 and parameters: {'n_estimators': 3107, 'max_depth': 54, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:19:57,866] Trial 131 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3017, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:22:34,076] Trial 132 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3036, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:25:20,568] Trial 133 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3005, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:28:02,946] Trial 134 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3068, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:30:02,442] Trial 135 finished with value: 0.19961612284069097 and parameters: {'n_estimators': 2911, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:32:47,386] Trial 136 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 2968, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:35:23,937] Trial 137 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 2989, 'max_depth': 62, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:37:29,284] Trial 138 finished with value: 0.19424460431654675 and parameters: {'n_estimators': 3026, 'max_depth': 56, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:39:36,327] Trial 139 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3127, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:41:34,900] Trial 140 finished with value: 0.19607843137254902 and parameters: {'n_estimators': 3044, 'max_depth': 57, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:43:45,676] Trial 141 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3083, 'max_depth': 63, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:46:19,756] Trial 142 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3097, 'max_depth': 62, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:49:05,338] Trial 143 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3071, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:51:45,437] Trial 144 finished with value: 0.19999999999999998 and parameters: {'n_estimators': 3178, 'max_depth': 54, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:53:49,828] Trial 145 finished with value: 0.20306513409961682 and parameters: {'n_estimators': 3008, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:56:07,519] Trial 146 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3047, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 02:58:27,342] Trial 147 finished with value: 0.20306513409961682 and parameters: {'n_estimators': 2981, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:00:11,801] Trial 148 finished with value: 0.16216216216216214 and parameters: {'n_estimators': 3031, 'max_depth': 59, 'min_samples_split': 2, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:02:08,791] Trial 149 finished with value: 0.19646365422396855 and parameters: {'n_estimators': 2956, 'max_depth': 53, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:04:16,980] Trial 150 finished with value: 0.19999999999999998 and parameters: {'n_estimators': 3149, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:06:49,638] Trial 151 finished with value: 0.20306513409961682 and parameters: {'n_estimators': 2984, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:09:12,767] Trial 152 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3014, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:11:29,558] Trial 153 finished with value: 0.19999999999999998 and parameters: {'n_estimators': 2975, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:13:53,032] Trial 154 finished with value: 0.19961612284069097 and parameters: {'n_estimators': 2934, 'max_depth': 61, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:16:26,784] Trial 155 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3085, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:18:35,980] Trial 156 finished with value: 0.19424460431654675 and parameters: {'n_estimators': 3057, 'max_depth': 54, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:20:43,410] Trial 157 finished with value: 0.20306513409961682 and parameters: {'n_estimators': 3002, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:23:01,846] Trial 158 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3020, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:25:19,016] Trial 159 finished with value: 0.19607843137254902 and parameters: {'n_estimators': 2958, 'max_depth': 65, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:27:19,365] Trial 160 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 2911, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:29:32,402] Trial 161 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3029, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:32:15,071] Trial 162 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3061, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:34:58,334] Trial 163 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 2998, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:37:00,436] Trial 164 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3037, 'max_depth': 53, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:38:58,356] Trial 165 finished with value: 0.19961612284069097 and parameters: {'n_estimators': 2975, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:40:59,468] Trial 166 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3015, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:43:09,465] Trial 167 finished with value: 0.19424460431654675 and parameters: {'n_estimators': 3074, 'max_depth': 59, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:44:42,278] Trial 168 finished with value: 0.17355371900826447 and parameters: {'n_estimators': 3108, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:46:39,363] Trial 169 finished with value: 0.19607843137254902 and parameters: {'n_estimators': 2989, 'max_depth': 56, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:48:45,835] Trial 170 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3048, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:51:01,286] Trial 171 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3026, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:53:04,035] Trial 172 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3050, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 03:55:34,571] Trial 173 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3007, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# ...
# [I 2024-08-23 11:09:49,597] Trial 396 finished with value: 0.19961612284069097 and parameters: {'n_estimators': 2936, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 11:11:30,855] Trial 397 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3139, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 11:12:36,668] Trial 398 finished with value: 0.15448851774530273 and parameters: {'n_estimators': 3081, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 7, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 11:13:49,597] Trial 399 finished with value: 0.17355371900826447 and parameters: {'n_estimators': 3024, 'max_depth': 59, 'min_samples_split': 2, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 11:15:15,927] Trial 400 finished with value: 0.18442622950819673 and parameters: {'n_estimators': 2998, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 11:16:56,710] Trial 401 finished with value: 0.20306513409961682 and parameters: {'n_estimators': 3058, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 11:18:55,211] Trial 402 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 3314, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 11:20:31,466] Trial 403 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 2891, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [I 2024-08-23 11:22:10,438] Trial 404 finished with value: 0.19999999999999998 and parameters: {'n_estimators': 2969, 'max_depth': 54, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 78 with value: 0.2034548944337812.
# [W 2024-08-23 11:23:35,751] Trial 405 failed with parameters: {'n_estimators': 3118, 'max_depth': 53, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\optuna\study\_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\KimDongyoung\AppData\Local\Temp\ipykernel_23380\1281007404.py", line 39, in <lambda>
#     study.optimize(lambda trial: objectiveExtraTreesClassifier(trial, x_train, y_train, x_val, y_val), n_trials=500)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\KimDongyoung\AppData\Local\Temp\ipykernel_23380\1281007404.py", line 22, in objectiveExtraTreesClassifier
#     model.fit(x_tr, y_tr)
#   File "c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_forest.py", line 456, in fit
#     trees = Parallel(
#             ^^^^^^^^^
#   File "c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\parallel.py", line 65, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py", line 1863, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py", line 1792, in _get_sequential_output
#     res = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\parallel.py", line 127, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_forest.py", line 190, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_classes.py", line 959, in fit
#     super()._fit(
#   File "c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_classes.py", line 443, in _fit
#     builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
# KeyboardInterrupt
# [W 2024-08-23 11:23:35,772] Trial 405 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 39
#      37 # 하이퍼 파라미터 튜닝
#      38 study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# ---> 39 study.optimize(lambda trial: objectiveExtraTreesClassifier(trial, x_train, y_train, x_val, y_val), n_trials=500)
#      41 print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\optuna\study\study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\optuna\study\_optimize.py:62, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      60 try:
#      61     if n_jobs == 1:
# ---> 62         _optimize_sequential(
#      63             study,
#      64             func,
#      65             n_trials,
#      66             timeout,
#      67             catch,
#      68             callbacks,
#      69             gc_after_trial,
#      70             reseed_sampler_rng=False,
#      71             time_start=None,
#      72             progress_bar=progress_bar,
#      73         )
#      74     else:
#      75         if n_jobs == -1:
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\optuna\study\_optimize.py:159, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     156         break
#     158 try:
# --> 159     frozen_trial = _run_trial(study, func, catch)
#     160 finally:
#     161     # The following line mitigates memory problems that can be occurred in some
#     162     # environments (e.g., services that use computing containers such as GitHub Actions).
#     163     # Please refer to the following PR for further details:
#     164     # https://github.com/optuna/optuna/pull/325.
#     165     if gc_after_trial:
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\optuna\study\_optimize.py:247, in _run_trial(study, func, catch)
#     240         assert False, "Should not reach."
#     242 if (
#     243     frozen_trial.state == TrialState.FAIL
#     244     and func_err is not None
#     245     and not isinstance(func_err, catch)
#     246 ):
# --> 247     raise func_err
#     248 return frozen_trial
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\optuna\study\_optimize.py:196, in _run_trial(study, func, catch)
#     194 with get_heartbeat_thread(trial._trial_id, study._storage):
#     195     try:
# --> 196         value_or_values = func(trial)
#     197     except exceptions.TrialPruned as e:
#     198         # TODO(mamu): Handle multi-objective cases.
#     199         state = TrialState.PRUNED
#
# Cell In[8], line 39, in <lambda>(trial)
#      37 # 하이퍼 파라미터 튜닝
#      38 study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# ---> 39 study.optimize(lambda trial: objectiveExtraTreesClassifier(trial, x_train, y_train, x_val, y_val), n_trials=500)
#      41 print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
#
# Cell In[8], line 22, in objectiveExtraTreesClassifier(trial, x_tr, y_tr, x_val, y_val)
#      11 param = {
#      12     'n_estimators': trial.suggest_int('n_estimators', 2500, 3500)
#      13     , 'max_depth': trial.suggest_int('max_depth', 50, 70)
#    (...)
#      18     , 'random_state': RANDOM_STATE
#      19 }
#      21 model = ExtraTreesClassifier(**param)
# ---> 22 model.fit(x_tr, y_tr)
#      23 pred = model.predict(x_val)
#      24 score = f1_score(y_val, pred, average="binary")
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_forest.py:456, in BaseForest.fit(self, X, y, sample_weight)
#     445 trees = [
#     446     self._make_estimator(append=False, random_state=random_state)
#     447     for i in range(n_more_estimators)
#     448 ]
#     450 # Parallel loop: we prefer the threading backend as the Cython code
#     451 # for fitting the trees is internally releasing the Python GIL
#     452 # making threading more efficient than multiprocessing in
#     453 # that case. However, for joblib 0.12+ we respect any
#     454 # parallel_backend contexts set at a higher level,
#     455 # since correctness does not rely on using threads.
# --> 456 trees = Parallel(
#     457     n_jobs=self.n_jobs,
#     458     verbose=self.verbose,
#     459     prefer="threads",
#     460 )(
#     461     delayed(_parallel_build_trees)(
#     462         t,
#     463         self.bootstrap,
#     464         X,
#     465         y,
#     466         sample_weight,
#     467         i,
#     468         len(trees),
#     469         verbose=self.verbose,
#     470         class_weight=self.class_weight,
#     471         n_samples_bootstrap=n_samples_bootstrap,
#     472     )
#     473     for i, t in enumerate(trees)
#     474 )
#     476 # Collect newly grown trees
#     477 self.estimators_.extend(trees)
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_forest.py:190, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     188     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     189 else:
# --> 190     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#     192 return tree
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_classes.py:959, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     928 @_fit_context(prefer_skip_nested_validation=True)
#     929 def fit(self, X, y, sample_weight=None, check_input=True):
#     930     """Build a decision tree classifier from the training set (X, y).
#     931
#     932     Parameters
#    (...)
#     956         Fitted estimator.
#     957     """
# --> 959     super()._fit(
#     960         X,
#     961         y,
#     962         sample_weight=sample_weight,
#     963         check_input=check_input,
#     964     )
#     965     return self
#
# File c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_classes.py:443, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     432 else:
#     433     builder = BestFirstTreeBuilder(
#     434         splitter,
#     435         min_samples_split,
#    (...)
#     440         self.min_impurity_decrease,
#     441     )
# --> 443 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     445 if self.n_outputs_ == 1 and is_classifier(self):
#     446     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %% [markdown]
# Best trial: score 0.2034548944337812,
# params {'n_estimators': 2884, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 1,
# 'criterion': 'entropy', 'bootstrap': False}

# %%
# import optuna
# from sklearn.ensemble import ExtraTreesClassifier 

# # 'Normal'과 'AbNormal'을 숫자로 변환
# train_data['target'] = train_data['target'].map({'Normal': 0, 'AbNormal': 1})

# # 스레드홀드 설정
# THRESHOLD = 0.3

# def objectiveExtraTreesClassifier(trial, x_tr, y_tr, x_val, y_val):
#     param = {
#         'n_estimators': trial.suggest_int('n_estimators', 1000, 3500)
#         , 'max_depth': trial.suggest_int('max_depth', 20, 80)
#         , 'min_samples_split': trial.suggest_int('min_samples_split', 2, 10)
#         , 'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 4)
#         , 'criterion': trial.suggest_categorical('criterion', ['entropy'])
#         , 'bootstrap': trial.suggest_categorical('bootstrap', [False])
#         , 'random_state': RANDOM_STATE
#     }
    
#     model = ExtraTreesClassifier(**param)
#     model.fit(x_tr, y_tr)
#     pred = model.predict(x_val)
#     score = f1_score(y_val, pred, average="binary")
    
#     return score

# # 데이터셋 분할
# x_train, x_val, y_train, y_val = train_test_split(
#     train_data.drop("target", axis=1),
#     train_data["target"],
#     test_size=0.2,
#     shuffle=True,
#     random_state=RANDOM_STATE,
# )

# # 하이퍼 파라미터 튜닝
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# study.optimize(lambda trial: objectiveExtraTreesClassifier(trial, x_train, y_train, x_val, y_val), n_trials=100)

# print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))

# %% [markdown]
# Trial 51 finished with value: 0.20384615384615384 and parameters: {'n_estimators': 2204, 'max_depth': 42,
# 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}.

# %% [markdown]
# .
