# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ### 데이터 읽어오기

# %%
import os
from pprint import pprint

import optuna
import numpy as np
import pandas as pd
#import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import pandas as pd

RANDOM_STATE = 110

train_data = pd.read_csv("../../../data/train_data_0827.csv")
test_data = pd.read_csv("../../../data/test_data_0827.csv")

# %%
# dam, fill1, fill2 공통 변수
var_dam_fill = [
    'Receip_No_encoded',
    'Equipment_same_num',
    'PalletID_Collect_Result_encoded',
    'Production_Qty_Collect_Result',
    'WorkMode Collect Result'
]

# %%
# 전체 공통 변수
### train
var_all_train = [
    'target',
    'model_suffix_encoded',
    'cleaned_workorder_encoded'
]

### test
var_all_test = [
    'Set ID',
    'target',
    'model_suffix_encoded',
    'cleaned_workorder_encoded'
]

# %%
# '_Dam'을 포함하는 변수 선택
dam_variables = [var for var in train_data.columns if '_Dam' in var]

# train
final_columns_train = var_dam_fill + var_all_train + dam_variables
train_data_dam = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + dam_variables
test_data_dam = test_data[final_columns_test]

# %%
# '_Fill1'을 포함하는 변수 선택
fill1_variables = [var for var in train_data.columns if '_Fill1' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill1_variables
train_data_fill1 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill1_variables
test_data_fill1 = test_data[final_columns_test]

# %%
# '_Fill2'을 포함하는 변수 선택
fill2_variables = [var for var in train_data.columns if '_Fill2' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill2_variables
train_data_fill2 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill2_variables
test_data_fill2 = test_data[final_columns_test]

# %%
# '_AutoClave'을 포함하는 변수 선택
autoclave_variables = [var for var in train_data.columns if '_AutoClave' in var]

# train
final_columns_train = var_all_train + autoclave_variables
train_data_autoclave = train_data[final_columns_train]

# test 
final_columns_test = var_all_test + autoclave_variables
test_data_autoclave = test_data[final_columns_test]

# %%
# 각 DataFrame의 칼럼 수 계산
num_columns_train_data = train_data.shape[1]
num_columns_train_data_dam = train_data_dam.shape[1]
num_columns_train_data_autoclave = train_data_autoclave.shape[1]
num_columns_train_data_fill1 = train_data_fill1.shape[1]
num_columns_train_data_fill2 = train_data_fill2.shape[1]

num_columns_test_data = test_data.shape[1]
num_columns_test_data_dam = test_data_dam.shape[1]
num_columns_test_data_autoclave = test_data_autoclave.shape[1]
num_columns_test_data_fill1 = test_data_fill1.shape[1]
num_columns_test_data_fill2 = test_data_fill2.shape[1]

# 각 DataFrame의 칼럼 수 출력
print("----train data-----")
print(f"train_data DataFrame의 칼럼 수: {num_columns_train_data}")
print(f"train_data_dam DataFrame의 칼럼 수: {num_columns_train_data_dam}")
print(f"train_data_autoclave DataFrame의 칼럼 수: {num_columns_train_data_autoclave}")
print(f"train_data_fill1 DataFrame의 칼럼 수: {num_columns_train_data_fill1}")
print(f"train_data_fill2 DataFrame의 칼럼 수: {num_columns_train_data_fill2}")
print("----test data-----")
print(f"test_data DataFrame의 칼럼 수: {num_columns_test_data}")
print(f"test_data_dam DataFrame의 칼럼 수: {num_columns_test_data_dam}")
print(f"test_data_autoclave DataFrame의 칼럼 수: {num_columns_test_data_autoclave}")
print(f"test_data_fill1 DataFrame의 칼럼 수: {num_columns_test_data_fill1}")
print(f"test_data_fill2 DataFrame의 칼럼 수: {num_columns_test_data_fill2}")
# Out:
# ----train data-----
# train_data DataFrame의 칼럼 수: 40
# train_data_dam DataFrame의 칼럼 수: 23
# train_data_autoclave DataFrame의 칼럼 수: 8
# train_data_fill1 DataFrame의 칼럼 수: 14
# train_data_fill2 DataFrame의 칼럼 수: 14
# ----test data-----
# test_data DataFrame의 칼럼 수: 41
# test_data_dam DataFrame의 칼럼 수: 24
# test_data_autoclave DataFrame의 칼럼 수: 9
# test_data_fill1 DataFrame의 칼럼 수: 15
# test_data_fill2 DataFrame의 칼럼 수: 15

# %% [markdown]
# ---

# %% [markdown]
# ## Optuna

# %% [markdown]
# 스레스홀드 0.3으로 맞춘상태에서 튜닝 진행한 것

# %%
RANDOM_STATE = 110
THRESHOLD = 0.3

# %%
import optuna
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# 'Normal'과 'AbNormal'을 숫자로 변환
train_data_fill2['target'] = train_data_fill2['target'].map({'Normal': 0, 'AbNormal': 1})

# 스레드홀드 설정
THRESHOLD = 0.3

def objectiveLGBM_dart(trial, x_tr, y_tr, x_val, y_val):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 500, 3000),
        'num_leaves': trial.suggest_int('num_leaves', 500, 3000),
        'max_depth': trial.suggest_int('max_depth', 10, 300),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1),
        'min_child_samples': trial.suggest_int('min_child_samples', 3, 300),
        
        'boosting_type': 'dart',  # 'boosting'를 'boosting_type'으로 수정
        'random_state': RANDOM_STATE,
        'verbose': -1
    }
       
    model = LGBMClassifier(**param)
    model.fit(x_tr, y_tr)
    pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
    pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
    
    score = f1_score(y_val, pred, average="binary")
    
    return score

# 데이터셋 분할
x_train, x_val, y_train, y_val = train_test_split(
    train_data_fill2.drop("target", axis=1),
    train_data_fill2["target"],
    test_size=0.2,
    shuffle=True,
    random_state=RANDOM_STATE,
)

# 하이퍼 파라미터 튜닝
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=200)

print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# C:\Users\juneh\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# [I 2024-08-28 11:49:23,041] A new study created in memory with name: no-name-f58c040f-a6d6-4cd2-8571-e20d7b571662
# [I 2024-08-28 11:49:58,157] Trial 0 finished with value: 0.18685121107266436 and parameters: {'n_estimators': 790, 'num_leaves': 2146, 'max_depth': 119, 'learning_rate': 0.06166547557397882, 'min_child_samples': 205}. Best is trial 0 with value: 0.18685121107266436.
# [I 2024-08-28 11:57:33,636] Trial 1 finished with value: 0.1770186335403727 and parameters: {'n_estimators': 2206, 'num_leaves': 2888, 'max_depth': 195, 'learning_rate': 0.05178141716690417, 'min_child_samples': 28}. Best is trial 0 with value: 0.18685121107266436.
# [I 2024-08-28 11:59:15,512] Trial 2 finished with value: 0.20105820105820107 and parameters: {'n_estimators': 1469, 'num_leaves': 1226, 'max_depth': 49, 'learning_rate': 0.002000452888170992, 'min_child_samples': 126}. Best is trial 2 with value: 0.20105820105820107.
# [I 2024-08-28 12:01:02,782] Trial 3 finished with value: 0.17721518987341772 and parameters: {'n_estimators': 1731, 'num_leaves': 553, 'max_depth': 172, 'learning_rate': 0.008684052021612865, 'min_child_samples': 124}. Best is trial 2 with value: 0.20105820105820107.
# [I 2024-08-28 12:02:53,108] Trial 4 finished with value: 0.19884726224783864 and parameters: {'n_estimators': 1285, 'num_leaves': 2427, 'max_depth': 184, 'learning_rate': 0.042318458794414655, 'min_child_samples': 102}. Best is trial 2 with value: 0.20105820105820107.
# [I 2024-08-28 12:03:34,036] Trial 5 finished with value: 0.20162601626016258 and parameters: {'n_estimators': 562, 'num_leaves': 723, 'max_depth': 258, 'learning_rate': 0.04962001162483311, 'min_child_samples': 77}. Best is trial 5 with value: 0.20162601626016258.
# [I 2024-08-28 12:09:36,138] Trial 6 finished with value: 0.1878612716763006 and parameters: {'n_estimators': 2403, 'num_leaves': 1851, 'max_depth': 122, 'learning_rate': 0.06476333477413102, 'min_child_samples': 54}. Best is trial 5 with value: 0.20162601626016258.
# [I 2024-08-28 12:13:14,640] Trial 7 finished with value: 0.200836820083682 and parameters: {'n_estimators': 2273, 'num_leaves': 600, 'max_depth': 184, 'learning_rate': 0.02113127234039541, 'min_child_samples': 77}. Best is trial 5 with value: 0.20162601626016258.
# [I 2024-08-28 12:15:56,868] Trial 8 finished with value: 0.18732782369146003 and parameters: {'n_estimators': 1498, 'num_leaves': 2285, 'max_depth': 240, 'learning_rate': 0.08959229338857824, 'min_child_samples': 68}. Best is trial 5 with value: 0.20162601626016258.
# [I 2024-08-28 12:16:15,615] Trial 9 finished with value: 0.18248175182481752 and parameters: {'n_estimators': 532, 'num_leaves': 2402, 'max_depth': 63, 'learning_rate': 0.0795619223737381, 'min_child_samples': 286}. Best is trial 5 with value: 0.20162601626016258.
# [I 2024-08-28 12:16:55,834] Trial 10 finished with value: 0.17500000000000002 and parameters: {'n_estimators': 1010, 'num_leaves': 1104, 'max_depth': 286, 'learning_rate': 0.03483524235844172, 'min_child_samples': 190}. Best is trial 5 with value: 0.20162601626016258.
# [I 2024-08-28 12:17:42,349] Trial 11 finished with value: 0.16906474820143885 and parameters: {'n_estimators': 1153, 'num_leaves': 1221, 'max_depth': 14, 'learning_rate': 0.0073253759541514266, 'min_child_samples': 168}. Best is trial 5 with value: 0.20162601626016258.
# [I 2024-08-28 12:29:36,296] Trial 12 finished with value: 0.16293929712460062 and parameters: {'n_estimators': 2723, 'num_leaves': 1183, 'max_depth': 276, 'learning_rate': 0.027360646572396674, 'min_child_samples': 3}. Best is trial 5 with value: 0.20162601626016258.
# [I 2024-08-28 12:30:08,838] Trial 13 finished with value: 0.20426829268292684 and parameters: {'n_estimators': 532, 'num_leaves': 944, 'max_depth': 68, 'learning_rate': 0.0972683392531865, 'min_child_samples': 131}. Best is trial 13 with value: 0.20426829268292684.
# [I 2024-08-28 12:30:39,951] Trial 14 finished with value: 0.21001615508885302 and parameters: {'n_estimators': 719, 'num_leaves': 835, 'max_depth': 119, 'learning_rate': 0.09937905186776663, 'min_child_samples': 238}. Best is trial 14 with value: 0.21001615508885302.
# [I 2024-08-28 12:31:19,487] Trial 15 finished with value: 0.2086677367576244 and parameters: {'n_estimators': 931, 'num_leaves': 908, 'max_depth': 100, 'learning_rate': 0.09449538097253757, 'min_child_samples': 253}. Best is trial 14 with value: 0.21001615508885302.
# [I 2024-08-28 12:31:59,960] Trial 16 finished with value: 0.19561551433389543 and parameters: {'n_estimators': 930, 'num_leaves': 1679, 'max_depth': 118, 'learning_rate': 0.07936773820210498, 'min_child_samples': 255}. Best is trial 14 with value: 0.21001615508885302.
# [I 2024-08-28 12:33:49,708] Trial 17 finished with value: 0.19148936170212766 and parameters: {'n_estimators': 1897, 'num_leaves': 1473, 'max_depth': 93, 'learning_rate': 0.09870358079378871, 'min_child_samples': 238}. Best is trial 14 with value: 0.21001615508885302.
# [I 2024-08-28 12:34:23,092] Trial 18 finished with value: 0.19298245614035087 and parameters: {'n_estimators': 789, 'num_leaves': 843, 'max_depth': 145, 'learning_rate': 0.08231016974093434, 'min_child_samples': 297}. Best is trial 14 with value: 0.21001615508885302.
# [I 2024-08-28 12:36:34,210] Trial 19 finished with value: 0.19519094766619524 and parameters: {'n_estimators': 3000, 'num_leaves': 1620, 'max_depth': 14, 'learning_rate': 0.0890407141480724, 'min_child_samples': 233}. Best is trial 14 with value: 0.21001615508885302.
# [I 2024-08-28 12:37:30,285] Trial 20 finished with value: 0.20421393841166938 and parameters: {'n_estimators': 1164, 'num_leaves': 1403, 'max_depth': 229, 'learning_rate': 0.06926818413021942, 'min_child_samples': 264}. Best is trial 14 with value: 0.21001615508885302.
# [I 2024-08-28 12:37:51,125] Trial 21 finished with value: 0.1952054794520548 and parameters: {'n_estimators': 528, 'num_leaves': 867, 'max_depth': 70, 'learning_rate': 0.09909163196878161, 'min_child_samples': 207}. Best is trial 14 with value: 0.21001615508885302.
# [I 2024-08-28 12:38:30,874] Trial 22 finished with value: 0.1967213114754098 and parameters: {'n_estimators': 767, 'num_leaves': 950, 'max_depth': 88, 'learning_rate': 0.09006469227283333, 'min_child_samples': 151}. Best is trial 14 with value: 0.21001615508885302.
# [I 2024-08-28 12:39:06,926] Trial 23 finished with value: 0.19345238095238096 and parameters: {'n_estimators': 750, 'num_leaves': 505, 'max_depth': 147, 'learning_rate': 0.09938722393318586, 'min_child_samples': 167}. Best is trial 14 with value: 0.21001615508885302.
# [I 2024-08-28 12:39:44,685] Trial 24 finished with value: 0.18965517241379312 and parameters: {'n_estimators': 923, 'num_leaves': 995, 'max_depth': 93, 'learning_rate': 0.07155503214745301, 'min_child_samples': 273}. Best is trial 14 with value: 0.21001615508885302.
# [I 2024-08-28 12:40:47,501] Trial 25 finished with value: 0.1971014492753623 and parameters: {'n_estimators': 1358, 'num_leaves': 771, 'max_depth': 42, 'learning_rate': 0.08985454644468799, 'min_child_samples': 225}. Best is trial 14 with value: 0.21001615508885302.
# [I 2024-08-28 12:41:59,206] Trial 26 finished with value: 0.19236209335219237 and parameters: {'n_estimators': 1064, 'num_leaves': 1952, 'max_depth': 107, 'learning_rate': 0.08225331526027733, 'min_child_samples': 138}. Best is trial 14 with value: 0.21001615508885302.
# [I 2024-08-28 12:43:42,990] Trial 27 finished with value: 0.18181818181818182 and parameters: {'n_estimators': 1713, 'num_leaves': 1404, 'max_depth': 37, 'learning_rate': 0.07204216663763327, 'min_child_samples': 177}. Best is trial 14 with value: 0.21001615508885302.
# [I 2024-08-28 12:44:05,034] Trial 28 finished with value: 0.1996615905245347 and parameters: {'n_estimators': 626, 'num_leaves': 1013, 'max_depth': 70, 'learning_rate': 0.09435714166407756, 'min_child_samples': 248}. Best is trial 14 with value: 0.21001615508885302.
# [I 2024-08-28 12:44:35,709] Trial 29 finished with value: 0.1837088388214905 and parameters: {'n_estimators': 741, 'num_leaves': 663, 'max_depth': 137, 'learning_rate': 0.05780684171846131, 'min_child_samples': 210}. Best is trial 14 with value: 0.21001615508885302.
# [I 2024-08-28 12:45:24,270] Trial 30 finished with value: 0.1971383147853736 and parameters: {'n_estimators': 905, 'num_leaves': 1366, 'max_depth': 165, 'learning_rate': 0.07554373080717966, 'min_child_samples': 191}. Best is trial 14 with value: 0.21001615508885302.
# [I 2024-08-28 12:46:30,569] Trial 31 finished with value: 0.2124183006535948 and parameters: {'n_estimators': 1193, 'num_leaves': 1539, 'max_depth': 217, 'learning_rate': 0.06531849950509866, 'min_child_samples': 265}. Best is trial 31 with value: 0.2124183006535948.
# [I 2024-08-28 12:47:01,803] Trial 32 finished with value: 0.19649122807017544 and parameters: {'n_estimators': 667, 'num_leaves': 2787, 'max_depth': 212, 'learning_rate': 0.08587091754837095, 'min_child_samples': 272}. Best is trial 31 with value: 0.2124183006535948.
# [I 2024-08-28 12:47:58,300] Trial 33 finished with value: 0.19655172413793104 and parameters: {'n_estimators': 1152, 'num_leaves': 2085, 'max_depth': 122, 'learning_rate': 0.06019631590327569, 'min_child_samples': 300}. Best is trial 31 with value: 0.2124183006535948.
# [I 2024-08-28 12:49:43,159] Trial 34 finished with value: 0.1887824897400821 and parameters: {'n_estimators': 1581, 'num_leaves': 1592, 'max_depth': 81, 'learning_rate': 0.0943029189231274, 'min_child_samples': 222}. Best is trial 31 with value: 0.2124183006535948.
# [I 2024-08-28 12:51:59,982] Trial 35 finished with value: 0.1977401129943503 and parameters: {'n_estimators': 1306, 'num_leaves': 1094, 'max_depth': 209, 'learning_rate': 0.052016169914746856, 'min_child_samples': 109}. Best is trial 31 with value: 0.2124183006535948.
# [I 2024-08-28 12:54:03,552] Trial 36 finished with value: 0.1869158878504673 and parameters: {'n_estimators': 1976, 'num_leaves': 1280, 'max_depth': 110, 'learning_rate': 0.09465931005436472, 'min_child_samples': 250}. Best is trial 31 with value: 0.2124183006535948.
# [I 2024-08-28 12:54:45,539] Trial 37 finished with value: 0.1798165137614679 and parameters: {'n_estimators': 890, 'num_leaves': 722, 'max_depth': 55, 'learning_rate': 0.04504491259644086, 'min_child_samples': 277}. Best is trial 31 with value: 0.2124183006535948.
# [I 2024-08-28 12:55:26,089] Trial 38 finished with value: 0.19463087248322145 and parameters: {'n_estimators': 506, 'num_leaves': 1819, 'max_depth': 133, 'learning_rate': 0.06423166312660807, 'min_child_samples': 110}. Best is trial 31 with value: 0.2124183006535948.
# [I 2024-08-28 12:56:40,493] Trial 39 finished with value: 0.18930041152263372 and parameters: {'n_estimators': 1068, 'num_leaves': 852, 'max_depth': 160, 'learning_rate': 0.08677157191604826, 'min_child_samples': 132}. Best is trial 31 with value: 0.2124183006535948.
# [I 2024-08-28 12:59:01,297] Trial 40 finished with value: 0.1827956989247312 and parameters: {'n_estimators': 1405, 'num_leaves': 1519, 'max_depth': 32, 'learning_rate': 0.07749791963180243, 'min_child_samples': 94}. Best is trial 31 with value: 0.2124183006535948.
# [I 2024-08-28 13:00:04,964] Trial 41 finished with value: 0.2023608768971332 and parameters: {'n_estimators': 1205, 'num_leaves': 1269, 'max_depth': 220, 'learning_rate': 0.055464808365143996, 'min_child_samples': 262}. Best is trial 31 with value: 0.2124183006535948.
# [I 2024-08-28 13:00:34,119] Trial 42 finished with value: 0.18996415770609318 and parameters: {'n_estimators': 641, 'num_leaves': 1125, 'max_depth': 241, 'learning_rate': 0.06878034067002207, 'min_child_samples': 265}. Best is trial 31 with value: 0.2124183006535948.
# [I 2024-08-28 13:01:56,520] Trial 43 finished with value: 0.19873817034700317 and parameters: {'n_estimators': 1557, 'num_leaves': 967, 'max_depth': 192, 'learning_rate': 0.06563229494136696, 'min_child_samples': 286}. Best is trial 31 with value: 0.2124183006535948.
# [I 2024-08-28 13:03:10,555] Trial 44 finished with value: 0.20542082738944364 and parameters: {'n_estimators': 1238, 'num_leaves': 624, 'max_depth': 258, 'learning_rate': 0.09432675610075604, 'min_child_samples': 235}. Best is trial 31 with value: 0.2124183006535948.
# [I 2024-08-28 13:04:04,419] Trial 45 finished with value: 0.21263482280431437 and parameters: {'n_estimators': 1020, 'num_leaves': 580, 'max_depth': 266, 'learning_rate': 0.09386760220893021, 'min_child_samples': 243}. Best is trial 45 with value: 0.21263482280431437.
# [I 2024-08-28 13:04:55,973] Trial 46 finished with value: 0.20276497695852533 and parameters: {'n_estimators': 984, 'num_leaves': 543, 'max_depth': 299, 'learning_rate': 0.09300405484279357, 'min_child_samples': 245}. Best is trial 45 with value: 0.21263482280431437.
# [I 2024-08-28 13:06:09,388] Trial 47 finished with value: 0.1956204379562044 and parameters: {'n_estimators': 1245, 'num_leaves': 656, 'max_depth': 264, 'learning_rate': 0.0848129900466842, 'min_child_samples': 222}. Best is trial 45 with value: 0.21263482280431437.
# [I 2024-08-28 13:06:54,563] Trial 48 finished with value: 0.1675977653631285 and parameters: {'n_estimators': 858, 'num_leaves': 615, 'max_depth': 258, 'learning_rate': 0.016804802774200343, 'min_child_samples': 196}. Best is trial 45 with value: 0.21263482280431437.
# [I 2024-08-28 13:07:52,025] Trial 49 finished with value: 0.20615384615384616 and parameters: {'n_estimators': 1054, 'num_leaves': 764, 'max_depth': 248, 'learning_rate': 0.09190320202450257, 'min_child_samples': 234}. Best is trial 45 with value: 0.21263482280431437.
# [I 2024-08-28 13:08:34,671] Trial 50 finished with value: 0.17712177121771214 and parameters: {'n_estimators': 1021, 'num_leaves': 787, 'max_depth': 239, 'learning_rate': 0.031751557573389204, 'min_child_samples': 288}. Best is trial 45 with value: 0.21263482280431437.
# [I 2024-08-28 13:09:34,995] Trial 51 finished with value: 0.1967213114754098 and parameters: {'n_estimators': 1097, 'num_leaves': 743, 'max_depth': 275, 'learning_rate': 0.09200347386847063, 'min_child_samples': 233}. Best is trial 45 with value: 0.21263482280431437.
# [I 2024-08-28 13:10:52,581] Trial 52 finished with value: 0.20314735336194567 and parameters: {'n_estimators': 1289, 'num_leaves': 578, 'max_depth': 248, 'learning_rate': 0.09645114102343909, 'min_child_samples': 215}. Best is trial 45 with value: 0.21263482280431437.
# [I 2024-08-28 13:12:03,969] Trial 53 finished with value: 0.20238095238095236 and parameters: {'n_estimators': 1426, 'num_leaves': 670, 'max_depth': 285, 'learning_rate': 0.08202413416606341, 'min_child_samples': 256}. Best is trial 45 with value: 0.21263482280431437.
# [I 2024-08-28 13:12:42,449] Trial 54 finished with value: 0.20678513731825526 and parameters: {'n_estimators': 817, 'num_leaves': 842, 'max_depth': 270, 'learning_rate': 0.0869138359659428, 'min_child_samples': 240}. Best is trial 45 with value: 0.21263482280431437.
# [I 2024-08-28 13:13:24,395] Trial 55 finished with value: 0.20261437908496732 and parameters: {'n_estimators': 854, 'num_leaves': 845, 'max_depth': 274, 'learning_rate': 0.0871738457243005, 'min_child_samples': 242}. Best is trial 45 with value: 0.21263482280431437.
# [I 2024-08-28 13:14:05,541] Trial 56 finished with value: 0.19699499165275458 and parameters: {'n_estimators': 729, 'num_leaves': 1087, 'max_depth': 177, 'learning_rate': 0.0747016686948752, 'min_child_samples': 202}. Best is trial 45 with value: 0.21263482280431437.
# [I 2024-08-28 13:14:51,585] Trial 57 finished with value: 0.20029027576197386 and parameters: {'n_estimators': 826, 'num_leaves': 872, 'max_depth': 294, 'learning_rate': 0.09988555832770847, 'min_child_samples': 178}. Best is trial 45 with value: 0.21263482280431437.
# [I 2024-08-28 13:15:39,753] Trial 58 finished with value: 0.20395738203957384 and parameters: {'n_estimators': 970, 'num_leaves': 502, 'max_depth': 230, 'learning_rate': 0.09017377333280574, 'min_child_samples': 227}. Best is trial 45 with value: 0.21263482280431437.
# [I 2024-08-28 13:16:06,953] Trial 59 finished with value: 0.1779359430604982 and parameters: {'n_estimators': 636, 'num_leaves': 2657, 'max_depth': 267, 'learning_rate': 0.08391774701928723, 'min_child_samples': 278}. Best is trial 45 with value: 0.21263482280431437.
# [I 2024-08-28 13:16:53,714] Trial 60 finished with value: 0.20355411954765754 and parameters: {'n_estimators': 1065, 'num_leaves': 923, 'max_depth': 201, 'learning_rate': 0.07944483585584516, 'min_child_samples': 255}. Best is trial 45 with value: 0.21263482280431437.
# [I 2024-08-28 13:17:51,757] Trial 61 finished with value: 0.21613394216133944 and parameters: {'n_estimators': 1145, 'num_leaves': 713, 'max_depth': 256, 'learning_rate': 0.09607564271122122, 'min_child_samples': 259}. Best is trial 61 with value: 0.21613394216133944.
# [I 2024-08-28 13:18:36,572] Trial 62 finished with value: 0.21019108280254775 and parameters: {'n_estimators': 968, 'num_leaves': 806, 'max_depth': 289, 'learning_rate': 0.09684112568625254, 'min_child_samples': 268}. Best is trial 61 with value: 0.21613394216133944.
# [I 2024-08-28 13:19:25,381] Trial 63 finished with value: 0.21359223300970873 and parameters: {'n_estimators': 959, 'num_leaves': 1034, 'max_depth': 288, 'learning_rate': 0.09620763016945957, 'min_child_samples': 267}. Best is trial 61 with value: 0.21613394216133944.
# [I 2024-08-28 13:20:17,998] Trial 64 finished with value: 0.208398133748056 and parameters: {'n_estimators': 1140, 'num_leaves': 1185, 'max_depth': 285, 'learning_rate': 0.0949980922585413, 'min_child_samples': 291}. Best is trial 61 with value: 0.21613394216133944.
# [I 2024-08-28 13:21:02,806] Trial 65 finished with value: 0.20569620253164558 and parameters: {'n_estimators': 953, 'num_leaves': 1037, 'max_depth': 293, 'learning_rate': 0.09750755488870462, 'min_child_samples': 267}. Best is trial 61 with value: 0.21613394216133944.
# [I 2024-08-28 13:21:31,919] Trial 66 finished with value: 0.20338983050847456 and parameters: {'n_estimators': 693, 'num_leaves': 688, 'max_depth': 280, 'learning_rate': 0.09785229661271411, 'min_child_samples': 279}. Best is trial 61 with value: 0.21613394216133944.
# [I 2024-08-28 13:29:52,460] Trial 67 finished with value: 0.17185185185185184 and parameters: {'n_estimators': 2298, 'num_leaves': 940, 'max_depth': 256, 'learning_rate': 0.09053095431332425, 'min_child_samples': 31}. Best is trial 61 with value: 0.21613394216133944.
# [I 2024-08-28 13:31:20,150] Trial 68 finished with value: 0.19263456090651557 and parameters: {'n_estimators': 1500, 'num_leaves': 2041, 'max_depth': 112, 'learning_rate': 0.09948722780190092, 'min_child_samples': 257}. Best is trial 61 with value: 0.21613394216133944.
# [I 2024-08-28 13:32:24,061] Trial 69 finished with value: 0.20183486238532108 and parameters: {'n_estimators': 1155, 'num_leaves': 1753, 'max_depth': 229, 'learning_rate': 0.08857521342152057, 'min_child_samples': 270}. Best is trial 61 with value: 0.21613394216133944.
# [I 2024-08-28 13:33:43,545] Trial 70 finished with value: 0.1929824561403509 and parameters: {'n_estimators': 1332, 'num_leaves': 1032, 'max_depth': 98, 'learning_rate': 0.08182846820514118, 'min_child_samples': 216}. Best is trial 61 with value: 0.21613394216133944.
# [I 2024-08-28 13:34:41,005] Trial 71 finished with value: 0.20763358778625954 and parameters: {'n_estimators': 1140, 'num_leaves': 1162, 'max_depth': 286, 'learning_rate': 0.09609843635249893, 'min_child_samples': 288}. Best is trial 61 with value: 0.21613394216133944.
# [I 2024-08-28 13:35:21,760] Trial 72 finished with value: 0.1727941176470588 and parameters: {'n_estimators': 983, 'num_leaves': 1213, 'max_depth': 300, 'learning_rate': 0.04119526721102761, 'min_child_samples': 292}. Best is trial 61 with value: 0.21613394216133944.
# [I 2024-08-28 13:36:19,501] Trial 73 finished with value: 0.20276497695852533 and parameters: {'n_estimators': 1211, 'num_leaves': 908, 'max_depth': 280, 'learning_rate': 0.09556840428886926, 'min_child_samples': 280}. Best is trial 61 with value: 0.21613394216133944.
# [I 2024-08-28 13:37:01,540] Trial 74 finished with value: 0.1925675675675676 and parameters: {'n_estimators': 908, 'num_leaves': 1313, 'max_depth': 288, 'learning_rate': 0.09312912756444076, 'min_child_samples': 298}. Best is trial 61 with value: 0.21613394216133944.
# [I 2024-08-28 13:37:43,451] Trial 75 finished with value: 0.19776714513556617 and parameters: {'n_estimators': 799, 'num_leaves': 1053, 'max_depth': 132, 'learning_rate': 0.09985685611458887, 'min_child_samples': 247}. Best is trial 61 with value: 0.21613394216133944.
# [I 2024-08-28 13:38:42,865] Trial 76 finished with value: 0.20496894409937888 and parameters: {'n_estimators': 1105, 'num_leaves': 793, 'max_depth': 265, 'learning_rate': 0.09202617847603749, 'min_child_samples': 258}. Best is trial 61 with value: 0.21613394216133944.
# [I 2024-08-28 13:40:06,905] Trial 77 finished with value: 0.20497803806734993 and parameters: {'n_estimators': 1354, 'num_leaves': 1153, 'max_depth': 148, 'learning_rate': 0.09579134719565209, 'min_child_samples': 267}. Best is trial 61 with value: 0.21613394216133944.
# [I 2024-08-28 13:43:02,069] Trial 78 finished with value: 0.1848523748395379 and parameters: {'n_estimators': 2708, 'num_leaves': 1497, 'max_depth': 248, 'learning_rate': 0.08905221300583453, 'min_child_samples': 250}. Best is trial 61 with value: 0.21613394216133944.
# [I 2024-08-28 13:43:19,639] Trial 79 finished with value: 0.2017423200366804 and parameters: {'n_estimators': 571, 'num_leaves': 731, 'max_depth': 84, 'learning_rate': 0.0032501166763311898, 'min_child_samples': 281}. Best is trial 61 with value: 0.21613394216133944.
# [I 2024-08-28 13:44:06,687] Trial 80 finished with value: 0.2222222222222222 and parameters: {'n_estimators': 1005, 'num_leaves': 2304, 'max_depth': 293, 'learning_rate': 0.08460539739469425, 'min_child_samples': 272}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 13:44:49,561] Trial 81 finished with value: 0.20504201680672268 and parameters: {'n_estimators': 915, 'num_leaves': 1577, 'max_depth': 285, 'learning_rate': 0.08452800814788566, 'min_child_samples': 274}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 13:45:35,657] Trial 82 finished with value: 0.20032310177705975 and parameters: {'n_estimators': 1002, 'num_leaves': 1887, 'max_depth': 292, 'learning_rate': 0.09748226525605769, 'min_child_samples': 293}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 13:46:12,807] Trial 83 finished with value: 0.21487603305785125 and parameters: {'n_estimators': 747, 'num_leaves': 2494, 'max_depth': 278, 'learning_rate': 0.09333027130085475, 'min_child_samples': 263}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 13:46:44,540] Trial 84 finished with value: 0.19831932773109245 and parameters: {'n_estimators': 742, 'num_leaves': 2571, 'max_depth': 275, 'learning_rate': 0.09269154750927243, 'min_child_samples': 262}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 13:48:40,753] Trial 85 finished with value: 0.18904109589041096 and parameters: {'n_estimators': 1950, 'num_leaves': 2396, 'max_depth': 264, 'learning_rate': 0.08836046181201927, 'min_child_samples': 251}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 13:49:08,620] Trial 86 finished with value: 0.19444444444444442 and parameters: {'n_estimators': 588, 'num_leaves': 2301, 'max_depth': 103, 'learning_rate': 0.09040396659830115, 'min_child_samples': 239}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 13:49:54,141] Trial 87 finished with value: 0.1963394342762063 and parameters: {'n_estimators': 865, 'num_leaves': 2237, 'max_depth': 124, 'learning_rate': 0.0860692460728884, 'min_child_samples': 263}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 13:50:32,071] Trial 88 finished with value: 0.19365609348914858 and parameters: {'n_estimators': 780, 'num_leaves': 2921, 'max_depth': 254, 'learning_rate': 0.07781427430035594, 'min_child_samples': 230}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 13:51:29,586] Trial 89 finished with value: 0.20833333333333334 and parameters: {'n_estimators': 1019, 'num_leaves': 2518, 'max_depth': 270, 'learning_rate': 0.09394240315582564, 'min_child_samples': 271}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 13:52:06,292] Trial 90 finished with value: 0.208955223880597 and parameters: {'n_estimators': 691, 'num_leaves': 575, 'max_depth': 299, 'learning_rate': 0.09775101489462923, 'min_child_samples': 245}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 13:52:42,000] Trial 91 finished with value: 0.2006472491909385 and parameters: {'n_estimators': 728, 'num_leaves': 2996, 'max_depth': 300, 'learning_rate': 0.09703930849346859, 'min_child_samples': 245}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 13:53:11,507] Trial 92 finished with value: 0.1996615905245347 and parameters: {'n_estimators': 687, 'num_leaves': 599, 'max_depth': 295, 'learning_rate': 0.09195648803077741, 'min_child_samples': 254}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 13:53:56,403] Trial 93 finished with value: 0.2073365231259968 and parameters: {'n_estimators': 928, 'num_leaves': 560, 'max_depth': 278, 'learning_rate': 0.09768294823125792, 'min_child_samples': 260}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 13:54:32,466] Trial 94 finished with value: 0.20333333333333334 and parameters: {'n_estimators': 838, 'num_leaves': 811, 'max_depth': 288, 'learning_rate': 0.0995810074289121, 'min_child_samples': 284}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 13:55:31,803] Trial 95 finished with value: 0.20552147239263804 and parameters: {'n_estimators': 1046, 'num_leaves': 2801, 'max_depth': 238, 'learning_rate': 0.09440110264028656, 'min_child_samples': 238}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 13:56:14,586] Trial 96 finished with value: 0.20098846787479405 and parameters: {'n_estimators': 877, 'num_leaves': 694, 'max_depth': 281, 'learning_rate': 0.09083050019074519, 'min_child_samples': 273}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 13:56:43,445] Trial 97 finished with value: 0.18983050847457625 and parameters: {'n_estimators': 620, 'num_leaves': 634, 'max_depth': 262, 'learning_rate': 0.08371795246492028, 'min_child_samples': 224}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 13:57:20,783] Trial 98 finished with value: 0.19601328903654486 and parameters: {'n_estimators': 783, 'num_leaves': 535, 'max_depth': 271, 'learning_rate': 0.08673391446613357, 'min_child_samples': 246}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 13:59:02,524] Trial 99 finished with value: 0.208 and parameters: {'n_estimators': 1803, 'num_leaves': 2597, 'max_depth': 294, 'learning_rate': 0.04686164010112387, 'min_child_samples': 267}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:00:57,636] Trial 100 finished with value: 0.19734904270986747 and parameters: {'n_estimators': 2092, 'num_leaves': 993, 'max_depth': 280, 'learning_rate': 0.05378845502530203, 'min_child_samples': 252}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:01:55,030] Trial 101 finished with value: 0.20657276995305163 and parameters: {'n_estimators': 1173, 'num_leaves': 901, 'max_depth': 289, 'learning_rate': 0.09492416673427416, 'min_child_samples': 293}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:02:51,884] Trial 102 finished with value: 0.19906687402799378 and parameters: {'n_estimators': 1102, 'num_leaves': 733, 'max_depth': 79, 'learning_rate': 0.09584688157581855, 'min_child_samples': 277}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:04:05,865] Trial 103 finished with value: 0.2029411764705882 and parameters: {'n_estimators': 1261, 'num_leaves': 812, 'max_depth': 253, 'learning_rate': 0.09769632310579121, 'min_child_samples': 261}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:04:58,284] Trial 104 finished with value: 0.1948051948051948 and parameters: {'n_estimators': 950, 'num_leaves': 1414, 'max_depth': 282, 'learning_rate': 0.09416318629617963, 'min_child_samples': 285}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:05:54,923] Trial 105 finished with value: 0.1943573667711599 and parameters: {'n_estimators': 1101, 'num_leaves': 1701, 'max_depth': 272, 'learning_rate': 0.08890108798067196, 'min_child_samples': 270}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:07:06,092] Trial 106 finished with value: 0.20802377414561662 and parameters: {'n_estimators': 1200, 'num_leaves': 2433, 'max_depth': 261, 'learning_rate': 0.09235164894679027, 'min_child_samples': 242}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:07:34,771] Trial 107 finished with value: 0.18214936247723132 and parameters: {'n_estimators': 687, 'num_leaves': 967, 'max_depth': 296, 'learning_rate': 0.06219466520733396, 'min_child_samples': 292}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:08:39,167] Trial 108 finished with value: 0.2042042042042042 and parameters: {'n_estimators': 967, 'num_leaves': 2688, 'max_depth': 116, 'learning_rate': 0.09841563242859229, 'min_child_samples': 214}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:09:01,310] Trial 109 finished with value: 0.18571428571428572 and parameters: {'n_estimators': 510, 'num_leaves': 873, 'max_depth': 288, 'learning_rate': 0.08151519624533614, 'min_child_samples': 230}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:10:10,870] Trial 110 finished with value: 0.20588235294117646 and parameters: {'n_estimators': 1032, 'num_leaves': 767, 'max_depth': 244, 'learning_rate': 0.0690755988623548, 'min_child_samples': 149}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:11:13,074] Trial 111 finished with value: 0.2137404580152672 and parameters: {'n_estimators': 1129, 'num_leaves': 2527, 'max_depth': 271, 'learning_rate': 0.09390958490971776, 'min_child_samples': 272}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:12:33,877] Trial 112 finished with value: 0.20057306590257878 and parameters: {'n_estimators': 1404, 'num_leaves': 2320, 'max_depth': 274, 'learning_rate': 0.09583813765493752, 'min_child_samples': 257}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:13:33,073] Trial 113 finished with value: 0.19968304278922347 and parameters: {'n_estimators': 1135, 'num_leaves': 2181, 'max_depth': 168, 'learning_rate': 0.0880688332730423, 'min_child_samples': 276}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:14:32,656] Trial 114 finished with value: 0.20481927710843373 and parameters: {'n_estimators': 1267, 'num_leaves': 2501, 'max_depth': 268, 'learning_rate': 0.0906885355625251, 'min_child_samples': 265}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:15:04,401] Trial 115 finished with value: 0.2026578073089701 and parameters: {'n_estimators': 829, 'num_leaves': 2732, 'max_depth': 300, 'learning_rate': 0.09356790036375767, 'min_child_samples': 283}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:15:44,636] Trial 116 finished with value: 0.20032310177705975 and parameters: {'n_estimators': 898, 'num_leaves': 2401, 'max_depth': 283, 'learning_rate': 0.0968437655852009, 'min_child_samples': 253}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:16:23,268] Trial 117 finished with value: 0.20602218700475436 and parameters: {'n_estimators': 998, 'num_leaves': 700, 'max_depth': 220, 'learning_rate': 0.09949735495002474, 'min_child_samples': 297}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:17:10,078] Trial 118 finished with value: 0.2052980132450331 and parameters: {'n_estimators': 1071, 'num_leaves': 2479, 'max_depth': 276, 'learning_rate': 0.0735426580120724, 'min_child_samples': 270}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:18:08,270] Trial 119 finished with value: 0.19849624060150373 and parameters: {'n_estimators': 1206, 'num_leaves': 1088, 'max_depth': 293, 'learning_rate': 0.09097625523239217, 'min_child_samples': 260}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:19:15,060] Trial 120 finished with value: 0.20178041543026706 and parameters: {'n_estimators': 1117, 'num_leaves': 2579, 'max_depth': 186, 'learning_rate': 0.09531495272530817, 'min_child_samples': 248}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:20:13,746] Trial 121 finished with value: 0.20063694267515925 and parameters: {'n_estimators': 1007, 'num_leaves': 2526, 'max_depth': 92, 'learning_rate': 0.09318675325459162, 'min_child_samples': 275}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:21:09,978] Trial 122 finished with value: 0.20923076923076922 and parameters: {'n_estimators': 1041, 'num_leaves': 647, 'max_depth': 265, 'learning_rate': 0.09989781405657905, 'min_child_samples': 268}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:23:25,019] Trial 123 finished with value: 0.1878453038674033 and parameters: {'n_estimators': 933, 'num_leaves': 644, 'max_depth': 252, 'learning_rate': 0.09989629055408467, 'min_child_samples': 57}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:24:51,052] Trial 124 finished with value: 0.19491525423728814 and parameters: {'n_estimators': 1653, 'num_leaves': 586, 'max_depth': 266, 'learning_rate': 0.09760547472938999, 'min_child_samples': 287}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:25:44,261] Trial 125 finished with value: 0.19937694704049844 and parameters: {'n_estimators': 1062, 'num_leaves': 674, 'max_depth': 289, 'learning_rate': 0.09604034113431768, 'min_child_samples': 264}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:26:58,119] Trial 126 finished with value: 0.2029411764705882 and parameters: {'n_estimators': 1307, 'num_leaves': 527, 'max_depth': 101, 'learning_rate': 0.09274780901360308, 'min_child_samples': 236}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:27:30,223] Trial 127 finished with value: 0.1719626168224299 and parameters: {'n_estimators': 732, 'num_leaves': 2340, 'max_depth': 261, 'learning_rate': 0.02349881374078882, 'min_child_samples': 278}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:28:36,595] Trial 128 finished with value: 0.19969742813918306 and parameters: {'n_estimators': 1170, 'num_leaves': 830, 'max_depth': 278, 'learning_rate': 0.08981587949087708, 'min_child_samples': 255}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:29:28,103] Trial 129 finished with value: 0.20602218700475436 and parameters: {'n_estimators': 865, 'num_leaves': 1968, 'max_depth': 283, 'learning_rate': 0.0983817361843646, 'min_child_samples': 243}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:30:18,049] Trial 130 finished with value: 0.2015748031496063 and parameters: {'n_estimators': 957, 'num_leaves': 500, 'max_depth': 273, 'learning_rate': 0.09471645623405335, 'min_child_samples': 263}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:31:13,794] Trial 131 finished with value: 0.2052117263843648 and parameters: {'n_estimators': 1006, 'num_leaves': 2637, 'max_depth': 235, 'learning_rate': 0.09342456851951937, 'min_child_samples': 271}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:32:01,982] Trial 132 finished with value: 0.20722135007849293 and parameters: {'n_estimators': 1038, 'num_leaves': 743, 'max_depth': 258, 'learning_rate': 0.09716089357124079, 'min_child_samples': 269}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:32:39,723] Trial 133 finished with value: 0.1955403087478559 and parameters: {'n_estimators': 784, 'num_leaves': 2453, 'max_depth': 272, 'learning_rate': 0.09151469411891952, 'min_child_samples': 282}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:33:41,674] Trial 134 finished with value: 0.1990950226244344 and parameters: {'n_estimators': 1154, 'num_leaves': 609, 'max_depth': 266, 'learning_rate': 0.08603577656657944, 'min_child_samples': 248}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:34:24,862] Trial 135 finished with value: 0.19999999999999998 and parameters: {'n_estimators': 900, 'num_leaves': 921, 'max_depth': 291, 'learning_rate': 0.09451125499201102, 'min_child_samples': 273}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:34:49,626] Trial 136 finished with value: 0.1972318339100346 and parameters: {'n_estimators': 639, 'num_leaves': 778, 'max_depth': 246, 'learning_rate': 0.08790832634804736, 'min_child_samples': 257}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:35:52,971] Trial 137 finished with value: 0.20710059171597636 and parameters: {'n_estimators': 1238, 'num_leaves': 1226, 'max_depth': 285, 'learning_rate': 0.09998049155281218, 'min_child_samples': 267}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:36:45,792] Trial 138 finished with value: 0.19937694704049844 and parameters: {'n_estimators': 1108, 'num_leaves': 996, 'max_depth': 296, 'learning_rate': 0.0961776397224613, 'min_child_samples': 287}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:37:22,952] Trial 139 finished with value: 0.21172638436482083 and parameters: {'n_estimators': 812, 'num_leaves': 565, 'max_depth': 155, 'learning_rate': 0.09350265109912065, 'min_child_samples': 252}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:38:02,478] Trial 140 finished with value: 0.17454545454545456 and parameters: {'n_estimators': 810, 'num_leaves': 601, 'max_depth': 152, 'learning_rate': 0.0395200148648433, 'min_child_samples': 238}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:38:32,573] Trial 141 finished with value: 0.1849912739965096 and parameters: {'n_estimators': 577, 'num_leaves': 2521, 'max_depth': 142, 'learning_rate': 0.09393707181900605, 'min_child_samples': 260}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:39:06,883] Trial 142 finished with value: 0.20198675496688742 and parameters: {'n_estimators': 690, 'num_leaves': 674, 'max_depth': 125, 'learning_rate': 0.09802619624134093, 'min_child_samples': 250}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:39:54,729] Trial 143 finished with value: 0.21003134796238246 and parameters: {'n_estimators': 969, 'num_leaves': 561, 'max_depth': 268, 'learning_rate': 0.09196895059882632, 'min_child_samples': 254}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:40:32,954] Trial 144 finished with value: 0.2146341463414634 and parameters: {'n_estimators': 843, 'num_leaves': 563, 'max_depth': 194, 'learning_rate': 0.08965156665237861, 'min_child_samples': 253}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:41:16,743] Trial 145 finished with value: 0.19902120717781402 and parameters: {'n_estimators': 850, 'num_leaves': 577, 'max_depth': 200, 'learning_rate': 0.08902587201910699, 'min_child_samples': 242}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:41:46,564] Trial 146 finished with value: 0.17989417989417988 and parameters: {'n_estimators': 759, 'num_leaves': 564, 'max_depth': 162, 'learning_rate': 0.05772448319644462, 'min_child_samples': 253}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:42:38,057] Trial 147 finished with value: 0.20063694267515925 and parameters: {'n_estimators': 941, 'num_leaves': 701, 'max_depth': 219, 'learning_rate': 0.09133782148766659, 'min_child_samples': 231}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:43:26,396] Trial 148 finished with value: 0.1986970684039088 and parameters: {'n_estimators': 890, 'num_leaves': 634, 'max_depth': 210, 'learning_rate': 0.09181913473384469, 'min_child_samples': 257}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:44:15,116] Trial 149 finished with value: 0.20134228187919462 and parameters: {'n_estimators': 961, 'num_leaves': 543, 'max_depth': 253, 'learning_rate': 0.06704826643385572, 'min_child_samples': 245}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:44:54,152] Trial 150 finished with value: 0.20066889632107024 and parameters: {'n_estimators': 836, 'num_leaves': 662, 'max_depth': 194, 'learning_rate': 0.08477688942977142, 'min_child_samples': 263}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:45:54,091] Trial 151 finished with value: 0.20987654320987653 and parameters: {'n_estimators': 1069, 'num_leaves': 510, 'max_depth': 175, 'learning_rate': 0.09582920242898439, 'min_child_samples': 253}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:46:54,454] Trial 152 finished with value: 0.20150375939849627 and parameters: {'n_estimators': 1074, 'num_leaves': 507, 'max_depth': 177, 'learning_rate': 0.09634937821978717, 'min_child_samples': 248}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:47:28,031] Trial 153 finished with value: 0.20655737704918034 and parameters: {'n_estimators': 728, 'num_leaves': 609, 'max_depth': 187, 'learning_rate': 0.09802800656471472, 'min_child_samples': 253}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:48:23,972] Trial 154 finished with value: 0.2015748031496063 and parameters: {'n_estimators': 1011, 'num_leaves': 552, 'max_depth': 176, 'learning_rate': 0.08982901314222777, 'min_child_samples': 266}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:49:06,070] Trial 155 finished with value: 0.20602218700475436 and parameters: {'n_estimators': 809, 'num_leaves': 712, 'max_depth': 200, 'learning_rate': 0.09278436427882494, 'min_child_samples': 223}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:49:51,097] Trial 156 finished with value: 0.19811320754716982 and parameters: {'n_estimators': 904, 'num_leaves': 636, 'max_depth': 182, 'learning_rate': 0.09608371363095017, 'min_child_samples': 238}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:52:10,019] Trial 157 finished with value: 0.1792929292929293 and parameters: {'n_estimators': 2525, 'num_leaves': 765, 'max_depth': 107, 'learning_rate': 0.09993154202222856, 'min_child_samples': 259}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:56:04,205] Trial 158 finished with value: 0.18009478672985782 and parameters: {'n_estimators': 1050, 'num_leaves': 876, 'max_depth': 155, 'learning_rate': 0.08762803497481095, 'min_child_samples': 8}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:56:50,670] Trial 159 finished with value: 0.20421393841166938 and parameters: {'n_estimators': 977, 'num_leaves': 504, 'max_depth': 133, 'learning_rate': 0.09367234848984542, 'min_child_samples': 276}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:57:23,804] Trial 160 finished with value: 0.20065789473684212 and parameters: {'n_estimators': 771, 'num_leaves': 579, 'max_depth': 279, 'learning_rate': 0.09564114916757895, 'min_child_samples': 250}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:58:22,096] Trial 161 finished with value: 0.20307692307692304 and parameters: {'n_estimators': 1134, 'num_leaves': 815, 'max_depth': 171, 'learning_rate': 0.09450169981141188, 'min_child_samples': 266}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 14:59:21,091] Trial 162 finished with value: 0.2042042042042042 and parameters: {'n_estimators': 1199, 'num_leaves': 719, 'max_depth': 286, 'learning_rate': 0.09788154643740159, 'min_child_samples': 280}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:00:21,940] Trial 163 finished with value: 0.20657276995305163 and parameters: {'n_estimators': 1095, 'num_leaves': 1542, 'max_depth': 268, 'learning_rate': 0.0924037841852047, 'min_child_samples': 259}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:01:24,116] Trial 164 finished with value: 0.20904836193447737 and parameters: {'n_estimators': 1026, 'num_leaves': 1775, 'max_depth': 76, 'learning_rate': 0.09051075187930192, 'min_child_samples': 244}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:02:17,040] Trial 165 finished with value: 0.19844961240310077 and parameters: {'n_estimators': 954, 'num_leaves': 2099, 'max_depth': 74, 'learning_rate': 0.08962238115457723, 'min_child_samples': 241}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:03:15,430] Trial 166 finished with value: 0.1987951807228916 and parameters: {'n_estimators': 1022, 'num_leaves': 1660, 'max_depth': 205, 'learning_rate': 0.09100742232784213, 'min_child_samples': 233}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:03:43,679] Trial 167 finished with value: 0.1973244147157191 and parameters: {'n_estimators': 661, 'num_leaves': 617, 'max_depth': 88, 'learning_rate': 0.09663266333511683, 'min_child_samples': 245}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:05:22,696] Trial 168 finished with value: 0.19293478260869568 and parameters: {'n_estimators': 866, 'num_leaves': 2261, 'max_depth': 76, 'learning_rate': 0.08697429712542364, 'min_child_samples': 85}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:06:10,895] Trial 169 finished with value: 0.2086677367576244 and parameters: {'n_estimators': 898, 'num_leaves': 1327, 'max_depth': 67, 'learning_rate': 0.09453735314258448, 'min_child_samples': 254}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:06:59,117] Trial 170 finished with value: 0.2073365231259968 and parameters: {'n_estimators': 989, 'num_leaves': 560, 'max_depth': 35, 'learning_rate': 0.09174535985594229, 'min_child_samples': 268}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:07:53,408] Trial 171 finished with value: 0.20285261489698891 and parameters: {'n_estimators': 922, 'num_leaves': 1299, 'max_depth': 64, 'learning_rate': 0.09459715940091808, 'min_child_samples': 253}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:08:44,182] Trial 172 finished with value: 0.20512820512820512 and parameters: {'n_estimators': 870, 'num_leaves': 1723, 'max_depth': 85, 'learning_rate': 0.09843373638351857, 'min_child_samples': 256}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:09:36,728] Trial 173 finished with value: 0.2006172839506173 and parameters: {'n_estimators': 1072, 'num_leaves': 647, 'max_depth': 62, 'learning_rate': 0.09328747401108684, 'min_child_samples': 261}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:10:16,515] Trial 174 finished with value: 0.19488817891373802 and parameters: {'n_estimators': 816, 'num_leaves': 681, 'max_depth': 98, 'learning_rate': 0.09559287717810007, 'min_child_samples': 248}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:10:57,882] Trial 175 finished with value: 0.16998191681735986 and parameters: {'n_estimators': 932, 'num_leaves': 1441, 'max_depth': 53, 'learning_rate': 0.014034243827796812, 'min_child_samples': 273}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:11:44,325] Trial 176 finished with value: 0.19482496194824964 and parameters: {'n_estimators': 724, 'num_leaves': 1803, 'max_depth': 48, 'learning_rate': 0.09990417767318549, 'min_child_samples': 175}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:12:36,209] Trial 177 finished with value: 0.19936708860759494 and parameters: {'n_estimators': 1028, 'num_leaves': 783, 'max_depth': 69, 'learning_rate': 0.09048570716315454, 'min_child_samples': 252}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:13:26,347] Trial 178 finished with value: 0.1990811638591118 and parameters: {'n_estimators': 974, 'num_leaves': 853, 'max_depth': 140, 'learning_rate': 0.09701457225931905, 'min_child_samples': 237}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:14:17,497] Trial 179 finished with value: 0.19699499165275458 and parameters: {'n_estimators': 908, 'num_leaves': 1352, 'max_depth': 57, 'learning_rate': 0.08918631355037045, 'min_child_samples': 264}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:14:52,735] Trial 180 finished with value: 0.1801801801801802 and parameters: {'n_estimators': 776, 'num_leaves': 556, 'max_depth': 261, 'learning_rate': 0.05032168085115887, 'min_child_samples': 243}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:15:52,642] Trial 181 finished with value: 0.1970149253731343 and parameters: {'n_estimators': 1117, 'num_leaves': 1098, 'max_depth': 292, 'learning_rate': 0.09491691051203406, 'min_child_samples': 255}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:18:55,237] Trial 182 finished with value: 0.17902813299232734 and parameters: {'n_estimators': 2993, 'num_leaves': 1211, 'max_depth': 278, 'learning_rate': 0.09270560775427159, 'min_child_samples': 271}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:19:59,434] Trial 183 finished with value: 0.20089955022488756 and parameters: {'n_estimators': 1183, 'num_leaves': 1050, 'max_depth': 298, 'learning_rate': 0.09759758266393802, 'min_child_samples': 261}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:20:54,670] Trial 184 finished with value: 0.20512820512820512 and parameters: {'n_estimators': 1045, 'num_leaves': 1249, 'max_depth': 287, 'learning_rate': 0.09450264051054859, 'min_child_samples': 279}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:21:59,791] Trial 185 finished with value: 0.20389805097451275 and parameters: {'n_estimators': 1146, 'num_leaves': 1147, 'max_depth': 161, 'learning_rate': 0.09580495564024363, 'min_child_samples': 247}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:23:04,058] Trial 186 finished with value: 0.20574886535552192 and parameters: {'n_estimators': 1090, 'num_leaves': 1602, 'max_depth': 224, 'learning_rate': 0.09268511620325247, 'min_child_samples': 228}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:23:58,646] Trial 187 finished with value: 0.20062695924764892 and parameters: {'n_estimators': 986, 'num_leaves': 1364, 'max_depth': 274, 'learning_rate': 0.0981189008426651, 'min_child_samples': 268}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:24:22,990] Trial 188 finished with value: 0.19182948490230906 and parameters: {'n_estimators': 606, 'num_leaves': 1475, 'max_depth': 269, 'learning_rate': 0.09111485470539098, 'min_child_samples': 291}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:25:03,506] Trial 189 finished with value: 0.2006472491909385 and parameters: {'n_estimators': 835, 'num_leaves': 939, 'max_depth': 282, 'learning_rate': 0.09423582157415615, 'min_child_samples': 257}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:25:36,848] Trial 190 finished with value: 0.1996615905245347 and parameters: {'n_estimators': 696, 'num_leaves': 591, 'max_depth': 148, 'learning_rate': 0.0967440216630755, 'min_child_samples': 264}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:26:33,359] Trial 191 finished with value: 0.2 and parameters: {'n_estimators': 1031, 'num_leaves': 2574, 'max_depth': 116, 'learning_rate': 0.09375883108909601, 'min_child_samples': 273}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:27:32,530] Trial 192 finished with value: 0.20030349013657053 and parameters: {'n_estimators': 1068, 'num_leaves': 2358, 'max_depth': 264, 'learning_rate': 0.09832153555432128, 'min_child_samples': 251}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:28:22,057] Trial 193 finished with value: 0.20327868852459013 and parameters: {'n_estimators': 1002, 'num_leaves': 2645, 'max_depth': 191, 'learning_rate': 0.09527190648697244, 'min_child_samples': 300}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:29:07,600] Trial 194 finished with value: 0.2038834951456311 and parameters: {'n_estimators': 941, 'num_leaves': 512, 'max_depth': 257, 'learning_rate': 0.08908311822039316, 'min_child_samples': 273}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:30:04,699] Trial 195 finished with value: 0.20000000000000004 and parameters: {'n_estimators': 1227, 'num_leaves': 1893, 'max_depth': 300, 'learning_rate': 0.09120142217804714, 'min_child_samples': 281}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:30:43,692] Trial 196 finished with value: 0.20787401574803147 and parameters: {'n_estimators': 888, 'num_leaves': 2542, 'max_depth': 271, 'learning_rate': 0.09994167944262794, 'min_child_samples': 259}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:31:39,967] Trial 197 finished with value: 0.20211161387631976 and parameters: {'n_estimators': 1142, 'num_leaves': 2769, 'max_depth': 292, 'learning_rate': 0.09274532354247429, 'min_child_samples': 243}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:32:26,195] Trial 198 finished with value: 0.21020092735703244 and parameters: {'n_estimators': 1027, 'num_leaves': 2451, 'max_depth': 278, 'learning_rate': 0.09560982290321322, 'min_child_samples': 268}. Best is trial 80 with value: 0.2222222222222222.
# [I 2024-08-28 15:33:17,104] Trial 199 finished with value: 0.19631901840490798 and parameters: {'n_estimators': 1093, 'num_leaves': 2457, 'max_depth': 280, 'learning_rate': 0.09639847771869574, 'min_child_samples': 264}. Best is trial 80 with value: 0.2222222222222222.
# Best trial: score 0.2222222222222222,
# params {'n_estimators': 1005, 'num_leaves': 2304, 'max_depth': 293, 'learning_rate': 0.08460539739469425, 'min_child_samples': 272}

# %% [markdown]
# Best trial: score 0.2222222222222222,
# params {'n_estimators': 1005, 'num_leaves': 2304, 'max_depth': 293, 'learning_rate': 0.08460539739469425, 'min_child_samples': 272}
