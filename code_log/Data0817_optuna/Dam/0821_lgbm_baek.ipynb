# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ### 데이터 읽어오기

# %%
import pandas as pd

THRESHOLD = 0.3
RANDOM_STATE = 110

train_data = pd.read_csv("../../../data/train_data_0817.csv")
test_data = pd.read_csv("../../../data/test_data_0817.csv")

# %%
train_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40506 entries, 0 to 40505
# Data columns (total 38 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   CURE SPEED Collect Result_Dam                   40506 non-null  int64
#  1   DISCHARGED SPEED OF RESIN Collect Result_Dam    40506 non-null  int64
#  2   Head Clean Position Z Collect Result_Dam        40506 non-null  float64
#  3   Head Purge Position Z Collect Result_Dam        40506 non-null  float64
#  4   Head Zero Position Y Collect Result_Dam         40506 non-null  float64
#  5   Stage2_Circle_Distance_Speed_Dam                40506 non-null  int64
#  6   WorkMode Collect Result                         40506 non-null  float64
#  7   Chamber Temp. Collect Result_AutoClave          40506 non-null  int64
#  8   DISCHARGED SPEED OF RESIN Collect Result_Fill1  40506 non-null  float64
#  9   Head Purge Position Z Collect Result_Fill1      40506 non-null  int64
#  10  CURE SPEED Collect Result_Fill2                 40506 non-null  int64
#  11  Head Purge Position Z Collect Result_Fill2      40506 non-null  float64
#  12  target                                          40506 non-null  object
#  13  Equipment_same_num                              40506 non-null  int64
#  14  Production_Qty_Collect_Result                   40506 non-null  int64
#  15  CURE_DISTANCE_Dam                               40506 non-null  float64
#  16  HEAD NORMAL DISTANCE_STAGE1_STAGE3_Dam          40506 non-null  float64
#  17  HEAD NORMAL DISTANCE_TRIANGLE_height_Dam        40506 non-null  float64
#  18  HEAD NORMAL DISTANCE_STAGE1_STAGE3_Fill1        40506 non-null  float64
#  19  HEAD NORMAL DISTANCE_TRIANGLE_height_Fill1      40506 non-null  float64
#  20  HEAD NORMAL DISTANCE_STAGE1_STAGE2_Fill2        40506 non-null  float64
#  21  volume_time_multip_avg_Dam                      40506 non-null  float64
#  22  volume_time_multip_avg_Fill1                    40506 non-null  float64
#  23  average_thickness_Dam                           40506 non-null  float64
#  24  1st_pressure_time_AutoClave                     40506 non-null  float64
#  25  2nd_pressure_time_AutoClave                     40506 non-null  float64
#  26  3rd_pressure_time_AutoClave                     40506 non-null  float64
#  27  time_ratio_Dam                                  40506 non-null  float64
#  28  time_ratio_Fill1                                40506 non-null  float64
#  29  time_ratio_Fill2                                40506 non-null  float64
#  30  time_ratio_AutoClave                            40506 non-null  float64
#  31  model_receip_encoded                            40506 non-null  float64
#  32  workorder_receip_encoded                        40506 non-null  float64
#  33  PalletID_Collect_Result_encoded                 40506 non-null  float64
#  34  cure_end_position_XZ_Fill2_encoded              40506 non-null  float64
#  35  cure_start_position_XZ_Fill2_encoded            40506 non-null  float64
#  36  stage1_line13_distance_speed_Dam_encoded        40506 non-null  float64
#  37  stage2_line24_distance_speed_Dam_encoded        40506 non-null  float64
# dtypes: float64(29), int64(8), object(1)
# memory usage: 11.7+ MB

# %%
# dam, fill1, fill2 공통 변수
var_dam_fill = [
    'Equipment_same_num',
    'PalletID_Collect_Result_encoded',
    'Production_Qty_Collect_Result',
    'WorkMode Collect Result'
]

# %%
# 전체 공통 변수
### correlation 확인을 위한 변수 리스트
var_all_corr = [
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### train
var_all_train = [
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### test
var_all_test = [
    'Set ID',
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

# %%
# '_Dam'을 포함하는 변수 선택
dam_variables = [var for var in train_data.columns if '_Dam' in var]

# train
final_columns_train = var_dam_fill + var_all_train + dam_variables
train_data_dam = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + dam_variables
test_data_dam = test_data[final_columns_test]

# %%
# '_Fill1'을 포함하는 변수 선택
fill1_variables = [var for var in train_data.columns if '_Fill1' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill1_variables
train_data_fill1 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill1_variables
test_data_fill1 = test_data[final_columns_test]

# %%
# '_Fill2'을 포함하는 변수 선택
fill2_variables = [var for var in train_data.columns if '_Fill2' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill2_variables
train_data_fill2 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill2_variables
test_data_fill2 = test_data[final_columns_test]

# %%
# '_AutoClave'을 포함하는 변수 선택
autoclave_variables = [var for var in train_data.columns if '_AutoClave' in var]

# train
final_columns_train = var_all_train + autoclave_variables
train_data_autoclave = train_data[final_columns_train]

# test 
final_columns_test = var_all_test + autoclave_variables
test_data_autoclave = test_data[final_columns_test]

# %%
# 각 DataFrame의 칼럼 수 계산
num_columns_train_data = train_data.shape[1]
num_columns_train_data_dam = train_data_dam.shape[1]
num_columns_train_data_autoclave = train_data_autoclave.shape[1]
num_columns_train_data_fill1 = train_data_fill1.shape[1]
num_columns_train_data_fill2 = train_data_fill2.shape[1]

num_columns_test_data = test_data.shape[1]
num_columns_test_data_dam = test_data_dam.shape[1]
num_columns_test_data_autoclave = test_data_autoclave.shape[1]
num_columns_test_data_fill1 = test_data_fill1.shape[1]
num_columns_test_data_fill2 = test_data_fill2.shape[1]

# 각 DataFrame의 칼럼 수 출력
print("----train data-----")
print(f"train_data DataFrame의 칼럼 수: {num_columns_train_data}")
print(f"train_data_dam DataFrame의 칼럼 수: {num_columns_train_data_dam}")
print(f"train_data_autoclave DataFrame의 칼럼 수: {num_columns_train_data_autoclave}")
print(f"train_data_fill1 DataFrame의 칼럼 수: {num_columns_train_data_fill1}")
print(f"train_data_fill2 DataFrame의 칼럼 수: {num_columns_train_data_fill2}")
print("----test data-----")
print(f"test_data DataFrame의 칼럼 수: {num_columns_test_data}")
print(f"test_data_dam DataFrame의 칼럼 수: {num_columns_test_data_dam}")
print(f"test_data_autoclave DataFrame의 칼럼 수: {num_columns_test_data_autoclave}")
print(f"test_data_fill1 DataFrame의 칼럼 수: {num_columns_test_data_fill1}")
print(f"test_data_fill2 DataFrame의 칼럼 수: {num_columns_test_data_fill2}")
# Out:
# ----train data-----
# train_data DataFrame의 칼럼 수: 38
# train_data_dam DataFrame의 칼럼 수: 21
# train_data_autoclave DataFrame의 칼럼 수: 8
# train_data_fill1 DataFrame의 칼럼 수: 13
# train_data_fill2 DataFrame의 칼럼 수: 13
# ----test data-----
# test_data DataFrame의 칼럼 수: 39
# test_data_dam DataFrame의 칼럼 수: 22
# test_data_autoclave DataFrame의 칼럼 수: 9
# test_data_fill1 DataFrame의 칼럼 수: 14
# test_data_fill2 DataFrame의 칼럼 수: 14

# %% [markdown]
# ---

# %% [markdown]
# ## Optuna

# %% [markdown]
# 스레스홀드 0.3으로 맞춘상태에서 튜닝 진행한 것

# %%
# import optuna
# from lightgbm import LGBMClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import f1_score

# # 'Normal'과 'AbNormal'을 숫자로 변환
# train_data_dam['target'] = train_data_dam['target'].map({'Normal': 0, 'AbNormal': 1})

# # 스레드홀드 설정
# THRESHOLD = 0.3

# def objectiveLGBM_dart(trial, x_tr, y_tr, x_val, y_val):
#     param = {
#         'n_estimators': trial.suggest_int('n_estimators', 500, 3000),
#         'num_leaves': trial.suggest_int('num_leaves', 500, 3000),
#         'max_depth': trial.suggest_int('max_depth', 10, 300),
#         'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1),
#         'min_child_samples': trial.suggest_int('min_child_samples', 3, 300),
        
#         'boosting_type': 'dart',  # 'boosting'를 'boosting_type'으로 수정
#         'random_state': RANDOM_STATE,
#         'verbose': -1
#     }
       
#     model = LGBMClassifier(**param)
#     model.fit(x_tr, y_tr)
#     pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
#     pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
    
#     score = f1_score(y_val, pred, average="binary")
    
#     return score

# # 데이터셋 분할
# x_train, x_val, y_train, y_val = train_test_split(
#     train_data_dam.drop("target", axis=1),
#     train_data_dam["target"],
#     test_size=0.2,
#     shuffle=True,
#     random_state=RANDOM_STATE,
# )

# # 하이퍼 파라미터 튜닝
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=200)

# print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))

# %% [markdown]
# Trial 59 finished with value: 0.21949078138718175
# parameters: {'n_estimators': 1901, 'num_leaves': 1247, 'max_depth': 36,
# 'learning_rate': 0.0011375205361216431, 'min_child_samples': 129}

# %%
# import optuna
# from lightgbm import LGBMClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import f1_score

# # 'Normal'과 'AbNormal'을 숫자로 변환
# train_data_dam['target'] = train_data_dam['target'].map({'Normal': 0, 'AbNormal': 1})

# # 스레드홀드 설정
# THRESHOLD = 0.3

# def objectiveLGBM_dart(trial, x_tr, y_tr, x_val, y_val):
#     param = {
#         'n_estimators': trial.suggest_int('n_estimators', 1000, 3500),
#         'num_leaves': trial.suggest_int('num_leaves', 500, 3000),
#         'max_depth': trial.suggest_int('max_depth', 10, 200),
#         'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1),
#         'min_child_samples': trial.suggest_int('min_child_samples', 50, 250),
        
#         'boosting_type': 'dart',  # 'boosting'를 'boosting_type'으로 수정
#         'random_state': RANDOM_STATE,
#         'verbose': -1
#     }
       
#     model = LGBMClassifier(**param)
#     model.fit(x_tr, y_tr)
#     pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
#     pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
    
#     score = f1_score(y_val, pred, average="binary")
    
#     return score

# # 데이터셋 분할
# x_train, x_val, y_train, y_val = train_test_split(
#     train_data_dam.drop("target", axis=1),
#     train_data_dam["target"],
#     test_size=0.2,
#     shuffle=True,
#     random_state=RANDOM_STATE,
# )

# # 하이퍼 파라미터 튜닝
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=300)

# print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))

# %% [markdown]
# Trial 213 finished with value: 0.2222222222222222
# parameters: {'n_estimators': 1467, 'num_leaves': 2545, 'max_depth': 37,
# 'learning_rate': 0.04353920224587149, 'min_child_samples': 83}.

# %% [markdown]
# 한번더 돌렸을때 더 낮은 성능

# %%
import optuna
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# 'Normal'과 'AbNormal'을 숫자로 변환
train_data_dam['target'] = train_data_dam['target'].map({'Normal': 0, 'AbNormal': 1})

# 스레드홀드 설정
THRESHOLD = 0.3

def objectiveLGBM_dart(trial, x_tr, y_tr, x_val, y_val):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 1000, 3500),
        'num_leaves': trial.suggest_int('num_leaves', 500, 3500),
        'max_depth': trial.suggest_int('max_depth', 10, 200),
        'learning_rate': trial.suggest_float('learning_rate', 0.0003, 0.3),
        'min_child_samples': trial.suggest_int('min_child_samples', 50, 250),
        
        'boosting_type': 'dart',  # 'boosting'를 'boosting_type'으로 수정
        'random_state': RANDOM_STATE,
        'verbose': -1
    }
       
    model = LGBMClassifier(**param)
    model.fit(x_tr, y_tr)
    pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
    pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
    
    score = f1_score(y_val, pred, average="binary")
    
    return score

# 데이터셋 분할
x_train, x_val, y_train, y_val = train_test_split(
    train_data_dam.drop("target", axis=1),
    train_data_dam["target"],
    test_size=0.2,
    shuffle=True,
    random_state=RANDOM_STATE,
)

# 하이퍼 파라미터 튜닝
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=300)

print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# C:\Users\juneh\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# [I 2024-08-22 00:16:16,098] A new study created in memory with name: no-name-a685f4cf-e162-4d61-98ba-c31247e25653
# [I 2024-08-22 00:17:34,149] Trial 0 finished with value: 0.21011673151750973 and parameters: {'n_estimators': 1290, 'num_leaves': 2476, 'max_depth': 81, 'learning_rate': 0.18395093969213586, 'min_child_samples': 186}. Best is trial 0 with value: 0.21011673151750973.
# [I 2024-08-22 00:21:53,027] Trial 1 finished with value: 0.19020172910662822 and parameters: {'n_estimators': 2706, 'num_leaves': 3365, 'max_depth': 131, 'learning_rate': 0.15402919924162803, 'min_child_samples': 67}. Best is trial 0 with value: 0.21011673151750973.
# [I 2024-08-22 00:23:49,645] Trial 2 finished with value: 0.17921146953405018 and parameters: {'n_estimators': 1969, 'num_leaves': 1371, 'max_depth': 35, 'learning_rate': 0.0033286437432812747, 'min_child_samples': 132}. Best is trial 0 with value: 0.21011673151750973.
# [I 2024-08-22 00:26:27,214] Trial 3 finished with value: 0.21194029850746268 and parameters: {'n_estimators': 2231, 'num_leaves': 564, 'max_depth': 116, 'learning_rate': 0.023561721119973494, 'min_child_samples': 131}. Best is trial 3 with value: 0.21194029850746268.
# [I 2024-08-22 00:29:09,100] Trial 4 finished with value: 0.19597315436241614 and parameters: {'n_estimators': 1785, 'num_leaves': 2812, 'max_depth': 124, 'learning_rate': 0.12538224344127344, 'min_child_samples': 117}. Best is trial 3 with value: 0.21194029850746268.
# [I 2024-08-22 00:30:41,497] Trial 5 finished with value: 0.2010869565217391 and parameters: {'n_estimators': 1062, 'num_leaves': 768, 'max_depth': 173, 'learning_rate': 0.1474860351915402, 'min_child_samples': 100}. Best is trial 3 with value: 0.21194029850746268.
# [I 2024-08-22 00:36:39,803] Trial 6 finished with value: 0.1954674220963173 and parameters: {'n_estimators': 2903, 'num_leaves': 2121, 'max_depth': 83, 'learning_rate': 0.19332900436168748, 'min_child_samples': 84}. Best is trial 3 with value: 0.21194029850746268.
# [I 2024-08-22 00:41:21,178] Trial 7 finished with value: 0.19390581717451522 and parameters: {'n_estimators': 2773, 'num_leaves': 620, 'max_depth': 124, 'learning_rate': 0.06124285172137882, 'min_child_samples': 100}. Best is trial 3 with value: 0.21194029850746268.
# [I 2024-08-22 00:45:01,407] Trial 8 finished with value: 0.1940928270042194 and parameters: {'n_estimators': 1998, 'num_leaves': 2642, 'max_depth': 161, 'learning_rate': 0.26849303362178684, 'min_child_samples': 94}. Best is trial 3 with value: 0.21194029850746268.
# [I 2024-08-22 00:46:01,175] Trial 9 finished with value: 0.2065359477124183 and parameters: {'n_estimators': 1032, 'num_leaves': 2783, 'max_depth': 44, 'learning_rate': 0.2381283650041344, 'min_child_samples': 241}. Best is trial 3 with value: 0.21194029850746268.
# [I 2024-08-22 00:47:34,069] Trial 10 finished with value: 0.2091917591125198 and parameters: {'n_estimators': 2420, 'num_leaves': 1225, 'max_depth': 10, 'learning_rate': 0.06394358289928086, 'min_child_samples': 171}. Best is trial 3 with value: 0.21194029850746268.
# [I 2024-08-22 00:49:19,711] Trial 11 finished with value: 0.2065359477124183 and parameters: {'n_estimators': 1523, 'num_leaves': 1954, 'max_depth': 81, 'learning_rate': 0.19478727639452784, 'min_child_samples': 176}. Best is trial 3 with value: 0.21194029850746268.
# [I 2024-08-22 00:52:58,758] Trial 12 finished with value: 0.2028985507246377 and parameters: {'n_estimators': 3403, 'num_leaves': 1961, 'max_depth': 83, 'learning_rate': 0.09078523302313296, 'min_child_samples': 204}. Best is trial 3 with value: 0.21194029850746268.
# [I 2024-08-22 00:54:38,336] Trial 13 finished with value: 0.19272727272727272 and parameters: {'n_estimators': 1566, 'num_leaves': 1365, 'max_depth': 99, 'learning_rate': 0.011529242989058427, 'min_child_samples': 161}. Best is trial 3 with value: 0.21194029850746268.
# [I 2024-08-22 00:57:15,277] Trial 14 finished with value: 0.19195849546044097 and parameters: {'n_estimators': 2335, 'num_leaves': 2367, 'max_depth': 55, 'learning_rate': 0.2981202206542389, 'min_child_samples': 208}. Best is trial 3 with value: 0.21194029850746268.
# [I 2024-08-22 00:59:08,247] Trial 15 finished with value: 0.2045152722443559 and parameters: {'n_estimators': 1361, 'num_leaves': 3270, 'max_depth': 149, 'learning_rate': 0.20504167407678067, 'min_child_samples': 140}. Best is trial 3 with value: 0.21194029850746268.
# [I 2024-08-22 01:03:14,738] Trial 16 finished with value: 0.21372031662269128 and parameters: {'n_estimators': 3356, 'num_leaves': 1605, 'max_depth': 187, 'learning_rate': 0.11013788010922732, 'min_child_samples': 194}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 01:06:34,297] Trial 17 finished with value: 0.19440745672436752 and parameters: {'n_estimators': 3467, 'num_leaves': 971, 'max_depth': 195, 'learning_rate': 0.05502002973640764, 'min_child_samples': 249}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 01:10:50,685] Trial 18 finished with value: 0.21243523316062177 and parameters: {'n_estimators': 3139, 'num_leaves': 1622, 'max_depth': 200, 'learning_rate': 0.10514694759676553, 'min_child_samples': 215}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 01:14:08,711] Trial 19 finished with value: 0.20492866407263294 and parameters: {'n_estimators': 3117, 'num_leaves': 1504, 'max_depth': 199, 'learning_rate': 0.10982412305657996, 'min_child_samples': 228}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 01:17:43,741] Trial 20 finished with value: 0.2030848329048843 and parameters: {'n_estimators': 3174, 'num_leaves': 1711, 'max_depth': 183, 'learning_rate': 0.08660752054678868, 'min_child_samples': 212}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 01:20:42,699] Trial 21 finished with value: 0.2033426183844011 and parameters: {'n_estimators': 2555, 'num_leaves': 1010, 'max_depth': 149, 'learning_rate': 0.036296618780082765, 'min_child_samples': 153}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 01:24:29,898] Trial 22 finished with value: 0.202365308804205 and parameters: {'n_estimators': 3061, 'num_leaves': 505, 'max_depth': 175, 'learning_rate': 0.13244146698964554, 'min_child_samples': 190}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 01:26:31,001] Trial 23 finished with value: 0.21093749999999997 and parameters: {'n_estimators': 2173, 'num_leaves': 1664, 'max_depth': 155, 'learning_rate': 0.09623081688468123, 'min_child_samples': 222}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 01:30:47,227] Trial 24 finished with value: 0.21094793057409883 and parameters: {'n_estimators': 3282, 'num_leaves': 979, 'max_depth': 191, 'learning_rate': 0.04057384475811528, 'min_child_samples': 124}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 01:33:51,812] Trial 25 finished with value: 0.2035398230088496 and parameters: {'n_estimators': 2918, 'num_leaves': 1720, 'max_depth': 171, 'learning_rate': 0.026173735423473277, 'min_child_samples': 197}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 01:36:53,005] Trial 26 finished with value: 0.20986093552465232 and parameters: {'n_estimators': 2529, 'num_leaves': 2138, 'max_depth': 136, 'learning_rate': 0.16376970311115763, 'min_child_samples': 227}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 01:39:34,841] Trial 27 finished with value: 0.20717131474103587 and parameters: {'n_estimators': 2213, 'num_leaves': 1220, 'max_depth': 200, 'learning_rate': 0.07444573424044924, 'min_child_samples': 164}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 01:48:20,082] Trial 28 finished with value: 0.1839080459770115 and parameters: {'n_estimators': 3305, 'num_leaves': 3103, 'max_depth': 106, 'learning_rate': 0.12234813679764965, 'min_child_samples': 55}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 01:52:37,962] Trial 29 finished with value: 0.19788918205804748 and parameters: {'n_estimators': 2925, 'num_leaves': 2501, 'max_depth': 105, 'learning_rate': 0.1722698026567965, 'min_child_samples': 183}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 01:58:01,453] Trial 30 finished with value: 0.20027063599458728 and parameters: {'n_estimators': 3496, 'num_leaves': 779, 'max_depth': 163, 'learning_rate': 0.13844863125555673, 'min_child_samples': 147}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 02:03:15,602] Trial 31 finished with value: 0.19946091644204852 and parameters: {'n_estimators': 3259, 'num_leaves': 990, 'max_depth': 185, 'learning_rate': 0.039918843478473756, 'min_child_samples': 116}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 02:06:43,261] Trial 32 finished with value: 0.20212765957446807 and parameters: {'n_estimators': 2680, 'num_leaves': 790, 'max_depth': 187, 'learning_rate': 0.04239693552579622, 'min_child_samples': 126}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 02:11:03,222] Trial 33 finished with value: 0.20689655172413793 and parameters: {'n_estimators': 3311, 'num_leaves': 1122, 'max_depth': 137, 'learning_rate': 0.0174934643123755, 'min_child_samples': 130}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 02:16:08,759] Trial 34 finished with value: 0.2051983584131327 and parameters: {'n_estimators': 3041, 'num_leaves': 1399, 'max_depth': 184, 'learning_rate': 0.07230575232859084, 'min_child_samples': 117}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 02:20:09,673] Trial 35 finished with value: 0.1954022988505747 and parameters: {'n_estimators': 1994, 'num_leaves': 627, 'max_depth': 173, 'learning_rate': 0.11147975243753365, 'min_child_samples': 78}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 02:24:27,694] Trial 36 finished with value: 0.2030178326474623 and parameters: {'n_estimators': 2754, 'num_leaves': 1522, 'max_depth': 190, 'learning_rate': 0.10418775683700343, 'min_child_samples': 142}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 02:26:31,916] Trial 37 finished with value: 0.19830028328611896 and parameters: {'n_estimators': 1748, 'num_leaves': 1856, 'max_depth': 65, 'learning_rate': 0.04695832630139709, 'min_child_samples': 155}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 02:30:16,590] Trial 38 finished with value: 0.18806509945750452 and parameters: {'n_estimators': 3206, 'num_leaves': 885, 'max_depth': 114, 'learning_rate': 0.002567223001794256, 'min_child_samples': 120}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 02:34:21,964] Trial 39 finished with value: 0.2054794520547945 and parameters: {'n_estimators': 2969, 'num_leaves': 2172, 'max_depth': 163, 'learning_rate': 0.02604773307049582, 'min_child_samples': 111}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 02:37:29,438] Trial 40 finished with value: 0.2054794520547945 and parameters: {'n_estimators': 2089, 'num_leaves': 621, 'max_depth': 141, 'learning_rate': 0.08013483352719983, 'min_child_samples': 106}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 02:39:46,614] Trial 41 finished with value: 0.1962864721485411 and parameters: {'n_estimators': 2181, 'num_leaves': 1560, 'max_depth': 155, 'learning_rate': 0.09296021612397282, 'min_child_samples': 222}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 02:41:42,491] Trial 42 finished with value: 0.21121251629726207 and parameters: {'n_estimators': 1757, 'num_leaves': 1712, 'max_depth': 123, 'learning_rate': 0.14758741357319902, 'min_child_samples': 215}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 02:43:33,648] Trial 43 finished with value: 0.20492866407263294 and parameters: {'n_estimators': 1824, 'num_leaves': 1830, 'max_depth': 119, 'learning_rate': 0.1490294763937397, 'min_child_samples': 237}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 02:44:54,381] Trial 44 finished with value: 0.20136054421768707 and parameters: {'n_estimators': 1201, 'num_leaves': 1254, 'max_depth': 95, 'learning_rate': 0.12308577540511507, 'min_child_samples': 194}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 02:48:59,752] Trial 45 finished with value: 0.20286085825747727 and parameters: {'n_estimators': 3367, 'num_leaves': 2046, 'max_depth': 127, 'learning_rate': 0.17986714508364454, 'min_child_samples': 215}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 02:51:16,818] Trial 46 finished with value: 0.19867549668874168 and parameters: {'n_estimators': 1626, 'num_leaves': 1107, 'max_depth': 94, 'learning_rate': 0.21140032682779705, 'min_child_samples': 171}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 02:54:42,210] Trial 47 finished with value: 0.19060773480662982 and parameters: {'n_estimators': 1849, 'num_leaves': 2280, 'max_depth': 30, 'learning_rate': 0.15885664405439076, 'min_child_samples': 94}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 02:58:00,241] Trial 48 finished with value: 0.2034346103038309 and parameters: {'n_estimators': 2837, 'num_leaves': 1373, 'max_depth': 177, 'learning_rate': 0.06563701802190317, 'min_child_samples': 200}. Best is trial 16 with value: 0.21372031662269128.
# [I 2024-08-22 03:01:11,467] Trial 49 finished with value: 0.21614583333333334 and parameters: {'n_estimators': 2415, 'num_leaves': 1900, 'max_depth': 73, 'learning_rate': 0.1321797261462464, 'min_child_samples': 183}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:04:01,803] Trial 50 finished with value: 0.20025348542458804 and parameters: {'n_estimators': 2500, 'num_leaves': 1896, 'max_depth': 57, 'learning_rate': 0.22661959715806645, 'min_child_samples': 238}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:07:27,284] Trial 51 finished with value: 0.20546163849154747 and parameters: {'n_estimators': 2640, 'num_leaves': 1753, 'max_depth': 88, 'learning_rate': 0.14342389734889646, 'min_child_samples': 183}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:10:58,643] Trial 52 finished with value: 0.20588235294117646 and parameters: {'n_estimators': 2341, 'num_leaves': 1593, 'max_depth': 74, 'learning_rate': 0.11490966107662622, 'min_child_samples': 139}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:15:04,073] Trial 53 finished with value: 0.2 and parameters: {'n_estimators': 3407, 'num_leaves': 2033, 'max_depth': 114, 'learning_rate': 0.05640330011967666, 'min_child_samples': 205}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:16:51,623] Trial 54 finished with value: 0.21485411140583552 and parameters: {'n_estimators': 1457, 'num_leaves': 1391, 'max_depth': 39, 'learning_rate': 0.13187714408402357, 'min_child_samples': 175}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:18:44,021] Trial 55 finished with value: 0.20472440944881892 and parameters: {'n_estimators': 1667, 'num_leaves': 1663, 'max_depth': 25, 'learning_rate': 0.1295864201749487, 'min_child_samples': 172}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:19:47,124] Trial 56 finished with value: 0.20625000000000002 and parameters: {'n_estimators': 1432, 'num_leaves': 1424, 'max_depth': 12, 'learning_rate': 0.10260867996203923, 'min_child_samples': 187}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:21:01,964] Trial 57 finished with value: 0.20052770448548815 and parameters: {'n_estimators': 1132, 'num_leaves': 1802, 'max_depth': 44, 'learning_rate': 0.15511799608230362, 'min_child_samples': 180}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:22:27,420] Trial 58 finished with value: 0.19740259740259739 and parameters: {'n_estimators': 1416, 'num_leaves': 2284, 'max_depth': 42, 'learning_rate': 0.16684354250092193, 'min_child_samples': 214}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:23:53,310] Trial 59 finished with value: 0.20472440944881892 and parameters: {'n_estimators': 1257, 'num_leaves': 1982, 'max_depth': 70, 'learning_rate': 0.18617990534155104, 'min_child_samples': 193}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:26:29,100] Trial 60 finished with value: 0.20157068062827224 and parameters: {'n_estimators': 2090, 'num_leaves': 1282, 'max_depth': 50, 'learning_rate': 0.13446478011751892, 'min_child_samples': 167}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:30:43,284] Trial 61 finished with value: 0.1951219512195122 and parameters: {'n_estimators': 3122, 'num_leaves': 1135, 'max_depth': 194, 'learning_rate': 0.11894048897291334, 'min_child_samples': 156}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:32:39,172] Trial 62 finished with value: 0.21354166666666666 and parameters: {'n_estimators': 1900, 'num_leaves': 527, 'max_depth': 194, 'learning_rate': 0.14488412057769975, 'min_child_samples': 201}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:34:54,034] Trial 63 finished with value: 0.20618556701030927 and parameters: {'n_estimators': 2303, 'num_leaves': 586, 'max_depth': 199, 'learning_rate': 0.14125641113603202, 'min_child_samples': 205}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:36:55,205] Trial 64 finished with value: 0.20957309184993533 and parameters: {'n_estimators': 1945, 'num_leaves': 699, 'max_depth': 105, 'learning_rate': 0.1507078546450583, 'min_child_samples': 199}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:38:49,111] Trial 65 finished with value: 0.21080368906455862 and parameters: {'n_estimators': 1532, 'num_leaves': 892, 'max_depth': 168, 'learning_rate': 0.1743818323475987, 'min_child_samples': 177}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:40:39,837] Trial 66 finished with value: 0.2076215505913272 and parameters: {'n_estimators': 1744, 'num_leaves': 1467, 'max_depth': 179, 'learning_rate': 0.13148817284044, 'min_child_samples': 218}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:42:16,068] Trial 67 finished with value: 0.21173104434907009 and parameters: {'n_estimators': 1930, 'num_leaves': 1629, 'max_depth': 17, 'learning_rate': 0.10200600640656579, 'min_child_samples': 230}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:44:10,509] Trial 68 finished with value: 0.20081411126187246 and parameters: {'n_estimators': 1924, 'num_leaves': 2503, 'max_depth': 25, 'learning_rate': 0.10406430272447992, 'min_child_samples': 226}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:45:57,809] Trial 69 finished with value: 0.20527859237536655 and parameters: {'n_estimators': 2379, 'num_leaves': 540, 'max_depth': 14, 'learning_rate': 0.08411289474624459, 'min_child_samples': 231}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:47:51,553] Trial 70 finished with value: 0.20080321285140562 and parameters: {'n_estimators': 2100, 'num_leaves': 1312, 'max_depth': 21, 'learning_rate': 0.11371081761140055, 'min_child_samples': 210}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:49:47,680] Trial 71 finished with value: 0.19839142091152817 and parameters: {'n_estimators': 1868, 'num_leaves': 1619, 'max_depth': 59, 'learning_rate': 0.09547162195883252, 'min_child_samples': 232}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:51:51,413] Trial 72 finished with value: 0.2084942084942085 and parameters: {'n_estimators': 2029, 'num_leaves': 1711, 'max_depth': 78, 'learning_rate': 0.12391604030668488, 'min_child_samples': 248}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:53:25,547] Trial 73 finished with value: 0.20316622691292877 and parameters: {'n_estimators': 1666, 'num_leaves': 1491, 'max_depth': 18, 'learning_rate': 0.16096759465601956, 'min_child_samples': 189}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:56:01,467] Trial 74 finished with value: 0.19791666666666669 and parameters: {'n_estimators': 2458, 'num_leaves': 1777, 'max_depth': 194, 'learning_rate': 0.2560023356596953, 'min_child_samples': 221}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 03:58:58,358] Trial 75 finished with value: 0.20183486238532108 and parameters: {'n_estimators': 2619, 'num_leaves': 1896, 'max_depth': 38, 'learning_rate': 0.10290260275351593, 'min_child_samples': 210}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 04:01:14,020] Trial 76 finished with value: 0.19693094629156008 and parameters: {'n_estimators': 1763, 'num_leaves': 1639, 'max_depth': 145, 'learning_rate': 0.13912906121372803, 'min_child_samples': 200}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 04:03:26,456] Trial 77 finished with value: 0.2045152722443559 and parameters: {'n_estimators': 1589, 'num_leaves': 2990, 'max_depth': 33, 'learning_rate': 0.15124903055195377, 'min_child_samples': 160}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 04:04:54,859] Trial 78 finished with value: 0.198019801980198 and parameters: {'n_estimators': 1456, 'num_leaves': 726, 'max_depth': 122, 'learning_rate': 0.07293290014129455, 'min_child_samples': 204}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 04:08:16,173] Trial 79 finished with value: 0.21066666666666664 and parameters: {'n_estimators': 2275, 'num_leaves': 872, 'max_depth': 129, 'learning_rate': 0.12861337385942248, 'min_child_samples': 147}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 04:11:23,223] Trial 80 finished with value: 0.203921568627451 and parameters: {'n_estimators': 2158, 'num_leaves': 3409, 'max_depth': 182, 'learning_rate': 0.19511343231105993, 'min_child_samples': 194}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 04:16:14,444] Trial 81 finished with value: 0.1997264021887825 and parameters: {'n_estimators': 3216, 'num_leaves': 1194, 'max_depth': 188, 'learning_rate': 0.02695014907368633, 'min_child_samples': 124}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 04:20:54,474] Trial 82 finished with value: 0.19851851851851854 and parameters: {'n_estimators': 2995, 'num_leaves': 1040, 'max_depth': 195, 'learning_rate': 0.01809331233335384, 'min_child_samples': 132}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 04:26:01,377] Trial 83 finished with value: 0.2081081081081081 and parameters: {'n_estimators': 3300, 'num_leaves': 1551, 'max_depth': 189, 'learning_rate': 0.03098225639868608, 'min_child_samples': 135}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 04:30:27,519] Trial 84 finished with value: 0.19601837672281774 and parameters: {'n_estimators': 3383, 'num_leaves': 674, 'max_depth': 167, 'learning_rate': 0.01039561010702095, 'min_child_samples': 110}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 04:34:34,529] Trial 85 finished with value: 0.20553359683794467 and parameters: {'n_estimators': 3461, 'num_leaves': 814, 'max_depth': 86, 'learning_rate': 0.11828987024962413, 'min_child_samples': 176}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 04:36:55,665] Trial 86 finished with value: 0.19464033850493653 and parameters: {'n_estimators': 2240, 'num_leaves': 1342, 'max_depth': 113, 'learning_rate': 0.0512810648207839, 'min_child_samples': 217}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 04:40:36,232] Trial 87 finished with value: 0.19440745672436752 and parameters: {'n_estimators': 3148, 'num_leaves': 1881, 'max_depth': 156, 'learning_rate': 0.06385285499577134, 'min_child_samples': 225}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 04:44:37,548] Trial 88 finished with value: 0.1965471447543161 and parameters: {'n_estimators': 3074, 'num_leaves': 505, 'max_depth': 65, 'learning_rate': 0.10806312381252296, 'min_child_samples': 182}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 04:46:42,538] Trial 89 finished with value: 0.1975642760487145 and parameters: {'n_estimators': 2029, 'num_leaves': 1438, 'max_depth': 181, 'learning_rate': 0.08917945470106053, 'min_child_samples': 243}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 04:49:07,921] Trial 90 finished with value: 0.1989247311827957 and parameters: {'n_estimators': 1360, 'num_leaves': 1702, 'max_depth': 191, 'learning_rate': 0.0817348080881262, 'min_child_samples': 123}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 04:51:24,833] Trial 91 finished with value: 0.19815059445178335 and parameters: {'n_estimators': 1921, 'num_leaves': 1588, 'max_depth': 200, 'learning_rate': 0.09364959442021747, 'min_child_samples': 232}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 04:54:12,494] Trial 92 finished with value: 0.20876288659793812 and parameters: {'n_estimators': 2146, 'num_leaves': 1799, 'max_depth': 175, 'learning_rate': 0.14459924278927402, 'min_child_samples': 220}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 04:57:39,621] Trial 93 finished with value: 0.2094240837696335 and parameters: {'n_estimators': 2840, 'num_leaves': 1666, 'max_depth': 137, 'learning_rate': 0.09775262770114301, 'min_child_samples': 206}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 04:59:34,797] Trial 94 finished with value: 0.21437908496732028 and parameters: {'n_estimators': 1685, 'num_leaves': 1939, 'max_depth': 158, 'learning_rate': 0.13762559014506326, 'min_child_samples': 215}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:01:35,534] Trial 95 finished with value: 0.19870967741935483 and parameters: {'n_estimators': 1720, 'num_leaves': 1523, 'max_depth': 98, 'learning_rate': 0.13793564192855212, 'min_child_samples': 191}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:03:44,216] Trial 96 finished with value: 0.2049934296977661 and parameters: {'n_estimators': 1822, 'num_leaves': 2054, 'max_depth': 186, 'learning_rate': 0.12487642660605673, 'min_child_samples': 212}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:05:35,776] Trial 97 finished with value: 0.20645161290322583 and parameters: {'n_estimators': 1507, 'num_leaves': 2073, 'max_depth': 133, 'learning_rate': 0.16857229066041646, 'min_child_samples': 197}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:07:48,263] Trial 98 finished with value: 0.203921568627451 and parameters: {'n_estimators': 1685, 'num_leaves': 1945, 'max_depth': 171, 'learning_rate': 0.15860236053729793, 'min_child_samples': 185}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:09:48,945] Trial 99 finished with value: 0.19843342036553524 and parameters: {'n_estimators': 1887, 'num_leaves': 928, 'max_depth': 108, 'learning_rate': 0.2979545028310625, 'min_child_samples': 201}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:12:57,229] Trial 100 finished with value: 0.21052631578947367 and parameters: {'n_estimators': 1601, 'num_leaves': 2111, 'max_depth': 160, 'learning_rate': 0.14638848866843557, 'min_child_samples': 99}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:16:39,141] Trial 101 finished with value: 0.2036082474226804 and parameters: {'n_estimators': 3336, 'num_leaves': 1746, 'max_depth': 145, 'learning_rate': 0.11132462981854209, 'min_child_samples': 237}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:18:50,759] Trial 102 finished with value: 0.2080624187256177 and parameters: {'n_estimators': 1984, 'num_leaves': 2183, 'max_depth': 151, 'learning_rate': 0.13407061648746432, 'min_child_samples': 215}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:20:43,104] Trial 103 finished with value: 0.19374999999999998 and parameters: {'n_estimators': 1779, 'num_leaves': 1926, 'max_depth': 193, 'learning_rate': 0.03785158072942188, 'min_child_samples': 223}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:23:13,666] Trial 104 finished with value: 0.2105263157894737 and parameters: {'n_estimators': 2391, 'num_leaves': 1839, 'max_depth': 197, 'learning_rate': 0.11783512667060685, 'min_child_samples': 229}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:27:06,761] Trial 105 finished with value: 0.2065359477124183 and parameters: {'n_estimators': 3254, 'num_leaves': 1989, 'max_depth': 49, 'learning_rate': 0.09910200157508843, 'min_child_samples': 196}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:29:56,173] Trial 106 finished with value: 0.20789473684210527 and parameters: {'n_estimators': 2220, 'num_leaves': 1041, 'max_depth': 119, 'learning_rate': 0.12829740916879037, 'min_child_samples': 167}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:31:16,378] Trial 107 finished with value: 0.2073669849931787 and parameters: {'n_estimators': 1355, 'num_leaves': 566, 'max_depth': 179, 'learning_rate': 0.10883950068144116, 'min_child_samples': 208}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:36:42,512] Trial 108 finished with value: 0.20027063599458728 and parameters: {'n_estimators': 3447, 'num_leaves': 1657, 'max_depth': 124, 'learning_rate': 0.07611194126024436, 'min_child_samples': 127}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:38:55,590] Trial 109 finished with value: 0.20546163849154747 and parameters: {'n_estimators': 2031, 'num_leaves': 1564, 'max_depth': 186, 'learning_rate': 0.13665654528378374, 'min_child_samples': 202}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:42:35,973] Trial 110 finished with value: 0.20027816411682894 and parameters: {'n_estimators': 2103, 'num_leaves': 1485, 'max_depth': 93, 'learning_rate': 0.15577903888155142, 'min_child_samples': 115}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:44:23,990] Trial 111 finished with value: 0.20860495436766624 and parameters: {'n_estimators': 1534, 'num_leaves': 832, 'max_depth': 169, 'learning_rate': 0.1849933696045356, 'min_child_samples': 177}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:46:09,209] Trial 112 finished with value: 0.20969855832241155 and parameters: {'n_estimators': 1486, 'num_leaves': 649, 'max_depth': 154, 'learning_rate': 0.17123610747640777, 'min_child_samples': 187}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:47:36,990] Trial 113 finished with value: 0.10302036993678296 and parameters: {'n_estimators': 1653, 'num_leaves': 771, 'max_depth': 166, 'learning_rate': 0.00040463806905296357, 'min_child_samples': 177}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:49:18,876] Trial 114 finished with value: 0.20129032258064514 and parameters: {'n_estimators': 1548, 'num_leaves': 1769, 'max_depth': 175, 'learning_rate': 0.17552205764091425, 'min_child_samples': 213}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:51:13,729] Trial 115 finished with value: 0.20286085825747727 and parameters: {'n_estimators': 1820, 'num_leaves': 1173, 'max_depth': 192, 'learning_rate': 0.1646326482009426, 'min_child_samples': 219}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:53:27,125] Trial 116 finished with value: 0.19736842105263158 and parameters: {'n_estimators': 1698, 'num_leaves': 1384, 'max_depth': 111, 'learning_rate': 0.12150804191517686, 'min_child_samples': 170}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:55:13,974] Trial 117 finished with value: 0.2103861517976032 and parameters: {'n_estimators': 1278, 'num_leaves': 954, 'max_depth': 159, 'learning_rate': 0.14772406445626354, 'min_child_samples': 144}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:57:14,748] Trial 118 finished with value: 0.1978021978021978 and parameters: {'n_estimators': 2336, 'num_leaves': 722, 'max_depth': 164, 'learning_rate': 0.008575317639640603, 'min_child_samples': 209}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 05:59:31,149] Trial 119 finished with value: 0.19163763066202094 and parameters: {'n_estimators': 1890, 'num_leaves': 1732, 'max_depth': 28, 'learning_rate': 0.017203592093011033, 'min_child_samples': 180}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:02:07,069] Trial 120 finished with value: 0.1951871657754011 and parameters: {'n_estimators': 1624, 'num_leaves': 1834, 'max_depth': 143, 'learning_rate': 0.20584550758106493, 'min_child_samples': 136}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:04:56,153] Trial 121 finished with value: 0.20533333333333334 and parameters: {'n_estimators': 2292, 'num_leaves': 881, 'max_depth': 126, 'learning_rate': 0.13055850254392487, 'min_child_samples': 152}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:09:32,552] Trial 122 finished with value: 0.19759679572763686 and parameters: {'n_estimators': 3184, 'num_leaves': 1097, 'max_depth': 130, 'learning_rate': 0.14203826738954287, 'min_child_samples': 159}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:12:18,004] Trial 123 finished with value: 0.20397350993377486 and parameters: {'n_estimators': 2171, 'num_leaves': 897, 'max_depth': 39, 'learning_rate': 0.12846689053719054, 'min_child_samples': 147}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:14:35,861] Trial 124 finished with value: 0.20707732634338138 and parameters: {'n_estimators': 2422, 'num_leaves': 587, 'max_depth': 103, 'learning_rate': 0.11342577232316978, 'min_child_samples': 234}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:17:25,897] Trial 125 finished with value: 0.19822109275730623 and parameters: {'n_estimators': 2500, 'num_leaves': 1614, 'max_depth': 117, 'learning_rate': 0.12143813046298949, 'min_child_samples': 226}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:19:33,033] Trial 126 finished with value: 0.21227621483375958 and parameters: {'n_estimators': 2286, 'num_leaves': 857, 'max_depth': 182, 'learning_rate': 0.1515331109765338, 'min_child_samples': 243}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:20:56,409] Trial 127 finished with value: 0.2034805890227577 and parameters: {'n_estimators': 1413, 'num_leaves': 1282, 'max_depth': 182, 'learning_rate': 0.15129457937558638, 'min_child_samples': 246}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:22:59,518] Trial 128 finished with value: 0.2090322580645161 and parameters: {'n_estimators': 2046, 'num_leaves': 995, 'max_depth': 197, 'learning_rate': 0.1783814963090914, 'min_child_samples': 240}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:26:58,195] Trial 129 finished with value: 0.2007722007722008 and parameters: {'n_estimators': 3261, 'num_leaves': 645, 'max_depth': 172, 'learning_rate': 0.15960052869393587, 'min_child_samples': 191}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:29:46,531] Trial 130 finished with value: 0.20725388601036268 and parameters: {'n_estimators': 2202, 'num_leaves': 1682, 'max_depth': 189, 'learning_rate': 0.19214937769580284, 'min_child_samples': 217}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:33:27,804] Trial 131 finished with value: 0.1959183673469388 and parameters: {'n_estimators': 2264, 'num_leaves': 830, 'max_depth': 185, 'learning_rate': 0.1366291384589336, 'min_child_samples': 129}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:36:16,929] Trial 132 finished with value: 0.21024967148488832 and parameters: {'n_estimators': 2286, 'num_leaves': 748, 'max_depth': 130, 'learning_rate': 0.10552533396964384, 'min_child_samples': 174}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:38:06,856] Trial 133 finished with value: 0.19345238095238096 and parameters: {'n_estimators': 1973, 'num_leaves': 856, 'max_depth': 179, 'learning_rate': 0.04554301780067613, 'min_child_samples': 234}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:40:51,853] Trial 134 finished with value: 0.20424403183023873 and parameters: {'n_estimators': 2353, 'num_leaves': 1061, 'max_depth': 148, 'learning_rate': 0.08708749404906813, 'min_child_samples': 244}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:44:36,372] Trial 135 finished with value: 0.2047872340425532 and parameters: {'n_estimators': 2592, 'num_leaves': 703, 'max_depth': 121, 'learning_rate': 0.1449275066103656, 'min_child_samples': 164}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:46:37,502] Trial 136 finished with value: 0.20472440944881892 and parameters: {'n_estimators': 2117, 'num_leaves': 924, 'max_depth': 15, 'learning_rate': 0.15360453241272895, 'min_child_samples': 138}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:48:20,652] Trial 137 finished with value: 0.202365308804205 and parameters: {'n_estimators': 1794, 'num_leaves': 503, 'max_depth': 200, 'learning_rate': 0.12712301381288066, 'min_child_samples': 228}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:50:43,728] Trial 138 finished with value: 0.20565552699228792 and parameters: {'n_estimators': 2248, 'num_leaves': 1869, 'max_depth': 191, 'learning_rate': 0.13391329906562208, 'min_child_samples': 222}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 06:54:54,251] Trial 139 finished with value: 0.20418848167539266 and parameters: {'n_estimators': 3423, 'num_leaves': 1447, 'max_depth': 22, 'learning_rate': 0.11746503133365514, 'min_child_samples': 148}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:01:34,684] Trial 140 finished with value: 0.19505494505494506 and parameters: {'n_estimators': 3362, 'num_leaves': 1565, 'max_depth': 140, 'learning_rate': 0.13928539534035178, 'min_child_samples': 119}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:04:08,866] Trial 141 finished with value: 0.200260078023407 and parameters: {'n_estimators': 2394, 'num_leaves': 1839, 'max_depth': 197, 'learning_rate': 0.11584165659042343, 'min_child_samples': 229}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:07:19,969] Trial 142 finished with value: 0.202365308804205 and parameters: {'n_estimators': 2733, 'num_leaves': 1948, 'max_depth': 195, 'learning_rate': 0.09850183528714491, 'min_child_samples': 223}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:10:15,422] Trial 143 finished with value: 0.20592020592020593 and parameters: {'n_estimators': 2458, 'num_leaves': 1760, 'max_depth': 50, 'learning_rate': 0.12365034953858704, 'min_child_samples': 214}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:12:06,560] Trial 144 finished with value: 0.1954484605087015 and parameters: {'n_estimators': 1579, 'num_leaves': 1685, 'max_depth': 185, 'learning_rate': 0.10823147039575519, 'min_child_samples': 205}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:13:50,837] Trial 145 finished with value: 0.20680628272251306 and parameters: {'n_estimators': 1729, 'num_leaves': 1633, 'max_depth': 196, 'learning_rate': 0.11467662149768638, 'min_child_samples': 239}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:16:25,963] Trial 146 finished with value: 0.20636942675159237 and parameters: {'n_estimators': 2330, 'num_leaves': 1815, 'max_depth': 190, 'learning_rate': 0.13071294936760947, 'min_child_samples': 231}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:19:32,006] Trial 147 finished with value: 0.21011673151750973 and parameters: {'n_estimators': 2550, 'num_leaves': 785, 'max_depth': 157, 'learning_rate': 0.09246015746739139, 'min_child_samples': 185}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:22:02,206] Trial 148 finished with value: 0.2066326530612245 and parameters: {'n_estimators': 2204, 'num_leaves': 1511, 'max_depth': 178, 'learning_rate': 0.1638077702092351, 'min_child_samples': 218}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:24:17,867] Trial 149 finished with value: 0.19704433497536944 and parameters: {'n_estimators': 2403, 'num_leaves': 1988, 'max_depth': 63, 'learning_rate': 0.02298545158960008, 'min_child_samples': 249}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:26:52,057] Trial 150 finished with value: 0.2134502923976608 and parameters: {'n_estimators': 1926, 'num_leaves': 1897, 'max_depth': 200, 'learning_rate': 0.03299948438525189, 'min_child_samples': 132}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:29:19,527] Trial 151 finished with value: 0.19941348973607037 and parameters: {'n_estimators': 1867, 'num_leaves': 1881, 'max_depth': 194, 'learning_rate': 0.030061362119410948, 'min_child_samples': 126}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:31:50,903] Trial 152 finished with value: 0.20310296191819463 and parameters: {'n_estimators': 1923, 'num_leaves': 2023, 'max_depth': 199, 'learning_rate': 0.03636080045798433, 'min_child_samples': 140}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:35:26,862] Trial 153 finished with value: 0.20754716981132076 and parameters: {'n_estimators': 2137, 'num_leaves': 1728, 'max_depth': 189, 'learning_rate': 0.14738019879738443, 'min_child_samples': 130}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:38:39,013] Trial 154 finished with value: 0.19839142091152817 and parameters: {'n_estimators': 2065, 'num_leaves': 2201, 'max_depth': 200, 'learning_rate': 0.1007372670529729, 'min_child_samples': 135}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:40:46,426] Trial 155 finished with value: 0.1966101694915254 and parameters: {'n_estimators': 1955, 'num_leaves': 1930, 'max_depth': 183, 'learning_rate': 0.021226693723598967, 'min_child_samples': 197}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:42:37,048] Trial 156 finished with value: 0.20105820105820107 and parameters: {'n_estimators': 1479, 'num_leaves': 1798, 'max_depth': 76, 'learning_rate': 0.12096345133648916, 'min_child_samples': 211}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:47:33,345] Trial 157 finished with value: 0.19586206896551722 and parameters: {'n_estimators': 3495, 'num_leaves': 580, 'max_depth': 116, 'learning_rate': 0.13969137419475117, 'min_child_samples': 122}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:52:32,055] Trial 158 finished with value: 0.20260492040520983 and parameters: {'n_estimators': 2300, 'num_leaves': 1594, 'max_depth': 162, 'learning_rate': 0.040849966566982185, 'min_child_samples': 53}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:54:27,738] Trial 159 finished with value: 0.21329639889196675 and parameters: {'n_estimators': 2445, 'num_leaves': 968, 'max_depth': 195, 'learning_rate': 0.057324160620781675, 'min_child_samples': 235}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:55:51,885] Trial 160 finished with value: 0.19760479041916168 and parameters: {'n_estimators': 1765, 'num_leaves': 1199, 'max_depth': 151, 'learning_rate': 0.05553510917573315, 'min_child_samples': 235}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 07:57:54,644] Trial 161 finished with value: 0.1935483870967742 and parameters: {'n_estimators': 2429, 'num_leaves': 979, 'max_depth': 193, 'learning_rate': 0.05129289669450632, 'min_child_samples': 227}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 08:00:57,535] Trial 162 finished with value: 0.20192307692307696 and parameters: {'n_estimators': 2377, 'num_leaves': 1104, 'max_depth': 187, 'learning_rate': 0.013111701891998936, 'min_child_samples': 111}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 08:02:48,100] Trial 163 finished with value: 0.18930041152263372 and parameters: {'n_estimators': 2260, 'num_leaves': 903, 'max_depth': 192, 'learning_rate': 0.06787134016219279, 'min_child_samples': 242}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 08:04:14,669] Trial 164 finished with value: 0.21487603305785125 and parameters: {'n_estimators': 2816, 'num_leaves': 643, 'max_depth': 10, 'learning_rate': 0.04544384831759581, 'min_child_samples': 230}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 08:06:24,170] Trial 165 finished with value: 0.2006172839506173 and parameters: {'n_estimators': 3096, 'num_leaves': 632, 'max_depth': 16, 'learning_rate': 0.03215167426236476, 'min_child_samples': 180}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 08:08:50,396] Trial 166 finished with value: 0.20444444444444443 and parameters: {'n_estimators': 3249, 'num_leaves': 693, 'max_depth': 12, 'learning_rate': 0.047745420888385286, 'min_child_samples': 133}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 08:10:43,286] Trial 167 finished with value: 0.20512820512820512 and parameters: {'n_estimators': 2490, 'num_leaves': 793, 'max_depth': 20, 'learning_rate': 0.04431551658611226, 'min_child_samples': 236}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 08:12:10,588] Trial 168 finished with value: 0.21452145214521454 and parameters: {'n_estimators': 2842, 'num_leaves': 575, 'max_depth': 10, 'learning_rate': 0.054066640750929366, 'min_child_samples': 224}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 08:14:02,458] Trial 169 finished with value: 0.20408163265306126 and parameters: {'n_estimators': 2826, 'num_leaves': 552, 'max_depth': 12, 'learning_rate': 0.051913291755804065, 'min_child_samples': 222}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 08:15:36,389] Trial 170 finished with value: 0.21236133122028525 and parameters: {'n_estimators': 2889, 'num_leaves': 611, 'max_depth': 10, 'learning_rate': 0.057427190540594954, 'min_child_samples': 219}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 08:17:43,303] Trial 171 finished with value: 0.19692307692307692 and parameters: {'n_estimators': 2941, 'num_leaves': 615, 'max_depth': 17, 'learning_rate': 0.03760869527921604, 'min_child_samples': 218}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 08:19:27,770] Trial 172 finished with value: 0.21474358974358976 and parameters: {'n_estimators': 3006, 'num_leaves': 559, 'max_depth': 10, 'learning_rate': 0.05954888740064482, 'min_child_samples': 226}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 08:21:48,526] Trial 173 finished with value: 0.20148148148148146 and parameters: {'n_estimators': 3041, 'num_leaves': 543, 'max_depth': 15, 'learning_rate': 0.058776996937500735, 'min_child_samples': 225}. Best is trial 49 with value: 0.21614583333333334.
# [I 2024-08-22 08:23:20,272] Trial 174 finished with value: 0.21739130434782608 and parameters: {'n_estimators': 2862, 'num_leaves': 663, 'max_depth': 10, 'learning_rate': 0.06807070400641976, 'min_child_samples': 230}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 08:25:44,054] Trial 175 finished with value: 0.19087136929460585 and parameters: {'n_estimators': 2799, 'num_leaves': 512, 'max_depth': 24, 'learning_rate': 0.06002977302693664, 'min_child_samples': 231}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 08:27:19,672] Trial 176 finished with value: 0.20940819423368742 and parameters: {'n_estimators': 2889, 'num_leaves': 649, 'max_depth': 11, 'learning_rate': 0.06462628866397868, 'min_child_samples': 239}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 08:30:00,552] Trial 177 finished with value: 0.2064343163538874 and parameters: {'n_estimators': 2877, 'num_leaves': 735, 'max_depth': 29, 'learning_rate': 0.06839277142866523, 'min_child_samples': 227}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 08:31:39,855] Trial 178 finished with value: 0.21543408360128616 and parameters: {'n_estimators': 2653, 'num_leaves': 575, 'max_depth': 10, 'learning_rate': 0.05885137606271881, 'min_child_samples': 215}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 08:33:07,545] Trial 179 finished with value: 0.21221864951768488 and parameters: {'n_estimators': 2717, 'num_leaves': 558, 'max_depth': 10, 'learning_rate': 0.059774778451728655, 'min_child_samples': 214}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 08:34:25,710] Trial 180 finished with value: 0.2080745341614907 and parameters: {'n_estimators': 2707, 'num_leaves': 595, 'max_depth': 10, 'learning_rate': 0.07153118872911984, 'min_child_samples': 210}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 08:35:56,791] Trial 181 finished with value: 0.2105263157894737 and parameters: {'n_estimators': 2662, 'num_leaves': 691, 'max_depth': 10, 'learning_rate': 0.07631449951990424, 'min_child_samples': 219}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 08:38:05,222] Trial 182 finished with value: 0.20256776034236806 and parameters: {'n_estimators': 2737, 'num_leaves': 592, 'max_depth': 19, 'learning_rate': 0.060674604198350746, 'min_child_samples': 214}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 08:39:59,830] Trial 183 finished with value: 0.20637329286798178 and parameters: {'n_estimators': 2996, 'num_leaves': 506, 'max_depth': 15, 'learning_rate': 0.050210251837102565, 'min_child_samples': 223}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 08:42:05,171] Trial 184 finished with value: 0.1934566145092461 and parameters: {'n_estimators': 2861, 'num_leaves': 565, 'max_depth': 19, 'learning_rate': 0.057138822037145105, 'min_child_samples': 214}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 08:43:30,397] Trial 185 finished with value: 0.2121684867394696 and parameters: {'n_estimators': 2789, 'num_leaves': 645, 'max_depth': 10, 'learning_rate': 0.062481741686036055, 'min_child_samples': 208}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 08:45:22,191] Trial 186 finished with value: 0.20298507462686569 and parameters: {'n_estimators': 2777, 'num_leaves': 665, 'max_depth': 15, 'learning_rate': 0.05405370627678881, 'min_child_samples': 206}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 08:47:01,296] Trial 187 finished with value: 0.2106969205834684 and parameters: {'n_estimators': 2926, 'num_leaves': 650, 'max_depth': 11, 'learning_rate': 0.043245224643905594, 'min_child_samples': 208}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 08:49:34,062] Trial 188 finished with value: 0.21265141318977118 and parameters: {'n_estimators': 2786, 'num_leaves': 599, 'max_depth': 22, 'learning_rate': 0.06551663693867164, 'min_child_samples': 203}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 08:51:48,823] Trial 189 finished with value: 0.20297699594046006 and parameters: {'n_estimators': 2805, 'num_leaves': 603, 'max_depth': 21, 'learning_rate': 0.06699397808713088, 'min_child_samples': 201}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 08:53:51,391] Trial 190 finished with value: 0.21081081081081082 and parameters: {'n_estimators': 2589, 'num_leaves': 747, 'max_depth': 26, 'learning_rate': 0.06428541792922574, 'min_child_samples': 202}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 08:56:04,026] Trial 191 finished with value: 0.19822485207100593 and parameters: {'n_estimators': 2977, 'num_leaves': 550, 'max_depth': 14, 'learning_rate': 0.06155559213020065, 'min_child_samples': 232}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 08:57:49,679] Trial 192 finished with value: 0.196969696969697 and parameters: {'n_estimators': 2687, 'num_leaves': 502, 'max_depth': 10, 'learning_rate': 0.08300368005347161, 'min_child_samples': 194}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 08:59:59,414] Trial 193 finished with value: 0.1994459833795014 and parameters: {'n_estimators': 2754, 'num_leaves': 685, 'max_depth': 19, 'learning_rate': 0.07706427534949634, 'min_child_samples': 219}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 09:02:33,342] Trial 194 finished with value: 0.20457604306864066 and parameters: {'n_estimators': 2859, 'num_leaves': 594, 'max_depth': 33, 'learning_rate': 0.05509968012271451, 'min_child_samples': 211}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 09:04:32,901] Trial 195 finished with value: 0.2005813953488372 and parameters: {'n_estimators': 2786, 'num_leaves': 631, 'max_depth': 14, 'learning_rate': 0.07093758635360095, 'min_child_samples': 205}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 09:06:38,585] Trial 196 finished with value: 0.19851851851851854 and parameters: {'n_estimators': 2943, 'num_leaves': 726, 'max_depth': 17, 'learning_rate': 0.048896175411273626, 'min_child_samples': 223}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 09:09:05,564] Trial 197 finished with value: 0.2013986013986014 and parameters: {'n_estimators': 2733, 'num_leaves': 556, 'max_depth': 21, 'learning_rate': 0.060502058634918664, 'min_child_samples': 216}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 09:11:14,817] Trial 198 finished with value: 0.19533527696793004 and parameters: {'n_estimators': 2641, 'num_leaves': 675, 'max_depth': 24, 'learning_rate': 0.04431996984348712, 'min_child_samples': 229}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 09:12:55,403] Trial 199 finished with value: 0.20504201680672268 and parameters: {'n_estimators': 2903, 'num_leaves': 634, 'max_depth': 10, 'learning_rate': 0.0347859709359228, 'min_child_samples': 199}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 09:14:42,722] Trial 200 finished with value: 0.21098265895953758 and parameters: {'n_estimators': 2779, 'num_leaves': 501, 'max_depth': 14, 'learning_rate': 0.07082089920413125, 'min_child_samples': 235}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 09:16:59,523] Trial 201 finished with value: 0.1968162083936324 and parameters: {'n_estimators': 3031, 'num_leaves': 574, 'max_depth': 16, 'learning_rate': 0.05524464009471712, 'min_child_samples': 208}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 09:18:37,231] Trial 202 finished with value: 0.21405750798722048 and parameters: {'n_estimators': 2823, 'num_leaves': 763, 'max_depth': 10, 'learning_rate': 0.06130613415088273, 'min_child_samples': 214}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 09:20:06,618] Trial 203 finished with value: 0.21484992101105846 and parameters: {'n_estimators': 2837, 'num_leaves': 803, 'max_depth': 10, 'learning_rate': 0.06495282917142846, 'min_child_samples': 216}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 09:22:13,536] Trial 204 finished with value: 0.20444444444444443 and parameters: {'n_estimators': 2842, 'num_leaves': 814, 'max_depth': 14, 'learning_rate': 0.062909973259845, 'min_child_samples': 213}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 09:24:02,104] Trial 205 finished with value: 0.21103896103896103 and parameters: {'n_estimators': 2818, 'num_leaves': 757, 'max_depth': 11, 'learning_rate': 0.04791355997737986, 'min_child_samples': 216}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 09:25:50,699] Trial 206 finished with value: 0.20872274143302183 and parameters: {'n_estimators': 2863, 'num_leaves': 692, 'max_depth': 10, 'learning_rate': 0.07460869051509245, 'min_child_samples': 221}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 09:27:21,280] Trial 207 finished with value: 0.2028985507246377 and parameters: {'n_estimators': 2691, 'num_leaves': 778, 'max_depth': 10, 'learning_rate': 0.05778126438714484, 'min_child_samples': 211}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 09:29:23,455] Trial 208 finished with value: 0.20362622036262204 and parameters: {'n_estimators': 2901, 'num_leaves': 635, 'max_depth': 18, 'learning_rate': 0.06680152329698394, 'min_child_samples': 205}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 09:31:38,206] Trial 209 finished with value: 0.1986013986013986 and parameters: {'n_estimators': 2981, 'num_leaves': 723, 'max_depth': 23, 'learning_rate': 0.05307905859471037, 'min_child_samples': 225}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 09:32:18,810] Trial 210 finished with value: 0.21105527638190955 and parameters: {'n_estimators': 1111, 'num_leaves': 857, 'max_depth': 13, 'learning_rate': 0.08181435094774489, 'min_child_samples': 189}. Best is trial 174 with value: 0.21739130434782608.
# [I 2024-08-22 09:34:16,930] Trial 211 finished with value: 0.20303030303030303 and parameters: {'n_estimators': 2770, 'num_leaves': 596, 'max_depth': 70, 'learning_rate': 0.02731032461263464, 'min_child_samples': 219}. Best is trial 174 with value: 0.21739130434782608.
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.

# %% [markdown]
# .
