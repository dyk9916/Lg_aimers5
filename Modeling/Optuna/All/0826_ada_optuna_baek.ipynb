# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ## 1. 데이터 불러오기

# %% [markdown]
# ### 필수 라이브러리

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)

def get_clf_eval(y_test, y_pred_proba, threshold=0.5):
    # 확률을 기준으로 예측 레이블 생성
    y_pred = (y_pred_proba >= threshold).astype(int)  # 0.5 이상의 확률을 양성으로 간주

    confusion = confusion_matrix(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    print("Confusion Matrix:\n", confusion)
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")

# %% [markdown]
# ### 데이터 읽어오기

# %%
import pandas as pd

THRESHOLD = 0.3
RANDOM_STATE = 110

train_data = pd.read_csv("./data/train_data_0825.csv")
test_data = pd.read_csv("./data/test_data_0825.csv")

# %% [markdown]
# ---

# %% [markdown]
# ## 3. 모델 학습

# %% [markdown]
# ### 모델 정의

# %% [markdown]
# optuna

# %%
import optuna
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# 'Normal'과 'AbNormal'을 숫자로 변환
train_data['target'] = train_data['target'].map({'Normal': 0, 'AbNormal': 1})

# 스레드홀드 설정
THRESHOLD = 0.3

def objectiveAdaBoost(trial, x_tr, y_tr, x_val, y_val):
    # Base Estimator 설정
    base_estimator = DecisionTreeClassifier(
        max_depth=trial.suggest_int('max_depth', 1, 10),
        min_samples_split=trial.suggest_int('min_samples_split', 2, 20),
        min_samples_leaf=trial.suggest_int('min_samples_leaf', 1, 20),
        max_features=trial.suggest_float('max_features', 0.1, 1.0),
        random_state=RANDOM_STATE  # RANDOM_STATE 추가
    )

    # AdaBoost 모델 설정
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 500),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.3),
        'estimator': base_estimator,
        'random_state': RANDOM_STATE  # RANDOM_STATE 추가
    }
    
    model = AdaBoostClassifier(**param)
    model.fit(x_tr, y_tr)
    pred = model.predict(x_val)
    score = f1_score(y_val, pred, average="binary")
    
    return score

# 데이터셋 분할
x_train, x_val, y_train, y_val = train_test_split(
    train_data.drop("target", axis=1),
    train_data["target"],
    test_size=0.2,
    shuffle=True,
    random_state=RANDOM_STATE,
)

# 하이퍼 파라미터 튜닝
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
study.optimize(lambda trial: objectiveAdaBoost(trial, x_train, y_train, x_val, y_val), n_trials=200)

print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# [I 2024-08-26 08:33:59,493] A new study created in memory with name: no-name-be1869fd-3d7c-4756-986f-83c7ca8d2c0a
# [I 2024-08-26 08:34:13,962] Trial 0 finished with value: 0.15918367346938775 and parameters: {'max_depth': 2, 'min_samples_split': 14, 'min_samples_leaf': 8, 'max_features': 0.6515043233998075, 'n_estimators': 356, 'learning_rate': 0.20505647563755436}. Best is trial 0 with value: 0.15918367346938775.
# [I 2024-08-26 08:34:24,977] Trial 1 finished with value: 0.16697588126159557 and parameters: {'max_depth': 10, 'min_samples_split': 14, 'min_samples_leaf': 11, 'max_features': 0.1775586959624329, 'n_estimators': 224, 'learning_rate': 0.087842652266996}. Best is trial 1 with value: 0.16697588126159557.
# [I 2024-08-26 08:34:27,109] Trial 2 finished with value: 0.15289256198347106 and parameters: {'max_depth': 2, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': 0.5433318093400571, 'n_estimators': 59, 'learning_rate': 0.16829351079096685}. Best is trial 1 with value: 0.16697588126159557.
# [I 2024-08-26 08:34:36,549] Trial 3 finished with value: 0.15289256198347106 and parameters: {'max_depth': 1, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 0.7934957410298107, 'n_estimators': 321, 'learning_rate': 0.12579009272252506}. Best is trial 1 with value: 0.16697588126159557.
# [I 2024-08-26 08:35:00,428] Trial 4 finished with value: 0.16129032258064518 and parameters: {'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 0.8686759201566782, 'n_estimators': 271, 'learning_rate': 0.07563174172307575}. Best is trial 1 with value: 0.16697588126159557.
# [I 2024-08-26 08:35:16,823] Trial 5 finished with value: 0.1802721088435374 and parameters: {'max_depth': 8, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_features': 0.6796666797648274, 'n_estimators': 127, 'learning_rate': 0.21304650591551394}. Best is trial 5 with value: 0.1802721088435374.
# [I 2024-08-26 08:35:21,050] Trial 6 finished with value: 0.15289256198347106 and parameters: {'max_depth': 1, 'min_samples_split': 13, 'min_samples_leaf': 5, 'max_features': 0.3240457908570065, 'n_estimators': 229, 'learning_rate': 0.21444424052136832}. Best is trial 5 with value: 0.1802721088435374.
# [I 2024-08-26 08:35:34,298] Trial 7 finished with value: 0.16479400749063672 and parameters: {'max_depth': 8, 'min_samples_split': 19, 'min_samples_leaf': 5, 'max_features': 0.11167603254772318, 'n_estimators': 393, 'learning_rate': 0.05561598621222868}. Best is trial 5 with value: 0.1802721088435374.
# [I 2024-08-26 08:36:49,141] Trial 8 finished with value: 0.18115942028985507 and parameters: {'max_depth': 8, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': 0.908454487342815, 'n_estimators': 449, 'learning_rate': 0.29609513107459184}. Best is trial 8 with value: 0.18115942028985507.
# [I 2024-08-26 08:37:19,385] Trial 9 finished with value: 0.1808695652173913 and parameters: {'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 18, 'max_features': 0.5382699287779011, 'n_estimators': 271, 'learning_rate': 0.2719491131700392}. Best is trial 8 with value: 0.18115942028985507.
# [I 2024-08-26 08:38:28,036] Trial 10 finished with value: 0.21187800963081863 and parameters: {'max_depth': 6, 'min_samples_split': 20, 'min_samples_leaf': 14, 'max_features': 0.9888327062838588, 'n_estimators': 493, 'learning_rate': 0.28062919446006107}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:39:35,023] Trial 11 finished with value: 0.1732283464566929 and parameters: {'max_depth': 6, 'min_samples_split': 20, 'min_samples_leaf': 14, 'max_features': 0.9616467841550762, 'n_estimators': 497, 'learning_rate': 0.2915815009409174}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:40:43,426] Trial 12 finished with value: 0.1797752808988764 and parameters: {'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 14, 'max_features': 0.9933648395801151, 'n_estimators': 495, 'learning_rate': 0.2728244338922686}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:41:24,759] Trial 13 finished with value: 0.18543046357615892 and parameters: {'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 20, 'max_features': 0.8076356323401104, 'n_estimators': 423, 'learning_rate': 0.24643342825942408}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:41:57,537] Trial 14 finished with value: 0.1967799642218247 and parameters: {'max_depth': 4, 'min_samples_split': 17, 'min_samples_leaf': 20, 'max_features': 0.7661941126701977, 'n_estimators': 421, 'learning_rate': 0.25466193706938667}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:42:30,081] Trial 15 finished with value: 0.17726396917148363 and parameters: {'max_depth': 4, 'min_samples_split': 16, 'min_samples_leaf': 17, 'max_features': 0.7153933133842805, 'n_estimators': 443, 'learning_rate': 0.15255922242035252}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:42:47,799] Trial 16 finished with value: 0.2014388489208633 and parameters: {'max_depth': 4, 'min_samples_split': 16, 'min_samples_leaf': 14, 'max_features': 0.4243207989807375, 'n_estimators': 369, 'learning_rate': 0.24476689733221835}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:43:13,682] Trial 17 finished with value: 0.19439868204283361 and parameters: {'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 13, 'max_features': 0.4075104461021043, 'n_estimators': 343, 'learning_rate': 0.2350265191979877}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:43:28,043] Trial 18 finished with value: 0.17165668662674652 and parameters: {'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 16, 'max_features': 0.41252730788797903, 'n_estimators': 366, 'learning_rate': 0.18630406108031952}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:43:41,341] Trial 19 finished with value: 0.15448851774530273 and parameters: {'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 12, 'max_features': 0.27259402675195354, 'n_estimators': 314, 'learning_rate': 0.002546321907604704}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:44:17,946] Trial 20 finished with value: 0.17699115044247787 and parameters: {'max_depth': 7, 'min_samples_split': 18, 'min_samples_leaf': 15, 'max_features': 0.44905280625589966, 'n_estimators': 466, 'learning_rate': 0.1204435068609569}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:44:44,270] Trial 21 finished with value: 0.18928571428571428 and parameters: {'max_depth': 4, 'min_samples_split': 16, 'min_samples_leaf': 20, 'max_features': 0.6151112792917438, 'n_estimators': 406, 'learning_rate': 0.2376561057732266}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:45:08,079] Trial 22 finished with value: 0.19157088122605365 and parameters: {'max_depth': 3, 'min_samples_split': 18, 'min_samples_leaf': 18, 'max_features': 0.7507090900245822, 'n_estimators': 395, 'learning_rate': 0.26060928187408317}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:45:56,388] Trial 23 finished with value: 0.18885448916408668 and parameters: {'max_depth': 5, 'min_samples_split': 20, 'min_samples_leaf': 11, 'max_features': 0.8522174266289089, 'n_estimators': 473, 'learning_rate': 0.29511467011666376}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:46:17,520] Trial 24 finished with value: 0.18355640535372847 and parameters: {'max_depth': 3, 'min_samples_split': 16, 'min_samples_leaf': 16, 'max_features': 0.5876732109556406, 'n_estimators': 438, 'learning_rate': 0.24690741192760132}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:46:44,481] Trial 25 finished with value: 0.17107309486780714 and parameters: {'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 19, 'max_features': 0.47175744988291085, 'n_estimators': 379, 'learning_rate': 0.20015304754956909}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:47:10,589] Trial 26 finished with value: 0.19572953736654805 and parameters: {'max_depth': 4, 'min_samples_split': 19, 'min_samples_leaf': 13, 'max_features': 0.9259268695288517, 'n_estimators': 305, 'learning_rate': 0.2739640980138769}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:47:34,130] Trial 27 finished with value: 0.18360655737704917 and parameters: {'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 16, 'max_features': 0.30966835392093395, 'n_estimators': 427, 'learning_rate': 0.22557552016964605}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:48:18,617] Trial 28 finished with value: 0.18983050847457625 and parameters: {'max_depth': 5, 'min_samples_split': 12, 'min_samples_leaf': 18, 'max_features': 0.7870389867711554, 'n_estimators': 468, 'learning_rate': 0.17392976366362659}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:48:31,799] Trial 29 finished with value: 0.1494949494949495 and parameters: {'max_depth': 2, 'min_samples_split': 14, 'min_samples_leaf': 14, 'max_features': 0.6815597918051286, 'n_estimators': 350, 'learning_rate': 0.25523094583245437}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:48:46,138] Trial 30 finished with value: 0.1596806387225549 and parameters: {'max_depth': 3, 'min_samples_split': 15, 'min_samples_leaf': 10, 'max_features': 0.8550580311779048, 'n_estimators': 227, 'learning_rate': 0.18659524352654394}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:49:13,963] Trial 31 finished with value: 0.19855595667870038 and parameters: {'max_depth': 4, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_features': 0.9330507652147891, 'n_estimators': 310, 'learning_rate': 0.2810247474827179}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:49:31,737] Trial 32 finished with value: 0.18819188191881916 and parameters: {'max_depth': 4, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_features': 0.9824066801471376, 'n_estimators': 186, 'learning_rate': 0.2784049177737314}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:50:07,469] Trial 33 finished with value: 0.18092105263157895 and parameters: {'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_features': 0.9123027293502407, 'n_estimators': 335, 'learning_rate': 0.2626915787167443}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:50:23,226] Trial 34 finished with value: 0.1566265060240964 and parameters: {'max_depth': 2, 'min_samples_split': 15, 'min_samples_leaf': 9, 'max_features': 0.951408036348218, 'n_estimators': 298, 'learning_rate': 0.29876823093076443}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:51:08,440] Trial 35 finished with value: 0.19032258064516128 and parameters: {'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 15, 'max_features': 0.8851767219102726, 'n_estimators': 366, 'learning_rate': 0.22705190689126864}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:51:41,790] Trial 36 finished with value: 0.1930783242258652 and parameters: {'max_depth': 4, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': 0.8289867090132991, 'n_estimators': 414, 'learning_rate': 0.2002086951818001}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:51:53,339] Trial 37 finished with value: 0.18702290076335876 and parameters: {'max_depth': 3, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': 0.515411637092889, 'n_estimators': 287, 'learning_rate': 0.2799050572076249}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:52:22,980] Trial 38 finished with value: 0.17204301075268813 and parameters: {'max_depth': 10, 'min_samples_split': 19, 'min_samples_leaf': 5, 'max_features': 0.7634000188383663, 'n_estimators': 187, 'learning_rate': 0.12745790864929404}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:52:25,844] Trial 39 finished with value: 0.15320910973084886 and parameters: {'max_depth': 2, 'min_samples_split': 17, 'min_samples_leaf': 11, 'max_features': 0.7159114173925127, 'n_estimators': 68, 'learning_rate': 0.2191303920221704}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:52:33,481] Trial 40 finished with value: 0.1856060606060606 and parameters: {'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_features': 0.22659519935412425, 'n_estimators': 251, 'learning_rate': 0.26113577458983017}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:53:02,236] Trial 41 finished with value: 0.1930783242258652 and parameters: {'max_depth': 4, 'min_samples_split': 19, 'min_samples_leaf': 13, 'max_features': 0.9232843283305949, 'n_estimators': 320, 'learning_rate': 0.27795805352359143}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:53:29,241] Trial 42 finished with value: 0.18434782608695652 and parameters: {'max_depth': 5, 'min_samples_split': 19, 'min_samples_leaf': 15, 'max_features': 0.9993353399110314, 'n_estimators': 264, 'learning_rate': 0.2454842517836542}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:53:36,948] Trial 43 finished with value: 0.15289256198347106 and parameters: {'max_depth': 1, 'min_samples_split': 20, 'min_samples_leaf': 13, 'max_features': 0.935772826280464, 'n_estimators': 305, 'learning_rate': 0.2848856046000458}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:54:04,283] Trial 44 finished with value: 0.18629173989455186 and parameters: {'max_depth': 4, 'min_samples_split': 18, 'min_samples_leaf': 17, 'max_features': 0.8838683233325987, 'n_estimators': 391, 'learning_rate': 0.2683955782856665}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:54:13,364] Trial 45 finished with value: 0.17578125 and parameters: {'max_depth': 3, 'min_samples_split': 16, 'min_samples_leaf': 14, 'max_features': 0.3667231677492094, 'n_estimators': 331, 'learning_rate': 0.25089673739817275}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:55:01,103] Trial 46 finished with value: 0.15336463223787164 and parameters: {'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_features': 0.9511908730562766, 'n_estimators': 372, 'learning_rate': 0.29984492782626043}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:55:24,797] Trial 47 finished with value: 0.18213058419243988 and parameters: {'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 13, 'max_features': 0.8223345132547839, 'n_estimators': 252, 'learning_rate': 0.23212287590171488}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:55:49,350] Trial 48 finished with value: 0.20540540540540542 and parameters: {'max_depth': 4, 'min_samples_split': 20, 'min_samples_leaf': 3, 'max_features': 0.6185398198960693, 'n_estimators': 482, 'learning_rate': 0.20900383342904302}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:56:38,763] Trial 49 finished with value: 0.20205479452054795 and parameters: {'max_depth': 7, 'min_samples_split': 20, 'min_samples_leaf': 3, 'max_features': 0.6288471984543087, 'n_estimators': 499, 'learning_rate': 0.2120463460025196}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:57:34,085] Trial 50 finished with value: 0.16849816849816848 and parameters: {'max_depth': 8, 'min_samples_split': 20, 'min_samples_leaf': 3, 'max_features': 0.6379359638163351, 'n_estimators': 498, 'learning_rate': 0.20937985899167688}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:58:10,081] Trial 51 finished with value: 0.18652849740932642 and parameters: {'max_depth': 7, 'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': 0.5646041384029437, 'n_estimators': 480, 'learning_rate': 0.2379939217933389}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:58:45,275] Trial 52 finished with value: 0.20134228187919462 and parameters: {'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 1, 'max_features': 0.6715649426828082, 'n_estimators': 456, 'learning_rate': 0.14328456332540523}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 08:59:15,383] Trial 53 finished with value: 0.18538324420677363 and parameters: {'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 1, 'max_features': 0.5179992964750371, 'n_estimators': 458, 'learning_rate': 0.09491001987434669}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:00:06,238] Trial 54 finished with value: 0.1751824817518248 and parameters: {'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 0.6082324211004135, 'n_estimators': 483, 'learning_rate': 0.15062889257828338}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:00:46,047] Trial 55 finished with value: 0.17543859649122806 and parameters: {'max_depth': 7, 'min_samples_split': 20, 'min_samples_leaf': 2, 'max_features': 0.6680437397969261, 'n_estimators': 451, 'learning_rate': 0.13510701798844646}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:01:31,493] Trial 56 finished with value: 0.17059891107078037 and parameters: {'max_depth': 9, 'min_samples_split': 19, 'min_samples_leaf': 3, 'max_features': 0.5561159757989296, 'n_estimators': 436, 'learning_rate': 0.16327473185737268}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:02:07,677] Trial 57 finished with value: 0.17627118644067796 and parameters: {'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 4, 'max_features': 0.4820152617675083, 'n_estimators': 500, 'learning_rate': 0.1847551981591287}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:03:14,509] Trial 58 finished with value: 0.1764705882352941 and parameters: {'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 0.6960498236739514, 'n_estimators': 483, 'learning_rate': 0.1075345440484744}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:03:28,190] Trial 59 finished with value: 0.1856060606060606 and parameters: {'max_depth': 7, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_features': 0.12287619330679178, 'n_estimators': 457, 'learning_rate': 0.06064934016410556}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:03:53,342] Trial 60 finished with value: 0.20000000000000004 and parameters: {'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 3, 'max_features': 0.39721708065390376, 'n_estimators': 406, 'learning_rate': 0.1647361772387716}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:04:19,631] Trial 61 finished with value: 0.15959252971137522 and parameters: {'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 1, 'max_features': 0.42015322558332846, 'n_estimators': 402, 'learning_rate': 0.14030794756959244}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:04:41,793] Trial 62 finished with value: 0.18085106382978725 and parameters: {'max_depth': 5, 'min_samples_split': 19, 'min_samples_leaf': 3, 'max_features': 0.3600543010510123, 'n_estimators': 434, 'learning_rate': 0.1717890042320142}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:05:25,819] Trial 63 finished with value: 0.19420783645655879 and parameters: {'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 4, 'max_features': 0.6335337042528546, 'n_estimators': 475, 'learning_rate': 0.16012489128251234}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:06:16,172] Trial 64 finished with value: 0.19332161687170474 and parameters: {'max_depth': 7, 'min_samples_split': 17, 'min_samples_leaf': 1, 'max_features': 0.7345439801556184, 'n_estimators': 421, 'learning_rate': 0.21841449369838323}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:07:03,934] Trial 65 finished with value: 0.1751824817518248 and parameters: {'max_depth': 8, 'min_samples_split': 19, 'min_samples_leaf': 6, 'max_features': 0.5859437489461795, 'n_estimators': 448, 'learning_rate': 0.18706671931052143}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:07:31,032] Trial 66 finished with value: 0.1724709784411277 and parameters: {'max_depth': 5, 'min_samples_split': 20, 'min_samples_leaf': 2, 'max_features': 0.4558664255832534, 'n_estimators': 465, 'learning_rate': 0.19631670119798986}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:07:50,949] Trial 67 finished with value: 0.15670103092783505 and parameters: {'max_depth': 7, 'min_samples_split': 18, 'min_samples_leaf': 5, 'max_features': 0.28910648328906463, 'n_estimators': 383, 'learning_rate': 0.0029196851491247455}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:08:27,185] Trial 68 finished with value: 0.15202702702702703 and parameters: {'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.49390710261494675, 'n_estimators': 487, 'learning_rate': 0.28788687835019305}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:08:49,170] Trial 69 finished with value: 0.1839863713798978 and parameters: {'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 8, 'max_features': 0.3853629602943675, 'n_estimators': 415, 'learning_rate': 0.20790620704229024}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:08:58,756] Trial 70 finished with value: 0.19405940594059407 and parameters: {'max_depth': 3, 'min_samples_split': 18, 'min_samples_leaf': 4, 'max_features': 0.2494493017818516, 'n_estimators': 352, 'learning_rate': 0.11635443827192148}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:09:29,851] Trial 71 finished with value: 0.19478260869565217 and parameters: {'max_depth': 4, 'min_samples_split': 16, 'min_samples_leaf': 11, 'max_features': 0.781164381603566, 'n_estimators': 405, 'learning_rate': 0.26836449747698804}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:10:05,808] Trial 72 finished with value: 0.1642512077294686 and parameters: {'max_depth': 5, 'min_samples_split': 19, 'min_samples_leaf': 20, 'max_features': 0.6684216955298089, 'n_estimators': 445, 'learning_rate': 0.24127196201233242}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:10:33,985] Trial 73 finished with value: 0.19343065693430658 and parameters: {'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 17, 'max_features': 0.5888499985760527, 'n_estimators': 466, 'learning_rate': 0.17729254497640845}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:11:10,192] Trial 74 finished with value: 0.19465648854961834 and parameters: {'max_depth': 3, 'min_samples_split': 17, 'min_samples_leaf': 19, 'max_features': 0.9766388222775667, 'n_estimators': 492, 'learning_rate': 0.25711633958787916}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:11:50,594] Trial 75 finished with value: 0.1711568938193344 and parameters: {'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 15, 'max_features': 0.6506974902796957, 'n_estimators': 428, 'learning_rate': 0.2240409974589887}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:12:12,307] Trial 76 finished with value: 0.1954624781849913 and parameters: {'max_depth': 4, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 0.5257657233024539, 'n_estimators': 390, 'learning_rate': 0.25162088352375717}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:12:43,950] Trial 77 finished with value: 0.18566775244299677 and parameters: {'max_depth': 5, 'min_samples_split': 19, 'min_samples_leaf': 16, 'max_features': 0.7109428798871572, 'n_estimators': 364, 'learning_rate': 0.2873113210265371}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:13:13,220] Trial 78 finished with value: 0.1705685618729097 and parameters: {'max_depth': 7, 'min_samples_split': 20, 'min_samples_leaf': 14, 'max_features': 0.3311738815373744, 'n_estimators': 471, 'learning_rate': 0.2672842533396626}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:13:37,621] Trial 79 finished with value: 0.20306513409961682 and parameters: {'max_depth': 3, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 0.7423300149136958, 'n_estimators': 416, 'learning_rate': 0.19391173784186075}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:13:55,891] Trial 80 finished with value: 0.17600000000000002 and parameters: {'max_depth': 3, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_features': 0.4393169172469476, 'n_estimators': 456, 'learning_rate': 0.14252843850003666}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:14:13,726] Trial 81 finished with value: 0.15605749486652978 and parameters: {'max_depth': 2, 'min_samples_split': 16, 'min_samples_leaf': 5, 'max_features': 0.751507321701635, 'n_estimators': 414, 'learning_rate': 0.15783440276464905}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:14:47,976] Trial 82 finished with value: 0.19855595667870038 and parameters: {'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': 0.8067190482587052, 'n_estimators': 433, 'learning_rate': 0.19095759411992788}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:15:18,427] Trial 83 finished with value: 0.196078431372549 and parameters: {'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': 0.6946749362877904, 'n_estimators': 435, 'learning_rate': 0.19883831281220593}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:16:01,087] Trial 84 finished with value: 0.1733102253032929 and parameters: {'max_depth': 5, 'min_samples_split': 14, 'min_samples_leaf': 3, 'max_features': 0.8043888501809695, 'n_estimators': 444, 'learning_rate': 0.1796509162133506}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:16:24,951] Trial 85 finished with value: 0.17509727626459146 and parameters: {'max_depth': 3, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': 0.892440227106106, 'n_estimators': 340, 'learning_rate': 0.1936098021228844}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:16:56,949] Trial 86 finished with value: 0.16195856873822975 and parameters: {'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 1, 'max_features': 0.8570628276817909, 'n_estimators': 379, 'learning_rate': 0.16698544392722411}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:17:32,529] Trial 87 finished with value: 0.18211382113821137 and parameters: {'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 2, 'max_features': 0.6118958281140263, 'n_estimators': 398, 'learning_rate': 0.21246665368128553}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:17:55,447] Trial 88 finished with value: 0.15821501014198783 and parameters: {'max_depth': 2, 'min_samples_split': 15, 'min_samples_leaf': 4, 'max_features': 0.823619830025818, 'n_estimators': 491, 'learning_rate': 0.230417619115004}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:18:09,767] Trial 89 finished with value: 0.1913696060037523 and parameters: {'max_depth': 4, 'min_samples_split': 19, 'min_samples_leaf': 3, 'max_features': 0.7246516023210804, 'n_estimators': 198, 'learning_rate': 0.19319893876228156}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:18:44,409] Trial 90 finished with value: 0.19696969696969696 and parameters: {'max_depth': 3, 'min_samples_split': 18, 'min_samples_leaf': 14, 'max_features': 0.9625456412687062, 'n_estimators': 478, 'learning_rate': 0.22159582404392764}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:19:18,764] Trial 91 finished with value: 0.19659735349716445 and parameters: {'max_depth': 3, 'min_samples_split': 18, 'min_samples_leaf': 14, 'max_features': 0.9609642351215071, 'n_estimators': 477, 'learning_rate': 0.21868715475713602}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:19:52,588] Trial 92 finished with value: 0.1849056603773585 and parameters: {'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 13, 'max_features': 0.997139045142042, 'n_estimators': 466, 'learning_rate': 0.20581203302551287}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:20:27,281] Trial 93 finished with value: 0.18702290076335876 and parameters: {'max_depth': 3, 'min_samples_split': 19, 'min_samples_leaf': 15, 'max_features': 0.9416381506923885, 'n_estimators': 500, 'learning_rate': 0.2030437552990882}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:21:05,800] Trial 94 finished with value: 0.1758241758241758 and parameters: {'max_depth': 4, 'min_samples_split': 18, 'min_samples_leaf': 2, 'max_features': 0.970098230537679, 'n_estimators': 426, 'learning_rate': 0.18291021447063355}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:21:28,144] Trial 95 finished with value: 0.1606425702811245 and parameters: {'max_depth': 2, 'min_samples_split': 16, 'min_samples_leaf': 14, 'max_features': 0.8958198466139394, 'n_estimators': 461, 'learning_rate': 0.22269681289132168}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:22:10,995] Trial 96 finished with value: 0.19365609348914858 and parameters: {'max_depth': 6, 'min_samples_split': 20, 'min_samples_leaf': 7, 'max_features': 0.6382465920977227, 'n_estimators': 482, 'learning_rate': 0.24325466336436932}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:22:56,848] Trial 97 finished with value: 0.18342151675485005 and parameters: {'max_depth': 5, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_features': 0.8715094732461588, 'n_estimators': 452, 'learning_rate': 0.14548184865221953}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:23:40,383] Trial 98 finished with value: 0.18612521150592215 and parameters: {'max_depth': 7, 'min_samples_split': 17, 'min_samples_leaf': 13, 'max_features': 0.6755318113923566, 'n_estimators': 411, 'learning_rate': 0.16965439728197806}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:24:05,273] Trial 99 finished with value: 0.15955473098330242 and parameters: {'max_depth': 4, 'min_samples_split': 18, 'min_samples_leaf': 8, 'max_features': 0.9151853901493219, 'n_estimators': 286, 'learning_rate': 0.2159736298768597}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:24:30,836] Trial 100 finished with value: 0.17821782178217824 and parameters: {'max_depth': 3, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': 0.7446633306141232, 'n_estimators': 441, 'learning_rate': 0.19058028081311174}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:25:02,514] Trial 101 finished with value: 0.1967799642218247 and parameters: {'max_depth': 4, 'min_samples_split': 16, 'min_samples_leaf': 12, 'max_features': 0.7783581655993195, 'n_estimators': 419, 'learning_rate': 0.23145723632250526}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:25:05,667] Trial 102 finished with value: 0.15289256198347106 and parameters: {'max_depth': 1, 'min_samples_split': 17, 'min_samples_leaf': 16, 'max_features': 0.8431291156061348, 'n_estimators': 107, 'learning_rate': 0.2776513825343899}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:25:40,707] Trial 103 finished with value: 0.1878980891719745 and parameters: {'max_depth': 5, 'min_samples_split': 19, 'min_samples_leaf': 11, 'max_features': 0.569444720218012, 'n_estimators': 490, 'learning_rate': 0.23596811517749533}. Best is trial 10 with value: 0.21187800963081863.
# [I 2024-08-26 09:26:13,367] Trial 104 finished with value: 0.21328671328671328 and parameters: {'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 17, 'max_features': 0.7009684986301644, 'n_estimators': 473, 'learning_rate': 0.25112141981467107}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:26:59,321] Trial 105 finished with value: 0.19589257503949445 and parameters: {'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 19, 'max_features': 0.6919194190512564, 'n_estimators': 472, 'learning_rate': 0.29249796327151556}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:27:31,635] Trial 106 finished with value: 0.18975332068311196 and parameters: {'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_features': 0.6538381013078141, 'n_estimators': 482, 'learning_rate': 0.12943807499999113}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:27:55,516] Trial 107 finished with value: 0.18074656188605107 and parameters: {'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 15, 'max_features': 0.629659738108414, 'n_estimators': 458, 'learning_rate': 0.15461583913163823}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:28:12,711] Trial 108 finished with value: 0.18867924528301888 and parameters: {'max_depth': 5, 'min_samples_split': 18, 'min_samples_leaf': 5, 'max_features': 0.39094051073802966, 'n_estimators': 327, 'learning_rate': 0.21320240309178806}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:28:56,257] Trial 109 finished with value: 0.18243243243243243 and parameters: {'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 2, 'max_features': 0.7109835898618747, 'n_estimators': 427, 'learning_rate': 0.2834240157586574}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:29:24,501] Trial 110 finished with value: 0.18671454219030523 and parameters: {'max_depth': 4, 'min_samples_split': 19, 'min_samples_leaf': 18, 'max_features': 0.5979201281128379, 'n_estimators': 449, 'learning_rate': 0.2623293199836514}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:29:58,406] Trial 111 finished with value: 0.1757469244288225 and parameters: {'max_depth': 4, 'min_samples_split': 16, 'min_samples_leaf': 17, 'max_features': 0.781003641055728, 'n_estimators': 437, 'learning_rate': 0.2555442387904257}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:30:30,638] Trial 112 finished with value: 0.2031523642732049 and parameters: {'max_depth': 4, 'min_samples_split': 17, 'min_samples_leaf': 19, 'max_features': 0.8003620852282922, 'n_estimators': 406, 'learning_rate': 0.249538260688214}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:31:00,852] Trial 113 finished with value: 0.20567375886524822 and parameters: {'max_depth': 4, 'min_samples_split': 17, 'min_samples_leaf': 18, 'max_features': 0.7988874786303538, 'n_estimators': 387, 'learning_rate': 0.24723691077487245}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:31:31,295] Trial 114 finished with value: 0.19683655536028116 and parameters: {'max_depth': 4, 'min_samples_split': 17, 'min_samples_leaf': 18, 'max_features': 0.8022971850920081, 'n_estimators': 390, 'learning_rate': 0.2711912784454763}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:31:59,449] Trial 115 finished with value: 0.19163763066202094 and parameters: {'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 19, 'max_features': 0.7611550203317281, 'n_estimators': 372, 'learning_rate': 0.24271194888372286}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:32:35,459] Trial 116 finished with value: 0.19934640522875818 and parameters: {'max_depth': 5, 'min_samples_split': 16, 'min_samples_leaf': 20, 'max_features': 0.8426269920640284, 'n_estimators': 361, 'learning_rate': 0.25157714337918013}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:33:09,999] Trial 117 finished with value: 0.1711568938193344 and parameters: {'max_depth': 5, 'min_samples_split': 16, 'min_samples_leaf': 20, 'max_features': 0.8373117037174186, 'n_estimators': 357, 'learning_rate': 0.24668600225952217}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:33:46,051] Trial 118 finished with value: 0.16039279869067102 and parameters: {'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 19, 'max_features': 0.730957336640791, 'n_estimators': 346, 'learning_rate': 0.2504304774452659}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:34:19,928] Trial 119 finished with value: 0.19365079365079363 and parameters: {'max_depth': 5, 'min_samples_split': 16, 'min_samples_leaf': 18, 'max_features': 0.7620812214274596, 'n_estimators': 365, 'learning_rate': 0.2573831115198947}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:34:38,986] Trial 120 finished with value: 0.20428336079077428 and parameters: {'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 17, 'max_features': 0.3428024435401598, 'n_estimators': 405, 'learning_rate': 0.26288258184313146}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:34:57,167] Trial 121 finished with value: 0.18635607321131445 and parameters: {'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 17, 'max_features': 0.3381903838154886, 'n_estimators': 384, 'learning_rate': 0.26638373157221146}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:35:14,950] Trial 122 finished with value: 0.2052117263843648 and parameters: {'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 18, 'max_features': 0.30358953506858816, 'n_estimators': 401, 'learning_rate': 0.2778134276727685}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:35:33,194] Trial 123 finished with value: 0.1839080459770115 and parameters: {'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 19, 'max_features': 0.30255168009591354, 'n_estimators': 409, 'learning_rate': 0.23791062902613666}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:35:50,998] Trial 124 finished with value: 0.16216216216216214 and parameters: {'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 18, 'max_features': 0.2633126870293196, 'n_estimators': 402, 'learning_rate': 0.27456239092400375}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:36:11,205] Trial 125 finished with value: 0.17275747508305647 and parameters: {'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 18, 'max_features': 0.3663989439151924, 'n_estimators': 396, 'learning_rate': 0.2630583533041712}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:36:29,288] Trial 126 finished with value: 0.20068027210884354 and parameters: {'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 19, 'max_features': 0.34023172793785794, 'n_estimators': 379, 'learning_rate': 0.2283570735536702}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:36:44,915] Trial 127 finished with value: 0.17235772357723578 and parameters: {'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 17, 'max_features': 0.21807089961079495, 'n_estimators': 377, 'learning_rate': 0.23599769363821174}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:37:03,326] Trial 128 finished with value: 0.18307426597582038 and parameters: {'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 19, 'max_features': 0.3415797875093966, 'n_estimators': 387, 'learning_rate': 0.24608704227999112}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:37:32,960] Trial 129 finished with value: 0.175787728026534 and parameters: {'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 16, 'max_features': 0.41973002477878013, 'n_estimators': 400, 'learning_rate': 0.22945176589103172}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:37:52,114] Trial 130 finished with value: 0.1900161030595813 and parameters: {'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 17, 'max_features': 0.31613159876889935, 'n_estimators': 373, 'learning_rate': 0.22631133324320796}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:38:10,908] Trial 131 finished with value: 0.18892508143322476 and parameters: {'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 20, 'max_features': 0.35096559448917997, 'n_estimators': 392, 'learning_rate': 0.25570804921017504}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:38:33,045] Trial 132 finished with value: 0.1717171717171717 and parameters: {'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 20, 'max_features': 0.38951616366775715, 'n_estimators': 410, 'learning_rate': 0.25111478513750524}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:38:48,400] Trial 133 finished with value: 0.20797227036395147 and parameters: {'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 19, 'max_features': 0.28930469965289946, 'n_estimators': 361, 'learning_rate': 0.2595955419590801}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:39:03,552] Trial 134 finished with value: 0.20422535211267603 and parameters: {'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 18, 'max_features': 0.29137864118543105, 'n_estimators': 417, 'learning_rate': 0.27573726689135875}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:39:18,700] Trial 135 finished with value: 0.1762589928057554 and parameters: {'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 18, 'max_features': 0.2872342210105158, 'n_estimators': 418, 'learning_rate': 0.27077180716901933}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:39:34,154] Trial 136 finished with value: 0.1993006993006993 and parameters: {'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 19, 'max_features': 0.22699745815602856, 'n_estimators': 490, 'learning_rate': 0.2785830987569018}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:39:47,100] Trial 137 finished with value: 0.17883211678832117 and parameters: {'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 18, 'max_features': 0.24512770261184907, 'n_estimators': 384, 'learning_rate': 0.2635397100932321}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:40:00,522] Trial 138 finished with value: 0.18579234972677594 and parameters: {'max_depth': 4, 'min_samples_split': 11, 'min_samples_leaf': 17, 'max_features': 0.29068940657470976, 'n_estimators': 373, 'learning_rate': 0.2874794096695322}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:40:23,095] Trial 139 finished with value: 0.203125 and parameters: {'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 19, 'max_features': 0.31736706310947993, 'n_estimators': 498, 'learning_rate': 0.2958740934642144}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:40:39,903] Trial 140 finished with value: 0.19736842105263155 and parameters: {'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 18, 'max_features': 0.1925372132671072, 'n_estimators': 500, 'learning_rate': 0.2961407986038368}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:40:59,876] Trial 141 finished with value: 0.19273301737756715 and parameters: {'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 19, 'max_features': 0.27677373578480946, 'n_estimators': 472, 'learning_rate': 0.27316328980653104}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:41:19,113] Trial 142 finished with value: 0.20192307692307696 and parameters: {'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 19, 'max_features': 0.2545875580110502, 'n_estimators': 488, 'learning_rate': 0.281776042739662}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:41:37,890] Trial 143 finished with value: 0.18339100346020762 and parameters: {'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 16, 'max_features': 0.31231535524533127, 'n_estimators': 490, 'learning_rate': 0.2934500131211201}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:41:56,837] Trial 144 finished with value: 0.20454545454545453 and parameters: {'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 18, 'max_features': 0.2674395399305697, 'n_estimators': 482, 'learning_rate': 0.283654995069568}. Best is trial 104 with value: 0.21328671328671328.
# [I 2024-08-26 09:42:15,955] Trial 145 finished with value: 0.18619582664526482 and parameters: {'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 18, 'max_features': 0.2625277820093478, 'n_estimators': 484, 'learning_rate': 0.28191393090076167}. Best is trial 104 with value: 0.21328671328671328.
# [W 2024-08-26 09:42:27,404] Trial 146 failed with parameters: {'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 19, 'max_features': 0.24929684550037584, 'n_estimators': 500, 'learning_rate': 0.29860099077170354} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/elicer/.local/lib/python3.10/site-packages/optuna/study/_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_191/3297321235.py", line 49, in <lambda>
#     study.optimize(lambda trial: objectiveAdaBoost(trial, x_train, y_train, x_val, y_val), n_trials=200)
#   File "/tmp/ipykernel_191/3297321235.py", line 32, in objectiveAdaBoost
#     model.fit(x_tr, y_tr)
#   File "/home/elicer/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py", line 162, in fit
#     sample_weight, estimator_weight, estimator_error = self._boost(
#   File "/home/elicer/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py", line 569, in _boost
#     return self._boost_real(iboost, X, y, sample_weight, random_state)
#   File "/home/elicer/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py", line 578, in _boost_real
#     estimator.fit(X, y, sample_weight=sample_weight)
#   File "/home/elicer/.local/lib/python3.10/site-packages/sklearn/tree/_classes.py", line 889, in fit
#     super().fit(
#   File "/home/elicer/.local/lib/python3.10/site-packages/sklearn/tree/_classes.py", line 379, in fit
#     builder.build(self.tree_, X, y, sample_weight)
# KeyboardInterrupt
# [W 2024-08-26 09:42:27,423] Trial 146 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 49
#      47 # 하이퍼 파라미터 튜닝
#      48 study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# ---> 49 study.optimize(lambda trial: objectiveAdaBoost(trial, x_train, y_train, x_val, y_val), n_trials=200)
#      51 print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
#
# File ~/.local/lib/python3.10/site-packages/optuna/study/study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File ~/.local/lib/python3.10/site-packages/optuna/study/_optimize.py:62, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      60 try:
#      61     if n_jobs == 1:
# ---> 62         _optimize_sequential(
#      63             study,
#      64             func,
#      65             n_trials,
#      66             timeout,
#      67             catch,
#      68             callbacks,
#      69             gc_after_trial,
#      70             reseed_sampler_rng=False,
#      71             time_start=None,
#      72             progress_bar=progress_bar,
#      73         )
#      74     else:
#      75         if n_jobs == -1:
#
# File ~/.local/lib/python3.10/site-packages/optuna/study/_optimize.py:159, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     156         break
#     158 try:
# --> 159     frozen_trial = _run_trial(study, func, catch)
#     160 finally:
#     161     # The following line mitigates memory problems that can be occurred in some
#     162     # environments (e.g., services that use computing containers such as GitHub Actions).
#     163     # Please refer to the following PR for further details:
#     164     # https://github.com/optuna/optuna/pull/325.
#     165     if gc_after_trial:
#
# File ~/.local/lib/python3.10/site-packages/optuna/study/_optimize.py:247, in _run_trial(study, func, catch)
#     240         assert False, "Should not reach."
#     242 if (
#     243     frozen_trial.state == TrialState.FAIL
#     244     and func_err is not None
#     245     and not isinstance(func_err, catch)
#     246 ):
# --> 247     raise func_err
#     248 return frozen_trial
#
# File ~/.local/lib/python3.10/site-packages/optuna/study/_optimize.py:196, in _run_trial(study, func, catch)
#     194 with get_heartbeat_thread(trial._trial_id, study._storage):
#     195     try:
# --> 196         value_or_values = func(trial)
#     197     except exceptions.TrialPruned as e:
#     198         # TODO(mamu): Handle multi-objective cases.
#     199         state = TrialState.PRUNED
#
# Cell In[3], line 49, in <lambda>(trial)
#      47 # 하이퍼 파라미터 튜닝
#      48 study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# ---> 49 study.optimize(lambda trial: objectiveAdaBoost(trial, x_train, y_train, x_val, y_val), n_trials=200)
#      51 print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
#
# Cell In[3], line 32, in objectiveAdaBoost(trial, x_tr, y_tr, x_val, y_val)
#      24 param = {
#      25     'n_estimators': trial.suggest_int('n_estimators', 50, 500),
#      26     'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.3),
#      27     'estimator': base_estimator,
#      28     'random_state': RANDOM_STATE  # RANDOM_STATE 추가
#      29 }
#      31 model = AdaBoostClassifier(**param)
# ---> 32 model.fit(x_tr, y_tr)
#      33 pred = model.predict(x_val)
#      34 score = f1_score(y_val, pred, average="binary")
#
# File ~/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:162, in BaseWeightBoosting.fit(self, X, y, sample_weight)
#     159 sample_weight[zero_weight_mask] = 0.0
#     161 # Boosting step
# --> 162 sample_weight, estimator_weight, estimator_error = self._boost(
#     163     iboost, X, y, sample_weight, random_state
#     164 )
#     166 # Early termination
#     167 if sample_weight is None:
#
# File ~/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:569, in AdaBoostClassifier._boost(self, iboost, X, y, sample_weight, random_state)
#     530 """Implement a single boost.
#     531
#     532 Perform a single boost according to the real multi-class SAMME.R
#    (...)
#     566     If None then boosting has terminated early.
#     567 """
#     568 if self.algorithm == "SAMME.R":
# --> 569     return self._boost_real(iboost, X, y, sample_weight, random_state)
#     571 else:  # elif self.algorithm == "SAMME":
#     572     return self._boost_discrete(iboost, X, y, sample_weight, random_state)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:578, in AdaBoostClassifier._boost_real(self, iboost, X, y, sample_weight, random_state)
#     575 """Implement a single boost using the SAMME.R real algorithm."""
#     576 estimator = self._make_estimator(random_state=random_state)
# --> 578 estimator.fit(X, y, sample_weight=sample_weight)
#     580 y_predict_proba = estimator.predict_proba(X)
#     582 if iboost == 0:
#
# File ~/.local/lib/python3.10/site-packages/sklearn/tree/_classes.py:889, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     859 def fit(self, X, y, sample_weight=None, check_input=True):
#     860     """Build a decision tree classifier from the training set (X, y).
#     861
#     862     Parameters
#    (...)
#     886         Fitted estimator.
#     887     """
# --> 889     super().fit(
#     890         X,
#     891         y,
#     892         sample_weight=sample_weight,
#     893         check_input=check_input,
#     894     )
#     895     return self
#
# File ~/.local/lib/python3.10/site-packages/sklearn/tree/_classes.py:379, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     368 else:
#     369     builder = BestFirstTreeBuilder(
#     370         splitter,
#     371         min_samples_split,
#    (...)
#     376         self.min_impurity_decrease,
#     377     )
# --> 379 builder.build(self.tree_, X, y, sample_weight)
#     381 if self.n_outputs_ == 1 and is_classifier(self):
#     382     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %% [markdown]
# Trial 104 finished with value: 0.21328671328671328
# parameters: {'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 17, 'max_features': 0.7009684986301644,
# 'n_estimators': 473, 'learning_rate': 0.25112141981467107}.
