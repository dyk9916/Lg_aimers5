# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ## 1. 데이터 불러오기

# %% [markdown]
# ### 필수 라이브러리

# %%
import os
from pprint import pprint

import optuna
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)

def get_clf_eval(y_test, y_pred_proba, threshold=0.5):
    # 확률을 기준으로 예측 레이블 생성
    y_pred = (y_pred_proba >= threshold).astype(int)  # 0.5 이상의 확률을 양성으로 간주

    confusion = confusion_matrix(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    print("Confusion Matrix:\n", confusion)
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")

# %% [markdown]
# ### 데이터 읽어오기

# %%
RANDOM_STATE = 110

# csv 불러오기
train_data = pd.read_csv('C:/Users/KimDongyoung/Desktop/git_LGaimers5/Lg_aimers5/data/train_data_0825.csv')
test_data  = pd.read_csv('C:/Users/KimDongyoung/Desktop/git_LGaimers5/Lg_aimers5/data/train_data_0825.csv')

# %% [markdown]
# ---

# %% [markdown]
# ## 데이터 분할

# %%
df_train, df_val = train_test_split(
    train_data,
    test_size=0.2,
    stratify=train_data["target"],
    shuffle=True,
    random_state=RANDOM_STATE,
)

def print_stats(df: pd.DataFrame):
    num_normal = len(df[df["target"] == "Normal"])
    num_abnormal = len(df[df["target"] == "AbNormal"])

    print(f"  Total: Normal: {num_normal}, AbNormal: {num_abnormal}" + f" ratio: {num_abnormal/num_normal}")


# Print statistics
print(f"  \tAbnormal\tNormal")
print_stats(df_train)
print_stats(df_val)
# Out:
#   	Abnormal	Normal
#   Total: Normal: 30524, AbNormal: 1880 ratio: 0.06159087930808544
#   Total: Normal: 7632, AbNormal: 470 ratio: 0.061582809224318656

# %% [markdown]
# ## 3. 모델 학습

# %% [markdown]
# ### 모델 정의

# %% [markdown]
# optuna

# %%
import optuna
from sklearn.ensemble import ExtraTreesClassifier 

# # 'Normal'과 'AbNormal'을 숫자로 변환
# train_data['target'] = train_data['target'].map({'Normal': 0, 'AbNormal': 1})

# # 스레드홀드 설정
# THRESHOLD = 0.3

# def objectiveExtraTreesClassifier(trial, x_tr, y_tr, x_val, y_val):
#     param = {
#         'n_estimators': trial.suggest_int('n_estimators', 1000, 3000)
#         , 'max_depth': trial.suggest_int('max_depth', 2, 60)
#         , 'min_samples_split': trial.suggest_int('min_samples_split', 2, 16)
#         , 'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 7)
#         , 'criterion': trial.suggest_categorical('criterion', ['entropy'])
#         , 'bootstrap': trial.suggest_categorical('bootstrap', [False])
#         , 'random_state': RANDOM_STATE
#     }
    
#     model = ExtraTreesClassifier(**param)
#     model.fit(x_tr, y_tr)
#     pred = model.predict(x_val)
#     score = f1_score(y_val, pred, average="binary")
    
#     return score

# # 데이터셋 분할
# x_train, x_val, y_train, y_val = train_test_split(
#     train_data.drop("target", axis=1),
#     train_data["target"],
#     test_size=0.2,
#     shuffle=True,
#     random_state=RANDOM_STATE,
# )

# # 하이퍼 파라미터 튜닝
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# study.optimize(lambda trial: objectiveExtraTreesClassifier(trial, x_train, y_train, x_val, y_val), n_trials=300)

# print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# [I 2024-08-25 20:18:43,728] A new study created in memory with name: no-name-8c3d715b-a673-4b13-b3d2-aa49111d6feb
# [I 2024-08-25 20:19:16,394] Trial 0 finished with value: 0.16216216216216214 and parameters: {'n_estimators': 1232, 'max_depth': 40, 'min_samples_split': 7, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.16216216216216214.
# [I 2024-08-25 20:20:18,251] Trial 1 finished with value: 0.15833333333333333 and parameters: {'n_estimators': 2359, 'max_depth': 42, 'min_samples_split': 16, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.16216216216216214.
# [I 2024-08-25 20:20:37,404] Trial 2 finished with value: 0.15448851774530273 and parameters: {'n_estimators': 2026, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.16216216216216214.
# [I 2024-08-25 20:20:42,489] Trial 3 finished with value: 0.0 and parameters: {'n_estimators': 1270, 'max_depth': 2, 'min_samples_split': 8, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.16216216216216214.
# [I 2024-08-25 20:21:11,045] Trial 4 finished with value: 0.1810699588477366 and parameters: {'n_estimators': 1042, 'max_depth': 35, 'min_samples_split': 3, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 4 with value: 0.1810699588477366.
# [I 2024-08-25 20:21:56,413] Trial 5 finished with value: 0.17355371900826447 and parameters: {'n_estimators': 1628, 'max_depth': 47, 'min_samples_split': 11, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 4 with value: 0.1810699588477366.
# [I 2024-08-25 20:22:04,951] Trial 6 finished with value: 0.053097345132743355 and parameters: {'n_estimators': 1670, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 6, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 4 with value: 0.1810699588477366.
# [I 2024-08-25 20:22:42,947] Trial 7 finished with value: 0.15448851774530273 and parameters: {'n_estimators': 1982, 'max_depth': 16, 'min_samples_split': 13, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 4 with value: 0.1810699588477366.
# [I 2024-08-25 20:23:28,322] Trial 8 finished with value: 0.16216216216216214 and parameters: {'n_estimators': 1771, 'max_depth': 40, 'min_samples_split': 4, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 4 with value: 0.1810699588477366.
# [I 2024-08-25 20:24:01,943] Trial 9 finished with value: 0.1806981519507187 and parameters: {'n_estimators': 1080, 'max_depth': 37, 'min_samples_split': 5, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 4 with value: 0.1810699588477366.
# [I 2024-08-25 20:25:47,004] Trial 10 finished with value: 0.19459459459459458 and parameters: {'n_estimators': 2694, 'max_depth': 60, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.19459459459459458.
# [I 2024-08-25 20:27:42,587] Trial 11 finished with value: 0.19459459459459458 and parameters: {'n_estimators': 2966, 'max_depth': 59, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.19459459459459458.
# [I 2024-08-25 20:29:38,776] Trial 12 finished with value: 0.19459459459459458 and parameters: {'n_estimators': 2995, 'max_depth': 59, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 10 with value: 0.19459459459459458.
# [I 2024-08-25 20:31:23,064] Trial 13 finished with value: 0.19880715705765406 and parameters: {'n_estimators': 2910, 'max_depth': 58, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 13 with value: 0.19880715705765406.
# [I 2024-08-25 20:32:58,137] Trial 14 finished with value: 0.19880715705765406 and parameters: {'n_estimators': 2605, 'max_depth': 49, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 13 with value: 0.19880715705765406.
# [I 2024-08-25 20:34:20,052] Trial 15 finished with value: 0.1810699588477366 and parameters: {'n_estimators': 2510, 'max_depth': 52, 'min_samples_split': 6, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 13 with value: 0.19880715705765406.
# [I 2024-08-25 20:35:25,841] Trial 16 finished with value: 0.15448851774530273 and parameters: {'n_estimators': 2683, 'max_depth': 25, 'min_samples_split': 10, 'min_samples_leaf': 7, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 13 with value: 0.19880715705765406.
# [I 2024-08-25 20:37:02,345] Trial 17 finished with value: 0.1810699588477366 and parameters: {'n_estimators': 2300, 'max_depth': 52, 'min_samples_split': 5, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 13 with value: 0.19880715705765406.
# [I 2024-08-25 20:39:02,590] Trial 18 finished with value: 0.19066937119675456 and parameters: {'n_estimators': 2724, 'max_depth': 26, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 13 with value: 0.19880715705765406.
# [I 2024-08-25 20:40:42,631] Trial 19 finished with value: 0.1810699588477366 and parameters: {'n_estimators': 2825, 'max_depth': 49, 'min_samples_split': 12, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 13 with value: 0.19880715705765406.
# [I 2024-08-25 20:42:08,834] Trial 20 finished with value: 0.1810699588477366 and parameters: {'n_estimators': 2484, 'max_depth': 54, 'min_samples_split': 9, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 13 with value: 0.19880715705765406.
# [I 2024-08-25 20:44:04,832] Trial 21 finished with value: 0.19921875000000003 and parameters: {'n_estimators': 2606, 'max_depth': 60, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 20:45:40,568] Trial 22 finished with value: 0.19880715705765406 and parameters: {'n_estimators': 2207, 'max_depth': 46, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 20:47:20,335] Trial 23 finished with value: 0.1806981519507187 and parameters: {'n_estimators': 2532, 'max_depth': 56, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 20:49:26,237] Trial 24 finished with value: 0.19678714859437751 and parameters: {'n_estimators': 2913, 'max_depth': 45, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 20:51:11,528] Trial 25 finished with value: 0.18442622950819673 and parameters: {'n_estimators': 2634, 'max_depth': 55, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 20:53:12,022] Trial 26 finished with value: 0.1971830985915493 and parameters: {'n_estimators': 2807, 'max_depth': 50, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 20:54:35,346] Trial 27 finished with value: 0.1810699588477366 and parameters: {'n_estimators': 2141, 'max_depth': 60, 'min_samples_split': 7, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 20:56:14,352] Trial 28 finished with value: 0.19729206963249515 and parameters: {'n_estimators': 2375, 'max_depth': 28, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 20:58:05,651] Trial 29 finished with value: 0.1810699588477366 and parameters: {'n_estimators': 2833, 'max_depth': 34, 'min_samples_split': 7, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 20:59:23,683] Trial 30 finished with value: 0.15448851774530273 and parameters: {'n_estimators': 2487, 'max_depth': 42, 'min_samples_split': 9, 'min_samples_leaf': 7, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 21:01:23,460] Trial 31 finished with value: 0.19880715705765406 and parameters: {'n_estimators': 2233, 'max_depth': 47, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 21:03:10,722] Trial 32 finished with value: 0.19880715705765406 and parameters: {'n_estimators': 2186, 'max_depth': 56, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 21:04:56,020] Trial 33 finished with value: 0.16597510373443985 and parameters: {'n_estimators': 2597, 'max_depth': 44, 'min_samples_split': 16, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 21:06:34,181] Trial 34 finished with value: 0.19921875000000003 and parameters: {'n_estimators': 1983, 'max_depth': 51, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 21:07:59,442] Trial 35 finished with value: 0.1806981519507187 and parameters: {'n_estimators': 1934, 'max_depth': 51, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 21:09:08,957] Trial 36 finished with value: 0.16216216216216214 and parameters: {'n_estimators': 1837, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 21:10:15,227] Trial 37 finished with value: 0.15833333333333333 and parameters: {'n_estimators': 2382, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 21:11:04,477] Trial 38 finished with value: 0.15448851774530273 and parameters: {'n_estimators': 1398, 'max_depth': 53, 'min_samples_split': 7, 'min_samples_leaf': 6, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 21:12:40,615] Trial 39 finished with value: 0.19472616632860038 and parameters: {'n_estimators': 2064, 'max_depth': 48, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 21:13:52,348] Trial 40 finished with value: 0.1697722567287785 and parameters: {'n_estimators': 1871, 'max_depth': 39, 'min_samples_split': 3, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 21:15:33,070] Trial 41 finished with value: 0.19880715705765406 and parameters: {'n_estimators': 2104, 'max_depth': 57, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 21:16:57,610] Trial 42 finished with value: 0.19921875000000003 and parameters: {'n_estimators': 1694, 'max_depth': 45, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 21 with value: 0.19921875000000003.
# [I 2024-08-25 21:18:07,558] Trial 43 finished with value: 0.1996086105675147 and parameters: {'n_estimators': 1408, 'max_depth': 41, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 43 with value: 0.1996086105675147.
# [I 2024-08-25 21:19:21,920] Trial 44 finished with value: 0.1806981519507187 and parameters: {'n_estimators': 1453, 'max_depth': 42, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 43 with value: 0.1996086105675147.
# [I 2024-08-25 21:20:49,347] Trial 45 finished with value: 0.19615384615384612 and parameters: {'n_estimators': 1602, 'max_depth': 33, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 43 with value: 0.1996086105675147.
# [I 2024-08-25 21:22:17,497] Trial 46 finished with value: 0.19459459459459458 and parameters: {'n_estimators': 1714, 'max_depth': 44, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 43 with value: 0.1996086105675147.
# [I 2024-08-25 21:23:08,884] Trial 47 finished with value: 0.1806981519507187 and parameters: {'n_estimators': 1171, 'max_depth': 38, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 43 with value: 0.1996086105675147.
# [I 2024-08-25 21:23:54,002] Trial 48 finished with value: 0.1697722567287785 and parameters: {'n_estimators': 1238, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 43 with value: 0.1996086105675147.
# [I 2024-08-25 21:25:12,472] Trial 49 finished with value: 0.1956521739130435 and parameters: {'n_estimators': 1519, 'max_depth': 36, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 43 with value: 0.1996086105675147.
# [I 2024-08-25 21:26:04,072] Trial 50 finished with value: 0.16597510373443985 and parameters: {'n_estimators': 1319, 'max_depth': 53, 'min_samples_split': 14, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 43 with value: 0.1996086105675147.
# [I 2024-08-25 21:27:19,531] Trial 51 finished with value: 0.19678714859437751 and parameters: {'n_estimators': 1544, 'max_depth': 49, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 43 with value: 0.1996086105675147.
# [I 2024-08-25 21:28:46,559] Trial 52 finished with value: 0.2 and parameters: {'n_estimators': 1787, 'max_depth': 58, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:30:13,834] Trial 53 finished with value: 0.19921875000000003 and parameters: {'n_estimators': 1694, 'max_depth': 58, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:31:39,574] Trial 54 finished with value: 0.1806981519507187 and parameters: {'n_estimators': 1978, 'max_depth': 58, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:33:06,614] Trial 55 finished with value: 0.1984732824427481 and parameters: {'n_estimators': 1766, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:34:28,397] Trial 56 finished with value: 0.1996086105675147 and parameters: {'n_estimators': 1668, 'max_depth': 54, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:35:51,765] Trial 57 finished with value: 0.1806981519507187 and parameters: {'n_estimators': 1851, 'max_depth': 54, 'min_samples_split': 2, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:37:10,934] Trial 58 finished with value: 0.19880715705765406 and parameters: {'n_estimators': 1607, 'max_depth': 51, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:38:27,061] Trial 59 finished with value: 0.1810699588477366 and parameters: {'n_estimators': 1758, 'max_depth': 46, 'min_samples_split': 6, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:39:33,722] Trial 60 finished with value: 0.1996086105675147 and parameters: {'n_estimators': 1443, 'max_depth': 41, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:40:36,631] Trial 61 finished with value: 0.1996086105675147 and parameters: {'n_estimators': 1392, 'max_depth': 41, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:41:35,760] Trial 62 finished with value: 0.19767441860465115 and parameters: {'n_estimators': 1316, 'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:42:40,249] Trial 63 finished with value: 0.199203187250996 and parameters: {'n_estimators': 1403, 'max_depth': 41, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:43:20,759] Trial 64 finished with value: 0.18218623481781376 and parameters: {'n_estimators': 1147, 'max_depth': 21, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:44:08,199] Trial 65 finished with value: 0.15448851774530273 and parameters: {'n_estimators': 1495, 'max_depth': 55, 'min_samples_split': 2, 'min_samples_leaf': 6, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:45:10,812] Trial 66 finished with value: 0.1984732824427481 and parameters: {'n_estimators': 1365, 'max_depth': 37, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:46:15,887] Trial 67 finished with value: 0.1806981519507187 and parameters: {'n_estimators': 1640, 'max_depth': 31, 'min_samples_split': 5, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:46:28,286] Trial 68 finished with value: 0.15062761506276148 and parameters: {'n_estimators': 1580, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:47:07,056] Trial 69 finished with value: 0.1810699588477366 and parameters: {'n_estimators': 1048, 'max_depth': 40, 'min_samples_split': 11, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:48:10,034] Trial 70 finished with value: 0.1971830985915493 and parameters: {'n_estimators': 1466, 'max_depth': 43, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:49:33,433] Trial 71 finished with value: 0.19921875000000003 and parameters: {'n_estimators': 1897, 'max_depth': 46, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:50:51,212] Trial 72 finished with value: 0.19880715705765406 and parameters: {'n_estimators': 1808, 'max_depth': 48, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:52:28,079] Trial 73 finished with value: 0.1996086105675147 and parameters: {'n_estimators': 2015, 'max_depth': 51, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:54:00,031] Trial 74 finished with value: 0.1806981519507187 and parameters: {'n_estimators': 2010, 'max_depth': 50, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:56:04,127] Trial 75 finished with value: 0.1996086105675147 and parameters: {'n_estimators': 2314, 'max_depth': 52, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 21:58:01,289] Trial 76 finished with value: 0.19880715705765406 and parameters: {'n_estimators': 2313, 'max_depth': 53, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 22:00:20,144] Trial 77 finished with value: 0.19809523809523813 and parameters: {'n_estimators': 2738, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 22:01:55,007] Trial 78 finished with value: 0.1810699588477366 and parameters: {'n_estimators': 2436, 'max_depth': 55, 'min_samples_split': 8, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 22:03:01,459] Trial 79 finished with value: 0.19921875000000003 and parameters: {'n_estimators': 1436, 'max_depth': 60, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 52 with value: 0.2.
# [I 2024-08-25 22:03:55,458] Trial 80 finished with value: 0.2008032128514056 and parameters: {'n_estimators': 1306, 'max_depth': 33, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-25 22:04:52,138] Trial 81 finished with value: 0.199203187250996 and parameters: {'n_estimators': 1277, 'max_depth': 35, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-25 22:05:35,335] Trial 82 finished with value: 0.1902834008097166 and parameters: {'n_estimators': 1186, 'max_depth': 23, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-25 22
 'max_depth': 58, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:27:30,030] Trial 245 finished with value: 0.2 and parameters: {'n_estimators': 1807, 'max_depth': 56, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:28:56,928] Trial 246 finished with value: 0.2 and parameters: {'n_estimators': 1768, 'max_depth': 54, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:30:15,725] Trial 247 finished with value: 0.19880715705765406 and parameters: {'n_estimators': 1683, 'max_depth': 59, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:32:05,212] Trial 248 finished with value: 0.19921875000000003 and parameters: {'n_estimators': 1847, 'max_depth': 57, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:33:32,997] Trial 249 finished with value: 0.2 and parameters: {'n_estimators': 1732, 'max_depth': 60, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:34:59,850] Trial 250 finished with value: 0.1996086105675147 and parameters: {'n_estimators': 1826, 'max_depth': 55, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:36:31,544] Trial 251 finished with value: 0.19809523809523813 and parameters: {'n_estimators': 1777, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:37:53,044] Trial 252 finished with value: 0.1996086105675147 and parameters: {'n_estimators': 1696, 'max_depth': 56, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:38:29,927] Trial 253 finished with value: 0.15448851774530273 and parameters: {'n_estimators': 1115, 'max_depth': 57, 'min_samples_split': 5, 'min_samples_leaf': 6, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:39:54,221] Trial 254 finished with value: 0.2 and parameters: {'n_estimators': 1749, 'max_depth': 53, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:41:34,865] Trial 255 finished with value: 0.18032786885245905 and parameters: {'n_estimators': 1809, 'max_depth': 59, 'min_samples_split': 15, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:42:56,287] Trial 256 finished with value: 0.1977186311787072 and parameters: {'n_estimators': 1647, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:44:43,832] Trial 257 finished with value: 0.1996086105675147 and parameters: {'n_estimators': 1711, 'max_depth': 58, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:46:11,196] Trial 258 finished with value: 0.2 and parameters: {'n_estimators': 1774, 'max_depth': 56, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:47:38,365] Trial 259 finished with value: 0.19880715705765406 and parameters: {'n_estimators': 1837, 'max_depth': 54, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:49:10,174] Trial 260 finished with value: 0.19921875000000003 and parameters: {'n_estimators': 1887, 'max_depth': 57, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:50:32,647] Trial 261 finished with value: 0.2 and parameters: {'n_estimators': 1738, 'max_depth': 58, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:52:01,753] Trial 262 finished with value: 0.19809523809523813 and parameters: {'n_estimators': 1782, 'max_depth': 60, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:53:22,114] Trial 263 finished with value: 0.19880715705765406 and parameters: {'n_estimators': 1679, 'max_depth': 56, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:54:46,667] Trial 264 finished with value: 0.1996086105675147 and parameters: {'n_estimators': 1726, 'max_depth': 59, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:56:29,851] Trial 265 finished with value: 0.1996086105675147 and parameters: {'n_estimators': 1814, 'max_depth': 55, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:56:43,003] Trial 266 finished with value: 0.053097345132743355 and parameters: {'n_estimators': 1856, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:58:10,070] Trial 267 finished with value: 0.1984732824427481 and parameters: {'n_estimators': 1766, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 01:59:29,987] Trial 268 finished with value: 0.1996086105675147 and parameters: {'n_estimators': 1668, 'max_depth': 54, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:00:45,354] Trial 269 finished with value: 0.19758064516129034 and parameters: {'n_estimators': 1620, 'max_depth': 58, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:02:08,536] Trial 270 finished with value: 0.2 and parameters: {'n_estimators': 1719, 'max_depth': 56, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:03:36,853] Trial 271 finished with value: 0.1996086105675147 and parameters: {'n_estimators': 1802, 'max_depth': 55, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:05:00,878] Trial 272 finished with value: 0.19880715705765406 and parameters: {'n_estimators': 1752, 'max_depth': 57, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:06:26,240] Trial 273 finished with value: 0.1984732824427481 and parameters: {'n_estimators': 1706, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:07:58,740] Trial 274 finished with value: 0.19921875000000003 and parameters: {'n_estimators': 1905, 'max_depth': 53, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:09:24,160] Trial 275 finished with value: 0.2 and parameters: {'n_estimators': 1774, 'max_depth': 58, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:10:43,099] Trial 276 finished with value: 0.179959100204499 and parameters: {'n_estimators': 1852, 'max_depth': 57, 'min_samples_split': 12, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:12:08,369] Trial 277 finished with value: 0.19880715705765406 and parameters: {'n_estimators': 1812, 'max_depth': 60, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:13:56,024] Trial 278 finished with value: 0.2 and parameters: {'n_estimators': 1738, 'max_depth': 55, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:14:21,385] Trial 279 finished with value: 0.15448851774530273 and parameters: {'n_estimators': 2091, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:15:44,006] Trial 280 finished with value: 0.1977186311787072 and parameters: {'n_estimators': 1673, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:17:10,793] Trial 281 finished with value: 0.2 and parameters: {'n_estimators': 1782, 'max_depth': 58, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:18:30,930] Trial 282 finished with value: 0.19880715705765406 and parameters: {'n_estimators': 1705, 'max_depth': 57, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:19:59,725] Trial 283 finished with value: 0.19921875000000003 and parameters: {'n_estimators': 1831, 'max_depth': 59, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:21:25,446] Trial 284 finished with value: 0.2 and parameters: {'n_estimators': 1747, 'max_depth': 55, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:22:48,985] Trial 285 finished with value: 0.19880715705765406 and parameters: {'n_estimators': 1790, 'max_depth': 54, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:24:11,144] Trial 286 finished with value: 0.1977186311787072 and parameters: {'n_estimators': 1631, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:25:35,619] Trial 287 finished with value: 0.2 and parameters: {'n_estimators': 1755, 'max_depth': 58, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:27:05,593] Trial 288 finished with value: 0.19921875000000003 and parameters: {'n_estimators': 1863, 'max_depth': 60, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:28:39,777] Trial 289 finished with value: 0.1996086105675147 and parameters: {'n_estimators': 1702, 'max_depth': 53, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:30:10,977] Trial 290 finished with value: 0.1984732824427481 and parameters: {'n_estimators': 1805, 'max_depth': 57, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:31:30,317] Trial 291 finished with value: 0.194331983805668 and parameters: {'n_estimators': 1742, 'max_depth': 56, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:32:50,647] Trial 292 finished with value: 0.19921875000000003 and parameters: {'n_estimators': 1651, 'max_depth': 59, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:33:49,612] Trial 293 finished with value: 0.15448851774530273 and parameters: {'n_estimators': 1787, 'max_depth': 58, 'min_samples_split': 4, 'min_samples_leaf': 7, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:35:11,804] Trial 294 finished with value: 0.19880715705765406 and parameters: {'n_estimators': 1722, 'max_depth': 57, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:36:22,033] Trial 295 finished with value: 0.1810699588477366 and parameters: {'n_estimators': 1815, 'max_depth': 54, 'min_samples_split': 4, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:37:55,095] Trial 296 finished with value: 0.1996086105675147 and parameters: {'n_estimators': 1920, 'max_depth': 56, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:39:25,050] Trial 297 finished with value: 0.19809523809523813 and parameters: {'n_estimators': 1762, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:40:02,775] Trial 298 finished with value: 0.15481171548117154 and parameters: {'n_estimators': 1682, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# [I 2024-08-26 02:41:32,969] Trial 299 finished with value: 0.1996086105675147 and parameters: {'n_estimators': 1871, 'max_depth': 55, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 80 with value: 0.2008032128514056.
# Best trial: score 0.2008032128514056,
# params {'n_estimators': 1306, 'max_depth': 33, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}

# %% [markdown]
# Best trial: score 0.2008032128514056,
#
# params {'n_estimators': 1306, 'max_depth': 33, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}

# %%
# 스레드홀드 설정
THRESHOLD = 0.3

# 모델 설정 및 하이퍼파라미터
models = {
    'et': ExtraTreesClassifier(),
    'rf': RandomForestClassifier(),
    'cat': CatBoostClassifier(),
    'lgbm': LGBMClassifier(),
    'xgb': XGBClassifier(),
    'dt': DecisionTreeClassifier()
}

def train_and_evaluate_model(model_name, data, **params):
    if model_name not in models:
        print(f"{model_name}은(는) 지원되지 않는 모델입니다.")
        return
    
    # 데이터셋 분할
    x_train, x_val, y_train, y_val = train_test_split(
        data.drop("target", axis=1),
        data["target"].map({'Normal': 0, 'AbNormal': 1}),
        test_size=0.2,
        shuffle=True,
        random_state=RANDOM_STATE,
    )

    # 모델 선택
    model = models[model_name]

    # 하이퍼파라미터 설정
    model.set_params(**params)

    # 모델 학습
    model.fit(x_train, y_train)

    # 데이터 이름을 자동으로 추출하기 위한 래퍼 함수
    data_name = [name for name in globals() if globals()[name] is data][0]

    # 예측
    y_val_pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
    y_val_pred = (y_val_pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측

    # 평가지표 계산
    f1 = f1_score(y_val, y_val_pred, average="binary")
    accuracy = accuracy_score(y_val, y_val_pred)
    precision = precision_score(y_val, y_val_pred)
    recall = recall_score(y_val, y_val_pred)
    conf_matrix = confusion_matrix(y_val, y_val_pred)
    
    # 결과 출력
    print(f'{model_name} 모델이 {data_name} 데이터로 학습한 결과:')
    print(f'F1 Score: {f1}')
    print('---')
    print('Confusion Matrix:')
    print(conf_matrix)
    print('---')
    print(f'Accuracy: {accuracy}')
    print(f'Precision: {precision}')
    print(f'Recall: {recall}')
    print('\n')

# %%
train_and_evaluate_model(
    'et', train_data,
    n_estimators = 1306,
    max_depth = 33,
    min_samples_split = 6,
    min_samples_leaf = 1,
    criterion = 'entropy',
    bootstrap = False,
    random_state=RANDOM_STATE
)
# Out:
# et 모델이 train_data 데이터로 학습한 결과:
# F1 Score: 0.21487603305785125
# ---
# Confusion Matrix:
# [[7562  100]
#  [ 375   65]]
# ---
# Accuracy: 0.9413725006171316
# Precision: 0.3939393939393939
# Recall: 0.14772727272727273

# %%
# import optuna
# from sklearn.ensemble import ExtraTreesClassifier 

# # 'Normal'과 'AbNormal'을 숫자로 변환
# train_data['target'] = train_data['target'].map({'Normal': 0, 'AbNormal': 1})

# # 스레드홀드 설정
# THRESHOLD = 0.3

# def objectiveExtraTreesClassifier(trial, x_tr, y_tr, x_val, y_val):
#     param = {
#         'n_estimators': trial.suggest_int('n_estimators', 1000, 3500)
#         , 'max_depth': trial.suggest_int('max_depth', 20, 80)
#         , 'min_samples_split': trial.suggest_int('min_samples_split', 2, 10)
#         , 'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 4)
#         , 'criterion': trial.suggest_categorical('criterion', ['entropy'])
#         , 'bootstrap': trial.suggest_categorical('bootstrap', [False])
#         , 'random_state': RANDOM_STATE
#     }
    
#     model = ExtraTreesClassifier(**param)
#     model.fit(x_tr, y_tr)
#     pred = model.predict(x_val)
#     score = f1_score(y_val, pred, average="binary")
    
#     return score

# # 데이터셋 분할
# x_train, x_val, y_train, y_val = train_test_split(
#     train_data.drop("target", axis=1),
#     train_data["target"],
#     test_size=0.2,
#     shuffle=True,
#     random_state=RANDOM_STATE,
# )

# # 하이퍼 파라미터 튜닝
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# study.optimize(lambda trial: objectiveExtraTreesClassifier(trial, x_train, y_train, x_val, y_val), n_trials=100)

# print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))

# %% [markdown]
# .
