# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ## 1. 데이터 불러오기

# %% [markdown]
# ### 필수 라이브러리

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)

def get_clf_eval(y_test, y_pred_proba, threshold=0.5):
    # 확률을 기준으로 예측 레이블 생성
    y_pred = (y_pred_proba >= threshold).astype(int)  # 0.5 이상의 확률을 양성으로 간주

    confusion = confusion_matrix(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    print("Confusion Matrix:\n", confusion)
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")

# %% [markdown]
# ### 데이터 읽어오기

# %%
RANDOM_STATE = 110

# csv 불러오기
train_data = pd.read_csv('C:/Users/KimDongyoung/Desktop/git_LGaimers5/Lg_aimers5/data/train_data_0817.csv')
test_data  = pd.read_csv('C:/Users/KimDongyoung/Desktop/git_LGaimers5/Lg_aimers5/data/test_data_0817.csv')

# %% [markdown]
# ---

# %% [markdown]
# ## 데이터 분할

# %%
df_train, df_val = train_test_split(
    train_data,
    test_size=0.2,
    stratify=train_data["target"],
    shuffle=True,
    random_state=RANDOM_STATE,
)

def print_stats(df: pd.DataFrame):
    num_normal = len(df[df["target"] == "Normal"])
    num_abnormal = len(df[df["target"] == "AbNormal"])

    print(f"  Total: Normal: {num_normal}, AbNormal: {num_abnormal}" + f" ratio: {num_abnormal/num_normal}")


# Print statistics
print(f"  \tAbnormal\tNormal")
print_stats(df_train)
print_stats(df_val)
# Out:
#   	Abnormal	Normal
#   Total: Normal: 30524, AbNormal: 1880 ratio: 0.06159087930808544
#   Total: Normal: 7632, AbNormal: 470 ratio: 0.061582809224318656

# %% [markdown]
# ## 3. 모델 학습

# %% [markdown]
# ### 모델 정의

# %% [markdown]
# optuna

# %%
import optuna
from sklearn.ensemble import ExtraTreesClassifier 

# 'Normal'과 'AbNormal'을 숫자로 변환
train_data['target'] = train_data['target'].map({'Normal': 0, 'AbNormal': 1})

# 스레드홀드 설정
THRESHOLD = 0.3

def objectiveExtraTreesClassifier(trial, x_tr, y_tr, x_val, y_val):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 1000, 3000)
        , 'max_depth': trial.suggest_int('max_depth', 2, 60)
        , 'min_samples_split': trial.suggest_int('min_samples_split', 2, 16)
        , 'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 7)
        , 'criterion': trial.suggest_categorical('criterion', ['entropy'])
        , 'bootstrap': trial.suggest_categorical('bootstrap', [False])
        , 'random_state': RANDOM_STATE
    }
    
    model = ExtraTreesClassifier(**param)
    model.fit(x_tr, y_tr)
    pred = model.predict(x_val)
    score = f1_score(y_val, pred, average="binary")
    
    return score

# 데이터셋 분할
x_train, x_val, y_train, y_val = train_test_split(
    train_data.drop("target", axis=1),
    train_data["target"],
    test_size=0.2,
    shuffle=True,
    random_state=RANDOM_STATE,
)

# 하이퍼 파라미터 튜닝
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
study.optimize(lambda trial: objectiveExtraTreesClassifier(trial, x_train, y_train, x_val, y_val), n_trials=500)

print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# [I 2024-08-21 11:19:43,430] A new study created in memory with name: no-name-e2b7e618-4fa4-4da6-ac83-93ff9bd91712
# [I 2024-08-21 11:20:46,271] Trial 0 finished with value: 0.16216216216216214 and parameters: {'n_estimators': 1232, 'max_depth': 40, 'min_samples_split': 7, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.16216216216216214.
# [I 2024-08-21 11:22:37,997] Trial 1 finished with value: 0.15833333333333333 and parameters: {'n_estimators': 2359, 'max_depth': 42, 'min_samples_split': 16, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.16216216216216214.
# [I 2024-08-21 11:23:13,006] Trial 2 finished with value: 0.15448851774530273 and parameters: {'n_estimators': 2026, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.16216216216216214.
# [I 2024-08-21 11:23:22,444] Trial 3 finished with value: 0.0 and parameters: {'n_estimators': 1270, 'max_depth': 2, 'min_samples_split': 8, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 0 with value: 0.16216216216216214.
# [I 2024-08-21 11:24:19,581] Trial 4 finished with value: 0.1810699588477366 and parameters: {'n_estimators': 1042, 'max_depth': 35, 'min_samples_split': 3, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 4 with value: 0.1810699588477366.
# [I 2024-08-21 11:25:49,461] Trial 5 finished with value: 0.17731958762886596 and parameters: {'n_estimators': 1628, 'max_depth': 47, 'min_samples_split': 11, 'min_samples_leaf': 3, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 4 with value: 0.1810699588477366.
# [I 2024-08-21 11:26:05,073] Trial 6 finished with value: 0.053097345132743355 and parameters: {'n_estimators': 1670, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 6, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 4 with value: 0.1810699588477366.
# [I 2024-08-21 11:27:18,856] Trial 7 finished with value: 0.15448851774530273 and parameters: {'n_estimators': 1982, 'max_depth': 16, 'min_samples_split': 13, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 4 with value: 0.1810699588477366.
# [I 2024-08-21 11:28:47,372] Trial 8 finished with value: 0.16216216216216214 and parameters: {'n_estimators': 1771, 'max_depth': 40, 'min_samples_split': 4, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 4 with value: 0.1810699588477366.
# [I 2024-08-21 11:29:55,389] Trial 9 finished with value: 0.18442622950819673 and parameters: {'n_estimators': 1080, 'max_depth': 37, 'min_samples_split': 5, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial
finished with value: 0.19607843137254902 and parameters: {'n_estimators': 2921, 'max_depth': 59, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 17:30:59,053] Trial 139 finished with value: 0.20306513409961682 and parameters: {'n_estimators': 2834, 'max_depth': 51, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 17:32:21,521] Trial 140 finished with value: 0.1806981519507187 and parameters: {'n_estimators': 2888, 'max_depth': 53, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 17:33:50,000] Trial 141 finished with value: 0.19961612284069097 and parameters: {'n_estimators': 2856, 'max_depth': 59, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 17:36:41,367] Trial 142 finished with value: 0.19961612284069097 and parameters: {'n_estimators': 2940, 'max_depth': 58, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 17:40:16,164] Trial 143 finished with value: 0.19961612284069097 and parameters: {'n_estimators': 2880, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 17:43:45,476] Trial 144 finished with value: 0.19424460431654675 and parameters: {'n_estimators': 2790, 'max_depth': 57, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 17:45:18,646] Trial 145 finished with value: 0.19066937119675456 and parameters: {'n_estimators': 3000, 'max_depth': 59, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 17:46:50,557] Trial 146 finished with value: 0.19999999999999998 and parameters: {'n_estimators': 2917, 'max_depth': 55, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 17:48:15,124] Trial 147 finished with value: 0.19607843137254902 and parameters: {'n_estimators': 2860, 'max_depth': 56, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 17:49:46,412] Trial 148 finished with value: 0.1938958707360862 and parameters: {'n_estimators': 2953, 'max_depth': 52, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 17:51:12,026] Trial 149 finished with value: 0.20306513409961682 and parameters: {'n_estimators': 2818, 'max_depth': 53, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 17:52:42,139] Trial 150 finished with value: 0.19961612284069097 and parameters: {'n_estimators': 2748, 'max_depth': 40, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 17:54:13,544] Trial 151 finished with value: 0.20306513409961682 and parameters: {'n_estimators': 2833, 'max_depth': 51, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 17:55:49,787] Trial 152 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 2896, 'max_depth': 48, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 17:57:39,813] Trial 153 finished with value: 0.19494584837545126 and parameters: {'n_estimators': 2905, 'max_depth': 47, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 18:00:01,193] Trial 154 finished with value: 0.19653179190751446 and parameters: {'n_estimators': 2958, 'max_depth': 35, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 18:03:52,067] Trial 155 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 2882, 'max_depth': 49, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 18:07:54,364] Trial 156 finished with value: 0.19607843137254902 and parameters: {'n_estimators': 2926, 'max_depth': 45, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 18:11:26,786] Trial 157 finished with value: 0.2034548944337812 and parameters: {'n_estimators': 2962, 'max_depth': 49, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 18:15:23,095] Trial 158 finished with value: 0.19424460431654675 and parameters: {'n_estimators': 2997, 'max_depth': 48, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 18:18:57,898] Trial 159 finished with value: 0.19685039370078738 and parameters: {'n_estimators': 2958, 'max_depth': 49, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 18:22:28,344] Trial 160 finished with value: 0.20306513409961682 and parameters: {'n_estimators': 2910, 'max_depth': 50, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 18:25:53,026] Trial 161 finished with value: 0.19961612284069097 and parameters: {'n_estimators': 2882, 'max_depth': 46, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 18:26:56,899] Trial 162 finished with value: 0.17355371900826447 and parameters: {'n_estimators': 2804, 'max_depth': 49, 'min_samples_split': 3, 'min_samples_leaf': 4, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 18:28:19,033] Trial 163 finished with value: 0.1972386587771203 and parameters: {'n_estimators': 2950, 'max_depth': 25, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 18:29:54,599] Trial 164 finished with value: 0.1938958707360862 and parameters: {'n_estimators': 2851, 'max_depth': 52, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.
# [I 2024-08-21 18:31:28,484] Trial 165 finished with value: 0.19685039370078738 and parameters: {'n_estimators': 2910, 'max_depth': 48, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}. Best is trial 91 with value: 0.2034548944337812.

# %% [markdown]
# Best trial: score 0.2034548944337812,
# params {'n_estimators': 2884, 'max_depth': 56, 'min_samples_split': 3, 'min_samples_leaf': 1,
# 'criterion': 'entropy', 'bootstrap': False}

# %%
# import optuna
# from sklearn.ensemble import ExtraTreesClassifier 

# # 'Normal'과 'AbNormal'을 숫자로 변환
# train_data['target'] = train_data['target'].map({'Normal': 0, 'AbNormal': 1})

# # 스레드홀드 설정
# THRESHOLD = 0.3

# def objectiveExtraTreesClassifier(trial, x_tr, y_tr, x_val, y_val):
#     param = {
#         'n_estimators': trial.suggest_int('n_estimators', 1000, 3500)
#         , 'max_depth': trial.suggest_int('max_depth', 20, 80)
#         , 'min_samples_split': trial.suggest_int('min_samples_split', 2, 10)
#         , 'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 4)
#         , 'criterion': trial.suggest_categorical('criterion', ['entropy'])
#         , 'bootstrap': trial.suggest_categorical('bootstrap', [False])
#         , 'random_state': RANDOM_STATE
#     }
    
#     model = ExtraTreesClassifier(**param)
#     model.fit(x_tr, y_tr)
#     pred = model.predict(x_val)
#     score = f1_score(y_val, pred, average="binary")
    
#     return score

# # 데이터셋 분할
# x_train, x_val, y_train, y_val = train_test_split(
#     train_data.drop("target", axis=1),
#     train_data["target"],
#     test_size=0.2,
#     shuffle=True,
#     random_state=RANDOM_STATE,
# )

# # 하이퍼 파라미터 튜닝
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# study.optimize(lambda trial: objectiveExtraTreesClassifier(trial, x_train, y_train, x_val, y_val), n_trials=100)

# print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))

# %% [markdown]
# Trial 51 finished with value: 0.20384615384615384 and parameters: {'n_estimators': 2204, 'max_depth': 42,
# 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False}.

# %% [markdown]
# .
