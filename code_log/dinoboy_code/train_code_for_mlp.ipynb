# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv('train_data_fixed.csv')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40506 entries, 0 to 40505
# Columns: 119 entries, Model.Suffix to Equipment_same_num
# dtypes: float64(93), int64(17), object(9)
# memory usage: 36.8+ MB

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

# suffix 열의 값을 숫자로 변환
train_data['suffix_encoded'] = label_encoder.fit_transform(train_data['Model.Suffix'])

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40506 entries, 0 to 40505
# Columns: 120 entries, Model.Suffix to suffix_encoded
# dtypes: float64(93), int64(18), object(9)
# memory usage: 37.1+ MB

# %%
train_data['suffix_encoded'].value_counts()
# Out:
# suffix_encoded
# 0    33820
# 1     3390
# 3     2635
# 5      310
# 2      162
# 4      129
# 6       60
# Name: count, dtype: int64

# %%
train_data = train_data.drop(columns=['Model.Suffix', 'Workorder'])

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40506 entries, 0 to 40505
# Columns: 118 entries, CURE END POSITION X Collect Result_Dam to suffix_encoded
# dtypes: float64(93), int64(18), object(7)
# memory usage: 36.5+ MB

# %%
train_data = train_data.drop(columns=['HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam', 'GMES_ORIGIN_INSP_JUDGE_CODE Collect Result_AutoClave','GMES_ORIGIN_INSP_JUDGE_CODE Judge Value_AutoClave'])

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40506 entries, 0 to 40505
# Columns: 115 entries, CURE END POSITION X Collect Result_Dam to suffix_encoded
# dtypes: float64(93), int64(18), object(4)
# memory usage: 35.5+ MB

# %%
train_data = train_data.drop(columns=['HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Fill1','WorkMode Collect Result_Fill1'])

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40506 entries, 0 to 40505
# Columns: 113 entries, CURE END POSITION X Collect Result_Dam to suffix_encoded
# dtypes: float64(92), int64(18), object(3)
# memory usage: 34.9+ MB

# %%
train_data = train_data.drop(columns=['HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Fill2'])

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40506 entries, 0 to 40505
# Columns: 112 entries, CURE END POSITION X Collect Result_Dam to suffix_encoded
# dtypes: float64(92), int64(18), object(2)
# memory usage: 34.6+ MB

# %%
delete = ['PalletID Collect Result_Dam',
          'Production Qty Collect Result_Dam',
          'Receip No Collect Result_Dam',
          'WorkMode Collect Result_Dam',
          'PalletID Collect Result_Fill1',
          'Production Qty Collect Result_Fill1',
          'Receip No Collect Result_Fill1',
          'PalletID Collect Result_Fill2',
          'Production Qty Collect Result_Fill2',
          'Receip No Collect Result_Fill2',
          'Equipment_same_num']

train_data = train_data.drop(columns=delete)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40506 entries, 0 to 40505
# Columns: 101 entries, CURE END POSITION X Collect Result_Dam to suffix_encoded
# dtypes: float64(82), int64(17), object(2)
# memory usage: 31.2+ MB

# %%
train_data.columns
# Out:
# Index(['CURE END POSITION X Collect Result_Dam',
#        'CURE END POSITION Z Collect Result_Dam',
#        'CURE END POSITION Θ Collect Result_Dam',
#        'CURE SPEED Collect Result_Dam',
#        'CURE START POSITION X Collect Result_Dam',
#        'CURE START POSITION Θ Collect Result_Dam',
#        'DISCHARGED SPEED OF RESIN Collect Result_Dam',
#        'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam',
#        'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam',
#        'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam',
#        ...
#        'HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Fill2',
#        'HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Fill2',
#        'HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Fill2',
#        'HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Fill2',
#        'HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Fill2',
#        'Head Purge Position Z Collect Result_Fill2',
# ...

# %%
train_data
# Out:
#        CURE END POSITION X Collect Result_Dam  \
# 0                                       240.0
# 1                                       240.0
# 2                                      1000.0
# 3                                      1000.0
# 4                                       240.0
# ...                                       ...
# 40501                                   240.0
# 40502                                  1000.0
# 40503                                   240.0
# 40504                                  1000.0
# 40505                                   240.0
#
#        CURE END POSITION Z Collect Result_Dam  \
# 0                                         2.5
# 1                                         2.5
# 2                                        12.5
# 3                                        12.5
# 4                                         2.5
# ...                                       ...
# 40501                                     2.5
# ...

# %%
for i in train_data.columns:
    print(i)
    print(train_data[i].dtype)
# Out:
# CURE END POSITION X Collect Result_Dam
# float64
# CURE END POSITION Z Collect Result_Dam
# float64
# CURE END POSITION Θ Collect Result_Dam
# int64
# CURE SPEED Collect Result_Dam
# int64
# CURE START POSITION X Collect Result_Dam
# int64
# CURE START POSITION Θ Collect Result_Dam
# int64
# DISCHARGED SPEED OF RESIN Collect Result_Dam
# int64
# DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam
# float64
# DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam
# float64
# DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam
# float64
# Dispense Volume(Stage1) Collect Result_Dam
# float64
# Dispense Volume(Stage2) Collect Result_Dam
# float64
# Dispense Volume(Stage3) Collect Result_Dam
# float64
# HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam
# float64
# HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Dam
# float64
# HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Dam
# float64
# HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Dam
# float64
# ...

# %%
train_data = train_data.drop(columns=['Chamber Temp. Judge Value_AutoClave','WorkMode Collect Result_Fill2'])

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40506 entries, 0 to 40505
# Data columns (total 99 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   CURE END POSITION X Collect Result_Dam                      40506 non-null  float64
#  1   CURE END POSITION Z Collect Result_Dam                      40506 non-null  float64
#  2   CURE END POSITION Θ Collect Result_Dam                      40506 non-null  int64
#  3   CURE SPEED Collect Result_Dam                               40506 non-null  int64
#  4   CURE START POSITION X Collect Result_Dam                    40506 non-null  int64
#  5   CURE START POSITION Θ Collect Result_Dam                    40506 non-null  int64
#  6   DISCHARGED SPEED OF RESIN Collect Result_Dam                40506 non-null  int64
# ...

# %%
train_data['target'] = label_encoder.fit_transform(train_data['target'])

# %%
train_data.to_csv('train_data_mlp.csv', index=False)

# %%
train_data.isnull().values.any()
# Out:
# False
