# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ### 데이터 읽어오기

# %%
import os
from pprint import pprint

import optuna
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import pandas as pd

THRESHOLD = 0.3
RANDOM_STATE = 110

train_data = pd.read_csv("../../../data/train_data_0817.csv")
test_data = pd.read_csv("../../../data/test_data_0817.csv")

# %%
# dam, fill1, fill2 공통 변수
var_dam_fill = [
    'Equipment_same_num',
    'PalletID_Collect_Result_encoded',
    'Production_Qty_Collect_Result',
    'WorkMode Collect Result'
]

# %%
# 전체 공통 변수
### correlation 확인을 위한 변수 리스트
var_all_corr = [
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### train
var_all_train = [
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### test
var_all_test = [
    'Set ID',
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

# %%
# '_Dam'을 포함하는 변수 선택
dam_variables = [var for var in train_data.columns if '_Dam' in var]

# train
final_columns_train = var_dam_fill + var_all_train + dam_variables
train_data_dam = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + dam_variables
test_data_dam = test_data[final_columns_test]

# %%
# '_Fill1'을 포함하는 변수 선택
fill1_variables = [var for var in train_data.columns if '_Fill1' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill1_variables
train_data_fill1 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill1_variables
test_data_fill1 = test_data[final_columns_test]

# %%
# '_Fill2'을 포함하는 변수 선택
fill2_variables = [var for var in train_data.columns if '_Fill2' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill2_variables
train_data_fill2 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill2_variables
test_data_fill2 = test_data[final_columns_test]

# %%
# '_AutoClave'을 포함하는 변수 선택
autoclave_variables = [var for var in train_data.columns if '_AutoClave' in var]

# train
final_columns_train = var_all_train + autoclave_variables
train_data_autoclave = train_data[final_columns_train]

# test 
final_columns_test = var_all_test + autoclave_variables
test_data_autoclave = test_data[final_columns_test]

# %%
# 각 DataFrame의 칼럼 수 계산
num_columns_train_data = train_data.shape[1]
num_columns_train_data_dam = train_data_dam.shape[1]
num_columns_train_data_autoclave = train_data_autoclave.shape[1]
num_columns_train_data_fill1 = train_data_fill1.shape[1]
num_columns_train_data_fill2 = train_data_fill2.shape[1]

num_columns_test_data = test_data.shape[1]
num_columns_test_data_dam = test_data_dam.shape[1]
num_columns_test_data_autoclave = test_data_autoclave.shape[1]
num_columns_test_data_fill1 = test_data_fill1.shape[1]
num_columns_test_data_fill2 = test_data_fill2.shape[1]

# 각 DataFrame의 칼럼 수 출력
print("----train data-----")
print(f"train_data DataFrame의 칼럼 수: {num_columns_train_data}")
print(f"train_data_dam DataFrame의 칼럼 수: {num_columns_train_data_dam}")
print(f"train_data_autoclave DataFrame의 칼럼 수: {num_columns_train_data_autoclave}")
print(f"train_data_fill1 DataFrame의 칼럼 수: {num_columns_train_data_fill1}")
print(f"train_data_fill2 DataFrame의 칼럼 수: {num_columns_train_data_fill2}")
print("----test data-----")
print(f"test_data DataFrame의 칼럼 수: {num_columns_test_data}")
print(f"test_data_dam DataFrame의 칼럼 수: {num_columns_test_data_dam}")
print(f"test_data_autoclave DataFrame의 칼럼 수: {num_columns_test_data_autoclave}")
print(f"test_data_fill1 DataFrame의 칼럼 수: {num_columns_test_data_fill1}")
print(f"test_data_fill2 DataFrame의 칼럼 수: {num_columns_test_data_fill2}")
# Out:
# ----train data-----
# train_data DataFrame의 칼럼 수: 38
# train_data_dam DataFrame의 칼럼 수: 21
# train_data_autoclave DataFrame의 칼럼 수: 8
# train_data_fill1 DataFrame의 칼럼 수: 13
# train_data_fill2 DataFrame의 칼럼 수: 13
# ----test data-----
# test_data DataFrame의 칼럼 수: 39
# test_data_dam DataFrame의 칼럼 수: 22
# test_data_autoclave DataFrame의 칼럼 수: 9
# test_data_fill1 DataFrame의 칼럼 수: 14
# test_data_fill2 DataFrame의 칼럼 수: 14

# %% [markdown]
# ---

# %% [markdown]
# ## Optuna

# %% [markdown]
# 스레스홀드 0.3으로 맞춘상태에서 튜닝 진행한 것

# %%
# # 'Normal'과 'AbNormal'을 숫자로 변환
# train_data_fill2['target'] = train_data_fill2['target'].map({'Normal': 0, 'AbNormal': 1})

# # 스레드홀드 설정
# THRESHOLD = 0.3

# def objectiveRandomForestClassifier(trial, x_tr, y_tr, x_val, y_val):
#     param = {
#         'n_estimators': trial.suggest_int('n_estimators', 500, 3000)
#         , 'max_depth': trial.suggest_int('max_depth', 2, 50)
#         , 'min_samples_split': trial.suggest_int('min_samples_split', 2, 16)
#         , 'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10)
#         , 'criterion': trial.suggest_categorical('criterion', ['entropy'])
#         , 'bootstrap': trial.suggest_categorical('bootstrap', [False])
#         , 'random_state': RANDOM_STATE
#     }
    
#     model = RandomForestClassifier(**param)
#     model.fit(x_tr, y_tr)
#     pred = model.predict(x_val)
#     score = f1_score(y_val, pred, average="binary")
    
#     return score

# # 데이터셋 분할
# x_train, x_val, y_train, y_val = train_test_split(
#     train_data_fill2.drop("target", axis=1),
#     train_data_fill2["target"],
#     test_size=0.2,
#     shuffle=True,
#     random_state=RANDOM_STATE,
# )

# # 하이퍼 파라미터 튜닝
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# study.optimize(lambda trial: objectiveRandomForestClassifier(trial, x_train, y_train, x_val, y_val), n_trials=500)

# print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))

# %% [markdown]
# Trial 152 finished with value: 0.18563922942206654
# parameters: {'n_estimators': 2879, 'max_depth': 27, 'min_samples_split': 4, 'min_samples_leaf': 1,
# 'criterion': 'entropy', 'bootstrap': False}

# %%
# # 'Normal'과 'AbNormal'을 숫자로 변환
# train_data_fill2['target'] = train_data_fill2['target'].map({'Normal': 0, 'AbNormal': 1})

# # 스레드홀드 설정
# THRESHOLD = 0.3

# def objectiveRandomForestClassifier(trial, x_tr, y_tr, x_val, y_val):
#     param = {
#         'n_estimators' : trial.suggest_int('n_estimators', 800, 3000),
#         'max_depth' : trial.suggest_int('max_depth', 20, 100),
#         'min_samples_split' : trial.suggest_int('min_samples_split', 2, 20),
#         'min_samples_leaf' : trial.suggest_int('min_samples_leaf', 1, 8),
#         'criterion' : trial.suggest_categorical("criterion", ["entropy",]),
#         'class_weight' : trial.suggest_categorical("class_weight", ["balanced"]),
#         'random_state': RANDOM_STATE
#     }
    
#     model = RandomForestClassifier(**param)
#     model.fit(x_tr, y_tr)
#     pred = model.predict(x_val)
#     score = f1_score(y_val, pred, average="binary")
    
#     return score

# # 데이터셋 분할
# x_train, x_val, y_train, y_val = train_test_split(
#     train_data_fill2.drop("target", axis=1),
#     train_data_fill2["target"],
#     test_size=0.2,
#     shuffle=True,
#     random_state=RANDOM_STATE,
# )

# # 하이퍼 파라미터 튜닝
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# study.optimize(lambda trial: objectiveRandomForestClassifier(trial, x_train, y_train, x_val, y_val), n_trials=300)

# print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))

# %% [markdown]
# Best trial: score 0.21387940841865755,
# params {'n_estimators': 1587, 'max_depth': 89, 'min_samples_split': 13, 'min_samples_leaf': 2, 'criterion': 'entropy', 'class_weight': 'balanced'}

# %%
# 'Normal'과 'AbNormal'을 숫자로 변환
train_data_fill2['target'] = train_data_fill2['target'].map({'Normal': 0, 'AbNormal': 1})

# 스레드홀드 설정
THRESHOLD = 0.3

def objectiveRandomForestClassifier(trial, x_tr, y_tr, x_val, y_val):
    param = {
        'n_estimators' : trial.suggest_int('n_estimators', 800, 3000),
        'max_depth' : trial.suggest_int('max_depth', 20, 100),
        'min_samples_split' : trial.suggest_int('min_samples_split', 2, 20),
        'min_samples_leaf' : trial.suggest_int('min_samples_leaf', 1, 8),
        'criterion' : trial.suggest_categorical("criterion", ["entropy",]),
        'class_weight' : trial.suggest_categorical("class_weight", ["balanced"]),
        'random_state': RANDOM_STATE
    }
    
    model = RandomForestClassifier(**param)
    model.fit(x_tr, y_tr)
    pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
    pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
    
    score = f1_score(y_val, pred, average="binary")
    
    return score

# 데이터셋 분할
x_train, x_val, y_train, y_val = train_test_split(
    train_data_fill2.drop("target", axis=1),
    train_data_fill2["target"],
    test_size=0.2,
    shuffle=True,
    random_state=RANDOM_STATE,
)

# 하이퍼 파라미터 튜닝
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
study.optimize(lambda trial: objectiveRandomForestClassifier(trial, x_train, y_train, x_val, y_val), n_trials=300)

print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# C:\Users\juneh\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# [I 2024-08-23 00:13:20,574] A new study created in memory with name: no-name-413c1ae2-cf6a-493a-9400-3d85f406208d
# [I 2024-08-23 00:13:43,719] Trial 0 finished with value: 0.18037518037518036 and parameters: {'n_estimators': 1055, 'max_depth': 73, 'min_samples_split': 9, 'min_samples_leaf': 5, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 0 with value: 0.18037518037518036.
# [I 2024-08-23 00:14:31,933] Trial 1 finished with value: 0.1717827626918536 and parameters: {'n_estimators': 2295, 'max_depth': 75, 'min_samples_split': 20, 'min_samples_leaf': 6, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 0 with value: 0.18037518037518036.
# [I 2024-08-23 00:15:16,731] Trial 2 finished with value: 0.1751361161524501 and parameters: {'n_estimators': 1928, 'max_depth': 26, 'min_samples_split': 9, 'min_samples_leaf': 3, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 0 with value: 0.18037518037518036.
# [I 2024-08-23 00:15:40,446] Trial 3 finished with value: 0.1732783243414789 and parameters: {'n_estimators': 1098, 'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 4, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 0 with value: 0.18037518037518036.
# [I 2024-08-23 00:16:00,194] Trial 4 finished with value: 0.18151260504201683 and parameters: {'n_estimators': 847, 'max_depth': 65, 'min_samples_split': 3, 'min_samples_leaf': 4, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 4 with value: 0.18151260504201683.
# [I 2024-08-23 00:16:35,973] Trial 5 finished with value: 0.17906030336662968 and parameters: {'n_estimators': 1491, 'max_depth': 82, 'min_samples_split': 13, 'min_samples_leaf': 4, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 4 with value: 0.18151260504201683.
# [I 2024-08-23 00:17:09,057] Trial 6 finished with value: 0.1678400450577302 and parameters: {'n_estimators': 1537, 'max_depth': 22, 'min_samples_split': 3, 'min_samples_leaf': 7, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 4 with value: 0.18151260504201683.
# [I 2024-08-23 00:17:50,979] Trial 7 finished with value: 0.17673814165042234 and parameters: {'n_estimators': 1880, 'max_depth': 40, 'min_samples_split': 16, 'min_samples_leaf': 5, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 4 with value: 0.18151260504201683.
# [I 2024-08-23 00:18:28,437] Trial 8 finished with value: 0.17688831504196256 and parameters: {'n_estimators': 1648, 'max_depth': 72, 'min_samples_split': 5, 'min_samples_leaf': 6, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 4 with value: 0.18151260504201683.
# [I 2024-08-23 00:18:49,898] Trial 9 finished with value: 0.18156028368794327 and parameters: {'n_estimators': 888, 'max_depth': 68, 'min_samples_split': 5, 'min_samples_leaf': 2, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 9 with value: 0.18156028368794327.
# [I 2024-08-23 00:19:57,491] Trial 10 finished with value: 0.1924342105263158 and parameters: {'n_estimators': 2663, 'max_depth': 100, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 00:21:12,303] Trial 11 finished with value: 0.19164619164619168 and parameters: {'n_estimators': 2962, 'max_depth': 98, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 00:22:27,165] Trial 12 finished with value: 0.1903199343724364 and parameters: {'n_estimators': 2995, 'max_depth': 99, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 00:23:43,184] Trial 13 finished with value: 0.17859064012910164 and parameters: {'n_estimators': 2901, 'max_depth': 97, 'min_samples_split': 12, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 00:24:46,754] Trial 14 finished with value: 0.18316831683168316 and parameters: {'n_estimators': 2571, 'max_depth': 85, 'min_samples_split': 7, 'min_samples_leaf': 2, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 00:25:48,390] Trial 15 finished with value: 0.19011406844106463 and parameters: {'n_estimators': 2574, 'max_depth': 53, 'min_samples_split': 2, 'min_samples_leaf': 2, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 00:26:52,402] Trial 16 finished with value: 0.17087378640776701 and parameters: {'n_estimators': 2652, 'max_depth': 90, 'min_samples_split': 14, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 00:27:40,183] Trial 17 finished with value: 0.16615211900084198 and parameters: {'n_estimators': 2276, 'max_depth': 56, 'min_samples_split': 7, 'min_samples_leaf': 8, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 00:28:46,650] Trial 18 finished with value: 0.17375727720555306 and parameters: {'n_estimators': 2773, 'max_depth': 93, 'min_samples_split': 10, 'min_samples_leaf': 3, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 00:29:43,374] Trial 19 finished with value: 0.17756512493354598 and parameters: {'n_estimators': 2293, 'max_depth': 81, 'min_samples_split': 4, 'min_samples_leaf': 3, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 00:30:44,065] Trial 20 finished with value: 0.18328173374613002 and parameters: {'n_estimators': 2437, 'max_depth': 45, 'min_samples_split': 7, 'min_samples_leaf': 2, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 00:31:57,945] Trial 21 finished with value: 0.19211822660098524 and parameters: {'n_estimators': 2981, 'max_depth': 100, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 00:33:05,714] Trial 22 finished with value: 0.17968210089841052 and parameters: {'n_estimators': 2808, 'max_depth': 100, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 00:34:24,988] Trial 23 finished with value: 0.17828571428571427 and parameters: {'n_estimators': 2996, 'max_depth': 88, 'min_samples_split': 11, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 00:35:30,305] Trial 24 finished with value: 0.18568391211906451 and parameters: {'n_estimators': 2718, 'max_depth': 93, 'min_samples_split': 5, 'min_samples_leaf': 2, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 00:36:32,325] Trial 25 finished with value: 0.17446808510638298 and parameters: {'n_estimators': 2481, 'max_depth': 80, 'min_samples_split': 4, 'min_samples_leaf': 3, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 00:37:48,467] Trial 26 finished with value: 0.17708333333333334 and parameters: {'n_estimators': 2841, 'max_depth': 93, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 00:38:35,211] Trial 27 finished with value: 0.18169848584595127 and parameters: {'n_estimators': 1962, 'max_depth': 100, 'min_samples_split': 6, 'min_samples_leaf': 2, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 00:39:25,999] Trial 28 finished with value: 0.1706801858893114 and parameters: {'n_estimators': 2125, 'max_depth': 88, 'min_samples_split': 17, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 00
 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 01:45:10,333] Trial 90 finished with value: 0.17817947062621042 and parameters: {'n_estimators': 2638, 'max_depth': 83, 'min_samples_split': 6, 'min_samples_leaf': 6, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 01:46:18,784] Trial 91 finished with value: 0.191960623461854 and parameters: {'n_estimators': 2730, 'max_depth': 97, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 01:47:24,899] Trial 92 finished with value: 0.191960623461854 and parameters: {'n_estimators': 2684, 'max_depth': 98, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 01:48:27,027] Trial 93 finished with value: 0.1849112426035503 and parameters: {'n_estimators': 2556, 'max_depth': 92, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 01:49:35,709] Trial 94 finished with value: 0.18005540166204986 and parameters: {'n_estimators': 2834, 'max_depth': 96, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 01:50:43,360] Trial 95 finished with value: 0.19227608874281021 and parameters: {'n_estimators': 2763, 'max_depth': 99, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 01:51:49,343] Trial 96 finished with value: 0.1854210898796886 and parameters: {'n_estimators': 2761, 'max_depth': 100, 'min_samples_split': 5, 'min_samples_leaf': 2, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 01:53:02,858] Trial 97 finished with value: 0.19021739130434784 and parameters: {'n_estimators': 2940, 'max_depth': 90, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 01:53:46,609] Trial 98 finished with value: 0.1827309236947791 and parameters: {'n_estimators': 1744, 'max_depth': 94, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 01:54:55,356] Trial 99 finished with value: 0.1716957076073098 and parameters: {'n_estimators': 2870, 'max_depth': 96, 'min_samples_split': 17, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 01:55:14,556] Trial 100 finished with value: 0.1822985468956407 and parameters: {'n_estimators': 813, 'max_depth': 91, 'min_samples_split': 6, 'min_samples_leaf': 2, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 01:56:19,736] Trial 101 finished with value: 0.19227608874281021 and parameters: {'n_estimators': 2635, 'max_depth': 98, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 01:57:21,661] Trial 102 finished with value: 0.17079010375099762 and parameters: {'n_estimators': 2648, 'max_depth': 99, 'min_samples_split': 19, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 01:58:21,869] Trial 103 finished with value: 0.18156618156618154 and parameters: {'n_estimators': 2482, 'max_depth': 95, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 01:59:10,975] Trial 104 finished with value: 0.1835677276091784 and parameters: {'n_estimators': 2013, 'max_depth': 99, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 02:00:15,671] Trial 105 finished with value: 0.19211822660098524 and parameters: {'n_estimators': 2613, 'max_depth': 96, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 02:01:20,657] Trial 106 finished with value: 0.19227608874281021 and parameters: {'n_estimators': 2621, 'max_depth': 93, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 02:02:31,219] Trial 107 finished with value: 0.1907356948228883 and parameters: {'n_estimators': 2782, 'max_depth': 93, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 02:03:05,599] Trial 108 finished with value: 0.1845386533665835 and parameters: {'n_estimators': 1448, 'max_depth': 86, 'min_samples_split': 7, 'min_samples_leaf': 2, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 02:04:18,215] Trial 109 finished with value: 0.17373530914665306 and parameters: {'n_estimators': 2870, 'max_depth': 90, 'min_samples_split': 13, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 02:05:30,720] Trial 110 finished with value: 0.1835677276091784 and parameters: {'n_estimators': 2937, 'max_depth': 100, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 02:06:35,738] Trial 111 finished with value: 0.19211822660098524 and parameters: {'n_estimators': 2613, 'max_depth': 96, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 02:07:41,852] Trial 112 finished with value: 0.17807308970099664 and parameters: {'n_estimators': 2737, 'max_depth': 23, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 02:08:46,966] Trial 113 finished with value: 0.19211822660098524 and parameters: {'n_estimators': 2620, 'max_depth': 92, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 02:09:56,700] Trial 114 finished with value: 0.1907356948228883 and parameters: {'n_estimators': 2810, 'max_depth': 94, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 02:11:03,964] Trial 115 finished with value: 0.191960623461854 and parameters: {'n_estimators': 2690, 'max_depth': 98, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 02:12:13,648] Trial 116 finished with value: 0.19038984587488667 and parameters: {'n_estimators': 2756, 'max_depth': 96, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 02:13:15,015] Trial 117 finished with value: 0.18305504019789734 and parameters: {'n_estimators': 2466, 'max_depth': 88, 'min_samples_split': 7, 'min_samples_leaf': 2, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 02:14:21,292] Trial 118 finished with value: 0.18316831683168316 and parameters: {'n_estimators': 2680, 'max_depth': 100, 'min_samples_split': 7, 'min_samples_leaf': 2, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 02:15:33,578] Trial 119 finished with value: 0.1829145728643216 and parameters: {'n_estimators': 2835, 'max_depth': 94, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 02:16:38,162] Trial 120 finished with value: 0.19227608874281021 and parameters: {'n_estimators': 2588, 'max_depth': 98, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 02:17:42,878] Trial 121 finished with value: 0.19227608874281021 and parameters: {'n_estimators': 2595, 'max_depth': 98, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 02:18:45,128] Trial 122 finished with value: 0.191960623461854 and parameters: {'n_estimators': 
 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 04:57:48,358] Trial 270 finished with value: 0.1846381093057607 and parameters: {'n_estimators': 2749, 'max_depth': 57, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 04:58:55,247] Trial 271 finished with value: 0.19211822660098524 and parameters: {'n_estimators': 2812, 'max_depth': 99, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 04:59:59,273] Trial 272 finished with value: 0.18823529411764706 and parameters: {'n_estimators': 2660, 'max_depth': 96, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:01:03,412] Trial 273 finished with value: 0.19211822660098524 and parameters: {'n_estimators': 2708, 'max_depth': 99, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:02:06,213] Trial 274 finished with value: 0.19211822660098524 and parameters: {'n_estimators': 2650, 'max_depth': 94, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:03:10,860] Trial 275 finished with value: 0.18436578171091447 and parameters: {'n_estimators': 2765, 'max_depth': 47, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:04:14,038] Trial 276 finished with value: 0.18504811250925243 and parameters: {'n_estimators': 2692, 'max_depth': 100, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:05:16,470] Trial 277 finished with value: 0.19021739130434784 and parameters: {'n_estimators': 2629, 'max_depth': 97, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:06:26,080] Trial 278 finished with value: 0.17898832684824903 and parameters: {'n_estimators': 2728, 'max_depth': 96, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:07:27,495] Trial 279 finished with value: 0.18169848584595127 and parameters: {'n_estimators': 2687, 'max_depth': 98, 'min_samples_split': 6, 'min_samples_leaf': 2, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:08:28,260] Trial 280 finished with value: 0.19211822660098524 and parameters: {'n_estimators': 2562, 'max_depth': 66, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:09:29,706] Trial 281 finished with value: 0.1849112426035503 and parameters: {'n_estimators': 2641, 'max_depth': 61, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:10:02,732] Trial 282 finished with value: 0.1897689768976898 and parameters: {'n_estimators': 1400, 'max_depth': 100, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:11:11,017] Trial 283 finished with value: 0.19021739130434784 and parameters: {'n_estimators': 2825, 'max_depth': 98, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:12:12,739] Trial 284 finished with value: 0.19211822660098524 and parameters: {'n_estimators': 2607, 'max_depth': 95, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:13:09,094] Trial 285 finished with value: 0.17207502232807387 and parameters: {'n_estimators': 2734, 'max_depth': 97, 'min_samples_split': 6, 'min_samples_leaf': 7, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:14:13,009] Trial 286 finished with value: 0.18874773139745915 and parameters: {'n_estimators': 2675, 'max_depth': 93, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:15:18,998] Trial 287 finished with value: 0.19211822660098524 and parameters: {'n_estimators': 2773, 'max_depth': 99, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:16:20,279] Trial 288 finished with value: 0.18504811250925243 and parameters: {'n_estimators': 2617, 'max_depth': 100, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:17:18,522] Trial 289 finished with value: 0.17201646090534978 and parameters: {'n_estimators': 2575, 'max_depth': 55, 'min_samples_split': 18, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:18:21,959] Trial 290 finished with value: 0.1924342105263158 and parameters: {'n_estimators': 2664, 'max_depth': 96, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:19:27,161] Trial 291 finished with value: 0.19021739130434784 and parameters: {'n_estimators': 2714, 'max_depth': 95, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:20:29,019] Trial 292 finished with value: 0.1849112426035503 and parameters: {'n_estimators': 2647, 'max_depth': 94, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:21:29,882] Trial 293 finished with value: 0.191960623461854 and parameters: {'n_estimators': 2567, 'max_depth': 92, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:22:37,681] Trial 294 finished with value: 0.17446808510638298 and parameters: {'n_estimators': 2792, 'max_depth': 98, 'min_samples_split': 6, 'min_samples_leaf': 3, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:23:23,463] Trial 295 finished with value: 0.18541854185418544 and parameters: {'n_estimators': 1916, 'max_depth': 96, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:24:23,255] Trial 296 finished with value: 0.19164619164619168 and parameters: {'n_estimators': 2510, 'max_depth': 100, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:24:45,074] Trial 297 finished with value: 0.18521284540702015 and parameters: {'n_estimators': 936, 'max_depth': 98, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:25:43,645] Trial 298 finished with value: 0.18181818181818182 and parameters: {'n_estimators': 2700, 'max_depth': 96, 'min_samples_split': 6, 'min_samples_leaf': 5, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# [I 2024-08-23 05:26:47,109] Trial 299 finished with value: 0.19021739130434784 and parameters: {'n_estimators': 2624, 'max_depth': 99, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 10 with value: 0.1924342105263158.
# Best trial: score 0.1924342105263158,
# params {'n_estimators': 2663, 'max_depth': 100, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}

# %% [markdown]
# Best trial: score 0.1924342105263158,
# params {'n_estimators': 2663, 'max_depth': 100, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy', 'class_weight': 'balanced'}

# %% [markdown]
# .
