# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ### 데이터 읽어오기

# %%
import pandas as pd

THRESHOLD = 0.3
RANDOM_STATE = 110

train_data = pd.read_csv("../../../data/train_data_0817.csv")
test_data = pd.read_csv("../../../data/test_data_0817.csv")

# %%
train_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40506 entries, 0 to 40505
# Data columns (total 38 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   CURE SPEED Collect Result_Dam                   40506 non-null  int64
#  1   DISCHARGED SPEED OF RESIN Collect Result_Dam    40506 non-null  int64
#  2   Head Clean Position Z Collect Result_Dam        40506 non-null  float64
#  3   Head Purge Position Z Collect Result_Dam        40506 non-null  float64
#  4   Head Zero Position Y Collect Result_Dam         40506 non-null  float64
#  5   Stage2_Circle_Distance_Speed_Dam                40506 non-null  int64
#  6   WorkMode Collect Result                         40506 non-null  float64
#  7   Chamber Temp. Collect Result_AutoClave          40506 non-null  int64
#  8   DISCHARGED SPEED OF RESIN Collect Result_Fill1  40506 non-null  float64
#  9   Head Purge Position Z Collect Result_Fill1      40506 non-null  int64
#  10  CURE SPEED Collect Result_Fill2                 40506 non-null  int64
#  11  Head Purge Position Z Collect Result_Fill2      40506 non-null  float64
#  12  target                                          40506 non-null  object
#  13  Equipment_same_num                              40506 non-null  int64
#  14  Production_Qty_Collect_Result                   40506 non-null  int64
#  15  CURE_DISTANCE_Dam                               40506 non-null  float64
#  16  HEAD NORMAL DISTANCE_STAGE1_STAGE3_Dam          40506 non-null  float64
#  17  HEAD NORMAL DISTANCE_TRIANGLE_height_Dam        40506 non-null  float64
#  18  HEAD NORMAL DISTANCE_STAGE1_STAGE3_Fill1        40506 non-null  float64
#  19  HEAD NORMAL DISTANCE_TRIANGLE_height_Fill1      40506 non-null  float64
#  20  HEAD NORMAL DISTANCE_STAGE1_STAGE2_Fill2        40506 non-null  float64
#  21  volume_time_multip_avg_Dam                      40506 non-null  float64
#  22  volume_time_multip_avg_Fill1                    40506 non-null  float64
#  23  average_thickness_Dam                           40506 non-null  float64
#  24  1st_pressure_time_AutoClave                     40506 non-null  float64
#  25  2nd_pressure_time_AutoClave                     40506 non-null  float64
#  26  3rd_pressure_time_AutoClave                     40506 non-null  float64
#  27  time_ratio_Dam                                  40506 non-null  float64
#  28  time_ratio_Fill1                                40506 non-null  float64
#  29  time_ratio_Fill2                                40506 non-null  float64
#  30  time_ratio_AutoClave                            40506 non-null  float64
#  31  model_receip_encoded                            40506 non-null  float64
#  32  workorder_receip_encoded                        40506 non-null  float64
#  33  PalletID_Collect_Result_encoded                 40506 non-null  float64
#  34  cure_end_position_XZ_Fill2_encoded              40506 non-null  float64
#  35  cure_start_position_XZ_Fill2_encoded            40506 non-null  float64
#  36  stage1_line13_distance_speed_Dam_encoded        40506 non-null  float64
#  37  stage2_line24_distance_speed_Dam_encoded        40506 non-null  float64
# dtypes: float64(29), int64(8), object(1)
# memory usage: 11.7+ MB

# %%
# dam, fill1, fill2 공통 변수
var_dam_fill = [
    'Equipment_same_num',
    'PalletID_Collect_Result_encoded',
    'Production_Qty_Collect_Result',
    'WorkMode Collect Result'
]

# %%
# 전체 공통 변수
### correlation 확인을 위한 변수 리스트
var_all_corr = [
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### train
var_all_train = [
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### test
var_all_test = [
    'Set ID',
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

# %%
# '_Dam'을 포함하는 변수 선택
dam_variables = [var for var in train_data.columns if '_Dam' in var]

# train
final_columns_train = var_dam_fill + var_all_train + dam_variables
train_data_dam = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + dam_variables
test_data_dam = test_data[final_columns_test]

# %%
# '_Fill1'을 포함하는 변수 선택
fill1_variables = [var for var in train_data.columns if '_Fill1' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill1_variables
train_data_fill1 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill1_variables
test_data_fill1 = test_data[final_columns_test]

# %%
# '_Fill2'을 포함하는 변수 선택
fill2_variables = [var for var in train_data.columns if '_Fill2' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill2_variables
train_data_fill2 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill2_variables
test_data_fill2 = test_data[final_columns_test]

# %%
# '_AutoClave'을 포함하는 변수 선택
autoclave_variables = [var for var in train_data.columns if '_AutoClave' in var]

# train
final_columns_train = var_all_train + autoclave_variables
train_data_autoclave = train_data[final_columns_train]

# test 
final_columns_test = var_all_test + autoclave_variables
test_data_autoclave = test_data[final_columns_test]

# %%
# 각 DataFrame의 칼럼 수 계산
num_columns_train_data = train_data.shape[1]
num_columns_train_data_dam = train_data_dam.shape[1]
num_columns_train_data_autoclave = train_data_autoclave.shape[1]
num_columns_train_data_fill1 = train_data_fill1.shape[1]
num_columns_train_data_fill2 = train_data_fill2.shape[1]

num_columns_test_data = test_data.shape[1]
num_columns_test_data_dam = test_data_dam.shape[1]
num_columns_test_data_autoclave = test_data_autoclave.shape[1]
num_columns_test_data_fill1 = test_data_fill1.shape[1]
num_columns_test_data_fill2 = test_data_fill2.shape[1]

# 각 DataFrame의 칼럼 수 출력
print("----train data-----")
print(f"train_data DataFrame의 칼럼 수: {num_columns_train_data}")
print(f"train_data_dam DataFrame의 칼럼 수: {num_columns_train_data_dam}")
print(f"train_data_autoclave DataFrame의 칼럼 수: {num_columns_train_data_autoclave}")
print(f"train_data_fill1 DataFrame의 칼럼 수: {num_columns_train_data_fill1}")
print(f"train_data_fill2 DataFrame의 칼럼 수: {num_columns_train_data_fill2}")
print("----test data-----")
print(f"test_data DataFrame의 칼럼 수: {num_columns_test_data}")
print(f"test_data_dam DataFrame의 칼럼 수: {num_columns_test_data_dam}")
print(f"test_data_autoclave DataFrame의 칼럼 수: {num_columns_test_data_autoclave}")
print(f"test_data_fill1 DataFrame의 칼럼 수: {num_columns_test_data_fill1}")
print(f"test_data_fill2 DataFrame의 칼럼 수: {num_columns_test_data_fill2}")
# Out:
# ----train data-----
# train_data DataFrame의 칼럼 수: 38
# train_data_dam DataFrame의 칼럼 수: 21
# train_data_autoclave DataFrame의 칼럼 수: 8
# train_data_fill1 DataFrame의 칼럼 수: 13
# train_data_fill2 DataFrame의 칼럼 수: 13
# ----test data-----
# test_data DataFrame의 칼럼 수: 39
# test_data_dam DataFrame의 칼럼 수: 22
# test_data_autoclave DataFrame의 칼럼 수: 9
# test_data_fill1 DataFrame의 칼럼 수: 14
# test_data_fill2 DataFrame의 칼럼 수: 14

# %% [markdown]
# ---

# %% [markdown]
# ## Optuna

# %% [markdown]
# 스레스홀드 0.3으로 맞춘상태에서 튜닝 진행한 것

# %%
# import optuna
# from lightgbm import LGBMClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import f1_score

# # 'Normal'과 'AbNormal'을 숫자로 변환
# train_data_fill1['target'] = train_data_fill1['target'].map({'Normal': 0, 'AbNormal': 1})

# # 스레드홀드 설정
# THRESHOLD = 0.3

# def objectiveLGBM_dart(trial, x_tr, y_tr, x_val, y_val):
#     param = {
#         'n_estimators': trial.suggest_int('n_estimators', 500, 3000),
#         'num_leaves': trial.suggest_int('num_leaves', 500, 3000),
#         'max_depth': trial.suggest_int('max_depth', 10, 300),
#         'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1),
#         'min_child_samples': trial.suggest_int('min_child_samples', 3, 300),
        
#         'boosting_type': 'dart',  # 'boosting'를 'boosting_type'으로 수정
#         'random_state': RANDOM_STATE,
#         'verbose': -1
#     }
       
#     model = LGBMClassifier(**param)
#     model.fit(x_tr, y_tr)
#     pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
#     pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
    
#     score = f1_score(y_val, pred, average="binary")
    
#     return score

# # 데이터셋 분할
# x_train, x_val, y_train, y_val = train_test_split(
#     train_data_fill1.drop("target", axis=1),
#     train_data_fill1["target"],
#     test_size=0.2,
#     shuffle=True,
#     random_state=RANDOM_STATE,
# )

# # 하이퍼 파라미터 튜닝
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=200)

# print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))

# %% [markdown]
# Trial 35 finished with value: 0.21714285714285714
# parameters: {'n_estimators': 1399, 'num_leaves': 1456, 'max_depth': 38,
# 'learning_rate': 0.0020188481674757053, 'min_child_samples': 21}

# %%
# import optuna
# from lightgbm import LGBMClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import f1_score

# # 'Normal'과 'AbNormal'을 숫자로 변환
# train_data_fill1['target'] = train_data_fill1['target'].map({'Normal': 0, 'AbNormal': 1})

# # 스레드홀드 설정
# THRESHOLD = 0.3

# def objectiveLGBM_dart(trial, x_tr, y_tr, x_val, y_val):
#     param = {
#         'n_estimators': trial.suggest_int('n_estimators', 600, 2800),
#         'num_leaves': trial.suggest_int('num_leaves', 1000, 3000),
#         'max_depth': trial.suggest_int('max_depth', 10, 100),
#         'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1),
#         'min_child_samples': trial.suggest_int('min_child_samples', 3, 100),
        
#         'boosting_type': 'dart',  # 'boosting'를 'boosting_type'으로 수정
#         'random_state': RANDOM_STATE,
#         'verbose': -1
#     }
       
#     model = LGBMClassifier(**param)
#     model.fit(x_tr, y_tr)
#     pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
#     pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
    
#     score = f1_score(y_val, pred, average="binary")
    
#     return score

# # 데이터셋 분할
# x_train, x_val, y_train, y_val = train_test_split(
#     train_data_fill1.drop("target", axis=1),
#     train_data_fill1["target"],
#     test_size=0.2,
#     shuffle=True,
#     random_state=RANDOM_STATE,
# )

# # 하이퍼 파라미터 튜닝
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=300)

# print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))

# %% [markdown]
# Trial 2 finished with value: 0.2260668973471742
# parameters: {'n_estimators': 1452, 'num_leaves': 1581, 'max_depth': 22, 'learning_rate': 0.002000452888170992, 'min_child_samples': 43}.

# %% [markdown]
# 한번더 돌렸을때 더 낮은 성능

# %%
import optuna
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# 'Normal'과 'AbNormal'을 숫자로 변환
train_data_fill1['target'] = train_data_fill1['target'].map({'Normal': 0, 'AbNormal': 1})

# 스레드홀드 설정
THRESHOLD = 0.3

def objectiveLGBM_dart(trial, x_tr, y_tr, x_val, y_val):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 500, 3500),
        'num_leaves': trial.suggest_int('num_leaves', 1000, 3000),
        'max_depth': trial.suggest_int('max_depth', 10, 100),
        'learning_rate': trial.suggest_float('learning_rate', 0.0003, 0.3),
        'min_child_samples': trial.suggest_int('min_child_samples', 3, 100),
        
        'boosting_type': 'dart',  # 'boosting'를 'boosting_type'으로 수정
        'random_state': RANDOM_STATE,
        'verbose': -1
    }
       
    model = LGBMClassifier(**param)
    model.fit(x_tr, y_tr)
    pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
    pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
    
    score = f1_score(y_val, pred, average="binary")
    
    return score

# 데이터셋 분할
x_train, x_val, y_train, y_val = train_test_split(
    train_data_fill1.drop("target", axis=1),
    train_data_fill1["target"],
    test_size=0.2,
    shuffle=True,
    random_state=RANDOM_STATE,
)

# 하이퍼 파라미터 튜닝
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=300)

print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# C:\Users\juneh\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# [I 2024-08-22 00:23:29,825] A new study created in memory with name: no-name-272167b9-32c5-4090-b176-e6bde723b495
# [I 2024-08-22 00:25:14,377] Trial 0 finished with value: 0.19089574155653452 and parameters: {'n_estimators': 848, 'num_leaves': 2317, 'max_depth': 44, 'learning_rate': 0.18395093969213586, 'min_child_samples': 69}. Best is trial 0 with value: 0.19089574155653452.
# [I 2024-08-22 00:38:09,779] Trial 1 finished with value: 0.20535714285714288 and parameters: {'n_estimators': 2548, 'num_leaves': 2910, 'max_depth': 67, 'learning_rate': 0.15402919924162803, 'min_child_samples': 11}. Best is trial 1 with value: 0.20535714285714288.
# [I 2024-08-22 00:43:20,598] Trial 2 finished with value: 0.20880913539967372 and parameters: {'n_estimators': 1662, 'num_leaves': 1581, 'max_depth': 22, 'learning_rate': 0.0033286437432812747, 'min_child_samples': 43}. Best is trial 2 with value: 0.20880913539967372.
# [I 2024-08-22 00:50:08,220] Trial 3 finished with value: 0.20821114369501467 and parameters: {'n_estimators': 1978, 'num_leaves': 1042, 'max_depth': 60, 'learning_rate': 0.023561721119973494, 'min_child_samples': 42}. Best is trial 2 with value: 0.20880913539967372.
# [I 2024-08-22 00:56:15,495] Trial 4 finished with value: 0.20520673813169985 and parameters: {'n_estimators': 1442, 'num_leaves': 2541, 'max_depth': 64, 'learning_rate': 0.12538224344127344, 'min_child_samples': 35}. Best is trial 2 with value: 0.20880913539967372.
# [I 2024-08-22 00:59:16,379] Trial 5 finished with value: 0.21069182389937108 and parameters: {'n_estimators': 575, 'num_leaves': 1179, 'max_depth': 87, 'learning_rate': 0.1474860351915402, 'min_child_samples': 27}. Best is trial 5 with value: 0.21069182389937108.
# [I 2024-08-22 01:11:16,491] Trial 6 finished with value: 0.20116618075801748 and parameters: {'n_estimators': 2784, 'num_leaves': 2081, 'max_depth': 45, 'learning_rate': 0.19332900436168748, 'min_child_samples': 19}. Best is trial 5 with value: 0.21069182389937108.
# [I 2024-08-22 01:25:05,210] Trial 7 finished with value: 0.2066772655007949 and parameters: {'n_estimators': 2628, 'num_leaves': 1080, 'max_depth': 64, 'learning_rate': 0.06124285172137882, 'min_child_samples': 27}. Best is trial 5 with value: 0.21069182389937108.
# [I 2024-08-22 01:31:02,719] Trial 8 finished with value: 0.19970631424375918 and parameters: {'n_estimators': 1697, 'num_leaves': 2428, 'max_depth': 82, 'learning_rate': 0.26849303362178684, 'min_child_samples': 24}. Best is trial 5 with value: 0.21069182389937108.
# [I 2024-08-22 01:31:51,310] Trial 9 finished with value: 0.2016348773841962 and parameters: {'n_estimators': 538, 'num_leaves': 2522, 'max_depth': 26, 'learning_rate': 0.2381283650041344, 'min_child_samples': 96}. Best is trial 5 with value: 0.21069182389937108.
# [I 2024-08-22 01:35:01,819] Trial 10 finished with value: 0.19705882352941176 and parameters: {'n_estimators': 1112, 'num_leaves': 1483, 'max_depth': 96, 'learning_rate': 0.10272850641237355, 'min_child_samples': 64}. Best is trial 5 with value: 0.21069182389937108.
# [I 2024-08-22 01:36:52,009] Trial 11 finished with value: 0.21217391304347824 and parameters: {'n_estimators': 1283, 'num_leaves': 1577, 'max_depth': 11, 'learning_rate': 0.019448638115749373, 'min_child_samples': 52}. Best is trial 11 with value: 0.21217391304347824.
# [I 2024-08-22 01:39:03,245] Trial 12 finished with value: 0.21337579617834396 and parameters: {'n_estimators': 542, 'num_leaves': 1543, 'max_depth': 12, 'learning_rate': 0.0765910430095935, 'min_child_samples': 3}. Best is trial 12 with value: 0.21337579617834396.
# [I 2024-08-22 01:48:07,328] Trial 13 finished with value: 0.20097244732576988 and parameters: {'n_estimators': 3407, 'num_leaves': 1694, 'max_depth': 11, 'learning_rate': 0.0728836649780788, 'min_child_samples': 4}. Best is trial 12 with value: 0.21337579617834396.
# [I 2024-08-22 01:49:30,529] Trial 14 finished with value: 0.19639934533551553 and parameters: {'n_estimators': 1131, 'num_leaves': 1896, 'max_depth': 11, 'learning_rate': 0.054999541611827046, 'min_child_samples': 59}. Best is trial 12 with value: 0.21337579617834396.
# [I 2024-08-22 01:52:10,378] Trial 15 finished with value: 0.18471337579617833 and parameters: {'n_estimators': 1171, 'num_leaves': 1362, 'max_depth': 29, 'learning_rate': 0.027593699926996992, 'min_child_samples': 84}. Best is trial 12 with value: 0.21337579617834396.
# [I 2024-08-22 01:55:07,979] Trial 16 finished with value: 0.2055800293685756 and parameters: {'n_estimators': 828, 'num_leaves': 1838, 'max_depth': 39, 'learning_rate': 0.08811459218396683, 'min_child_samples': 49}. Best is trial 12 with value: 0.21337579617834396.
# [I 2024-08-22 01:59:26,921] Trial 17 finished with value: 0.19830028328611896 and parameters: {'n_estimators': 2214, 'num_leaves': 1391, 'max_depth': 20, 'learning_rate': 0.04732383396784336, 'min_child_samples': 76}. Best is trial 12 with value: 0.21337579617834396.
# [I 2024-08-22 02:04:00,941] Trial 18 finished with value: 0.16633323806801945 and parameters: {'n_estimators': 1490, 'num_leaves': 2064, 'max_depth': 37, 'learning_rate': 0.0011000548922994492, 'min_child_samples': 51}. Best is trial 12 with value: 0.21337579617834396.
# [I 2024-08-22 02:05:40,240] Trial 19 finished with value: 0.22439024390243903 and parameters: {'n_estimators': 851, 'num_leaves': 1633, 'max_depth': 10, 'learning_rate': 0.09744469785792398, 'min_child_samples': 3}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 02:11:20,783] Trial 20 finished with value: 0.19769357495881384 and parameters: {'n_estimators': 834, 'num_leaves': 1271, 'max_depth': 50, 'learning_rate': 0.11785850729753859, 'min_child_samples': 3}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 02:12:14,298] Trial 21 finished with value: 0.19601328903654486 and parameters: {'n_estimators': 525, 'num_leaves': 1717, 'max_depth': 11, 'learning_rate': 0.0861507229779276, 'min_child_samples': 13}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 02:15:13,219] Trial 22 finished with value: 0.2084592145015106 and parameters: {'n_estimators': 937, 'num_leaves': 1576, 'max_depth': 20, 'learning_rate': 0.03944487442592975, 'min_child_samples': 35}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 02:24:46,240] Trial 23 finished with value: 0.2057877813504823 and parameters: {'n_estimators': 1342, 'num_leaves': 1757, 'max_depth': 32, 'learning_rate': 0.11141452017911774, 'min_child_samples': 14}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 02:26:01,942] Trial 24 finished with value: 0.20458015267175575 and parameters: {'n_estimators': 697, 'num_leaves': 1983, 'max_depth': 18, 'learning_rate': 0.07579776301090467, 'min_child_samples': 57}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 02:27:51,035] Trial 25 finished with value: 0.2074074074074074 and parameters: {'n_estimators': 1015, 'num_leaves': 1523, 'max_depth': 16, 'learning_rate': 0.1458401874129135, 'min_child_samples': 35}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 02:51:05,739] Trial 26 finished with value: 0.19837398373983742 and parameters: {'n_estimators': 1798, 'num_leaves': 2196, 'max_depth': 32, 'learning_rate': 0.023173549913552714, 'min_child_samples': 5}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 02:52:52,869] Trial 27 finished with value: 0.21263482280431437 and parameters: {'n_estimators': 1279, 'num_leaves': 1275, 'max_depth': 10, 'learning_rate': 0.08721417186233074, 'min_child_samples': 21}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 02:56:58,383] Trial 28 finished with value: 0.19902120717781402 and parameters: {'n_estimators': 825, 'num_leaves': 1248, 'max_depth': 23, 'learning_rate': 0.17863241739366215, 'min_child_samples': 20}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 03:02:47,949] Trial 29 finished with value: 0.20257234726688106 and parameters: {'n_estimators': 688, 'num_leaves': 1411, 'max_depth': 73, 'learning_rate': 0.1722698026567965, 'min_child_samples': 9}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 03:11:59,370] Trial 30 finished with value: 0.2073365231259968 and parameters: {'n_estimators': 1507, 'num_leaves': 1208, 'max_depth': 37, 'learning_rate': 0.0985673379212345, 'min_child_samples': 20}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 03:14:04,399] Trial 31 finished with value: 0.21362229102167185 and parameters: {'n_estimators': 1264, 'num_leaves': 1648, 'max_depth': 10, 'learning_rate': 0.06425097325033235, 'min_child_samples': 14}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 03:18:48,168] Trial 32 finished with value: 0.2032258064516129 and parameters: {'n_estimators': 968, 'num_leaves': 1665, 'max_depth': 16, 'learning_rate': 0.12770288626162934, 'min_child_samples': 11}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 03:20:32,720] Trial 33 finished with value: 0.208398133748056 and parameters: {'n_estimators': 1282, 'num_leaves': 2806, 'max_depth': 10, 'learning_rate': 0.06822902602974054, 'min_child_samples': 17}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 03:31:24,347] Trial 34 finished with value: 0.20189274447949526 and parameters: {'n_estimators': 2133, 'num_leaves': 1384, 'max_depth': 26, 'learning_rate': 0.09086161161774059, 'min_child_samples': 7}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 03:32:48,337] Trial 35 finished with value: 0.19440353460972018 and parameters: {'n_estimators': 692, 'num_leaves': 1847, 'max_depth': 15, 'learning_rate': 0.1362858119894051, 'min_child_samples': 30}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 03:45:02,531] Trial 36 finished with value: 0.19966722129783696 and parameters: {'n_estimators': 1832, 'num_leaves': 1114, 'max_depth': 24, 'learning_rate': 0.048331081175451436, 'min_child_samples': 11}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 03:53:32,297] Trial 37 finished with value: 0.19173553719008266 and parameters: {'n_estimators': 1631, 'num_leaves': 1025, 'max_depth': 16, 'learning_rate': 0.10981658744462298, 'min_child_samples': 3}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 04:00:23,841] Trial 38 finished with value: 0.20155038759689922 and parameters: {'n_estimators': 1064, 'num_leaves': 1625, 'max_depth': 56, 'learning_rate': 0.20808483241117057, 'min_child_samples': 17}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 04:12:06,612] Trial 39 finished with value: 0.20123839009287928 and parameters: {'n_estimators': 3076, 'num_leaves': 1481, 'max_depth': 43, 'learning_rate': 0.0750542406667464, 'min_child_samples': 42}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 04:20:21,413] Trial 40 finished with value: 0.20731707317073172 and parameters: {'n_estimators': 2015, 'num_leaves': 2226, 'max_depth': 29, 'learning_rate': 0.12573239096022604, 'min_child_samples': 24}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 04:22:01,664] Trial 41 finished with value: 0.20422535211267603 and parameters: {'n_estimators': 1307, 'num_leaves': 1305, 'max_depth': 10, 'learning_rate': 0.02406059724454912, 'min_child_samples': 46}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 04:24:37,209] Trial 42 finished with value: 0.21453287197231832 and parameters: {'n_estimators': 1229, 'num_leaves': 1599, 'max_depth': 14, 'learning_rate': 0.01617396826618185, 'min_child_samples': 56}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 04:26:14,566] Trial 43 finished with value: 0.19439868204283361 and parameters: {'n_estimators': 721, 'num_leaves': 1758, 'max_depth': 21, 'learning_rate': 0.036950569797530405, 'min_child_samples': 68}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 04:33:28,828] Trial 44 finished with value: 0.2066772655007949 and parameters: {'n_estimators': 1564, 'num_leaves': 1472, 'max_depth': 15, 'learning_rate': 0.06125386352677881, 'min_child_samples': 9}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 04:36:56,550] Trial 45 finished with value: 0.2041522491349481 and parameters: {'n_estimators': 1175, 'num_leaves': 1955, 'max_depth': 14, 'learning_rate': 0.010272023162234648, 'min_child_samples': 30}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 04:42:39,060] Trial 46 finished with value: 0.19968304278922347 and parameters: {'n_estimators': 1417, 'num_leaves': 1144, 'max_depth': 20, 'learning_rate': 0.15750334681864153, 'min_child_samples': 24}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 04:46:09,326] Trial 47 finished with value: 0.1965678627145086 and parameters: {'n_estimators': 928, 'num_leaves': 1809, 'max_depth': 27, 'learning_rate': 0.28170555528345786, 'min_child_samples': 38}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 04:50:06,042] Trial 48 finished with value: 0.19089574155653452 and parameters: {'n_estimators': 1235, 'num_leaves': 1608, 'max_depth': 74, 'learning_rate': 0.036366585542360934, 'min_child_samples': 57}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 04:53:30,497] Trial 49 finished with value: 0.19225251076040173 and parameters: {'n_estimators': 2454, 'num_leaves': 1533, 'max_depth': 13, 'learning_rate': 0.05464161655123789, 'min_child_samples': 74}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 04:58:01,249] Trial 50 finished with value: 0.20886075949367086 and parameters: {'n_estimators': 619, 'num_leaves': 1433, 'max_depth': 23, 'learning_rate': 0.0983508050097486, 'min_child_samples': 15}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 04:59:47,630] Trial 51 finished with value: 0.19459459459459458 and parameters: {'n_estimators': 1357, 'num_leaves': 1340, 'max_depth': 10, 'learning_rate': 0.011511668097297896, 'min_child_samples': 64}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 05:02:11,006] Trial 52 finished with value: 0.20497803806734993 and parameters: {'n_estimators': 1128, 'num_leaves': 1681, 'max_depth': 18, 'learning_rate': 0.082180745157085, 'min_child_samples': 48}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 05:03:34,591] Trial 53 finished with value: 0.20422535211267603 and parameters: {'n_estimators': 506, 'num_leaves': 1594, 'max_depth': 96, 'learning_rate': 0.01693734766726237, 'min_child_samples': 59}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 05:04:58,882] Trial 54 finished with value: 0.2090032154340836 and parameters: {'n_estimators': 817, 'num_leaves': 1910, 'max_depth': 13, 'learning_rate': 0.0638726452569271, 'min_child_samples': 44}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 05:07:22,352] Trial 55 finished with value: 0.20272314674735248 and parameters: {'n_estimators': 1025, 'num_leaves': 1538, 'max_depth': 19, 'learning_rate': 0.04501583782128015, 'min_child_samples': 54}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 05:14:04,931] Trial 56 finished with value: 0.2141732283464567 and parameters: {'n_estimators': 1686, 'num_leaves': 1752, 'max_depth': 13, 'learning_rate': 0.029465508580326268, 'min_child_samples': 7}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 05:21:03,055] Trial 57 finished with value: 0.21069182389937108 and parameters: {'n_estimators': 1792, 'num_leaves': 1781, 'max_depth': 13, 'learning_rate': 0.03426413513465214, 'min_child_samples': 7}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 05:42:06,294] Trial 58 finished with value: 0.10302036993678296 and parameters: {'n_estimators': 1670, 'num_leaves': 2096, 'max_depth': 33, 'learning_rate': 0.00031555253821615933, 'min_child_samples': 6}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 05:49:30,151] Trial 59 finished with value: 0.19776714513556617 and parameters: {'n_estimators': 1480, 'num_leaves': 1694, 'max_depth': 17, 'learning_rate': 0.05541581881981179, 'min_child_samples': 13}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 05:56:36,661] Trial 60 finished with value: 0.19395866454689986 and parameters: {'n_estimators': 898, 'num_leaves': 1892, 'max_depth': 89, 'learning_rate': 0.07670441915356027, 'min_child_samples': 21}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 05:58:04,059] Trial 61 finished with value: 0.2 and parameters: {'n_estimators': 1231, 'num_leaves': 1622, 'max_depth': 10, 'learning_rate': 0.027687941726302834, 'min_child_samples': 53}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 06:00:37,815] Trial 62 finished with value: 0.21052631578947364 and parameters: {'n_estimators': 1410, 'num_leaves': 1536, 'max_depth': 13, 'learning_rate': 0.011819398501110717, 'min_child_samples': 63}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 06:17:16,650] Trial 63 finished with value: 0.19224283305227657 and parameters: {'n_estimators': 1574, 'num_leaves': 1738, 'max_depth': 18, 'learning_rate': 0.04812066121298869, 'min_child_samples': 3}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 06:26:17,969] Trial 64 finished with value: 0.19672131147540983 and parameters: {'n_estimators': 1114, 'num_leaves': 1470, 'max_depth': 22, 'learning_rate': 0.0958242652648023, 'min_child_samples': 10}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 06:31:26,606] Trial 65 finished with value: 0.18524332810047095 and parameters: {'n_estimators': 1966, 'num_leaves': 1215, 'max_depth': 13, 'learning_rate': 0.11198802862128451, 'min_child_samples': 16}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 06:38:00,366] Trial 66 finished with value: 0.20032310177705975 and parameters: {'n_estimators': 759, 'num_leaves': 1326, 'max_depth': 24, 'learning_rate': 0.08359582739226559, 'min_child_samples': 9}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 06:39:35,714] Trial 67 finished with value: 0.19378427787934188 and parameters: {'n_estimators': 628, 'num_leaves': 2043, 'max_depth': 10, 'learning_rate': 0.02823239231618048, 'min_child_samples': 6}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 06:42:08,353] Trial 68 finished with value: 0.1968911917098446 and parameters: {'n_estimators': 1192, 'num_leaves': 1420, 'max_depth': 17, 'learning_rate': 0.019361275452215568, 'min_child_samples': 86}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 06:56:28,296] Trial 69 finished with value: 0.2022838499184339 and parameters: {'n_estimators': 1348, 'num_leaves': 1837, 'max_depth': 51, 'learning_rate': 0.06913619691619192, 'min_child_samples': 13}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 07:01:28,332] Trial 70 finished with value: 0.20579710144927535 and parameters: {'n_estimators': 1726, 'num_leaves': 1650, 'max_depth': 20, 'learning_rate': 0.05611726753608694, 'min_child_samples': 39}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 07:05:34,374] Trial 71 finished with value: 0.19837398373983742 and parameters: {'n_estimators': 577, 'num_leaves': 1140, 'max_depth': 64, 'learning_rate': 0.16305114068624957, 'min_child_samples': 18}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 07:08:03,134] Trial 72 finished with value: 0.2102102102102102 and parameters: {'n_estimators': 1024, 'num_leaves': 1059, 'max_depth': 15, 'learning_rate': 0.1069636419757071, 'min_child_samples': 27}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 07:11:17,437] Trial 73 finished with value: 0.2006172839506173 and parameters: {'n_estimators': 794, 'num_leaves': 1267, 'max_depth': 73, 'learning_rate': 0.21685038095303308, 'min_child_samples': 50}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 07:17:36,581] Trial 74 finished with value: 0.20162601626016258 and parameters: {'n_estimators': 876, 'num_leaves': 1203, 'max_depth': 87, 'learning_rate': 0.1311603269355379, 'min_child_samples': 21}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 07:23:13,343] Trial 75 finished with value: 0.19651347068145802 and parameters: {'n_estimators': 966, 'num_leaves': 1551, 'max_depth': 69, 'learning_rate': 0.14727550088272082, 'min_child_samples': 31}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 07:25:40,150] Trial 76 finished with value: 0.21221864951768488 and parameters: {'n_estimators': 675, 'num_leaves': 2870, 'max_depth': 12, 'learning_rate': 0.1182758315821126, 'min_child_samples': 5}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 07:27:51,693] Trial 77 finished with value: 0.2090032154340836 and parameters: {'n_estimators': 674, 'num_leaves': 2962, 'max_depth': 12, 'learning_rate': 0.11778967255986522, 'min_child_samples': 5}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 07:42:35,538] Trial 78 finished with value: 0.20155038759689922 and parameters: {'n_estimators': 1555, 'num_leaves': 2539, 'max_depth': 100, 'learning_rate': 0.09211170740420294, 'min_child_samples': 11}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 07:50:39,804] Trial 79 finished with value: 0.20261437908496732 and parameters: {'n_estimators': 1286, 'num_leaves': 2713, 'max_depth': 26, 'learning_rate': 0.10289643149653467, 'min_child_samples': 8}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:00:35,727] Trial 80 finished with value: 0.19466248037676606 and parameters: {'n_estimators': 3398, 'num_leaves': 2372, 'max_depth': 15, 'learning_rate': 0.11841534992250896, 'min_child_samples': 3}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:01:22,270] Trial 81 finished with value: 0.20904836193447737 and parameters: {'n_estimators': 505, 'num_leaves': 1720, 'max_depth': 12, 'learning_rate': 0.1415138099096697, 'min_child_samples': 12}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:02:08,167] Trial 82 finished with value: 0.2129783693843594 and parameters: {'n_estimators': 612, 'num_leaves': 1006, 'max_depth': 10, 'learning_rate': 0.08286906408374539, 'min_child_samples': 6}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:02:57,692] Trial 83 finished with value: 0.22331691297208536 and parameters: {'n_estimators': 613, 'num_leaves': 1501, 'max_depth': 10, 'learning_rate': 0.08002573177561921, 'min_child_samples': 6}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:06:04,051] Trial 84 finished with value: 0.20285261489698891 and parameters: {'n_estimators': 571, 'num_leaves': 1484, 'max_depth': 16, 'learning_rate': 0.08359205026584524, 'min_child_samples': 5}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:07:03,091] Trial 85 finished with value: 0.1983471074380165 and parameters: {'n_estimators': 752, 'num_leaves': 1372, 'max_depth': 10, 'learning_rate': 0.07644551583387524, 'min_child_samples': 8}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:09:06,384] Trial 86 finished with value: 0.19937694704049844 and parameters: {'n_estimators': 631, 'num_leaves': 1658, 'max_depth': 18, 'learning_rate': 0.09154518387795754, 'min_child_samples': 15}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:11:11,570] Trial 87 finished with value: 0.208398133748056 and parameters: {'n_estimators': 727, 'num_leaves': 1588, 'max_depth': 14, 'learning_rate': 0.06650293668794176, 'min_child_samples': 10}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:14:36,660] Trial 88 finished with value: 0.19387755102040816 and parameters: {'n_estimators': 882, 'num_leaves': 1005, 'max_depth': 22, 'learning_rate': 0.1021306797829799, 'min_child_samples': 3}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:17:11,434] Trial 89 finished with value: 0.20933977455716588 and parameters: {'n_estimators': 1061, 'num_leaves': 1299, 'max_depth': 12, 'learning_rate': 0.04085809152476366, 'min_child_samples': 7}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:19:33,601] Trial 90 finished with value: 0.1945288753799392 and parameters: {'n_estimators': 586, 'num_leaves': 2799, 'max_depth': 19, 'learning_rate': 0.0798624125584454, 'min_child_samples': 14}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:20:06,498] Trial 91 finished with value: 0.20422535211267603 and parameters: {'n_estimators': 663, 'num_leaves': 2631, 'max_depth': 10, 'learning_rate': 0.058580295215450606, 'min_child_samples': 61}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:21:13,225] Trial 92 finished with value: 0.20722135007849293 and parameters: {'n_estimators': 811, 'num_leaves': 1097, 'max_depth': 15, 'learning_rate': 0.06886792664975004, 'min_child_samples': 56}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:27:43,319] Trial 93 finished with value: 0.1986754966887417 and parameters: {'n_estimators': 2362, 'num_leaves': 1449, 'max_depth': 12, 'learning_rate': 0.005984931055558017, 'min_child_samples': 5}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:29:29,017] Trial 94 finished with value: 0.20527859237536655 and parameters: {'n_estimators': 973, 'num_leaves': 1510, 'max_depth': 17, 'learning_rate': 0.09312746283662744, 'min_child_samples': 47}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:33:22,683] Trial 95 finished with value: 0.20775193798449615 and parameters: {'n_estimators': 1412, 'num_leaves': 1794, 'max_depth': 14, 'learning_rate': 0.03232164054595498, 'min_child_samples': 11}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:36:07,694] Trial 96 finished with value: 0.20382165605095542 and parameters: {'n_estimators': 1201, 'num_leaves': 1563, 'max_depth': 12, 'learning_rate': 0.05074399122565188, 'min_child_samples': 8}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:38:36,225] Trial 97 finished with value: 0.2028985507246377 and parameters: {'n_estimators': 1083, 'num_leaves': 1627, 'max_depth': 20, 'learning_rate': 0.08744861170358263, 'min_child_samples': 53}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:42:32,171] Trial 98 finished with value: 0.21103896103896103 and parameters: {'n_estimators': 2726, 'num_leaves': 1709, 'max_depth': 10, 'learning_rate': 0.017805209402478542, 'min_child_samples': 6}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:54:14,319] Trial 99 finished with value: 0.1966101694915254 and parameters: {'n_estimators': 1896, 'num_leaves': 1413, 'max_depth': 16, 'learning_rate': 0.04111652275039007, 'min_child_samples': 3}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:54:47,946] Trial 100 finished with value: 0.18446601941747576 and parameters: {'n_estimators': 555, 'num_leaves': 2179, 'max_depth': 14, 'learning_rate': 0.11324889450511258, 'min_child_samples': 98}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 08:59:08,721] Trial 101 finished with value: 0.18887015177065766 and parameters: {'n_estimators': 2781, 'num_leaves': 1716, 'max_depth': 10, 'learning_rate': 0.007977511855911808, 'min_child_samples': 7}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 09:07:05,480] Trial 102 finished with value: 0.2086677367576244 and parameters: {'n_estimators': 2932, 'num_leaves': 1679, 'max_depth': 12, 'learning_rate': 0.024969260570094083, 'min_child_samples': 5}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 09:09:52,729] Trial 103 finished with value: 0.19823008849557522 and parameters: {'n_estimators': 2083, 'num_leaves': 1770, 'max_depth': 10, 'learning_rate': 0.012575411399658138, 'min_child_samples': 18}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 09:15:01,065] Trial 104 finished with value: 0.20408163265306126 and parameters: {'n_estimators': 1486, 'num_leaves': 1586, 'max_depth': 17, 'learning_rate': 0.07124397613619461, 'min_child_samples': 13}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 09:21:55,021] Trial 105 finished with value: 0.19589257503949445 and parameters: {'n_estimators': 2341, 'num_leaves': 1836, 'max_depth': 14, 'learning_rate': 0.06132525121880614, 'min_child_samples': 10}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 09:24:27,492] Trial 106 finished with value: 0.20333333333333334 and parameters: {'n_estimators': 1268, 'num_leaves': 1506, 'max_depth': 12, 'learning_rate': 0.01967426026353611, 'min_child_samples': 15}. Best is trial 19 with value: 0.22439024390243903.
# [I 2024-08-22 09:27:05,871] Trial 107 finished with value: 0.19667170953101362 and parameters: {'n_estimators': 1736, 'num_leaves': 1920, 'max_depth': 18, 'learning_rate': 0.03225682470103826, 'min_child_samples': 68}. Best is trial 19 with value: 0.22439024390243903.
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.

# %% [markdown]
# .
