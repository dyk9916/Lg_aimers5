# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ### 데이터 읽어오기

# %%
import os
from pprint import pprint

import optuna
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import pandas as pd

RANDOM_STATE = 110

train_data = pd.read_csv("C:/Users/KimDongyoung/Desktop/git_LGaimers5/Lg_aimers5/data/train_data_0817.csv")
test_data = pd.read_csv("C:/Users/KimDongyoung/Desktop/git_LGaimers5/Lg_aimers5/data/test_data_0817.csv")

# %%
# dam, fill1, fill2 공통 변수
var_dam_fill = [
    'Equipment_same_num',
    'PalletID_Collect_Result_encoded',
    'Production_Qty_Collect_Result',
    'WorkMode Collect Result'
]

# %%
# 전체 공통 변수
### correlation 확인을 위한 변수 리스트
var_all_corr = [
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### train
var_all_train = [
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### test
var_all_test = [
    'Set ID',
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

# %%
# '_Dam'을 포함하는 변수 선택
dam_variables = [var for var in train_data.columns if '_Dam' in var]

# train
final_columns_train = var_dam_fill + var_all_train + dam_variables
train_data_dam = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + dam_variables
test_data_dam = test_data[final_columns_test]

# %%
# '_Fill1'을 포함하는 변수 선택
fill1_variables = [var for var in train_data.columns if '_Fill1' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill1_variables
train_data_fill1 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill1_variables
test_data_fill1 = test_data[final_columns_test]

# %%
# '_Fill2'을 포함하는 변수 선택
fill2_variables = [var for var in train_data.columns if '_Fill2' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill2_variables
train_data_fill2 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill2_variables
test_data_fill2 = test_data[final_columns_test]

# %%
# '_AutoClave'을 포함하는 변수 선택
autoclave_variables = [var for var in train_data.columns if '_AutoClave' in var]

# train
final_columns_train = var_all_train + autoclave_variables
train_data_autoclave = train_data[final_columns_train]

# test 
final_columns_test = var_all_test + autoclave_variables
test_data_autoclave = test_data[final_columns_test]

# %%
# 각 DataFrame의 칼럼 수 계산
num_columns_train_data = train_data.shape[1]
num_columns_train_data_dam = train_data_dam.shape[1]
num_columns_train_data_autoclave = train_data_autoclave.shape[1]
num_columns_train_data_fill1 = train_data_fill1.shape[1]
num_columns_train_data_fill2 = train_data_fill2.shape[1]

num_columns_test_data = test_data.shape[1]
num_columns_test_data_dam = test_data_dam.shape[1]
num_columns_test_data_autoclave = test_data_autoclave.shape[1]
num_columns_test_data_fill1 = test_data_fill1.shape[1]
num_columns_test_data_fill2 = test_data_fill2.shape[1]

# 각 DataFrame의 칼럼 수 출력
print("----train data-----")
print(f"train_data DataFrame의 칼럼 수: {num_columns_train_data}")
print(f"train_data_dam DataFrame의 칼럼 수: {num_columns_train_data_dam}")
print(f"train_data_autoclave DataFrame의 칼럼 수: {num_columns_train_data_autoclave}")
print(f"train_data_fill1 DataFrame의 칼럼 수: {num_columns_train_data_fill1}")
print(f"train_data_fill2 DataFrame의 칼럼 수: {num_columns_train_data_fill2}")
print("----test data-----")
print(f"test_data DataFrame의 칼럼 수: {num_columns_test_data}")
print(f"test_data_dam DataFrame의 칼럼 수: {num_columns_test_data_dam}")
print(f"test_data_autoclave DataFrame의 칼럼 수: {num_columns_test_data_autoclave}")
print(f"test_data_fill1 DataFrame의 칼럼 수: {num_columns_test_data_fill1}")
print(f"test_data_fill2 DataFrame의 칼럼 수: {num_columns_test_data_fill2}")
# Out:
# ----train data-----
# train_data DataFrame의 칼럼 수: 38
# train_data_dam DataFrame의 칼럼 수: 21
# train_data_autoclave DataFrame의 칼럼 수: 8
# train_data_fill1 DataFrame의 칼럼 수: 13
# train_data_fill2 DataFrame의 칼럼 수: 13
# ----test data-----
# test_data DataFrame의 칼럼 수: 39
# test_data_dam DataFrame의 칼럼 수: 22
# test_data_autoclave DataFrame의 칼럼 수: 9
# test_data_fill1 DataFrame의 칼럼 수: 14
# test_data_fill2 DataFrame의 칼럼 수: 14

# %% [markdown]
# ---

# %% [markdown]
# ## Optuna

# %% [markdown]
# 스레스홀드 0.3으로 맞춘상태에서 튜닝 진행한 것

# %%
# 'Normal'과 'AbNormal'을 숫자로 변환
train_data_dam['target'] = train_data_dam['target'].map({'Normal': 0, 'AbNormal': 1})

# 스레드홀드 설정
THRESHOLD = 0.3

def objectiveLGBM_dart(trial, x_tr, y_tr, x_val, y_val):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 500, 3000),
        'num_leaves': trial.suggest_int('num_leaves', 500, 3000),
        'max_depth': trial.suggest_int('max_depth', 10, 300),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1),
        'min_child_samples': trial.suggest_int('min_child_samples', 3, 300),
        
        'boosting_type': 'dart',  # 'boosting'를 'boosting_type'으로 수정
        'random_state': RANDOM_STATE,
        'verbose': -1
    }
       
    model = LGBMClassifier(**param)
    model.fit(x_tr, y_tr)
    pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
    pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
    
    score = f1_score(y_val, pred, average="binary")
    
    return score

# 데이터셋 분할
x_train, x_val, y_train, y_val = train_test_split(
    train_data_dam.drop("target", axis=1),
    train_data_dam["target"],
    test_size=0.2,
    shuffle=True,
    random_state=RANDOM_STATE,
)

# 하이퍼 파라미터 튜닝
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
study.optimize(lambda trial: objectiveLGBM_dart(trial, x_train, y_train, x_val, y_val), n_trials=100)

print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# C:\Users\KimDongyoung\AppData\Local\Temp\ipykernel_24992\1524087016.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data_dam['target'] = train_data_dam['target'].map({'Normal': 0, 'AbNormal': 1})
# [I 2024-08-20 13:35:08,508] A new study created in memory with name: no-name-fa6bacf7-0e52-43f8-8127-00be7af50fad
# [I 2024-08-20 13:35:43,028] Trial 0 finished with value: 0.20066889632107024 and parameters: {'n_estimators': 790, 'num_leaves': 2146, 'max_depth': 119, 'learning_rate': 0.06166547557397882, 'min_child_samples': 205}. Best is trial 0 with value: 0.20066889632107024.
# [I 2024-08-20 13:41:09,347] Trial 1 finished with value: 0.19384615384615383 and parameters: {'n_estimators': 2206, 'num_leaves': 2888, 'max_depth': 195, 'learning_rate': 0.05178141716690417, 'min_child_samples': 28}. Best is trial 0 with value: 0.20066889632107024.
# [I 2024-08-20 13:42:31,551] Trial 2 finished with value: 0.21642764015645372 and parameters: {'n_estimators': 1469, 'num_leaves': 1226, 'max_depth': 49, 'learning_rate': 0.002000452888170992, 'min_child_samples': 126}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 13:44:12,812] Trial 3 finished with value: 0.18874773139745915 and parameters: {'n_estimators': 1731, 'num_leaves': 553, 'max_depth': 172, 'learning_rate': 0.008684052021612865, 'min_child_samples': 124}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 13:45:48,836] Trial 4 finished with value: 0.21007194244604316 and parameters: {'n_estimators': 1285, 'num_leaves': 2427, 'max_depth': 184, 'learning_rate': 0.042318458794414655, 'min_child_samples': 102}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 13:46:22,538] Trial 5 finished with value: 0.20833333333333334 and parameters: {'n_estimators': 562, 'num_leaves': 723, 'max_depth': 258, 'learning_rate': 0.04962001162483311, 'min_child_samples': 77}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 13:51:10,009] Trial 6 finished with value: 0.19117647058823528 and parameters: {'n_estimators': 2403, 'num_leaves': 1851, 'max_depth': 122, 'learning_rate': 0.06476333477413102, 'min_child_samples': 54}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 13:54:02,214] Trial 7 finished with value: 0.20845070422535214 and parameters: {'n_estimators': 2273, 'num_leaves': 600, 'max_depth': 184, 'learning_rate': 0.02113127234039541, 'min_child_samples': 77}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 13:56:55,622] Trial 8 finished with value: 0.19943820224719103 and parameters: {'n_estimators': 1498, 'num_leaves': 2285, 'max_depth': 240, 'learning_rate': 0.08959229338857824, 'min_child_samples': 68}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 13:57:17,880] Trial 9 finished with value: 0.1956521739130435 and parameters: {'n_estimators': 532, 'num_leaves': 2402, 'max_depth': 63, 'learning_rate': 0.0795619223737381, 'min_child_samples': 286}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 13:58:06,086] Trial 10 finished with value: 0.1868131868131868 and parameters: {'n_estimators': 1143, 'num_leaves': 1208, 'max_depth': 10, 'learning_rate': 0.02761795588449953, 'min_child_samples': 182}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 13:59:34,274] Trial 11 finished with value: 0.20221169036334913 and parameters: {'n_estimators': 1318, 'num_leaves': 1231, 'max_depth': 300, 'learning_rate': 0.0340554358442331, 'min_child_samples': 132}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:01:20,505] Trial 12 finished with value: 0.18315018315018314 and parameters: {'n_estimators': 1891, 'num_leaves': 1370, 'max_depth': 67, 'learning_rate': 0.00761198030891988, 'min_child_samples': 168}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:03:48,535] Trial 13 finished with value: 0.18629173989455186 and parameters: {'n_estimators': 2922, 'num_leaves': 2884, 'max_depth': 123, 'learning_rate': 0.002510110208577584, 'min_child_samples': 232}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:04:43,689] Trial 14 finished with value: 0.20069204152249134 and parameters: {'n_estimators': 1030, 'num_leaves': 1623, 'max_depth': 13, 'learning_rate': 0.03691209269089991, 'min_child_samples': 114}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:08:52,730] Trial 15 finished with value: 0.20972644376899693 and parameters: {'n_estimators': 1660, 'num_leaves': 952, 'max_depth': 61, 'learning_rate': 0.02340100121931054, 'min_child_samples': 13}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:10:05,260] Trial 16 finished with value: 0.2095238095238095 and parameters: {'n_estimators': 1007, 'num_leaves': 2613, 'max_depth': 224, 'learning_rate': 0.09750285832083126, 'min_child_samples': 104}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:12:02,672] Trial 17 finished with value: 0.19428571428571428 and parameters: {'n_estimators': 1983, 'num_leaves': 1768, 'max_depth': 146, 'learning_rate': 0.042891501346028316, 'min_child_samples': 166}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:13:03,017] Trial 18 finished with value: 0.18484288354898337 and parameters: {'n_estimators': 1395, 'num_leaves': 1908, 'max_depth': 97, 'learning_rate': 0.015983520844144776, 'min_child_samples': 244}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:14:35,720] Trial 19 finished with value: 0.2054794520547945 and parameters: {'n_estimators': 1244, 'num_leaves': 2578, 'max_depth': 210, 'learning_rate': 0.07349985223327475, 'min_child_samples': 99}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:17:42,671] Trial 20 finished with value: 0.19946808510638295 and parameters: {'n_estimators': 2674, 'num_leaves': 1447, 'max_depth': 273, 'learning_rate': 0.05605957255508697, 'min_child_samples': 141}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:21:23,401] Trial 21 finished with value: 0.20186335403726707 and parameters: {'n_estimators': 1627, 'num_leaves': 991, 'max_depth': 55, 'learning_rate': 0.017409218670556573, 'min_child_samples': 3}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:23:12,649] Trial 22 finished with value: 0.19999999999999998 and parameters: {'n_estimators': 1590, 'num_leaves': 974, 'max_depth': 46, 'learning_rate': 0.02682192480260816, 'min_child_samples': 28}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:24:41,045] Trial 23 finished with value: 0.21330902461257975 and parameters: {'n_estimators': 1871, 'num_leaves': 898, 'max_depth': 88, 'learning_rate': 0.0013093319275061834, 'min_child_samples': 40}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:25:49,649] Trial 24 finished with value: 0.18861209964412812 and parameters: {'n_estimators': 1951, 'num_leaves': 769, 'max_depth': 87, 'learning_rate': 0.0035952829835591005, 'min_child_samples': 95}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:26:19,234] Trial 25 finished with value: 0.20304568527918784 and parameters: {'n_estimators': 800, 'num_leaves': 1565, 'max_depth': 154, 'learning_rate': 0.012348338567444953, 'min_child_samples': 51}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:27:28,228] Trial 26 finished with value: 0.20113314447592068 and parameters: {'n_estimators': 1358, 'num_leaves': 2008, 'max_depth': 32, 'learning_rate': 0.036627932369901625, 'min_child_samples': 47}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:28:29,597] Trial 27 finished with value: 0.19494584837545126 and parameters: {'n_estimators': 1851, 'num_leaves': 1158, 'max_depth': 97, 'learning_rate': 0.010588472973831923, 'min_child_samples': 150}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:29:45,134] Trial 28 finished with value: 0.19938650306748468 and parameters: {'n_estimators': 2118, 'num_leaves': 836, 'max_depth': 138, 'learning_rate': 0.0018334716372545479, 'min_child_samples': 89}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:30:09,146] Trial 29 finished with value: 0.20257234726688106 and parameters: {'n_estimators': 835, 'num_leaves': 2133, 'max_depth': 90, 'learning_rate': 0.06639957838706945, 'min_child_samples': 190}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:31:38,290] Trial 30 finished with value: 0.20498614958448755 and parameters: {'n_estimators': 2546, 'num_leaves': 1358, 'max_depth': 170, 'learning_rate': 0.043599038123239967, 'min_child_samples': 211}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:33:16,620] Trial 31 finished with value: 0.19543973941368079 and parameters: {'n_estimators': 1692, 'num_leaves': 999, 'max_depth': 30, 'learning_rate': 0.023560311968528546, 'min_child_samples': 4}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:34:51,092] Trial 32 finished with value: 0.20145985401459854 and parameters: {'n_estimators': 1484, 'num_leaves': 957, 'max_depth': 74, 'learning_rate': 0.03139808626987984, 'min_child_samples': 27}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:36:36,186] Trial 33 finished with value: 0.19943820224719103 and parameters: {'n_estimators': 1766, 'num_leaves': 1150, 'max_depth': 107, 'learning_rate': 0.018103610039277688, 'min_child_samples': 33}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:37:49,779] Trial 34 finished with value: 0.20141342756183744 and parameters: {'n_estimators': 2117, 'num_leaves': 573, 'max_depth': 43, 'learning_rate': 0.008382916916522657, 'min_child_samples': 120}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:38:36,301] Trial 35 finished with value: 0.2070921985815603 and parameters: {'n_estimators': 1110, 'num_leaves': 776, 'max_depth': 78, 'learning_rate': 0.042885145303314526, 'min_child_samples': 68}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:40:47,668] Trial 36 finished with value: 0.2059282371294852 and parameters: {'n_estimators': 1507, 'num_leaves': 1522, 'max_depth': 192, 'learning_rate': 0.051756634078670344, 'min_child_samples': 17}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:41:39,699] Trial 37 finished with value: 0.19165378670788255 and parameters: {'n_estimators': 1225, 'num_leaves': 634, 'max_depth': 125, 'learning_rate': 0.01427760097670723, 'min_child_samples': 47}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:42:49,783] Trial 38 finished with value: 0.19653179190751444 and parameters: {'n_estimators': 1760, 'num_leaves': 500, 'max_depth': 168, 'learning_rate': 0.023814357991573994, 'min_child_samples': 78}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:44:06,013] Trial 39 finished with value: 0.19168173598553348 and parameters: {'n_estimators': 2257, 'num_leaves': 1711, 'max_depth': 27, 'learning_rate': 0.006271116577168475, 'min_child_samples': 115}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:45:42,540] Trial 40 finished with value: 0.20527045769764218 and parameters: {'n_estimators': 2044, 'num_leaves': 1079, 'max_depth': 107, 'learning_rate': 0.030625163465930156, 'min_child_samples': 64}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:46:18,858] Trial 41 finished with value: 0.209366391184573 and parameters: {'n_estimators': 922, 'num_leaves': 2679, 'max_depth': 216, 'learning_rate': 0.08082248575985376, 'min_child_samples': 100}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:46:38,199] Trial 42 finished with value: 0.20895522388059704 and parameters: {'n_estimators': 652, 'num_leaves': 2420, 'max_depth': 233, 'learning_rate': 0.0939163307731182, 'min_child_samples': 132}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:47:12,992] Trial 43 finished with value: 0.20268256333830104 and parameters: {'n_estimators': 955, 'num_leaves': 2924, 'max_depth': 214, 'learning_rate': 0.05712691161486011, 'min_child_samples': 109}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:47:59,433] Trial 44 finished with value: 0.2070921985815603 and parameters: {'n_estimators': 1145, 'num_leaves': 2693, 'max_depth': 245, 'learning_rate': 0.04754766611200792, 'min_child_samples': 83}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:49:00,470] Trial 45 finished with value: 0.20744680851063832 and parameters: {'n_estimators': 1434, 'num_leaves': 2349, 'max_depth': 184, 'learning_rate': 0.09957253941697095, 'min_child_samples': 163}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:50:32,204] Trial 46 finished with value: 0.19830028328611896 and parameters: {'n_estimators': 1613, 'num_leaves': 2498, 'max_depth': 225, 'learning_rate': 0.021828317197747627, 'min_child_samples': 35}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:51:00,025] Trial 47 finished with value: 0.21067415730337077 and parameters: {'n_estimators': 681, 'num_leaves': 2197, 'max_depth': 264, 'learning_rate': 0.06465056554146643, 'min_child_samples': 60}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:51:21,075] Trial 48 finished with value: 0.2023121387283237 and parameters: {'n_estimators': 586, 'num_leaves': 2094, 'max_depth': 286, 'learning_rate': 0.0656207049669639, 'min_child_samples': 61}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:51:50,399] Trial 49 finished with value: 0.2109704641350211 and parameters: {'n_estimators': 660, 'num_leaves': 857, 'max_depth': 56, 'learning_rate': 0.07046015051181026, 'min_child_samples': 45}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:52:18,359] Trial 50 finished with value: 0.19464033850493653 and parameters: {'n_estimators': 646, 'num_leaves': 1283, 'max_depth': 47, 'learning_rate': 0.07383298407596552, 'min_child_samples': 45}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:53:41,020] Trial 51 finished with value: 0.1990521327014218 and parameters: {'n_estimators': 864, 'num_leaves': 2224, 'max_depth': 69, 'learning_rate': 0.06112770730225936, 'min_child_samples': 11}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:54:19,860] Trial 52 finished with value: 0.19877675840978595 and parameters: {'n_estimators': 713, 'num_leaves': 855, 'max_depth': 63, 'learning_rate': 0.08001609830044963, 'min_child_samples': 17}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:54:33,969] Trial 53 finished with value: 0.2038834951456311 and parameters: {'n_estimators': 505, 'num_leaves': 712, 'max_depth': 16, 'learning_rate': 0.059725231385442765, 'min_child_samples': 36}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:55:42,190] Trial 54 finished with value: 0.20084865629420084 and parameters: {'n_estimators': 1272, 'num_leaves': 1096, 'max_depth': 59, 'learning_rate': 0.07022604805342021, 'min_child_samples': 59}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:57:27,091] Trial 55 finished with value: 0.19142857142857142 and parameters: {'n_estimators': 1846, 'num_leaves': 906, 'max_depth': 80, 'learning_rate': 0.07462876017613213, 'min_child_samples': 76}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:59:09,156] Trial 56 finished with value: 0.20535714285714288 and parameters: {'n_estimators': 1556, 'num_leaves': 1940, 'max_depth': 263, 'learning_rate': 0.0045037390383940515, 'min_child_samples': 22}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 14:59:46,007] Trial 57 finished with value: 0.19943019943019946 and parameters: {'n_estimators': 737, 'num_leaves': 2787, 'max_depth': 136, 'learning_rate': 0.08550199199022368, 'min_child_samples': 44}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 15:00:38,223] Trial 58 finished with value: 0.1879588839941263 and parameters: {'n_estimators': 1654, 'num_leaves': 668, 'max_depth': 44, 'learning_rate': 0.06801592570810822, 'min_child_samples': 270}. Best is trial 2 with value: 0.21642764015645372.
# [I 2024-08-20 15:01:39,427] Trial 59 finished with value: 0.21949078138718175 and parameters: {'n_estimators': 1901, 'num_leaves': 1247, 'max_depth': 36, 'learning_rate': 0.0011375205361216431, 'min_child_samples': 129}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:02:10,178] Trial 60 finished with value: 0.18416206261510126 and parameters: {'n_estimators': 1078, 'num_leaves': 1337, 'max_depth': 20, 'learning_rate': 0.009942641379267142, 'min_child_samples': 137}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:03:09,428] Trial 61 finished with value: 0.18181818181818182 and parameters: {'n_estimators': 1925, 'num_leaves': 1244, 'max_depth': 39, 'learning_rate': 0.0023850343425818096, 'min_child_samples': 145}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:04:27,035] Trial 62 finished with value: 0.19354838709677422 and parameters: {'n_estimators': 2379, 'num_leaves': 1440, 'max_depth': 53, 'learning_rate': 0.006829066506124883, 'min_child_samples': 127}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:05:18,993] Trial 63 finished with value: 0.19424460431654675 and parameters: {'n_estimators': 1803, 'num_leaves': 1096, 'max_depth': 33, 'learning_rate': 0.013298690965117987, 'min_child_samples': 178}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:06:37,497] Trial 64 finished with value: 0.1921921921921922 and parameters: {'n_estimators': 2079, 'num_leaves': 1020, 'max_depth': 298, 'learning_rate': 0.019040108546232677, 'min_child_samples': 94}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:07:47,055] Trial 65 finished with value: 0.1954674220963173 and parameters: {'n_estimators': 1979, 'num_leaves': 840, 'max_depth': 89, 'learning_rate': 0.03841905527405186, 'min_child_samples': 154}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:08:48,466] Trial 66 finished with value: 0.1613067891781521 and parameters: {'n_estimators': 1397, 'num_leaves': 2227, 'max_depth': 68, 'learning_rate': 0.0011527069959444095, 'min_child_samples': 72}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:10:47,623] Trial 67 finished with value: 0.19966722129783696 and parameters: {'n_estimators': 2210, 'num_leaves': 1811, 'max_depth': 23, 'learning_rate': 0.01022691638072027, 'min_child_samples': 84}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:12:29,075] Trial 68 finished with value: 0.208955223880597 and parameters: {'n_estimators': 1730, 'num_leaves': 1671, 'max_depth': 54, 'learning_rate': 0.05413563674382133, 'min_child_samples': 106}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:13:18,598] Trial 69 finished with value: 0.2028985507246377 and parameters: {'n_estimators': 1553, 'num_leaves': 909, 'max_depth': 10, 'learning_rate': 0.04723151545508832, 'min_child_samples': 53}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:15:01,785] Trial 70 finished with value: 0.1923076923076923 and parameters: {'n_estimators': 1304, 'num_leaves': 1200, 'max_depth': 201, 'learning_rate': 0.06346562016852311, 'min_child_samples': 38}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:15:54,347] Trial 71 finished with value: 0.20652173913043476 and parameters: {'n_estimators': 997, 'num_leaves': 2520, 'max_depth': 250, 'learning_rate': 0.08878145042570457, 'min_child_samples': 106}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:16:43,554] Trial 72 finished with value: 0.18556701030927833 and parameters: {'n_estimators': 1152, 'num_leaves': 2652, 'max_depth': 261, 'learning_rate': 0.005231301399472007, 'min_child_samples': 123}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:17:16,793] Trial 73 finished with value: 0.1914529914529914 and parameters: {'n_estimators': 875, 'num_leaves': 2795, 'max_depth': 158, 'learning_rate': 0.03990000459930097, 'min_child_samples': 157}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:20:18,296] Trial 74 finished with value: 0.20923913043478262 and parameters: {'n_estimators': 2990, 'num_leaves': 2401, 'max_depth': 275, 'learning_rate': 0.026997883447234257, 'min_child_samples': 89}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:20:50,755] Trial 75 finished with value: 0.21238938053097345 and parameters: {'n_estimators': 755, 'num_leaves': 2602, 'max_depth': 233, 'learning_rate': 0.07635546951637806, 'min_child_samples': 117}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:21:24,240] Trial 76 finished with value: 0.2062780269058296 and parameters: {'n_estimators': 772, 'num_leaves': 747, 'max_depth': 35, 'learning_rate': 0.07710789347430545, 'min_child_samples': 133}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:22:48,280] Trial 77 finished with value: 0.1943573667711599 and parameters: {'n_estimators': 645, 'num_leaves': 2554, 'max_depth': 111, 'learning_rate': 0.06828916892027752, 'min_child_samples': 9}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:24:45,385] Trial 78 finished with value: 0.19703103913630232 and parameters: {'n_estimators': 1874, 'num_leaves': 2300, 'max_depth': 179, 'learning_rate': 0.08352987564950443, 'min_child_samples': 120}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:25:06,443] Trial 79 finished with value: 0.20189274447949526 and parameters: {'n_estimators': 565, 'num_leaves': 2449, 'max_depth': 199, 'learning_rate': 0.07204865338139038, 'min_child_samples': 114}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:26:34,859] Trial 80 finished with value: 0.20533333333333334 and parameters: {'n_estimators': 1673, 'num_leaves': 2054, 'max_depth': 235, 'learning_rate': 0.07783366566917496, 'min_child_samples': 146}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:27:46,556] Trial 81 finished with value: 0.19645293315143245 and parameters: {'n_estimators': 1210, 'num_leaves': 2642, 'max_depth': 229, 'learning_rate': 0.09898397300345746, 'min_child_samples': 100}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:29:16,041] Trial 82 finished with value: 0.1924198250728863 and parameters: {'n_estimators': 955, 'num_leaves': 2842, 'max_depth': 221, 'learning_rate': 0.05809191528956828, 'min_child_samples': 27}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:30:15,395] Trial 83 finished with value: 0.21438263229308005 and parameters: {'n_estimators': 1044, 'num_leaves': 2721, 'max_depth': 241, 'learning_rate': 0.09532804596192467, 'min_child_samples': 127}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:31:52,950] Trial 84 finished with value: 0.1962864721485411 and parameters: {'n_estimators': 1463, 'num_leaves': 2744, 'max_depth': 245, 'learning_rate': 0.0907812814032474, 'min_child_samples': 129}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:32:23,432] Trial 85 finished with value: 0.20848056537102475 and parameters: {'n_estimators': 809, 'num_leaves': 1047, 'max_depth': 254, 'learning_rate': 0.032129707038299336, 'min_child_samples': 139}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:33:35,285] Trial 86 finished with value: 0.2019914651493599 and parameters: {'n_estimators': 1371, 'num_leaves': 907, 'max_depth': 266, 'learning_rate': 0.05002582700820757, 'min_child_samples': 116}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:34:11,656] Trial 87 finished with value: 0.20608108108108109 and parameters: {'n_estimators': 716, 'num_leaves': 1147, 'max_depth': 207, 'learning_rate': 0.008370425743485642, 'min_child_samples': 57}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:35:11,795] Trial 88 finished with value: 0.21565731166912852 and parameters: {'n_estimators': 601, 'num_leaves': 2581, 'max_depth': 283, 'learning_rate': 0.06318192764317689, 'min_child_samples': 17}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:35:58,616] Trial 89 finished with value: 0.2144927536231884 and parameters: {'n_estimators': 610, 'num_leaves': 2612, 'max_depth': 285, 'learning_rate': 0.06355263674840818, 'min_child_samples': 25}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:36:32,126] Trial 90 finished with value: 0.21398002853067047 and parameters: {'n_estimators': 596, 'num_leaves': 2954, 'max_depth': 283, 'learning_rate': 0.06327064267634457, 'min_child_samples': 42}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:37:27,118] Trial 91 finished with value: 0.2055800293685756 and parameters: {'n_estimators': 600, 'num_leaves': 2996, 'max_depth': 285, 'learning_rate': 0.06340469329166686, 'min_child_samples': 20}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:37:56,222] Trial 92 finished with value: 0.20467836257309943 and parameters: {'n_estimators': 510, 'num_leaves': 2951, 'max_depth': 279, 'learning_rate': 0.05520899990106078, 'min_child_samples': 40}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:38:51,175] Trial 93 finished with value: 0.20689655172413793 and parameters: {'n_estimators': 671, 'num_leaves': 2867, 'max_depth': 292, 'learning_rate': 0.07075130695851006, 'min_child_samples': 30}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:39:58,550] Trial 94 finished with value: 0.1949778434268833 and parameters: {'n_estimators': 773, 'num_leaves': 2723, 'max_depth': 270, 'learning_rate': 0.06141810144031898, 'min_child_samples': 23}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:41:20,622] Trial 95 finished with value: 0.19496855345911948 and parameters: {'n_estimators': 619, 'num_leaves': 2601, 'max_depth': 285, 'learning_rate': 0.06855466902005791, 'min_child_samples': 5}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:42:05,241] Trial 96 finished with value: 0.20056497175141244 and parameters: {'n_estimators': 694, 'num_leaves': 2772, 'max_depth': 278, 'learning_rate': 0.06623217221602536, 'min_child_samples': 49}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:42:38,643] Trial 97 finished with value: 0.20461095100864554 and parameters: {'n_estimators': 564, 'num_leaves': 2474, 'max_depth': 294, 'learning_rate': 0.06381985693011584, 'min_child_samples': 43}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:44:25,563] Trial 98 finished with value: 0.20606060606060606 and parameters: {'n_estimators': 875, 'num_leaves': 2588, 'max_depth': 272, 'learning_rate': 0.05868283082146458, 'min_child_samples': 16}. Best is trial 59 with value: 0.21949078138718175.
# [I 2024-08-20 15:44:51,106] Trial 99 finished with value: 0.20444444444444443 and parameters: {'n_estimators': 548, 'num_leaves': 2366, 'max_depth': 253, 'learning_rate': 0.06081909005329713, 'min_child_samples': 66}. Best is trial 59 with value: 0.21949078138718175.
# Best trial: score 0.21949078138718175,
# params {'n_estimators': 1901, 'num_leaves': 1247, 'max_depth': 36, 'learning_rate': 0.0011375205361216431, 'min_child_samples': 129}

# %%
# 스레드홀드 설정
THRESHOLD = 0.3

# 모델 설정 및 하이퍼파라미터
models = {
    'et': ExtraTreesClassifier(),
    'rf': RandomForestClassifier(),
    'cat': CatBoostClassifier(),
    'lgbm': LGBMClassifier(),
    'xgb': XGBClassifier(),
    'dt': DecisionTreeClassifier()
}

def train_and_evaluate_model(model_name, data, **params):
    if model_name not in models:
        print(f"{model_name}은(는) 지원되지 않는 모델입니다.")
        return
    
    # 데이터셋 분할
    x_train, x_val, y_train, y_val = train_test_split(
        data.drop("target", axis=1),
        data["target"].map({'Normal': 0, 'AbNormal': 1}),
        test_size=0.2,
        shuffle=True,
        random_state=RANDOM_STATE,
    )

    # 모델 선택
    model = models[model_name]

    # 하이퍼파라미터 설정
    model.set_params(**params)

    # 모델 학습
    model.fit(x_train, y_train)

    # 데이터 이름을 자동으로 추출하기 위한 래퍼 함수
    data_name = [name for name in globals() if globals()[name] is data][0]

    # 예측
    y_val_pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
    y_val_pred = (y_val_pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측

    # 평가지표 계산
    f1 = f1_score(y_val, y_val_pred, average="binary")
    accuracy = accuracy_score(y_val, y_val_pred)
    precision = precision_score(y_val, y_val_pred)
    recall = recall_score(y_val, y_val_pred)
    conf_matrix = confusion_matrix(y_val, y_val_pred)
    
    # 결과 출력
    print(f'{model_name} 모델이 {data_name} 데이터로 학습한 결과:')
    print(f'F1 Score: {f1}')
    print('---')
    print('Confusion Matrix:')
    print(conf_matrix)
    print('---')
    print(f'Accuracy: {accuracy}')
    print(f'Precision: {precision}')
    print(f'Recall: {recall}')
    print('\n')

# %%
# train_and_evaluate_model(
#     'lgbm', train_data_dam,
#     n_estimators = 1707, 
#     learning_rate = 0.0321470219836192, 
#     max_depth = 7, 
#     alpha = 7.368872823521818e-05, 
#     gamma = 0.0007930035188326916, 
#     reg_alpha = 0.644199314174124, 
#     reg_lambda = 0.588270569327407, 
#     colsample_bytree = 0.883929103208459, 
#     subsample = 0.2534703342501092,
#     random_state=RANDOM_STATE
# )

# %% [markdown]
# .
