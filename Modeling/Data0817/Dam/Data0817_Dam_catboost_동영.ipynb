# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ### 데이터 읽어오기

# %%
import os
from pprint import pprint

import optuna
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import pandas as pd

RANDOM_STATE = 110

train_data = pd.read_csv("C:/Users/KimDongyoung/Desktop/git_LGaimers5/Lg_aimers5/data/train_data_0817.csv")
test_data = pd.read_csv("C:/Users/KimDongyoung/Desktop/git_LGaimers5/Lg_aimers5/data/test_data_0817.csv")

# %%
# dam, fill1, fill2 공통 변수
var_dam_fill = [
    'Equipment_same_num',
    'PalletID_Collect_Result_encoded',
    'Production_Qty_Collect_Result',
    'WorkMode Collect Result'
]

# %%
# 전체 공통 변수
### correlation 확인을 위한 변수 리스트
var_all_corr = [
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### train
var_all_train = [
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

### test
var_all_test = [
    'Set ID',
    'target',
    'model_receip_encoded',
    'workorder_receip_encoded'
]

# %%
# '_Dam'을 포함하는 변수 선택
dam_variables = [var for var in train_data.columns if '_Dam' in var]

# train
final_columns_train = var_dam_fill + var_all_train + dam_variables
train_data_dam = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + dam_variables
test_data_dam = test_data[final_columns_test]

# %%
# '_Fill1'을 포함하는 변수 선택
fill1_variables = [var for var in train_data.columns if '_Fill1' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill1_variables
train_data_fill1 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill1_variables
test_data_fill1 = test_data[final_columns_test]

# %%
# '_Fill2'을 포함하는 변수 선택
fill2_variables = [var for var in train_data.columns if '_Fill2' in var]

# train
final_columns_train = var_dam_fill + var_all_train + fill2_variables
train_data_fill2 = train_data[final_columns_train]

# test 
final_columns_test = var_dam_fill + var_all_test + fill2_variables
test_data_fill2 = test_data[final_columns_test]

# %%
# '_AutoClave'을 포함하는 변수 선택
autoclave_variables = [var for var in train_data.columns if '_AutoClave' in var]

# train
final_columns_train = var_all_train + autoclave_variables
train_data_autoclave = train_data[final_columns_train]

# test 
final_columns_test = var_all_test + autoclave_variables
test_data_autoclave = test_data[final_columns_test]

# %%
# 각 DataFrame의 칼럼 수 계산
num_columns_train_data = train_data.shape[1]
num_columns_train_data_dam = train_data_dam.shape[1]
num_columns_train_data_autoclave = train_data_autoclave.shape[1]
num_columns_train_data_fill1 = train_data_fill1.shape[1]
num_columns_train_data_fill2 = train_data_fill2.shape[1]

num_columns_test_data = test_data.shape[1]
num_columns_test_data_dam = test_data_dam.shape[1]
num_columns_test_data_autoclave = test_data_autoclave.shape[1]
num_columns_test_data_fill1 = test_data_fill1.shape[1]
num_columns_test_data_fill2 = test_data_fill2.shape[1]

# 각 DataFrame의 칼럼 수 출력
print("----train data-----")
print(f"train_data DataFrame의 칼럼 수: {num_columns_train_data}")
print(f"train_data_dam DataFrame의 칼럼 수: {num_columns_train_data_dam}")
print(f"train_data_autoclave DataFrame의 칼럼 수: {num_columns_train_data_autoclave}")
print(f"train_data_fill1 DataFrame의 칼럼 수: {num_columns_train_data_fill1}")
print(f"train_data_fill2 DataFrame의 칼럼 수: {num_columns_train_data_fill2}")
print("----test data-----")
print(f"test_data DataFrame의 칼럼 수: {num_columns_test_data}")
print(f"test_data_dam DataFrame의 칼럼 수: {num_columns_test_data_dam}")
print(f"test_data_autoclave DataFrame의 칼럼 수: {num_columns_test_data_autoclave}")
print(f"test_data_fill1 DataFrame의 칼럼 수: {num_columns_test_data_fill1}")
print(f"test_data_fill2 DataFrame의 칼럼 수: {num_columns_test_data_fill2}")
# Out:
# ----train data-----
# train_data DataFrame의 칼럼 수: 38
# train_data_dam DataFrame의 칼럼 수: 21
# train_data_autoclave DataFrame의 칼럼 수: 8
# train_data_fill1 DataFrame의 칼럼 수: 13
# train_data_fill2 DataFrame의 칼럼 수: 13
# ----test data-----
# test_data DataFrame의 칼럼 수: 39
# test_data_dam DataFrame의 칼럼 수: 22
# test_data_autoclave DataFrame의 칼럼 수: 9
# test_data_fill1 DataFrame의 칼럼 수: 14
# test_data_fill2 DataFrame의 칼럼 수: 14

# %% [markdown]
# ---

# %% [markdown]
# ## Optuna

# %% [markdown]
# 스레스홀드 0.3으로 맞춘상태에서 튜닝 진행한 것

# %%
import optuna
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# 'Normal'과 'AbNormal'을 숫자로 변환
#train_data_dam['target'] = train_data_dam['target'].map({'Normal': 0, 'AbNormal': 1})

# 스레드홀드 설정
THRESHOLD = 0.3

# def objectiveCatBoost(trial, x_tr, y_tr, x_val, y_val):
#     param = {
#         'iterations': trial.suggest_int('iterations', 400, 1500),
#         'learning_rate': trial.suggest_float('learning_rate', 0.05, 0.4),
#         'depth': trial.suggest_int('depth', 3, 14),
#         'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 0.05, 5.0, log=True),
#         'random_strength': trial.suggest_float('random_strength', 0.1, 10.0),
#         'bagging_temperature': trial.suggest_float('bagging_temperature', 0.1, 10.0),
#         'border_count': trial.suggest_int('border_count', 70, 270),
#         'scale_pos_weight': trial.suggest_float('scale_pos_weight', 0.5, 1.2),

#         'random_seed': RANDOM_STATE,
#         'eval_metric': 'F1',
#         'logging_level': 'Silent',
#         'boosting_type': 'Plain'
#     }

#     model = CatBoostClassifier(**param)
#     model.fit(x_tr, y_tr)
#     pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
#     pred = (pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측
    
#     score = f1_score(y_val, pred, average="binary")
    
#     return score

# # 데이터셋 분할
# x_train, x_val, y_train, y_val = train_test_split(
#     train_data_dam.drop("target", axis=1),
#     train_data_dam["target"],
#     test_size=0.2,
#     shuffle=True,
#     random_state=RANDOM_STATE,
# )

# # 하이퍼 파라미터 튜닝
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
# study.optimize(lambda trial: objectiveCatBoost(trial, x_train, y_train, x_val, y_val), n_trials=200)

# print('Best trial: score {}, \nparams {}'.format(study.best_trial.value, study.best_trial.params))

# %%
# 스레드홀드 설정
THRESHOLD = 0.3

# 모델 설정 및 하이퍼파라미터
models = {
    'et': ExtraTreesClassifier(),
    'rf': RandomForestClassifier(),
    'cat': CatBoostClassifier(),
    'lgbm': LGBMClassifier(),
    'xgb': XGBClassifier(),
    'dt': DecisionTreeClassifier()
}

def train_and_evaluate_model(model_name, data, **params):
    if model_name not in models:
        print(f"{model_name}은(는) 지원되지 않는 모델입니다.")
        return
    
    # 데이터셋 분할
    x_train, x_val, y_train, y_val = train_test_split(
        data.drop("target", axis=1),
        data["target"].map({'Normal': 0, 'AbNormal': 1}),
        test_size=0.2,
        shuffle=True,
        random_state=RANDOM_STATE,
    )

    # 모델 선택
    model = models[model_name]

    # 하이퍼파라미터 설정
    model.set_params(**params)

    # 모델 학습
    model.fit(x_train, y_train)

    # 데이터 이름을 자동으로 추출하기 위한 래퍼 함수
    data_name = [name for name in globals() if globals()[name] is data][0]

    # 예측
    y_val_pred_proba = model.predict_proba(x_val)[:, 1]  # 양성 클래스 확률
    y_val_pred = (y_val_pred_proba >= THRESHOLD).astype(int)  # 스레드홀드에 따른 예측

    # 평가지표 계산
    f1 = f1_score(y_val, y_val_pred, average="binary")
    accuracy = accuracy_score(y_val, y_val_pred)
    precision = precision_score(y_val, y_val_pred)
    recall = recall_score(y_val, y_val_pred)
    conf_matrix = confusion_matrix(y_val, y_val_pred)
    
    # 결과 출력
    print(f'{model_name} 모델이 {data_name} 데이터로 학습한 결과:')
    print(f'F1 Score: {f1}')
    #print('---')
    #print('Confusion Matrix:')
    #print(conf_matrix)
    #print('---')
    #print(f'Accuracy: {accuracy}')
    #print(f'Precision: {precision}')
    #print(f'Recall: {recall}')
    print('\n')

# %%
train_and_evaluate_model(
    'cat', train_data_dam,
    iterations = 522, 
    learning_rate = 0.3232219690134069, 
    depth = 6, 
    l2_leaf_reg = 1.0397848214639749, 
    random_strength = 6.633254145997919, 
    bagging_temperature = 5.102198603112521, 
    border_count = 114, 
    scale_pos_weight = 0.9986667213807143,
    random_state=RANDOM_STATE
)
# Out:
# 0:	learn: 0.3601815	total: 20.3ms	remaining: 10.6s
# 1:	learn: 0.2672713	total: 38.7ms	remaining: 10.1s
# 2:	learn: 0.2280158	total: 58.5ms	remaining: 10.1s
# 3:	learn: 0.2132252	total: 83ms	remaining: 10.8s
# 4:	learn: 0.2050491	total: 111ms	remaining: 11.4s
# 5:	learn: 0.2013073	total: 125ms	remaining: 10.7s
# 6:	learn: 0.2001915	total: 149ms	remaining: 11s
# 7:	learn: 0.1982368	total: 166ms	remaining: 10.7s
# 8:	learn: 0.1977243	total: 200ms	remaining: 11.4s
# 9:	learn: 0.1971633	total: 216ms	remaining: 11.1s
# 10:	learn: 0.1969136	total: 230ms	remaining: 10.7s
# 11:	learn: 0.1959400	total: 245ms	remaining: 10.4s
# 12:	learn: 0.1950012	total: 259ms	remaining: 10.1s
# 13:	learn: 0.1949432	total: 272ms	remaining: 9.88s
# 14:	learn: 0.1947256	total: 289ms	remaining: 9.77s
# 15:	learn: 0.1943246	total: 306ms	remaining: 9.67s
# 16:	learn: 0.1941304	total: 322ms	remaining: 9.56s
# 17:	learn: 0.1939412	total: 338ms	remaining: 9.46s
# 18:	learn: 0.1937309	total: 355ms	remaining: 9.39s
# 19:	learn: 0.1934381	total: 371ms	remaining: 9.31s
# 20:	learn: 0.1927370	total: 385ms	remaining: 9.19s
# 21:	learn: 0.1925680	total: 401ms	remaining: 9.11s
# 22:	learn: 0.1924676	total: 418ms	remaining: 9.06s
# 23:	learn: 0.1921529	total: 434ms	remaining: 9s
# 24:	learn: 0.1918074	total: 448ms	remaining: 8.91s
# 25:	learn: 0.1913955	total: 463ms	remaining: 8.84s
# 26:	learn: 0.1913362	total: 483ms	remaining: 8.85s
# 27:	learn: 0.1912583	total: 503ms	remaining: 8.87s
# 28:	learn: 0.1910754	total: 517ms	remaining: 8.79s
# 29:	learn: 0.1910391	total: 526ms	remaining: 8.62s
# 30:	learn: 0.1909889	total: 540ms	remaining: 8.55s
# 31:	learn: 0.1908259	total: 558ms	remaining: 8.54s
# 32:	learn: 0.1906144	total: 573ms	remaining: 8.49s
# 33:	learn: 0.1902745	total: 589ms	remaining: 8.45s
# 34:	learn: 0.1901775	total: 602ms	remaining: 8.37s
# 35:	learn: 0.1899038	total: 618ms	remaining: 8.34s
# 36:	learn: 0.1895171	total: 634ms	remaining: 8.31s
# 37:	learn: 0.1891241	total: 649ms	remaining: 8.26s
# 38:	learn: 0.1887097	total: 660ms	remaining: 8.18s
# 39:	learn: 0.1883312	total: 682ms	remaining: 8.22s
# 40:	learn: 0.1879490	total: 697ms	remaining: 8.17s
# 41:	learn: 0.1876030	total: 715ms	remaining: 8.17s
# 42:	learn: 0.1872611	total: 738ms	remaining: 8.22s
# 43:	learn: 0.1866807	total: 758ms	remaining: 8.23s
# 44:	learn: 0.1863409	total: 776ms	remaining: 8.23s
# 45:	learn: 0.1857854	total: 792ms	remaining: 8.2s
# 46:	learn: 0.1852959	total: 807ms	remaining: 8.15s
# 47:	learn: 0.1850151	total: 821ms	remaining: 8.11s
# 48:	learn: 0.1845677	total: 837ms	remaining: 8.08s
# 49:	learn: 0.1842103	total: 855ms	remaining: 8.07s
# 50:	learn: 0.1837628	total: 878ms	remaining: 8.11s
# 51:	learn: 0.1832872	total: 893ms	remaining: 8.07s
# 52:	learn: 0.1828849	total: 905ms	remaining: 8.01s
# 53:	learn: 0.1825423	total: 922ms	remaining: 7.99s
# 195:	learn: 0.1470825	total: 3.58s	remaining: 5.95s
# 196:	learn: 0.1468069	total: 3.59s	remaining: 5.93s
# 197:	learn: 0.1466806	total: 3.65s	remaining: 5.98s
# 198:	learn: 0.1464480	total: 3.67s	remaining: 5.96s
# 199:	learn: 0.1462998	total: 3.68s	remaining: 5.93s
# 200:	learn: 0.1460577	total: 3.7s	remaining: 5.91s
# 201:	learn: 0.1458726	total: 3.71s	remaining: 5.88s
# 202:	learn: 0.1456217	total: 3.74s	remaining: 5.88s
# 203:	learn: 0.1453626	total: 3.75s	remaining: 5.85s
# 204:	learn: 0.1449517	total: 3.77s	remaining: 5.83s
# 205:	learn: 0.1447372	total: 3.78s	remaining: 5.8s
# 206:	learn: 0.1445356	total: 3.79s	remaining: 5.77s
# 207:	learn: 0.1443566	total: 3.81s	remaining: 5.75s
# 208:	learn: 0.1440090	total: 3.84s	remaining: 5.75s
# 209:	learn: 0.1437003	total: 3.86s	remaining: 5.74s
# 210:	learn: 0.1434559	total: 3.88s	remaining: 5.72s
# 211:	learn: 0.1432652	total: 3.9s	remaining: 5.71s
# 212:	learn: 0.1431678	total: 3.92s	remaining: 5.68s
# 213:	learn: 0.1430099	total: 3.94s	remaining: 5.67s
# 214:	learn: 0.1429199	total: 4s	remaining: 5.7s
# 215:	learn: 0.1427108	total: 4.04s	remaining: 5.72s
# 216:	learn: 0.1425665	total: 4.05s	remaining: 5.7s
# 217:	learn: 0.1424294	total: 4.07s	remaining: 5.67s
# 218:	learn: 0.1422551	total: 4.08s	remaining: 5.64s
# 219:	learn: 0.1421248	total: 4.09s	remaining: 5.62s
# 220:	learn: 0.1419510	total: 4.11s	remaining: 5.59s
# 221:	learn: 0.1417455	total: 4.13s	remaining: 5.58s
# 222:	learn: 0.1415834	total: 4.14s	remaining: 5.56s
# 223:	learn: 0.1413599	total: 4.16s	remaining: 5.53s
# 224:	learn: 0.1411138	total: 4.17s	remaining: 5.51s
# 225:	learn: 0.1409462	total: 4.2s	remaining: 5.5s
# 226:	learn: 0.1407762	total: 4.22s	remaining: 5.48s
# 227:	learn: 0.1406716	total: 4.23s	remaining: 5.46s
# 228:	learn: 0.1404594	total: 4.24s	remaining: 5.43s
# 229:	learn: 0.1402296	total: 4.25s	remaining: 5.4s
# 230:	learn: 0.1401272	total: 4.27s	remaining: 5.38s
# 231:	learn: 0.1398883	total: 4.29s	remaining: 5.36s
# 232:	learn: 0.1398190	total: 4.3s	remaining: 5.34s
# 233:	learn: 0.1396629	total: 4.32s	remaining: 5.32s
# 234:	learn: 0.1394531	total: 4.34s	remaining: 5.3s
# 235:	learn: 0.1391750	total: 4.35s	remaining: 5.27s
# 236:	learn: 0.1390441	total: 4.37s	remaining: 5.25s
# 237:	learn: 0.1388711	total: 4.38s	remaining: 5.23s
# 238:	learn: 0.1387457	total: 4.4s	remaining: 5.21s
# 239:	learn: 0.1385619	total: 4.42s	remaining: 5.19s
# 240:	learn: 0.1383273	total: 4.45s	remaining: 5.18s
# 241:	learn: 0.1380713	total: 4.46s	remaining: 5.16s
# 289:	learn: 0.1300286	total: 5.36s	remaining: 4.28s
# 290:	learn: 0.1297819	total: 5.37s	remaining: 4.26s
# 291:	learn: 0.1296733	total: 5.38s	remaining: 4.24s
# 292:	learn: 0.1296046	total: 5.4s	remaining: 4.22s
# 293:	learn: 0.1294279	total: 5.41s	remaining: 4.2s
# 294:	learn: 0.1293618	total: 5.43s	remaining: 4.18s
# 295:	learn: 0.1291578	total: 5.44s	remaining: 4.16s
# 296:	learn: 0.1289748	total: 5.46s	remaining: 4.14s
# 297:	learn: 0.1288823	total: 5.47s	remaining: 4.11s
# 298:	learn: 0.1287512	total: 5.49s	remaining: 4.09s
# 299:	learn: 0.1285932	total: 5.5s	remaining: 4.07s
# 300:	learn: 0.1284166	total: 5.53s	remaining: 4.06s
# 301:	learn: 0.1283029	total: 5.55s	remaining: 4.04s
# 302:	learn: 0.1281579	total: 5.57s	remaining: 4.03s
# 303:	learn: 0.1279801	total: 5.61s	remaining: 4.02s
# 304:	learn: 0.1276888	total: 5.64s	remaining: 4.01s
# 305:	learn: 0.1274794	total: 5.65s	remaining: 3.99s
# 306:	learn: 0.1272884	total: 5.67s	remaining: 3.97s
# 307:	learn: 0.1271338	total: 5.69s	remaining: 3.96s
# 308:	learn: 0.1270295	total: 5.71s	remaining: 3.94s
# 309:	learn: 0.1269237	total: 5.72s	remaining: 3.92s
# 310:	learn: 0.1267394	total: 5.74s	remaining: 3.89s
# 311:	learn: 0.1265424	total: 5.75s	remaining: 3.87s
# 312:	learn: 0.1263926	total: 5.77s	remaining: 3.85s
# 313:	learn: 0.1262438	total: 5.8s	remaining: 3.84s
# 314:	learn: 0.1260763	total: 5.82s	remaining: 3.82s
# 315:	learn: 0.1259354	total: 5.83s	remaining: 3.8s
# 316:	learn: 0.1257674	total: 5.85s	remaining: 3.78s
# 317:	learn: 0.1255985	total: 5.86s	remaining: 3.76s
# 318:	learn: 0.1254543	total: 5.87s	remaining: 3.74s
# 319:	learn: 0.1251912	total: 5.89s	remaining: 3.72s
# 320:	learn: 0.1250651	total: 5.9s	remaining: 3.69s
# 321:	learn: 0.1248811	total: 5.91s	remaining: 3.67s
# 322:	learn: 0.1248139	total: 5.92s	remaining: 3.65s
# 323:	learn: 0.1246536	total: 5.94s	remaining: 3.63s
# 324:	learn: 0.1244925	total: 5.95s	remaining: 3.61s
# 325:	learn: 0.1243920	total: 5.97s	remaining: 3.59s
# 326:	learn: 0.1241770	total: 5.99s	remaining: 3.57s
# 327:	learn: 0.1241093	total: 6s	remaining: 3.55s
# 328:	learn: 0.1239758	total: 6.02s	remaining: 3.53s
# 329:	learn: 0.1238499	total: 6.03s	remaining: 3.51s
# 330:	learn: 0.1237303	total: 6.05s	remaining: 3.49s
# 331:	learn: 0.1236211	total: 6.07s	remaining: 3.47s
# 332:	learn: 0.1234486	total: 6.09s	remaining: 3.45s
# 333:	learn: 0.1233433	total: 6.11s	remaining: 3.44s
# 334:	learn: 0.1232157	total: 6.12s	remaining: 3.42s
# 335:	learn: 0.1230701	total: 6.14s	remaining: 3.4s
# 336:	learn: 0.1229456	total: 6.17s	remaining: 3.39s
# 337:	learn: 0.1228138	total: 6.19s	remaining: 3.37s
# 338:	learn: 0.1226965	total: 6.21s	remaining: 3.35s
# 339:	learn: 0.1224708	total: 6.24s	remaining: 3.34s
# 340:	learn: 0.1222392	total: 6.26s	remaining: 3.32s
# 341:	learn: 0.1220804	total: 6.27s	remaining: 3.3s
# 342:	learn: 0.1218855	total: 6.28s	remaining: 3.28s
# 343:	learn: 0.1217553	total: 6.29s	remaining: 3.26s
# 344:	learn: 0.1216362	total: 6.3s	remaining: 3.23s
# 345:	learn: 0.1213842	total: 6.32s	remaining: 3.21s
# 346:	learn: 0.1212102	total: 6.33s	remaining: 3.19s
# 347:	learn: 0.1210152	total: 6.34s	remaining: 3.17s
# 348:	learn: 0.1207805	total: 6.36s	remaining: 3.15s
# 349:	learn: 0.1207400	total: 6.39s	remaining: 3.14s
# 350:	learn: 0.1206479	total: 6.41s	remaining: 3.12s
# 351:	learn: 0.1205463	total: 6.43s	remaining: 3.1s
# 352:	learn: 0.1203965	total: 6.46s	remaining: 3.09s
# 353:	learn: 0.1202901	total: 6.47s	remaining: 3.07s
# 354:	learn: 0.1202324	total: 6.49s	remaining: 3.05s
# 355:	learn: 0.1200974	total: 6.51s	remaining: 3.03s
# 356:	learn: 0.1197815	total: 6.53s	remaining: 3.02s
# 357:	learn: 0.1196570	total: 6.54s	remaining: 3s
# 358:	learn: 0.1194821	total: 6.55s	remaining: 2.97s
# 359:	learn: 0.1192983	total: 6.57s	remaining: 2.96s
# 360:	learn: 0.1191670	total: 6.59s	remaining: 2.94s
# 361:	learn: 0.1190191	total: 6.61s	remaining: 2.92s
# 362:	learn: 0.1188433	total: 6.63s	remaining: 2.9s
# 363:	learn: 0.1186492	total: 6.65s	remaining: 2.89s
# 364:	learn: 0.1184777	total: 6.68s	remaining: 2.87s
# 365:	learn: 0.1183254	total: 6.7s	remaining: 2.86s
# 366:	learn: 0.1181948	total: 6.72s	remaining: 2.84s
# 367:	learn: 0.1180943	total: 6.74s	remaining: 2.82s
# 368:	learn: 0.1179326	total: 6.75s	remaining: 2.8s
# 369:	learn: 0.1177944	total: 6.77s	remaining: 2.78s
# 370:	learn: 0.1176886	total: 6.79s	remaining: 2.76s
# 371:	learn: 0.1175897	total: 6.81s	remaining: 2.75s
# 372:	learn: 0.1174617	total: 6.83s	remaining: 2.73s
# 373:	learn: 0.1172868	total: 6.85s	remaining: 2.71s
# 374:	learn: 0.1172007	total: 6.87s	remaining: 2.69s
# 375:	learn: 0.1170861	total: 6.89s	remaining: 2.68s
# 376:	learn: 0.1169559	total: 6.92s	remaining: 2.66s
# 377:	learn: 0.1168279	total: 7s	remaining: 2.67s
# 378:	learn: 0.1165898	total: 7.02s	remaining: 2.65s
# 379:	learn: 0.1164755	total: 7.04s	remaining: 2.63s
# 380:	learn: 0.1162332	total: 7.06s	remaining: 2.61s
# 381:	learn: 0.1161019	total: 7.08s	remaining: 2.59s
# 382:	learn: 0.1159951	total: 7.1s	remaining: 2.58s
# 383:	learn: 0.1159447	total: 7.11s	remaining: 2.56s
# 384:	learn: 0.1158030	total: 7.13s	remaining: 2.54s
# 385:	learn: 0.1155878	total: 7.15s	remaining: 2.52s
# 386:	learn: 0.1153933	total: 7.17s	remaining: 2.5s
# 387:	learn: 0.1152014	total: 7.18s	remaining: 2.48s
# 388:	learn: 0.1150884	total: 7.2s	remaining: 2.46s
# 389:	learn: 0.1149935	total: 7.21s	remaining: 2.44s
# 390:	learn: 0.1148937	total: 7.22s	remaining: 2.42s
# 391:	learn: 0.1147815	total: 7.24s	remaining: 2.4s
# 392:	learn: 0.1146872	total: 7.27s	remaining: 2.38s
# 393:	learn: 0.1145992	total: 7.28s	remaining: 2.37s
# 394:	learn: 0.1145037	total: 7.29s	remaining: 2.35s
# 395:	learn: 0.1143878	total: 7.3s	remaining: 2.32s
# 396:	learn: 0.1141398	total: 7.32s	remaining: 2.31s
# 397:	learn: 0.1140531	total: 7.34s	remaining: 2.29s
# 398:	learn: 0.1139035	total: 7.36s	remaining: 2.27s
# 399:	learn: 0.1137699	total: 7.37s	remaining: 2.25s
# 400:	learn: 0.1136764	total: 7.38s	remaining: 2.23s
# 401:	learn: 0.1136117	total: 7.4s	remaining: 2.21s
# 402:	learn: 0.1135450	total: 7.42s	remaining: 2.19s
# 403:	learn: 0.1134270	total: 7.45s	remaining: 2.17s
# 404:	learn: 0.1133154	total: 7.47s	remaining: 2.16s
# 405:	learn: 0.1131731	total: 7.49s	remaining: 2.14s
# 406:	learn: 0.1131064	total: 7.52s	remaining: 2.12s
# 407:	learn: 0.1129764	total: 7.54s	remaining: 2.1s
# 408:	learn: 0.1128661	total: 7.55s	remaining: 2.09s
# 409:	learn: 0.1127934	total: 7.56s	remaining: 2.06s
# 410:	learn: 0.1126616	total: 7.58s	remaining: 2.05s
# 411:	learn: 0.1125423	total: 7.6s	remaining: 2.03s
# 412:	learn: 0.1123781	total: 7.62s	remaining: 2.01s
# 413:	learn: 0.1122912	total: 7.63s	remaining: 1.99s
# 414:	learn: 0.1121184	total: 7.64s	remaining: 1.97s
# 415:	learn: 0.1120124	total: 7.65s	remaining: 1.95s
# 416:	learn: 0.1119367	total: 7.67s	remaining: 1.93s
# 417:	learn: 0.1118211	total: 7.68s	remaining: 1.91s
# 418:	learn: 0.1115434	total: 7.69s	remaining: 1.89s
# 419:	learn: 0.1114601	total: 7.71s	remaining: 1.87s
# 420:	learn: 0.1113729	total: 7.72s	remaining: 1.85s
# 421:	learn: 0.1112617	total: 7.73s	remaining: 1.83s
# 422:	learn: 0.1111895	total: 7.74s	remaining: 1.81s
# 423:	learn: 0.1110493	total: 7.76s	remaining: 1.79s
# 424:	learn: 0.1109419	total: 7.77s	remaining: 1.77s
# 425:	learn: 0.1107973	total: 7.79s	remaining: 1.75s
# 426:	learn: 0.1106804	total: 7.8s	remaining: 1.74s
# 427:	learn: 0.1105604	total: 7.82s	remaining: 1.72s
# 428:	learn: 0.1103932	total: 7.83s	remaining: 1.7s
# 429:	learn: 0.1102655	total: 7.85s	remaining: 1.68s
# 430:	learn: 0.1101253	total: 7.86s	remaining: 1.66s
# 431:	learn: 0.1099904	total: 7.88s	remaining: 1.64s
# 432:	learn: 0.1098371	total: 7.9s	remaining: 1.62s
# 433:	learn: 0.1096332	total: 7.92s	remaining: 1.61s
# 434:	learn: 0.1094235	total: 7.95s	remaining: 1.59s
# 435:	learn: 0.1093148	total: 7.96s	remaining: 1.57s
# 436:	learn: 0.1091942	total: 7.98s	remaining: 1.55s
# 437:	learn: 0.1091055	total: 7.99s	remaining: 1.53s
# 438:	learn: 0.1089545	total: 8.01s	remaining: 1.51s
# 439:	learn: 0.1087291	total: 8.03s	remaining: 1.5s
# 440:	learn: 0.1086385	total: 8.05s	remaining: 1.48s
# 441:	learn: 0.1085080	total: 8.06s	remaining: 1.46s
# 442:	learn: 0.1083795	total: 8.08s	remaining: 1.44s
# 443:	learn: 0.1082956	total: 8.1s	remaining: 1.42s
# 444:	learn: 0.1082178	total: 8.12s	remaining: 1.4s
# 445:	learn: 0.1080502	total: 8.14s	remaining: 1.39s
# 446:	learn: 0.1078108	total: 8.15s	remaining: 1.37s
# 447:	learn: 0.1076892	total: 8.16s	remaining: 1.35s
# 448:	learn: 0.1076289	total: 8.18s	remaining: 1.33s
# 449:	learn: 0.1075452	total: 8.19s	remaining: 1.31s
# 450:	learn: 0.1074210	total: 8.2s	remaining: 1.29s
# 451:	learn: 0.1073367	total: 8.22s	remaining: 1.27s
# 452:	learn: 0.1072236	total: 8.24s	remaining: 1.25s
# 453:	learn: 0.1071722	total: 8.26s	remaining: 1.24s
# 454:	learn: 0.1070774	total: 8.28s	remaining: 1.22s
# 455:	learn: 0.1069118	total: 8.29s	remaining: 1.2s
# 456:	learn: 0.1068121	total: 8.3s	remaining: 1.18s
# 457:	learn: 0.1067234	total: 8.31s	remaining: 1.16s
# 458:	learn: 0.1066642	total: 8.34s	remaining: 1.14s
# 459:	learn: 0.1065899	total: 8.35s	remaining: 1.13s
# 460:	learn: 0.1064956	total: 8.37s	remaining: 1.11s
# 461:	learn: 0.1064048	total: 8.39s	remaining: 1.09s
# 462:	learn: 0.1062681	total: 8.41s	remaining: 1.07s
# 463:	learn: 0.1061742	total: 8.44s	remaining: 1.05s
# 464:	learn: 0.1060781	total: 8.45s	remaining: 1.04s
# 465:	learn: 0.1059371	total: 8.48s	remaining: 1.02s
# 466:	learn: 0.1058423	total: 8.5s	remaining: 1s
# 467:	learn: 0.1057485	total: 8.52s	remaining: 983ms
# 468:	learn: 0.1056705	total: 8.53s	remaining: 964ms
# 469:	learn: 0.1055151	total: 8.56s	remaining: 947ms
# 470:	learn: 0.1054402	total: 8.58s	remaining: 929ms
# 471:	learn: 0.1052755	total: 8.59s	remaining: 910ms
# 472:	learn: 0.1051664	total: 8.61s	remaining: 892ms
# 473:	learn: 0.1050837	total: 8.62s	remaining: 873ms
# 474:	learn: 0.1050086	total: 8.64s	remaining: 855ms
# 475:	learn: 0.1049428	total: 8.66s	remaining: 837ms
# 476:	learn: 0.1048719	total: 8.68s	remaining: 819ms
# 477:	learn: 0.1047018	total: 8.7s	remaining: 801ms
# 478:	learn: 0.1046499	total: 8.71s	remaining: 782ms
# 479:	learn: 0.1045250	total: 8.73s	remaining: 764ms
# 480:	learn: 0.1043996	total: 8.74s	remaining: 745ms
# 481:	learn: 0.1043085	total: 8.76s	remaining: 727ms
# 482:	learn: 0.1041423	total: 8.77s	remaining: 708ms
# 483:	learn: 0.1039770	total: 8.79s	remaining: 690ms
# 484:	learn: 0.1039022	total: 8.8s	remaining: 671ms
# 485:	learn: 0.1037928	total: 8.82s	remaining: 653ms
# 486:	learn: 0.1036336	total: 8.83s	remaining: 635ms
# 487:	learn: 0.1034832	total: 8.85s	remaining: 617ms
# 488:	learn: 0.1033843	total: 8.86s	remaining: 598ms
# 489:	learn: 0.1032479	total: 8.87s	remaining: 579ms
# 490:	learn: 0.1031587	total: 8.89s	remaining: 561ms
# 491:	learn: 0.1030785	total: 8.91s	remaining: 543ms
# 492:	learn: 0.1030076	total: 8.92s	remaining: 525ms
# 493:	learn: 0.1028660	total: 8.94s	remaining: 507ms
# 494:	learn: 0.1027932	total: 8.95s	remaining: 488ms
# 495:	learn: 0.1027411	total: 8.97s	remaining: 470ms
# 496:	learn: 0.1026394	total: 8.99s	remaining: 452ms
# 497:	learn: 0.1025376	total: 9.02s	remaining: 435ms
# 498:	learn: 0.1024130	total: 9.05s	remaining: 417ms
# 499:	learn: 0.1023020	total: 9.07s	remaining: 399ms
# 500:	learn: 0.1020756	total: 9.09s	remaining: 381ms
# 501:	learn: 0.1020240	total: 9.1s	remaining: 363ms
# 502:	learn: 0.1018693	total: 9.12s	remaining: 344ms
# 503:	learn: 0.1017011	total: 9.13s	remaining: 326ms
# 504:	learn: 0.1015686	total: 9.14s	remaining: 308ms
# 505:	learn: 0.1014713	total: 9.15s	remaining: 289ms
# 506:	learn: 0.1013554	total: 9.17s	remaining: 271ms
# 507:	learn: 0.1013068	total: 9.19s	remaining: 253ms
# 508:	learn: 0.1011389	total: 9.21s	remaining: 235ms
# 509:	learn: 0.1010618	total: 9.23s	remaining: 217ms
# 510:	learn: 0.1009583	total: 9.24s	remaining: 199ms
# 511:	learn: 0.1008416	total: 9.26s	remaining: 181ms
# 512:	learn: 0.1007868	total: 9.27s	remaining: 163ms
# 513:	learn: 0.1007072	total: 9.28s	remaining: 145ms
# 514:	learn: 0.1006170	total: 9.3s	remaining: 126ms
# 515:	learn: 0.1004833	total: 9.32s	remaining: 108ms
# 516:	learn: 0.1003699	total: 9.35s	remaining: 90.4ms
# 517:	learn: 0.1001755	total: 9.37s	remaining: 72.3ms
# 518:	learn: 0.1000878	total: 9.38s	remaining: 54.2ms
# 519:	learn: 0.0999676	total: 9.4s	remaining: 36.2ms
# 520:	learn: 0.0998458	total: 9.42s	remaining: 18.1ms
# 521:	learn: 0.0996889	total: 9.43s	remaining: 0us
# cat 모델이 train_data_dam 데이터로 학습한 결과:
# F1 Score: 0.2323529411764706

# %% [markdown]
# cat 모델이 train_data_dam 데이터로 학습한 결과:
#
# F1 Score: 0.2323529411764706

# %% [markdown]
# .
